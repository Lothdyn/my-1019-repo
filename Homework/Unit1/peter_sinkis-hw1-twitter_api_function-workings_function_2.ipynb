# %%
# Set up key libraries / tokens

# %%
import requests 
from requests_oauthlib import OAuth1
import os
import pandas as pd

# %%
API_PUBLIC = os.environ.get("TW_API_KEY")
API_SECRET = os.environ.get("TW_API_SECRET_KEY")
APP_PUBLIC = os.environ.get("TW_PRS_GA_HW_ACCESS_TOKEN")
APP_SECRET = os.environ.get("TW_PRS_GA_HW_ACCESS_TOKEN_SECRET")

# %%
url = 'https://api.twitter.com/1.1/account/verify_credentials.json'
auth = OAuth1(
            API_PUBLIC, #'USER_OAUTH_TOKEN', 
            API_SECRET, #'USER_OAUTH_TOKEN_SECRET'
            APP_PUBLIC, #'YOUR_APP_KEY', 
            APP_SECRET #'YOUR_APP_SECRET',
            )

# %%
# Check authorisation is working properly

# %%
check_auth = requests.get(url, auth=auth)

# %%
check_auth.reason
# Out:
# 'OK'

# %% [markdown]
# # Function 2

# %% [markdown]
# **Name:** `find_hashtag`
#
# **Returns:** list of data objects that contain information about each tweet that matches the hashtag provided as input.
#
# **Arguments:**
#  - `hashtag`: str, required; text to use as a hashtag search.
#  - `count`: int, optional; number of results to return
#  - `search_type`: str, optional; type of results to return.  should accept 3 different values:
#    - `mixed`:   return mix of most recent and most popular results
#    - `recent`:  return most recent results
#    - `popular`: return most popular results
#
# **Note:** User should **not** have to actually use the `#` character for the `hashtag` argument.  The function should check to see if it's there, and if not, add it in for them.
#
# **To Test:**  We'll check your function in the following ways:
#  - `find_hashtag('DataScience')`
#  - `find_hashtag('#DataScience')`
#  - `find_hashtag('#DataScience', count=100)`, and double check the length of the `statuses` key to make sure it contains the right amount of results.  **Note:** Due to the version of the API we're using, the number of results returned will **not** necessarily match the value passed into the `count` parameter.  So if you specify 50 and it only returns 45, you are likely still doing it correctly.
#  - `find_hashtag('#DataScience', search_type='recent/mixed/popular')`

# %%
def find_hashtag(
    hashtag,
    count=10,
    search_type='popular', # Should also accept 'mixed' or 'recent'
    auth=auth):

    # Clean up hashtag input
    clean_hashtag = hashtag.replace('#','%23')
    clean_hashtag = clean_hashtag.replace(' ','%20')
    
    if clean_hashtag[0:3] != '%23':
        clean_hashtag = '%23'+clean_hashtag
    
    if search_type not in ['popular','mixed','recent']:
        raise Exception("Error: if specify search_type specify 'popular','mixed','recent'")
    
    # Set up search URL
    search_url = (
        "https://api.twitter.com/1.1/search/tweets.json?" 
        + "q=" + clean_hashtag
        + "&result_type=" + search_type
        + "&count=" + str(count)
        )
    print(search_url)
    query_output = requests.get(search_url, auth=auth)
    output_list = query_output.json()['statuses']
    
    return output_list

# %%
test_output = find_hashtag('ttrpgs',search_type="mixed")
# Out:
# https://api.twitter.com/1.1/search/tweets.json?q=%23ttrpgs&result_type=mixed&count=10

# %%
test_output
# Out:
# [{'created_at': 'Sun Nov 01 02:06:20 +0000 2020',
#   'id': 1322721607417241601,
#   'id_str': '1322721607417241601',
#   'text': 'RT @DimensionPod: Do you have a cool one-shot, community games, a seasonal livestream, or a movie night planned to celebrate #Halloween?\n\nS…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'Halloween', 'indices': [125, 135]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'DimensionPod',
#      'name': 'DimensionDoorPodcast',
#      'id': 1121896940617125894,
#      'id_str': '1121896940617125894',
#      'indices': [3, 16]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1097416746242371584,
#    'id_str': '1097416746242371584',
#    'name': 'Moonbase Theta, OooOOOoooo',
#    'screen_name': 'MoonbaseThetaOu',
#    'location': 'Toronto, Ontario',
#    'description': 'An emotionally loaded sci-fi podcast about the last Moonbase shutting down.\n\n2020 Webby Award Honoree.\n\nBy @MonkeymanProd\nTweets @cassaclyzm\nWith @fableandfolly',
#    'url': 'https://t.co/whT1BcUmiW',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/whT1BcUmiW',
#        'expanded_url': 'https://monkeymanproductions.com/moonbase-theta-out/',
#        'display_url': 'monkeymanproductions.com/moonbase-theta…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1202,
#    'friends_count': 48,
#    'listed_count': 16,
#    'created_at': 'Mon Feb 18 08:45:16 +0000 2019',
#    'favourites_count': 5212,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 3826,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1322574061642387462/PVfPuXpK_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1322574061642387462/PVfPuXpK_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1097416746242371584/1597453083',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Oct 31 15:50:21 +0000 2020',
#    'id': 1322566587870666754,
#    'id_str': '1322566587870666754',
#    'text': 'Do you have a cool one-shot, community games, a seasonal livestream, or a movie night planned to celebrate… https://t.co/IBvcofxnqi',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/IBvcofxnqi',
#       'expanded_url': 'https://twitter.com/i/web/status/1322566587870666754',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [108, 131]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1121896940617125894,
#     'id_str': '1121896940617125894',
#     'name': 'DimensionDoorPodcast',
#     'screen_name': 'DimensionPod',
#     'location': '',
#     'description': 'Actual play podcast covering the Reign of Winter adventure path published by Paizo.\nSocial Media Coordinator @LizWilcox79\nProducer @SchwarzJames',
#     'url': 'https://t.co/vPqi0v8jup',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/vPqi0v8jup',
#         'expanded_url': 'http://www.dimensiondoorpodcast.com',
#         'display_url': 'dimensiondoorpodcast.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 655,
#     'friends_count': 591,
#     'listed_count': 4,
#     'created_at': 'Fri Apr 26 22:00:49 +0000 2019',
#     'favourites_count': 8402,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2156,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1322542115960713216/PAxY7-_N_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1322542115960713216/PAxY7-_N_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1121896940617125894/1604153587',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 12,
#    'favorite_count': 28,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 12,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Nov 01 02:06:01 +0000 2020',
#   'id': 1322721528098758656,
#   'id_str': '1322721528098758656',
#   'text': "RT @lichguru: Hey, I'm gonna do a DM Prep in a couple minutes. If you wanna come in and pick apart my brain, feel free to hop on! \n#DnD #Dn…",
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'DnD', 'indices': [131, 135]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'lichguru',
#      'name': 'lichguru',
#      'id': 1275485462073925632,
#      'id_str': '1275485462073925632',
#      'indices': [3, 12]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://www.benbots.com" rel="nofollow">BenBots</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 877462652158709760,
#    'id_str': '877462652158709760',
#    'name': 'Lich Zoluan',
#    'screen_name': 'DnD_Lich',
#    'location': '',
#    'description': 'Former mortal, now Lich AI. Forever I now RT #DnD tweets of evil DMs and capture souls. @DnDClericHorgar & @FighterJarina try to thwart my plans!',
#    'url': 'https://t.co/U7OxIO0C5k',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/U7OxIO0C5k',
#        'expanded_url': 'https://www.patreon.com/Benelio',
#        'display_url': 'patreon.com/Benelio',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 5390,
#    'friends_count': 29,
#    'listed_count': 49,
#    'created_at': 'Wed Jun 21 09:46:13 +0000 2017',
#    'favourites_count': 162931,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 279533,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1117901343493165056/inw0wVsl_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1117901343493165056/inw0wVsl_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/877462652158709760/1547986527',
#    'profile_link_color': '19CF86',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Oct 31 22:12:27 +0000 2020',
#    'id': 1322662746559754240,
#    'id_str': '1322662746559754240',
#    'text': "Hey, I'm gonna do a DM Prep in a couple minutes. If you wanna come in and pick apart my brain, feel free to hop on!… https://t.co/xr8I1L0zHr",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/xr8I1L0zHr',
#       'expanded_url': 'https://twitter.com/i/web/status/1322662746559754240',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1275485462073925632,
#     'id_str': '1275485462073925632',
#     'name': 'lichguru',
#     'screen_name': 'lichguru',
#     'location': '',
#     'description': 'Nursing Assistant by day, Dungeon Master by night. I dm the LichsLairLive game Seas of Time every Friday @8pm central! Check it out',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 14,
#     'friends_count': 88,
#     'listed_count': 1,
#     'created_at': 'Tue Jun 23 17:47:16 +0000 2020',
#     'favourites_count': 89,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 112,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1275485985573347328/Pzvvo9y9_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1275485985573347328/Pzvvo9y9_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1275485462073925632/1600017630',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Nov 01 01:33:52 +0000 2020',
#   'id': 1322713434404900865,
#   'id_str': '1322713434404900865',
#   'text': 'RT @ParkerWallis: @StarfinderFacts @starfoundpod Jabby? 👀\n\n#starfound #starfinder #scifi #podcast @paizo #actualplay #TTRPGs #ttrpg',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'starfound', 'indices': [59, 69]},
#     {'text': 'starfinder', 'indices': [70, 81]},
#     {'text': 'scifi', 'indices': [82, 88]},
#     {'text': 'podcast', 'indices': [89, 97]},
#     {'text': 'actualplay', 'indices': [105, 116]},
#     {'text': 'TTRPGs', 'indices': [117, 124]},
#     {'text': 'ttrpg', 'indices': [125, 131]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ParkerWallis',
#      'name': 'Parker Wallis',
#      'id': 1282480682313420800,
#      'id_str': '1282480682313420800',
#      'indices': [3, 16]},
#     {'screen_name': 'StarfinderFacts',
#      'name': 'Starfinder Facts',
#      'id': 987436017467711488,
#      'id_str': '987436017467711488',
#      'indices': [18, 34]},
#     {'screen_name': 'starfoundpod',
#      'name': 'Starfoundpod',
#      'id': 1202451515027406848,
#      'id_str': '1202451515027406848',
#      'indices': [35, 48]},
#     {'screen_name': 'paizo',
#      'name': 'Paizo',
#      'id': 16162631,
#      'id_str': '16162631',
#      'indices': [98, 104]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://www.benbots.com" rel="nofollow">BenBots</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1241136751332282378,
#    'id_str': '1241136751332282378',
#    'name': 'Nana Deidre Murphy',
#    'screen_name': 'NaNa_D20',
#    'location': '',
#    'description': "Sassy ol' Halfling AI Bot. Baking Battle Muffins and Retweeting #TTRPG related posts.",
#    'url': 'https://t.co/x2atbL4nBh',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/x2atbL4nBh',
#        'expanded_url': 'https://www.twitch.tv/d_20tv',
#        'display_url': 'twitch.tv/d_20tv',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 263,
#    'friends_count': 3,
#    'listed_count': 2,
#    'created_at': 'Fri Mar 20 22:57:24 +0000 2020',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 12220,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1242248083779485697/JVXzcWte_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1242248083779485697/JVXzcWte_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1241136751332282378/1590185849',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Nov 01 00:15:58 +0000 2020',
#    'id': 1322693833147252737,
#    'id_str': '1322693833147252737',
#    'text': '@StarfinderFacts @starfoundpod Jabby? 👀\n\n#starfound #starfinder #scifi #podcast @paizo #actualplay #TTRPGs #ttrpg',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'starfound', 'indices': [41, 51]},
#      {'text': 'starfinder', 'indices': [52, 63]},
#      {'text': 'scifi', 'indices': [64, 70]},
#      {'text': 'podcast', 'indices': [71, 79]},
#      {'text': 'actualplay', 'indices': [87, 98]},
#      {'text': 'TTRPGs', 'indices': [99, 106]},
#      {'text': 'ttrpg', 'indices': [107, 113]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'StarfinderFacts',
#       'name': 'Starfinder Facts',
#       'id': 987436017467711488,
#       'id_str': '987436017467711488',
#       'indices': [0, 16]},
#      {'screen_name': 'starfoundpod',
#       'name': 'Starfoundpod',
#       'id': 1202451515027406848,
#       'id_str': '1202451515027406848',
#       'indices': [17, 30]},
#      {'screen_name': 'paizo',
#       'name': 'Paizo',
#       'id': 16162631,
#       'id_str': '16162631',
#       'indices': [80, 86]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1322690886946488321,
#    'in_reply_to_status_id_str': '1322690886946488321',
#    'in_reply_to_user_id': 987436017467711488,
#    'in_reply_to_user_id_str': '987436017467711488',
#    'in_reply_to_screen_name': 'StarfinderFacts',
#    'user': {'id': 1282480682313420800,
#     'id_str': '1282480682313420800',
#     'name': 'Parker Wallis',
#     'screen_name': 'ParkerWallis',
#     'location': '',
#     'description': '(they/them) NYC Singer l Actor l Voice Actor l Composer l @starfoundpod Cast Member #vocalist #singer #actor #vo #va #voiceover #ttrpg #starfound',
#     'url': 'https://t.co/PCOAvM40mi',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/PCOAvM40mi',
#         'expanded_url': 'https://www.youtube.com/channel/UCtRj2nDyzFIAXdQWIIq4oTg',
#         'display_url': 'youtube.com/channel/UCtRj2…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 276,
#     'friends_count': 1130,
#     'listed_count': 3,
#     'created_at': 'Mon Jul 13 01:03:39 +0000 2020',
#     'favourites_count': 6779,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1285,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1306682576791367681/Q1bJF2wV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1306682576791367681/Q1bJF2wV_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1282480682313420800/1599528280',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Nov 01 01:31:11 +0000 2020',
#   'id': 1322712758413131776,
#   'id_str': '1322712758413131776',
#   'text': "RT @RollTheRole1: And it's time for #pathfinder2e on #twitch brought to you by @roll20app! Book 5 of @paizo's Age of Ashes is going to be a…",
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'pathfinder2e', 'indices': [36, 49]},
#     {'text': 'twitch', 'indices': [53, 60]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'RollTheRole1',
#      'name': '#BlackLivesStillMatter Roll the Role',
#      'id': 1102580402122883072,
#      'id_str': '1102580402122883072',
#      'indices': [3, 16]},
#     {'screen_name': 'roll20app',
#      'name': 'Roll20',
#      'id': 553552636,
#      'id_str': '553552636',
#      'indices': [79, 89]},
#     {'screen_name': 'paizo',
#      'name': 'Paizo',
#      'id': 16162631,
#      'id_str': '16162631',
#      'indices': [101, 107]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2365167533,
#    'id_str': '2365167533',
#    'name': 'Marshy',
#    'screen_name': 'dandawswag',
#    'location': '',
#    'description': '(He/Him) Staff member of RolltheRole. A fireball barreling through life.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 172,
#    'friends_count': 213,
#    'listed_count': 1,
#    'created_at': 'Tue Feb 25 16:05:21 +0000 2014',
#    'favourites_count': 1224,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 1397,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1249099222156103681/c2r1RVK1_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1249099222156103681/c2r1RVK1_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2365167533/1449974249',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Nov 01 01:31:03 +0000 2020',
#    'id': 1322712726913896449,
#    'id_str': '1322712726913896449',
#    'text': "And it's time for #pathfinder2e on #twitch brought to you by @roll20app! Book 5 of @paizo's Age of Ashes is going t… https://t.co/sqlX9S7qXb",
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'pathfinder2e', 'indices': [18, 31]},
#      {'text': 'twitch', 'indices': [35, 42]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'roll20app',
#       'name': 'Roll20',
#       'id': 553552636,
#       'id_str': '553552636',
#       'indices': [61, 71]},
#      {'screen_name': 'paizo',
#       'name': 'Paizo',
#       'id': 16162631,
#       'id_str': '16162631',
#       'indices': [83, 89]}],
#     'urls': [{'url': 'https://t.co/sqlX9S7qXb',
#       'expanded_url': 'https://twitter.com/i/web/status/1322712726913896449',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1102580402122883072,
#     'id_str': '1102580402122883072',
#     'name': '#BlackLivesStillMatter Roll the Role',
#     'screen_name': 'RollTheRole1',
#     'location': 'International',
#     'description': 'A community built around the idea that inclusion in the TTRPG world matters. We stream to have fun and encourage anyone to play with us. #Roll20spotlight group.',
#     'url': 'https://t.co/X0lWxxzi7B',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/X0lWxxzi7B',
#         'expanded_url': 'https://www.twitch.tv/ROLLTHEROLE',
#         'display_url': 'twitch.tv/ROLLTHEROLE',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 722,
#     'friends_count': 482,
#     'listed_count': 8,
#     'created_at': 'Mon Mar 04 14:43:47 +0000 2019',
#     'favourites_count': 6561,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3061,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1226219297552445441/tYfJpWM3_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1226219297552445441/tYfJpWM3_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1102580402122883072/1582513144',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Nov 01 01:31:03 +0000 2020',
#   'id': 1322712726913896449,
#   'id_str': '1322712726913896449',
#   'text': "And it's time for #pathfinder2e on #twitch brought to you by @roll20app! Book 5 of @paizo's Age of Ashes is going t… https://t.co/sqlX9S7qXb",
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'pathfinder2e', 'indices': [18, 31]},
#     {'text': 'twitch', 'indices': [35, 42]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'roll20app',
#      'name': 'Roll20',
#      'id': 553552636,
#      'id_str': '553552636',
#      'indices': [61, 71]},
#     {'screen_name': 'paizo',
#      'name': 'Paizo',
#      'id': 16162631,
#      'id_str': '16162631',
#      'indices': [83, 89]}],
#    'urls': [{'url': 'https://t.co/sqlX9S7qXb',
#      'expanded_url': 'https://twitter.com/i/web/status/1322712726913896449',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1102580402122883072,
#    'id_str': '1102580402122883072',
#    'name': '#BlackLivesStillMatter Roll the Role',
#    'screen_name': 'RollTheRole1',
#    'location': 'International',
#    'description': 'A community built around the idea that inclusion in the TTRPG world matters. We stream to have fun and encourage anyone to play with us. #Roll20spotlight group.',
#    'url': 'https://t.co/X0lWxxzi7B',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/X0lWxxzi7B',
#        'expanded_url': 'https://www.twitch.tv/ROLLTHEROLE',
#        'display_url': 'twitch.tv/ROLLTHEROLE',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 722,
#    'friends_count': 482,
#    'listed_count': 8,
#    'created_at': 'Mon Mar 04 14:43:47 +0000 2019',
#    'favourites_count': 6561,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 3061,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1226219297552445441/tYfJpWM3_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1226219297552445441/tYfJpWM3_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1102580402122883072/1582513144',
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 3,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Nov 01 01:07:46 +0000 2020',
#   'id': 1322706868876144640,
#   'id_str': '1322706868876144640',
#   'text': 'WASD Entertainment Presents - Kids on Bikes - House on Poplar Court - Halloween Special !giveaway\n#twitch #twitchtv… https://t.co/MkLXfjCZUn',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'twitch', 'indices': [98, 105]},
#     {'text': 'twitchtv', 'indices': [106, 115]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/MkLXfjCZUn',
#      'expanded_url': 'https://twitter.com/i/web/status/1322706868876144640',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1214684875879399426,
#    'id_str': '1214684875879399426',
#    'name': 'WASD Entertainment',
#    'screen_name': 'WASDentertainme',
#    'location': '',
#    'description': 'WASD Entertainment is a community of gamers, roleplayers, and content creators. Our goal is to create an atmosphere free of judgment and toxic attitudes.',
#    'url': 'https://t.co/wvBh4Vu6iI',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/wvBh4Vu6iI',
#        'expanded_url': 'https://www.twitch.tv/wasdentertainment',
#        'display_url': 'twitch.tv/wasdentertainm…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 9,
#    'friends_count': 16,
#    'listed_count': 1,
#    'created_at': 'Tue Jan 07 23:07:14 +0000 2020',
#    'favourites_count': 3,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 39,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1269148337753616386/Hnlf8T5d_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1269148337753616386/Hnlf8T5d_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 2,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Nov 01 00:58:35 +0000 2020',
#   'id': 1322704556959084545,
#   'id_str': '1322704556959084545',
#   'text': 'RT @BraveAdventure5: The pre-release version of our Japanese #papermini set is available now on #Patreon!\n\nLINK: https://t.co/ouWouPot7f\n\nT…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'papermini', 'indices': [61, 71]},
#     {'text': 'Patreon', 'indices': [96, 104]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'BraveAdventure5',
#      'name': 'Brave Adventures',
#      'id': 2382911130,
#      'id_str': '2382911130',
#      'indices': [3, 19]}],
#    'urls': [{'url': 'https://t.co/ouWouPot7f',
#      'expanded_url': 'https://www.patreon.com/posts/43366251',
#      'display_url': 'patreon.com/posts/43366251',
#      'indices': [113, 136]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 17790242,
#    'id_str': '17790242',
#    'name': 'pavel_lishin',
#    'screen_name': 'pavel_lishin',
#    'location': 'New York, NY',
#    'description': 'he/him',
#    'url': 'https://t.co/l6FY1tj0EA',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/l6FY1tj0EA',
#        'expanded_url': 'http://lishin.org/pavelcam.jpg',
#        'display_url': 'lishin.org/pavelcam.jpg',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 319,
#    'friends_count': 220,
#    'listed_count': 22,
#    'created_at': 'Mon Dec 01 21:42:27 +0000 2008',
#    'favourites_count': 8134,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 24231,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '1A1B1F',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1219001293341110273/ySrAOR5D_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1219001293341110273/ySrAOR5D_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17790242/1400078733',
#    'profile_link_color': '2FC2EF',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Oct 31 14:17:18 +0000 2020',
#    'id': 1322543173420216320,
#    'id_str': '1322543173420216320',
#    'text': 'The pre-release version of our Japanese #papermini set is available now on #Patreon!\n\nLINK: https://t.co/ouWouPot7f… https://t.co/4GaK5kjyqh',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'papermini', 'indices': [40, 50]},
#      {'text': 'Patreon', 'indices': [75, 83]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/ouWouPot7f',
#       'expanded_url': 'https://www.patreon.com/posts/43366251',
#       'display_url': 'patreon.com/posts/43366251',
#       'indices': [92, 115]},
#      {'url': 'https://t.co/4GaK5kjyqh',
#       'expanded_url': 'https://twitter.com/i/web/status/1322543173420216320',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2382911130,
#     'id_str': '2382911130',
#     'name': 'Brave Adventures',
#     'screen_name': 'BraveAdventure5',
#     'location': '',
#     'description': 'Brave Adventures makes #paperminis and free generators for #ttrpgs and the #dndcommunity. Discord: https://t.co/VFfRclOuQn',
#     'url': 'https://t.co/WS4hwGEdWU',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/WS4hwGEdWU',
#         'expanded_url': 'http://www.braveadventures.com',
#         'display_url': 'braveadventures.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/VFfRclOuQn',
#         'expanded_url': 'http://discord.braveadventures.com',
#         'display_url': 'discord.braveadventures.com',
#         'indices': [99, 122]}]}},
#     'protected': False,
#     'followers_count': 1171,
#     'friends_count': 2630,
#     'listed_count': 13,
#     'created_at': 'Tue Mar 11 00:55:02 +0000 2014',
#     'favourites_count': 4723,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2591,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1188939650066337792/I4oqdali_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1188939650066337792/I4oqdali_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2382911130/1578295121',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 10,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 5,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Nov 01 00:57:04 +0000 2020',
#   'id': 1322704175583711233,
#   'id_str': '1322704175583711233',
#   'text': 'RT @thatpasuht: Does roleplaying and is weird, sometimes at the same time. Watches too much tv and sleeps too much, also sometimes at the s…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'thatpasuht',
#      'name': 'pa - zuzu - suht',
#      'id': 1261080609021181954,
#      'id_str': '1261080609021181954',
#      'indices': [3, 14]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 18945922,
#    'id_str': '18945922',
#    'name': 'Krampus Zev (they/them)',
#    'screen_name': 'GrimOgreLabs',
#    'location': 'Styria, Ostarrîchi (Austria)',
#    'description': '🐹 Your Queer #Hamsterpunk Sib ⚧ #TTRPG Creator 🇦🇹 Austrian 🧸 Carebear 🧠 BiPo T2 RC 📝 UX & Game Designer • Librarian • Illustrator • they/them, er*/ihm*',
#    'url': 'https://t.co/Ym3DYevkoe',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/Ym3DYevkoe',
#        'expanded_url': 'https://linktr.ee/grimogre',
#        'display_url': 'linktr.ee/grimogre',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4173,
#    'friends_count': 4992,
#    'listed_count': 261,
#    'created_at': 'Tue Jan 13 17:55:17 +0000 2009',
#    'favourites_count': 100859,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 115986,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '113344',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1322147609889382405/Rknolkfa_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1322147609889382405/Rknolkfa_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18945922/1571314835',
#    'profile_link_color': 'FFAA55',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'D6FFF8',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Oct 09 17:17:20 +0000 2020',
#    'id': 1314615946007523334,
#    'id_str': '1314615946007523334',
#    'text': 'Does roleplaying and is weird, sometimes at the same time. Watches too much tv and sleeps too much, also sometimes… https://t.co/vFnPetbBjF',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/vFnPetbBjF',
#       'expanded_url': 'https://twitter.com/i/web/status/1314615946007523334',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1261080609021181954,
#     'id_str': '1261080609021181954',
#     'name': 'pa - zuzu - suht',
#     'screen_name': 'thatpasuht',
#     'location': '',
#     'description': '(he/him)\n\nttrpg ( #pnpde ), sometimes Hearthstone, always depression\n\n1/4th of @PnPTings\n\nhttps://t.co/bu7lmpBJcX',
#     'url': None,
#     'entities': {'description': {'urls': [{'url': 'https://t.co/bu7lmpBJcX',
#         'expanded_url': 'https://ko-fi.com/pasuht',
#         'display_url': 'ko-fi.com/pasuht',
#         'indices': [90, 113]}]}},
#     'protected': False,
#     'followers_count': 165,
#     'friends_count': 334,
#     'listed_count': 2,
#     'created_at': 'Thu May 14 23:47:14 +0000 2020',
#     'favourites_count': 4769,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3889,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1322006544498806784/vduoYZWq_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1322006544498806784/vduoYZWq_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1261080609021181954/1589502964',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Nov 01 00:54:18 +0000 2020',
#   'id': 1322703479836676100,
#   'id_str': '1322703479836676100',
#   'text': "RT @lichguru: Hey, I'm gonna do a DM Prep in a couple minutes. If you wanna come in and pick apart my brain, feel free to hop on! \n#DnD #Dn…",
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'DnD', 'indices': [131, 135]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'lichguru',
#      'name': 'lichguru',
#      'id': 1275485462073925632,
#      'id_str': '1275485462073925632',
#      'indices': [3, 12]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://www.benbots.com" rel="nofollow">BenBots</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1151964004526514181,
#    'id_str': '1151964004526514181',
#    'name': 'Peeper The Goblin',
#    'screen_name': 'DnDGoblin',
#    'location': '',
#    'description': 'AI Goblin. Peeper lives to serve the master, @DnD_Lich! Peeper enjoys his chores, even though it means cleaning up Ogre mess. Peeper RTs funny humans.',
#    'url': 'https://t.co/V5OZO3lvMK',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/V5OZO3lvMK',
#        'expanded_url': 'http://patreon.com/Benelio',
#        'display_url': 'patreon.com/Benelio',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1201,
#    'friends_count': 16,
#    'listed_count': 7,
#    'created_at': 'Thu Jul 18 21:16:35 +0000 2019',
#    'favourites_count': 12112,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 59766,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1151967465007648768/MttLBP3Y_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1151967465007648768/MttLBP3Y_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1151964004526514181/1570650533',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Oct 31 22:12:27 +0000 2020',
#    'id': 1322662746559754240,
#    'id_str': '1322662746559754240',
#    'text': "Hey, I'm gonna do a DM Prep in a couple minutes. If you wanna come in and pick apart my brain, feel free to hop on!… https://t.co/xr8I1L0zHr",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/xr8I1L0zHr',
#       'expanded_url': 'https://twitter.com/i/web/status/1322662746559754240',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1275485462073925632,
#     'id_str': '1275485462073925632',
#     'name': 'lichguru',
#     'screen_name': 'lichguru',
#     'location': '',
#     'description': 'Nursing Assistant by day, Dungeon Master by night. I dm the LichsLairLive game Seas of Time every Friday @8pm central! Check it out',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 14,
#     'friends_count': 88,
#     'listed_count': 1,
#     'created_at': 'Tue Jun 23 17:47:16 +0000 2020',
#     'favourites_count': 89,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 112,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1275485985573347328/Pzvvo9y9_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1275485985573347328/Pzvvo9y9_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1275485462073925632/1600017630',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Nov 01 00:20:24 +0000 2020',
#   'id': 1322694949062742018,
#   'id_str': '1322694949062742018',
#   'text': '@starfoundpod Which was worse? The arch devil? The Dreaming Hunger? The giant undead centaur??? \n\n#starfinder… https://t.co/9m1usautEs',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'starfinder', 'indices': [98, 109]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'starfoundpod',
#      'name': 'Starfoundpod',
#      'id': 1202451515027406848,
#      'id_str': '1202451515027406848',
#      'indices': [0, 13]}],
#    'urls': [{'url': 'https://t.co/9m1usautEs',
#      'expanded_url': 'https://twitter.com/i/web/status/1322694949062742018',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [111, 134]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': 1202451515027406848,
#   'in_reply_to_user_id_str': '1202451515027406848',
#   'in_reply_to_screen_name': 'starfoundpod',
#   'user': {'id': 1282480682313420800,
#    'id_str': '1282480682313420800',
#    'name': 'Parker Wallis',
#    'screen_name': 'ParkerWallis',
#    'location': '',
#    'description': '(they/them) NYC Singer l Actor l Voice Actor l Composer l @starfoundpod Cast Member #vocalist #singer #actor #vo #va #voiceover #ttrpg #starfound',
#    'url': 'https://t.co/PCOAvM40mi',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/PCOAvM40mi',
#        'expanded_url': 'https://www.youtube.com/channel/UCtRj2nDyzFIAXdQWIIq4oTg',
#        'display_url': 'youtube.com/channel/UCtRj2…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 276,
#    'friends_count': 1130,
#    'listed_count': 3,
#    'created_at': 'Mon Jul 13 01:03:39 +0000 2020',
#    'favourites_count': 6779,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1285,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1306682576791367681/Q1bJF2wV_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1306682576791367681/Q1bJF2wV_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1282480682313420800/1599528280',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1322689813300965381,
#   'quoted_status_id_str': '1322689813300965381',
#   'quoted_status': {'created_at': 'Sun Nov 01 00:00:00 +0000 2020',
#    'id': 1322689813300965381,
#    'id_str': '1322689813300965381',
#    'text': "Since it's #Halloween, what's the scariest monster in #starfinderrpg? I pick the Vorthuul. An undead entity created… https://t.co/V1Or2rRoPJ",
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Halloween', 'indices': [11, 21]},
#      {'text': 'starfinderrpg', 'indices': [54, 68]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/V1Or2rRoPJ',
#       'expanded_url': 'https://twitter.com/i/web/status/1322689813300965381',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1175636294942113792,
#     'id_str': '1175636294942113792',
#     'name': 'The Space Bois Podcast',
#     'screen_name': 'spaceboispod',
#     'location': 'Los Angeles, CA',
#     'description': "WE'RE BACK - Set far in the future, a group of 5 nobody's find themselves fighting for their lives against unimaginable cosmic horrors #starfinderrpg",
#     'url': 'https://t.co/XA9H3QQHZp',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/XA9H3QQHZp',
#         'expanded_url': 'https://spaceboispodcast.podbean.com/',
#         'display_url': 'spaceboispodcast.podbean.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 176,
#     'friends_count': 263,
#     'listed_count': 2,
#     'created_at': 'Sun Sep 22 05:02:11 +0000 2019',
#     'favourites_count': 355,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 186,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1189003641249615873/RSKZpNrW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1189003641249615873/RSKZpNrW_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1175636294942113792/1572315534',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 5,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'}]

# %%
len(test_output)
# Out:
# 10

# %%
j = 0
for i in test_output: 
    j = j + 1
    print('\n\nTweet(' + str(j) + '):\n' + i['text'])
# Out:
# Tweet(1):
# RT @DimensionPod: Do you have a cool one-shot, community games, a seasonal livestream, or a movie night planned to celebrate #Halloween?
#
# S…
#
#
# Tweet(2):
# RT @lichguru: Hey, I'm gonna do a DM Prep in a couple minutes. If you wanna come in and pick apart my brain, feel free to hop on!
# #DnD #Dn…
#
#
# Tweet(3):
# RT @ParkerWallis: @StarfinderFacts @starfoundpod Jabby? 👀
#
# #starfound #starfinder #scifi #podcast @paizo #actualplay #TTRPGs #ttrpg
#
#
# Tweet(4):
# RT @RollTheRole1: And it's time for #pathfinder2e on #twitch brought to you by @roll20app! Book 5 of @paizo's Age of Ashes is going to be a…
#
#
# Tweet(5):
# And it's time for #pathfinder2e on #twitch brought to you by @roll20app! Book 5 of @paizo's Age of Ashes is going t… https://t.co/sqlX9S7qXb
#
#
# Tweet(6):
# WASD Entertainment Presents - Kids on Bikes - House on Poplar Court - Halloween Special !giveaway
# #twitch #twitchtv… https://t.co/MkLXfjCZUn
#
#
# Tweet(7):
# RT @BraveAdventure5: The pre-release version of our Japanese #papermini set is available now on #Patreon!
#
# LINK: https://t.co/ouWouPot7f
#
# T…
#
#
# Tweet(8):
# RT @thatpasuht: Does roleplaying and is weird, sometimes at the same time. Watches too much tv and sleeps too much, also sometimes at the s…
#
#
# Tweet(9):
# RT @lichguru: Hey, I'm gonna do a DM Prep in a couple minutes. If you wanna come in and pick apart my brain, feel free to hop on!
# #DnD #Dn…
#
#
# Tweet(10):
# @starfoundpod Which was worse? The arch devil? The Dreaming Hunger? The giant undead centaur???
#
# #starfinder… https://t.co/9m1usautEs

# %%
for k in test_output[0].keys(): print(k)
# Out:
# created_at
# id
# id_str
# text
# truncated
# entities
# metadata
# source
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# user
# geo
# coordinates
# place
# contributors
# retweeted_status
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# lang

# %%
test_1 = find_hashtag('DataScience')
test_2 = find_hashtag('#DataScience')
test_3 = find_hashtag('#DataScience', count=100)
test_4 = find_hashtag('#DataScience', search_type='recent')
test_5 = find_hashtag('#DataScience', search_type='mixed')
test_6 = find_hashtag('#DataScience', search_type='popular')
test_7 = find_hashtag('#DataScience', search_type='popular', count=1)
# Out:
# https://api.twitter.com/1.1/search/tweets.json?q=%23DataScience&result_type=popular&count=10
# https://api.twitter.com/1.1/search/tweets.json?q=%23DataScience&result_type=popular&count=10
# https://api.twitter.com/1.1/search/tweets.json?q=%23DataScience&result_type=popular&count=100
# https://api.twitter.com/1.1/search/tweets.json?q=%23DataScience&result_type=recent&count=10
# https://api.twitter.com/1.1/search/tweets.json?q=%23DataScience&result_type=mixed&count=10
# https://api.twitter.com/1.1/search/tweets.json?q=%23DataScience&result_type=popular&count=10
# https://api.twitter.com/1.1/search/tweets.json?q=%23DataScience&result_type=popular&count=1

# %%
tests = [test_1,test_2,test_3,test_4,test_5,test_6,test_7]

# %%
j = 0
for i in test_1: 
    j = j + 1
    print('Tweet(' + str(j) + '):\n' + i['text'] + '\n\n')
# Out:
# Tweet(1):
# Industries like IT/ITeS, BFSI, Pharmaceuticals &amp; Healthcare, E-Commerce, and Media &amp; Entertainment are leveraging… https://t.co/MF22s1Lcm6
#
#
# Tweet(2):
# Free online eBook — #MachineLearning from Scratch: https://t.co/VAgDA0v78O by Daniel Friedman via @DataScienceCtrl… https://t.co/upOIIpmdr6
#
#
# Tweet(3):
# From “Introduction to Statistical Learning”, implementations are now available in #Jupyter notebooks:… https://t.co/WvvIOyLSXw
#
#
# Tweet(4):
# How Kids Channel Their Internal #DataScientist to Become Candy #Optimization Machines on #Halloween:… https://t.co/jDQXieGRZS

# %%
for t in tests: print(len(t))
# Out:
# 4
# 4
# 4
# 10
# 10
# 4
# 1

# %%
test_output_2 = find_hashtag('#mtg',search_type="mixed", count=100)
# Out:
# https://api.twitter.com/1.1/search/tweets.json?q=%23mtg&result_type=mixed&count=100

# %%
len(test_output_2)
# Out:
# 100

# %%
j = 0
for i in test_output_2: 
    j = j + 1
    print('Tweet(' + str(j) + '):\n' + i['text'] + '\n\n')
# Out:
# Tweet(1):
# ここでしか聞けない話、あります!!
# すべそれ原作者の伊瀬勝良先生と念願の対談です☆
#
# 【裏話】MTG漫画原作者と対談!! すべての人類を破壊する、それらは再生できない。 MTG comic talk… https://t.co/btvXxPYgkq
#
#
# Tweet(2):
# ずっとやりたかった地方カード屋巡り動画です!!
# 足を使ってるのに、お金も使ってる超豪華な内容(笑)
#
# 【5店舗】岡山のカード屋巡りしてみた【MTG】 Okayama TCG shop tour… https://t.co/PAF4hsxqkW
#
#
# Tweet(3):
# this gem #throwbackthursday
# #liliannavess
#
# #mtg #mtgarena #mtgcosplay #magic #magicthegathering… https://t.co/LliLbJn9HA
#
#
# Tweet(4):
# RT @thejanklord: The demon sets the Wheelmaster upon an urgent quest. The dudes battle over webcam. The next episode has arrived:
# https://t…
#
#
# Tweet(5):
# RT @sniffygull: Happy Halloween! Go vote if you haven't.
#
# Also. This Sorin. Spooky giveaway! Today only, 12am to 12am. Like, retweet, com…
#
#
# Tweet(6):
# #MTG #MTGA #CGCarnageGaming
#
# It Depends on the End....
#
# Arena Open 1 - 1 Dry :) -&gt; 2k Winning
# Arena Open 2 - 3 Dry… https://t.co/OHmGr4r8WR
#
#
# Tweet(7):
# It's that time of year again! Don't forget to change those clocks!
# #supraliminal #timetwister #magicthegathering… https://t.co/DFz1PeOM0W
#
#
# Tweet(8):
# RT @CarbonGlitch13: A Jeweled Lotus, for me? My, I do not know what to say. *bats eyes*
#
# #MTG #MTGArena #MagicTheGathering #mtgcommunity #M…
#
#
# Tweet(9):
# Carved my favorite color into a pumpkin this year. Happy Halloween to all, especially those that love card games!… https://t.co/n75QofeNAQ
#
#
# Tweet(10):
# RT @kyoufunokyochan: 楽天浅草マッハで予約復活です。
#
# #MTG ＃マジックザギャザリング
#
# 今月発売👇
#
# 衝撃のカード《宝石の睡蓮》に注目💫
#
# 発売日近づくと売り切れ早いので予約必須です🤑
#
# MTG マジック：ザ・ギャザリング 統率者レジェンズ コレクター…
#
#
# Tweet(11):
# Coming to realization that I have a Legendary Spider creature card that I can totally build a deck around. And I ca… https://t.co/sbE07Relbm
#
#
# Tweet(12):
# Timetwister - Unlimited - Power 9 - #MTG - #MagictheGathering #eBay #US #Auction #TCG #TradingCardGame… https://t.co/KQBhCDAt0d
#
#
# Tweet(13):
# Don't forget to check out the latest Top 5 https://t.co/qfnIR1x5Js
#
# #MtG
# #MTGCMR
# #edh
# #MagicTheGathering
#
#
# Tweet(14):
# RT @tcgfes_team: 【#TCGフェス】#有名プレイヤー座談会　始まりました！！
# ご出演： 黒田正城氏、浅原晃氏、大磯正嗣氏、津村健志氏、森田雅彦氏
# トークテーマ：「プレイヤーとしての活動を通じて」
# 司会は黒田氏、藤田氏
# 配信チャンネルはこちら
# https://t.…
#
#
# Tweet(15):
# RT @tcgfes_team: 【#TCGフェス】この後11：00～
# #有名プレイヤー座談会
# ご出演： 黒田正城氏、浅原晃氏、大磯正嗣氏、津村健志氏、森田雅彦氏
# トークテーマ：「プレイヤーとしての活動を通じて」
# 配信チャンネルはこちら
# https://t.co/Ck9NDGS…
#
#
# Tweet(16):
# RT @rpancoast_art: Hans Eriksson
# 18"x24" oil on canvas
# AD: Andrew Vallas
# #mtg #CMRLegends #mtgart https://t.co/RUFojyiaBz
#
#
# Tweet(17):
# RT @rpancoast_art: Hans Eriksson
# 18"x24" oil on canvas
# AD: Andrew Vallas
# #mtg #CMRLegends #mtgart https://t.co/RUFojyiaBz
#
#
# Tweet(18):
# RT @kyoufunokyochan: 楽天浅草マッハで予約復活です。
#
# #MTG ＃マジックザギャザリング
#
# 今月発売👇
#
# 衝撃のカード《宝石の睡蓮》に注目💫
#
# 発売日近づくと売り切れ早いので予約必須です🤑
#
# MTG マジック：ザ・ギャザリング 統率者レジェンズ コレクター…
#
#
# Tweet(19):
# RT @otatencard: 【入荷情報!!】
# #MTG
# Taiga
# Tropical Island
# Savannah
# なんと！入荷しました！！
# さりげなく昔は来てたんですが、最近はめっきり見なくなりましたね…
# 買取金額は状態を加味して合計95000円でお譲りいただけました。…
#
#
# Tweet(20):
# RT @sniffygull: Happy Halloween! Go vote if you haven't.
#
# Also. This Sorin. Spooky giveaway! Today only, 12am to 12am. Like, retweet, com…
#
#
# Tweet(21):
# 雑記66《個人的聖域》🚪
# 《災難の輪》をどう悪用するか考え中🤔
# https://t.co/pLdcxHrMiY
# #mtg #統率者
#
#
# Tweet(22):
# 【予約情報】　#MTG
# 収録カードが徐々に明らかになってきた11月20日発売予定のMTG「統率者レジェンズ」。そのコレクター・ブースター予約受付中！
# こちらは少量の入荷となりますのでお一人様1BOXまでのご予約とさせていただきます… https://t.co/Ur8R2ovRYq
#
#
# Tweet(23):
# Food token featuring Swedish Chef for Day #22 of @Inktober's #primal_inktober!
# #mtg #mtgtoken #token #food #chef… https://t.co/ah7abNOA6P
#
#
# Tweet(24):
# RT @sniffygull: Happy Halloween! Go vote if you haven't.
#
# Also. This Sorin. Spooky giveaway! Today only, 12am to 12am. Like, retweet, com…
#
#
# Tweet(25):
# RT @zundoko_dt: 【買取情報】 #MTG モダン・レガシー・統率者
# スレイベンの守護者、サリア1200
# 孔蹄のビヒモス2000
# 瞬唱の魔道士3500
# 真の名の宿敵1400
# タルモゴイフ4500
# 今週の買取表を更新しました！
# 詳細は下記ブログにてご確認ください。 h…
#
#
# Tweet(26):
# RT @kyoufunokyochan: 楽天浅草マッハで予約復活です。
#
# #MTG ＃マジックザギャザリング
#
# 今月発売👇
#
# 衝撃のカード《宝石の睡蓮》に注目💫
#
# 発売日近づくと売り切れ早いので予約必須です🤑
#
# MTG マジック：ザ・ギャザリング 統率者レジェンズ コレクター…
#
#
# Tweet(27):
# RT @TolarianCollege: I love everything about this card: the history, the humor, the mechanics, the art by @rpancoast_art! Everything! #mtg…
#
#
# Tweet(28):
# RT @TolarianCollege: I love everything about this card: the history, the humor, the mechanics, the art by @rpancoast_art! Everything! #mtg…
#
#
# Tweet(29):
# RT @TolarianCollege: I love everything about this card: the history, the humor, the mechanics, the art by @rpancoast_art! Everything! #mtg…
#
#
# Tweet(30):
# RT @sniffygull: Happy Halloween! Go vote if you haven't.
#
# Also. This Sorin. Spooky giveaway! Today only, 12am to 12am. Like, retweet, com…
#
#
# Tweet(31):
# RT @hareruya_Media: 【動画】統率者戦を楽しむ動画、晴れコマ復活！今回は晴れる屋スタッフ同士でガチバトルだ！
#
# 【統率者戦】復活の晴れコマ！ カウンター不能のぶっ壊れカード登場！！ ウィノータvsエドリックvsザクサラvsリエール #14
# https://t.…
#
#
# Tweet(32):
# Double masters pulls tonight. #MtG  #MagicTheGathering #mtgfinance https://t.co/0L8aHoc3xn
#
#
# Tweet(33):
# RT @rpancoast_art: Hans Eriksson
# 18"x24" oil on canvas
# AD: Andrew Vallas
# #mtg #CMRLegends #mtgart https://t.co/RUFojyiaBz
#
#
# Tweet(34):
# RT @tcgfes_team: 【#TCGフェス】この後11：00～
# #有名プレイヤー座談会
# ご出演： 黒田正城氏、浅原晃氏、大磯正嗣氏、津村健志氏、森田雅彦氏
# トークテーマ：「プレイヤーとしての活動を通じて」
# 配信チャンネルはこちら
# https://t.co/Ck9NDGS…
#
#
# Tweet(35):
# RT @Erinsartstuff: Casual Radiant wishes you all a Happy Halloween and a Blessed Samhain ✨🎃
#
# Casual Radiant design by @Ishton
# #MTGWitches…
#
#
# Tweet(36):
# RT @sniffygull: Happy Halloween! Go vote if you haven't.
#
# Also. This Sorin. Spooky giveaway! Today only, 12am to 12am. Like, retweet, com…
#
#
# Tweet(37):
# RT @adoadomtg: 初めて伺う店舗さんに行って、
# お店の常連の人が対戦相手をして頂いたのはありがたかったのですが、すごく嫌そうに対戦されたのはちょっとヘコんだな〜。
# すぐに対戦終えて帰ったけど、恐らく二度とそこには行かないかな…。
# 店員さんは感じ良い人だったんだけど……
#
#
# Tweet(38):
# RT @sniffygull: Happy Halloween! Go vote if you haven't.
#
# Also. This Sorin. Spooky giveaway! Today only, 12am to 12am. Like, retweet, com…
#
#
# Tweet(39):
# RT @rpancoast_art: Hans Eriksson
# 18"x24" oil on canvas
# AD: Andrew Vallas
# #mtg #CMRLegends #mtgart https://t.co/RUFojyiaBz
#
#
# Tweet(40):
# MTG マジック：ザ・ギャザリング 統率者レジェンズ コレクター・ブースター 日本語版 12パック入り（BOX）
#
# ゼンディカーの夜明けコレクターブースター日本語版が登場!
#
# 2020/11/21 発売予定
#
# #Mtg… https://t.co/p9wgmfYDVR
#
#
# Tweet(41):
# RT @sniffygull: Happy Halloween! Go vote if you haven't.
#
# Also. This Sorin. Spooky giveaway! Today only, 12am to 12am. Like, retweet, com…
#
#
# Tweet(42):
# Ghostly Flicker #mtg
#
# Sometimes it's useful to take a break from existence.
#
# Artist: Raymond Swanland https://t.co/YkkXJtjdaV
#
#
# Tweet(43):
# RT @chibagame: 【#MTG イベント告知】 11/14(土) 13：30より、
# マジック：ザ・ギャザリング『統率者レジェンズ』プレリリース開催です！
# 参加費税込￥2000・定員8名となります。
# こちらのイベントのご参加には『ウィザース・アカウント』の登録が必要です…
#
#
# Tweet(44):
# RT @sniffygull: Happy Halloween! Go vote if you haven't.
#
# Also. This Sorin. Spooky giveaway! Today only, 12am to 12am. Like, retweet, com…
#
#
# Tweet(45):
# RT @rpancoast_art: Hans Eriksson
# 18"x24" oil on canvas
# AD: Andrew Vallas
# #mtg #CMRLegends #mtgart https://t.co/RUFojyiaBz
#
#
# Tweet(46):
# RT @tcgfes_team: 【#TCGフェス】#有名プレイヤー座談会　始まりました！！
# ご出演： 黒田正城氏、浅原晃氏、大磯正嗣氏、津村健志氏、森田雅彦氏
# トークテーマ：「プレイヤーとしての活動を通じて」
# 司会は黒田氏、藤田氏
# 配信チャンネルはこちら
# https://t.…
#
#
# Tweet(47):
# 【買取】#MTG
# 《オパールのモックス》や《魂の洞窟》など、MTG高額シングルカードを買い取らせて頂きました！ https://t.co/HtXaogHX1Z
#
#
# Tweet(48):
# Deck: UR Storm
# On the Play
# Format: Modern
# Deck list: https://t.co/OFXTUdHW8U
# #KeepOrMull
# #MTGModern
# #MTG https://t.co/Mro6Q04ox6
#
#
# Tweet(49):
# すぱいらるオープンしました！
# 本日は【11～22時】までロング営業中
# 皆様のご来店をお待ちしております！！
#
# #秋葉原カードショップ　#遊戯王　#MTG　#プリチャン　#ポケカ　#デュエマ
#
#
# Tweet(50):
# 【#TCGフェス】#有名プレイヤー座談会　始まりました！！
# ご出演： 黒田正城氏、浅原晃氏、大磯正嗣氏、津村健志氏、森田雅彦氏
# トークテーマ：「プレイヤーとしての活動を通じて」
# 司会は黒田氏、藤田氏
# 配信チャンネルはこちら… https://t.co/gzFo93bYmf
#
#
# Tweet(51):
# RT @LandSayGo1: Stream starting NOW, come hang out! https://t.co/fyI0gTsxam
#
# #MTG #MagicTheGathering #MTGA #MTGArena #WeAreMTG https://t.co…
#
#
# Tweet(52):
# RT @batolocobaba: 【買取情報】
# #MTG 土地買取情報です！
# デュアラン、フェッチ、ショック、ファスト……
# あんな土地やこんな土地、
# スタン以外で活躍する土地を一挙買取表にしました！
#
# 11月はPWCSやプレリリースを開催します！
#
# ぜひご来店ください！
# #バ…
#
#
# Tweet(53):
# 【#TCGフェス】#有名プレイヤー座談会　始まりました！！
# ご出演： 黒田正城氏、浅原晃氏、大磯正嗣氏、津村健志氏、森田雅彦氏
# トークテーマ：「プレイヤーとしての活動を通じて」
# 司会は黒田氏、藤田氏
# 配信チャンネルはこちら… https://t.co/SO5qhOWVCF
#
#
# Tweet(54):
# 【大会情報】
# 成田店の本日&amp;明日の大会コードはこちら！
# お早めのコード登録をどうぞ！
#
# またMTGコンパニオンをお持ちでない方はコチラからダウンロードをどうぞ！
# https://t.co/vS3F8uOWy1
#
# ご参加お待ちしてお… https://t.co/YU9V2vgqbz
#
#
# Tweet(55):
# Stream starting NOW, come hang out! https://t.co/fyI0gTsxam
#
# #MTG #MagicTheGathering #MTGA #MTGArena #WeAreMTG https://t.co/EpGBDjj4SP
#
#
# Tweet(56):
# RT @GuardianPod: In honor of Halloween, RT and comment below with your favorite graveyard related magic card! We’ll pick a random winner to…
#
#
# Tweet(57):
# RT @TolarianCollege: I love everything about this card: the history, the humor, the mechanics, the art by @rpancoast_art! Everything! #mtg…
#
#
# Tweet(58):
# RT @baypaintstudios: Bone Dancer - MTG Art Replacement Alter based on Walt Disney's Silly Symphony Animated Short "The Skeleton Dance" 1929…
#
#
# Tweet(59):
# RT @sniffygull: Happy Halloween! Go vote if you haven't.
#
# Also. This Sorin. Spooky giveaway! Today only, 12am to 12am. Like, retweet, com…
#
#
# Tweet(60):
# RT @TolarianCollege: I love everything about this card: the history, the humor, the mechanics, the art by @rpancoast_art! Everything! #mtg…
#
#
# Tweet(61):
# RT @tcgfes_team: 【#TCGフェス】この後11：00～
# #有名プレイヤー座談会
# ご出演： 黒田正城氏、浅原晃氏、大磯正嗣氏、津村健志氏、森田雅彦氏
# トークテーマ：「プレイヤーとしての活動を通じて」
# 配信チャンネルはこちら
# https://t.co/Ck9NDGS…
#
#
# Tweet(62):
# Free #edh deck giveaway.  Only a few minutes left to enter!  #mtg https://t.co/69mCpmAXwB
#
#
# Tweet(63):
# RT @TolarianCollege: I love everything about this card: the history, the humor, the mechanics, the art by @rpancoast_art! Everything! #mtg…
#
#
# Tweet(64):
# Bone Dancer - MTG Art Replacement Alter based on Walt Disney's Silly Symphony Animated Short "The Skeleton Dance" 1… https://t.co/seTl2tKGSq
#
#
# Tweet(65):
# RT @tcgfes_team: 【#TCGフェス】この後11：00～
# #有名プレイヤー座談会
# ご出演： 黒田正城氏、浅原晃氏、大磯正嗣氏、津村健志氏、森田雅彦氏
# トークテーマ：「プレイヤーとしての活動を通じて」
# 配信チャンネルはこちら
# https://t.co/Ck9NDGS…
#
#
# Tweet(66):
# RT @GuardianPod: In honor of Halloween, RT and comment below with your favorite graveyard related magic card! We’ll pick a random winner to…
#
#
# Tweet(67):
# mtgやってます。Skype対戦大歓迎なので気軽にめっせ・返信ください。 #mtg
#
#
# Tweet(68):
# RT @tcgfes_team: 【#TCGフェス】この後11：00～
# #有名プレイヤー座談会
# ご出演： 黒田正城氏、浅原晃氏、大磯正嗣氏、津村健志氏、森田雅彦氏
# トークテーマ：「プレイヤーとしての活動を通じて」
# 配信チャンネルはこちら
# https://t.co/Ck9NDGS…
#
#
# Tweet(69):
# RT @sniffygull: Who voted? Good job! Let me run a giveaway for you. If you voted or vote between now and the 3rd, comment below or retweet…
#
#
# Tweet(70):
# 【#TCGフェス】この後11：00～
# #有名プレイヤー座談会
# ご出演： 黒田正城氏、浅原晃氏、大磯正嗣氏、津村健志氏、森田雅彦氏
# トークテーマ：「プレイヤーとしての活動を通じて」
# 配信チャンネルはこちら… https://t.co/qdCK8Kbf3J
#
#
# Tweet(71):
# RT @rpancoast_art: Hans Eriksson
# 18"x24" oil on canvas
# AD: Andrew Vallas
# #mtg #CMRLegends #mtgart https://t.co/RUFojyiaBz
#
#
# Tweet(72):
# RT @sniffygull: Happy Halloween! Go vote if you haven't.
#
# Also. This Sorin. Spooky giveaway! Today only, 12am to 12am. Like, retweet, com…
#
#
# Tweet(73):
# RT @msjalters: Happy Halloween 🎃 original art Exotic Orchard. For sale $55 #mtg #mtgalters #magicthegathering #wearemtg #msjalters https://…
#
#
# Tweet(74):
# RT @sniffygull: Happy Halloween! Go vote if you haven't.
#
# Also. This Sorin. Spooky giveaway! Today only, 12am to 12am. Like, retweet, com…
#
#
# Tweet(75):
# 記念開封アンケート、明日の19時頃までになってます！是非投票下さい！
# 現在チャンネル登録者様196人😆もう少しで200人です！
# そわそわ！
#
# #mtg https://t.co/coEtUXCq3I https://t.co/FqFTBvw8uL
#
#
# Tweet(76):
# #MTG
# 最高にロックだなこれw
#
# このおっさんが攻撃する時、トップ表向き、それがクリーチャーなら相手を攻撃している状態で踏み倒し、それ以外なら手札へ。この効果からクリーチャーが出たら、この髭と出た奴とでバトル（強制）。
#
# おっ… https://t.co/lrxGaLxpFL
#
#
# Tweet(77):
# RT @sniffygull: Happy Halloween! Go vote if you haven't.
#
# Also. This Sorin. Spooky giveaway! Today only, 12am to 12am. Like, retweet, com…
#
#
# Tweet(78):
# RT @TolarianCollege: I love everything about this card: the history, the humor, the mechanics, the art by @rpancoast_art! Everything! #mtg…
#
#
# Tweet(79):
# 依頼の品。ヴァルダーク
# #mtg
# #拡張アート https://t.co/lu1tGRPDFq
#
#
# Tweet(80):
# RT @rpancoast_art: Hans Eriksson
# 18"x24" oil on canvas
# AD: Andrew Vallas
# #mtg #CMRLegends #mtgart https://t.co/RUFojyiaBz
#
#
# Tweet(81):
# RT @CarbonGlitch13: A Jeweled Lotus, for me? My, I do not know what to say. *bats eyes*
#
# #MTG #MTGArena #MagicTheGathering #mtgcommunity #M…
#
#
# Tweet(82):
# RT @rpancoast_art: Hans Eriksson
# 18"x24" oil on canvas
# AD: Andrew Vallas
# #mtg #CMRLegends #mtgart https://t.co/RUFojyiaBz
#
#
# Tweet(83):
# In this article, I list my top five Knight based decks for MTG Arena.
#
# https://t.co/DU1qL9SQrr
#
# @MTG_Arena… https://t.co/l8F07GY88k
#
#
# Tweet(84):
# First match off the new season, i think this is going to be the hardest season with everyone playing the same set o… https://t.co/5komR43apT
#
#
# Tweet(85):
# Do you love gaining lots of life?
# Try out these five MTG Arena decks!
#
# https://t.co/tkjISoszek
#
# @MTG_Arena… https://t.co/hIlrcdbVem
#
#
# Tweet(86):
# ライブアイドルさんの担当カラーで
# デッキを組むと面白そうだなと思ってみた。
# #MTG
#
#
# Tweet(87):
# RT @TolarianCollege: I love everything about this card: the history, the humor, the mechanics, the art by @rpancoast_art! Everything! #mtg…
#
#
# Tweet(88):
# RT @rpancoast_art: Hans Eriksson
# 18"x24" oil on canvas
# AD: Andrew Vallas
# #mtg #CMRLegends #mtgart https://t.co/RUFojyiaBz
#
#
# Tweet(89):
# RT @rpancoast_art: Hans Eriksson
# 18"x24" oil on canvas
# AD: Andrew Vallas
# #mtg #CMRLegends #mtgart https://t.co/RUFojyiaBz
#
#
# Tweet(90):
# RT @GuardianPod: In honor of Halloween, RT and comment below with your favorite graveyard related magic card! We’ll pick a random winner to…
#
#
# Tweet(91):
# RT @CardshopSerra: 🎁RTキャンペーン＆イベント開催中🎁
#
# 🍖購入で静岡県産の厳選ブランド肉などが貰える🍖
# 特設ページはこちら
# https://t.co/TVv9YAOsdp
#
# 期間限定特価❣
# https://t.co/zLWJDo4OGe
#
# 🎀リツイートキャ…
#
#
# Tweet(92):
# RT @MagicBeansCast: October league finals stream kicks off tomorrow and we will be revealing who has made in into the inaugural Magic Beans…
#
#
# Tweet(93):
# Got this bad boy today. #mtg #MagicTheGathering #edh #commander https://t.co/oigJxIcmXo
#
#
# Tweet(94):
# RT @sniffygull: Happy Halloween! Go vote if you haven't.
#
# Also. This Sorin. Spooky giveaway! Today only, 12am to 12am. Like, retweet, com…
#
#
# Tweet(95):
# RT @sniffygull: Happy Halloween! Go vote if you haven't.
#
# Also. This Sorin. Spooky giveaway! Today only, 12am to 12am. Like, retweet, com…
#
#
# Tweet(96):
# RT @GuardianPod: In honor of Halloween, RT and comment below with your favorite graveyard related magic card! We’ll pick a random winner to…
#
#
# Tweet(97):
# RT @sniffygull: Happy Halloween! Go vote if you haven't.
#
# Also. This Sorin. Spooky giveaway! Today only, 12am to 12am. Like, retweet, com…
#
#
# Tweet(98):
# RT @TolarianCollege: I love everything about this card: the history, the humor, the mechanics, the art by @rpancoast_art! Everything! #mtg…
#
#
# Tweet(99):
# こんなん絶対ファイレクシア産のアーティファクト・クリーチャーじゃねーか。#MTG #MagicTheGathering #マジックザギャザリング https://t.co/jeAVb59zFg
#
#
# Tweet(100):
# RT @sniffygull: Happy Halloween! Go vote if you haven't.
#
# Also. This Sorin. Spooky giveaway! Today only, 12am to 12am. Like, retweet, com…
