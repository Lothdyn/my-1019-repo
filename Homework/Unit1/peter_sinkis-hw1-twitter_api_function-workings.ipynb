# %%
# Set up key libraries / tokens

# %%
import requests 
from requests_oauthlib import OAuth1
import os
import pandas as pd

# %%
API_PUBLIC = os.environ.get("TW_API_KEY")
API_SECRET = os.environ.get("TW_API_SECRET_KEY")
APP_PUBLIC = os.environ.get("TW_PRS_GA_HW_ACCESS_TOKEN")
APP_SECRET = os.environ.get("TW_PRS_GA_HW_ACCESS_TOKEN_SECRET")

# %%
url = 'https://api.twitter.com/1.1/account/verify_credentials.json'
auth = OAuth1(
            API_PUBLIC, #'USER_OAUTH_TOKEN', 
            API_SECRET, #'USER_OAUTH_TOKEN_SECRET'
            APP_PUBLIC, #'YOUR_APP_KEY', 
            APP_SECRET #'YOUR_APP_SECRET',
            )

# %%
# Check authorisation is working properly

# %%
check_auth = requests.get(url, auth=auth)

# %%
check_auth.reason
# Out:
# 'OK'

# %%
keys = []
if not keys:
    print(True) 
else: 
    print("error")
# Out:
# True

# %% [markdown]
# # Function 1 - find_user

# %% [markdown]
# **Name:** `find_user`
#
# **Returns:** dictionary that represents user object returned by Twitter's API
#
# **Arguments:**
#  - `screen_name`: str, required; Twitter handle to search for.  **Can include the @ symbol.  The function should check for this and remove it if necessary.**
#  - `keys`: list, optional; list that contains keys to return about user object.  If not specified, then function should return the entire user object.  **These only need to be outer keys.** If they are keys nested within another key, you don't have to account for this.
#
# **To test:** We'll test your function in the following ways:
#
#  - `find_user('@GA')`
#  - `find_user('GA')`
#  - `find_user('GA', keys=['name', 'screen_name', 'followers_count', 'friends_count'])`

# %%
def find_user(screen_name,keys = [], auth=auth):
    # setup output dictionary
    output_dict = {}
    
    # Checks on screen_name input
    if screen_name[0] == '@':
        screen_name = screen_name[1:]

    # Go and get a result
    find_user_url = "https://api.twitter.com/1.1/users/search.json?q=" + screen_name
    req_output = requests.get(find_user_url, auth=auth)
    
    #convert the outut to a list, create an initial dictionary
    req_output_list = req_output.json()
    user_dict = {}
    i = 0
    for o in req_output_list:
        i = i+1
        user_dict.update({'user_' + str(i) : o})
    
    if not keys:
        output_dict = user_dict # don't filter the resulting dictionary
    else:
        filtered_user_info_dict = {}

        for u in user_dict.keys():
            for k in keys:
                filtered_user_info_dict.update({k : user_dict[u][k]})
            output_dict.update({u:filtered_user_info_dict})
    return output_dict

# %%
#abc = find_user('@ickbat')

# %%
print(abc)
# Out:
# {'user_1': {'id': 1015919502872096768, 'id_str': '1015919502872096768', 'name': 'jess', 'screen_name': 'bIckbat', 'location': '', 'description': 'im going to steal minato’s girl • she/her 19 • cw:bnha', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 649, 'friends_count': 330, 'listed_count': 39, 'created_at': 'Sun Jul 08 11:24:19 +0000 2018', 'favourites_count': 28596, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 29844, 'lang': None, 'status': {'created_at': 'Thu Oct 29 21:47:28 +0000 2020', 'id': 1321931684586024960, 'id_str': '1321931684586024960', 'text': '@kdawayv ur lying you don’t listen to lightbulb once a week', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'kdawayv', 'name': 'vnus', 'id': 1248339782821797889, 'id_str': '1248339782821797889', 'indices': [0, 8]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1321902433853825024, 'in_reply_to_status_id_str': '1321902433853825024', 'in_reply_to_user_id': 1248339782821797889, 'in_reply_to_user_id_str': '1248339782821797889', 'in_reply_to_screen_name': 'kdawayv', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1319368364779663360/d5WXxWC__normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1319368364779663360/d5WXxWC__normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1015919502872096768/1600144603', 'profile_link_color': '91D2FA', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'user_2': {'id': 272400161, 'id_str': '272400161', 'name': 'Nick Bate', 'screen_name': 'ickbat', 'location': 'London, UK', 'description': 'Sometimes I do galactic archaeology. Other times I write tabletop games. He/him.', 'url': 'https://t.co/ri2j5Ka7CM', 'entities': {'url': {'urls': [{'url': 'https://t.co/ri2j5Ka7CM', 'expanded_url': 'http://ickbat.itch.io', 'display_url': 'ickbat.itch.io', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 587, 'friends_count': 733, 'listed_count': 25, 'created_at': 'Sat Mar 26 12:45:18 +0000 2011', 'favourites_count': 9589, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 24661, 'lang': None, 'status': {'created_at': 'Thu Oct 29 16:41:51 +0000 2020', 'id': 1321854773574991881, 'id_str': '1321854773574991881', 'text': "@in_die_zine I'm pretty excited about how it's turned out! Looking forward to moving it on to editing.", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'in_die_zine', 'name': 'in🎲die zine', 'id': 1298170429429907457, 'id_str': '1298170429429907457', 'indices': [0, 12]}], 'urls': []}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': 1321836477979000837, 'in_reply_to_status_id_str': '1321836477979000837', 'in_reply_to_user_id': 1298170429429907457, 'in_reply_to_user_id_str': '1298170429429907457', 'in_reply_to_screen_name': 'in_die_zine',  ...

# %%
len(abc)
# Out:
# 2

# %%
print(abc.keys())
# Out:
# dict_keys(['user_1', 'user_2'])

# %%
abc["user_1"]
# Out:
# {'id': 1015919502872096768,
#  'id_str': '1015919502872096768',
#  'name': 'jess',
#  'screen_name': 'bIckbat',
#  'location': '',
#  'description': 'im going to steal minato’s girl • she/her 19 • cw:bnha',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 649,
#  'friends_count': 330,
#  'listed_count': 39,
#  'created_at': 'Sun Jul 08 11:24:19 +0000 2018',
#  'favourites_count': 28596,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 29844,
#  'lang': None,
#  'status': {'created_at': 'Thu Oct 29 21:47:28 +0000 2020',
#   'id': 1321931684586024960,
#   'id_str': '1321931684586024960',
#   'text': '@kdawayv ur lying you don’t listen to lightbulb once a week',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'kdawayv',
#      'name': 'vnus',
#      'id': 1248339782821797889,
#      'id_str': '1248339782821797889',
#      'indices': [0, 8]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': 1321902433853825024,
#   'in_reply_to_status_id_str': '1321902433853825024',
#   'in_reply_to_user_id': 1248339782821797889,
#   'in_reply_to_user_id_str': '1248339782821797889',
#   'in_reply_to_screen_name': 'kdawayv',
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': '000000',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1319368364779663360/d5WXxWC__normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1319368364779663360/d5WXxWC__normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1015919502872096768/1600144603',
#  'profile_link_color': '91D2FA',
#  'profile_sidebar_border_color': '000000',
#  'profile_sidebar_fill_color': '000000',
#  'profile_text_color': '000000',
#  'profile_use_background_image': False,
#  'has_extended_profile': True,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
abc["user_2"]
# Out:
# {'id': 272400161,
#  'id_str': '272400161',
#  'name': 'Nick Bate',
#  'screen_name': 'ickbat',
#  'location': 'London, UK',
#  'description': 'Sometimes I do galactic archaeology. Other times I write tabletop games. He/him.',
#  'url': 'https://t.co/ri2j5Ka7CM',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/ri2j5Ka7CM',
#      'expanded_url': 'http://ickbat.itch.io',
#      'display_url': 'ickbat.itch.io',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 587,
#  'friends_count': 733,
#  'listed_count': 25,
#  'created_at': 'Sat Mar 26 12:45:18 +0000 2011',
#  'favourites_count': 9589,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 24661,
#  'lang': None,
#  'status': {'created_at': 'Thu Oct 29 16:41:51 +0000 2020',
#   'id': 1321854773574991881,
#   'id_str': '1321854773574991881',
#   'text': "@in_die_zine I'm pretty excited about how it's turned out! Looking forward to moving it on to editing.",
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'in_die_zine',
#      'name': 'in🎲die zine',
#      'id': 1298170429429907457,
#      'id_str': '1298170429429907457',
#      'indices': [0, 12]}],
#    'urls': []},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'in_reply_to_status_id': 1321836477979000837,
#   'in_reply_to_status_id_str': '1321836477979000837',
#   'in_reply_to_user_id': 1298170429429907457,
#   'in_reply_to_user_id_str': '1298170429429907457',
#   'in_reply_to_screen_name': 'in_die_zine',
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 2,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': '001329',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1287775449/sticknick3_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1287775449/sticknick3_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/272400161/1430788640',
#  'profile_link_color': '448668',
#  'profile_sidebar_border_color': 'F7B565',
#  'profile_sidebar_fill_color': '000B17',
#  'profile_text_color': '004358',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': True,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
# Playing around with code and ideas to get the output I want

# %%
elem = ['user_' + str(i) for i in range(1,len(abc)+1)]

# %%
elem
# Out:
# ['user_1', 'user_2']

# %%
user_dict = {}
i = 0
for a in abc:
    i = i+1
    user_dict.update({'user_' + str(i) : a})

# %%
user_dict.keys()
# Out:
# dict_keys(['user_1', 'user_2'])

# %%
user_dict['user_2']
# Out:
# {'id': 272400161,
#  'id_str': '272400161',
#  'name': 'Nick Bate',
#  'screen_name': 'ickbat',
#  'location': 'London, UK',
#  'description': 'Sometimes I do galactic archaeology. Other times I write tabletop games. He/him.',
#  'url': 'https://t.co/ri2j5Ka7CM',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/ri2j5Ka7CM',
#      'expanded_url': 'http://ickbat.itch.io',
#      'display_url': 'ickbat.itch.io',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 587,
#  'friends_count': 733,
#  'listed_count': 25,
#  'created_at': 'Sat Mar 26 12:45:18 +0000 2011',
#  'favourites_count': 9589,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 24661,
#  'lang': None,
#  'status': {'created_at': 'Thu Oct 29 16:41:51 +0000 2020',
#   'id': 1321854773574991881,
#   'id_str': '1321854773574991881',
#   'text': "@in_die_zine I'm pretty excited about how it's turned out! Looking forward to moving it on to editing.",
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'in_die_zine',
#      'name': 'in🎲die zine',
#      'id': 1298170429429907457,
#      'id_str': '1298170429429907457',
#      'indices': [0, 12]}],
#    'urls': []},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'in_reply_to_status_id': 1321836477979000837,
#   'in_reply_to_status_id_str': '1321836477979000837',
#   'in_reply_to_user_id': 1298170429429907457,
#   'in_reply_to_user_id_str': '1298170429429907457',
#   'in_reply_to_screen_name': 'in_die_zine',
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 2,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': '001329',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1287775449/sticknick3_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1287775449/sticknick3_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/272400161/1430788640',
#  'profile_link_color': '448668',
#  'profile_sidebar_border_color': 'F7B565',
#  'profile_sidebar_fill_color': '000B17',
#  'profile_text_color': '004358',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': True,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
user_dict
# Out:
# {'user_1': {'id': 1015919502872096768,
#   'id_str': '1015919502872096768',
#   'name': 'jess',
#   'screen_name': 'bIckbat',
#   'location': '',
#   'description': 'im going to steal minato’s girl • she/her 19 • cw:bnha',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 649,
#   'friends_count': 330,
#   'listed_count': 39,
#   'created_at': 'Sun Jul 08 11:24:19 +0000 2018',
#   'favourites_count': 28596,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 29844,
#   'lang': None,
#   'status': {'created_at': 'Thu Oct 29 21:47:28 +0000 2020',
#    'id': 1321931684586024960,
#    'id_str': '1321931684586024960',
#    'text': '@kdawayv ur lying you don’t listen to lightbulb once a week',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'kdawayv',
#       'name': 'vnus',
#       'id': 1248339782821797889,
#       'id_str': '1248339782821797889',
#       'indices': [0, 8]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1321902433853825024,
#    'in_reply_to_status_id_str': '1321902433853825024',
#    'in_reply_to_user_id': 1248339782821797889,
#    'in_reply_to_user_id_str': '1248339782821797889',
#    'in_reply_to_screen_name': 'kdawayv',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1319368364779663360/d5WXxWC__normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1319368364779663360/d5WXxWC__normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1015919502872096768/1600144603',
#   'profile_link_color': '91D2FA',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'user_2': {'id': 272400161,
#   'id_str': '272400161',
#   'name': 'Nick Bate',
#   'screen_name': 'ickbat',
#   'location': 'London, UK',
#   'description': 'Sometimes I do galactic archaeology. Other times I write tabletop games. He/him.',
#   'url': 'https://t.co/ri2j5Ka7CM',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/ri2j5Ka7CM',
#       'expanded_url': 'http://ickbat.itch.io',
#       'display_url': 'ickbat.itch.io',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 587,
#   'friends_count': 733,
#   'listed_count': 25,
#   'created_at': 'Sat Mar 26 12:45:18 +0000 2011',
#   'favourites_count': 9589,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 24661,
#   'lang': None,
#   'status': {'created_at': 'Thu Oct 29 16:41:51 +0000 2020',
#    'id': 1321854773574991881,
#    'id_str': '1321854773574991881',
#    'text': "@in_die_zine I'm pretty excited about how it's turned out! Looking forward to moving it on to editing.",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'in_die_zine',
#       'name': 'in🎲die zine',
#       'id': 1298170429429907457,
#       'id_str': '1298170429429907457',
#       'indices': [0, 12]}],
#     'urls': []},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': 1321836477979000837,
#    'in_reply_to_status_id_str': '1321836477979000837',
#    'in_reply_to_user_id': 1298170429429907457,
#    'in_reply_to_user_id_str': '1298170429429907457',
#    'in_reply_to_screen_name': 'in_die_zine',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '001329',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1287775449/sticknick3_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1287775449/sticknick3_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/272400161/1430788640',
#   'profile_link_color': '448668',
#   'profile_sidebar_border_color': 'F7B565',
#   'profile_sidebar_fill_color': '000B17',
#   'profile_text_color': '004358',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': True,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'}}

# %%
user_dict["user_1"]
# Out:
# {'id': 1015919502872096768,
#  'id_str': '1015919502872096768',
#  'name': 'jess',
#  'screen_name': 'bIckbat',
#  'location': '',
#  'description': 'im going to steal minato’s girl • she/her 19 • cw:bnha',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 649,
#  'friends_count': 330,
#  'listed_count': 39,
#  'created_at': 'Sun Jul 08 11:24:19 +0000 2018',
#  'favourites_count': 28596,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 29844,
#  'lang': None,
#  'status': {'created_at': 'Thu Oct 29 21:47:28 +0000 2020',
#   'id': 1321931684586024960,
#   'id_str': '1321931684586024960',
#   'text': '@kdawayv ur lying you don’t listen to lightbulb once a week',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'kdawayv',
#      'name': 'vnus',
#      'id': 1248339782821797889,
#      'id_str': '1248339782821797889',
#      'indices': [0, 8]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': 1321902433853825024,
#   'in_reply_to_status_id_str': '1321902433853825024',
#   'in_reply_to_user_id': 1248339782821797889,
#   'in_reply_to_user_id_str': '1248339782821797889',
#   'in_reply_to_screen_name': 'kdawayv',
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': '000000',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1319368364779663360/d5WXxWC__normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1319368364779663360/d5WXxWC__normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1015919502872096768/1600144603',
#  'profile_link_color': '91D2FA',
#  'profile_sidebar_border_color': '000000',
#  'profile_sidebar_fill_color': '000000',
#  'profile_text_color': '000000',
#  'profile_use_background_image': False,
#  'has_extended_profile': True,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
keys = ['screen_name','created_at','lang']

# %%
user_dict["user_1"]['screen_name']
# Out:
# 'bIckbat'

# %%
user_dict["user_1"]['created_at']
# Out:
# 'Sun Jul 08 11:24:19 +0000 2018'

# %%
new_user_dict = {}
new_user_info_dict = {}

for u in user_dict.keys():
    for k in keys:
        new_user_info_dict.update({k : user_dict[u][k]})
    new_user_dict.update({u:new_user_info_dict})

# %%
new_user_dict
# Out:
# {'user_1': {'screen_name': 'ickbat',
#   'created_at': 'Sat Mar 26 12:45:18 +0000 2011',
#   'lang': None},
#  'user_2': {'screen_name': 'ickbat',
#   'created_at': 'Sat Mar 26 12:45:18 +0000 2011',
#   'lang': None}}

# %% [markdown]
# # Test function 1

# %%
function1_test1 = find_user('@GA')
function1_test2 = find_user('GA')
function1_test3 = find_user('GA', keys=['name', 'screen_name', 'followers_count', 'friends_count'])

# %%
function1_test1
# Out:
# {'user_1': {'id': 170393291,
#   'id_str': '170393291',
#   'name': 'General Assembly',
#   'screen_name': 'GA',
#   'location': '',
#   'description': 'We transform careers and teams — including more than one third of the Fortune 100 — through dynamic courses in coding, data, design, and business.',
#   'url': 'https://t.co/YQeEXPxJ4H',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/YQeEXPxJ4H',
#       'expanded_url': 'http://ga.co/Twitter',
#       'display_url': 'ga.co/Twitter',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 164594,
#   'friends_count': 5393,
#   'listed_count': 3251,
#   'created_at': 'Sat Jul 24 18:19:59 +0000 2010',
#   'favourites_count': 35102,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 22792,
#   'lang': None,
#   'status': {'created_at': 'Thu Oct 29 22:12:01 +0000 2020',
#    'id': 1321937862560985089,
#    'id_str': '1321937862560985089',
#    'text': 'Helpful quick tips and simple rules to stay organized as a data scientist:\nhttps://t.co/YYAC9fajGv via… https://t.co/uPcP8zBhGD',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/YYAC9fajGv',
#       'expanded_url': 'https://ga.co/35k8TMm',
#       'display_url': 'ga.co/35k8TMm',
#       'indices': [75, 98]},
#      {'url': 'https://t.co/uPcP8zBhGD',
#       'expanded_url': 'https://twitter.com/i/web/status/1321937862560985089',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [104, 127]}]},
#    'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 4,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'FFFFFF',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1318271172216324097/O7Xaryg2_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1318271172216324097/O7Xaryg2_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/170393291/1480618900',
#   'profile_link_color': 'DE2233',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'FFFFFF',
#   'profile_text_color': '000000',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'user_2': {'id': 17023762,
#   'id_str': '17023762',
#   'name': 'R/GA',
#   'screen_name': 'RGA',
#   'location': 'New York, NY',
#   'description': 'We design businesses and brands for a more human future. Tweets by @chapinc.',
#   'url': 'https://t.co/9sqEdBcAJs',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/9sqEdBcAJs',
#       'expanded_url': 'http://www.rga.com',
#       'display_url': 'rga.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 167241,
#   'friends_count': 3042,
#   'listed_count': 5970,
#   'created_at': 'Tue Oct 28 16:19:33 +0000 2008',
#   'favourites_count': 25046,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 32630,
#   'lang': None,
#   'status': {'created_at': 'Fri Oct 30 04:38:09 +0000 2020',
#    'id': 1322035038100348928,
#    'id_str': '1322035038100348928',
#    'text': '@karaswisher @TaylorLorenz 1/7',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'karaswisher',
#       'name': 'Kara Swisher',
#       'id': 5763262,
#       'id_str': '5763262',
#       'indices': [0, 12]},
#      {'screen_name': 'TaylorLorenz',
#       'name': 'Taylor Lorenz',
#       'id': 208725869,
#       'id_str': '208725869',
#       'indices': [13, 26]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1322025547527032832,
#    'in_reply_to_status_id_str': '1322025547527032832',
#    'in_reply_to_user_id': 5763262,
#    'in_reply_to_user_id_str': '5763262',
#    'in_reply_to_screen_name': 'karaswisher',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'und'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1280536964987588608/JSRj3_hV_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1280536964987588608/JSRj3_hV_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17023762/1572578296',
#   'profile_link_color': 'E51937',
#   'profile_sidebar_border_color': 'CCCCCC',
#   'profile_sidebar_fill_color': 'E5E5E5',
#   'profile_text_color': '666666',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'user_3': {'id': 1601876689,
#   'id_str': '1601876689',
#   'name': 'Georgia Southern Football',
#   'screen_name': 'GSAthletics_FB',
#   'location': 'Statesboro, Ga.',
#   'description': 'Official Twitter account of the Georgia Southern University Football Team. #HailSouthern #GATA',
#   'url': 'https://t.co/KHfH4jRBea',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/KHfH4jRBea',
#       'expanded_url': 'http://gseagles.com',
#       'display_url': 'gseagles.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 38624,
#   'friends_count': 244,
#   'listed_count': 223,
#   'created_at': 'Wed Jul 17 21:15:39 +0000 2013',
#   'favourites_count': 5386,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 12472,
#   'lang': None,
#   'status': {'created_at': 'Fri Oct 30 04:19:57 +0000 2020',
#    'id': 1322030457903611910,
#    'id_str': '1322030457903611910',
#    'text': 'RT @sammmthehammm: Eagles on top!!! Thanks for the tickets @chadlunsford.          \n\n@GSAthletics_FB https://t.co/un2YKRzTQO',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'sammmthehammm',
#       'name': 'Sam Wilson',
#       'id': 4831532043,
#       'id_str': '4831532043',
#       'indices': [3, 17]},
#      {'screen_name': 'chadlunsford',
#       'name': 'Coach Chad Lunsford',
#       'id': 29611205,
#       'id_str': '29611205',
#       'indices': [59, 72]},
#      {'screen_name': 'GSAthletics_FB',
#       'name': 'Georgia Southern Football',
#       'id': 1601876689,
#       'id_str': '1601876689',
#       'indices': [85, 100]}],
#     'urls': [],
#     'media': [{'id': 1322009978337742848,
#       'id_str': '1322009978337742848',
#       'indices': [101, 124],
#       'media_url': 'http://pbs.twimg.com/media/Eli5EixX0AABcef.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Eli5EixX0AABcef.jpg',
#       'url': 'https://t.co/un2YKRzTQO',
#       'display_url': 'pic.twitter.com/un2YKRzTQO',
#       'expanded_url': 'https://twitter.com/sammmthehammm/status/1322009984557875202/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 418, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 737, 'resize': 'fit'},
#        'large': {'w': 2048, 'h': 1258, 'resize': 'fit'}},
#       'source_status_id': 1322009984557875202,
#       'source_status_id_str': '1322009984557875202',
#       'source_user_id': 4831532043,
#       'source_user_id_str': '4831532043'}]},
#    'extended_entities': {'media': [{'id': 1322009978337742848,
#       'id_str': '1322009978337742848',
#       'indices': [101, 124],
#       'media_url': 'http://pbs.twimg.com/media/Eli5EixX0AABcef.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Eli5EixX0AABcef.jpg',
#       'url': 'https://t.co/un2YKRzTQO',
#       'display_url': 'pic.twitter.com/un2YKRzTQO',
#       'expanded_url': 'https://twitter.com/sammmthehammm/status/1322009984557875202/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 418, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 737, 'resize': 'fit'},
#        'large': {'w': 2048, 'h': 1258, 'resize': 'fit'}},
#       'source_status_id': 1322009984557875202,
#       'source_status_id_str': '1322009984557875202',
#       'source_user_id': 4831532043,
#       'source_user_id_str': '4831532043'}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Oct 30 02:58:36 +0000 2020',
#     'id': 1322009984557875202,
#     'id_str': '1322009984557875202',
#     'text': 'Eagles on top!!! Thanks for the tickets @chadlunsford.          \n\n@GSAthletics_FB https://t.co/un2YKRzTQO',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'chadlunsford',
#        'name': 'Coach Chad Lunsford',
#        'id': 29611205,
#        'id_str': '29611205',
#        'indices': [40, 53]},
#       {'screen_name': 'GSAthletics_FB',
#        'name': 'Georgia Southern Football',
#        'id': 1601876689,
#        'id_str': '1601876689',
#        'indices': [66, 81]}],
#      'urls': [],
#      'media': [{'id': 1322009978337742848,
#        'id_str': '1322009978337742848',
#        'indices': [82, 105],
#        'media_url': 'http://pbs.twimg.com/media/Eli5EixX0AABcef.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Eli5EixX0AABcef.jpg',
#        'url': 'https://t.co/un2YKRzTQO',
#        'display_url': 'pic.twitter.com/un2YKRzTQO',
#        'expanded_url': 'https://twitter.com/sammmthehammm/status/1322009984557875202/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 418, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 737, 'resize': 'fit'},
#         'large': {'w': 2048, 'h': 1258, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1322009978337742848,
#        'id_str': '1322009978337742848',
#        'indices': [82, 105],
#        'media_url': 'http://pbs.twimg.com/media/Eli5EixX0AABcef.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Eli5EixX0AABcef.jpg',
#        'url': 'https://t.co/un2YKRzTQO',
#        'display_url': 'pic.twitter.com/un2YKRzTQO',
#        'expanded_url': 'https://twitter.com/sammmthehammm/status/1322009984557875202/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 418, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 737, 'resize': 'fit'},
#         'large': {'w': 2048, 'h': 1258, 'resize': 'fit'}}}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 14,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '16274F',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1278283941124935685/OycY-I9p_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1278283941124935685/OycY-I9p_normal.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1601876689/1593601618',
#   'profile_link_color': '0084B4',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'user_4': {'id': 867351037,
#   'id_str': '867351037',
#   'name': 'UN GA President',
#   'screen_name': 'UN_PGA',
#   'location': 'New York',
#   'description': 'Official account of Volkan Bozkir, President of the 75th session of the United Nations General Assembly. Instagram: https://t.co/uh2lJrIZsZ',
#   'url': 'https://t.co/8is2Cfrvds',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/8is2Cfrvds',
#       'expanded_url': 'http://www.un.org/pga/',
#       'display_url': 'un.org/pga/',
#       'indices': [0, 23]}]},
#    'description': {'urls': [{'url': 'https://t.co/uh2lJrIZsZ',
#       'expanded_url': 'http://instagram.com/unpga/',
#       'display_url': 'instagram.com/unpga/',
#       'indices': [116, 139]}]}},
#   'protected': False,
#   'followers_count': 146524,
#   'friends_count': 661,
#   'listed_count': 984,
#   'created_at': 'Mon Oct 08 03:20:41 +0000 2012',
#   'favourites_count': 1272,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 11966,
#   'lang': None,
#   'status': {'created_at': 'Thu Oct 29 22:20:40 +0000 2020',
#    'id': 1321940039220289537,
#    'id_str': '1321940039220289537',
#    'text': 'Today I virtually met with PRs of @RussiaUN @ONUVENuevaYork @Chinamission2un @IranUNMission @CUBAONU @NicaraguaONU… https://t.co/oWfTzx9a8C',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'RussiaUN',
#       'name': 'Russian Mission UN',
#       'id': 347443535,
#       'id_str': '347443535',
#       'indices': [34, 43]},
#      {'screen_name': 'ONUVENuevaYork',
#       'name': '🇻🇪Mission of Venezuela to the UN',
#       'id': 3302275342,
#       'id_str': '3302275342',
#       'indices': [44, 59]},
#      {'screen_name': 'Chinamission2un',
#       'name': 'Chinese Mission to UN',
#       'id': 3210919822,
#       'id_str': '3210919822',
#       'indices': [60, 76]},
#      {'screen_name': 'IranUNMission',
#       'name': 'Iran UN Mission',
#       'id': 1034901134,
#       'id_str': '1034901134',
#       'indices': [77, 91]},
#      {'screen_name': 'CUBAONU',
#       'name': 'CUBAONU',
#       'id': 1511622306,
#       'id_str': '1511622306',
#       'indices': [92, 100]},
#      {'screen_name': 'NicaraguaONU',
#       'name': 'Misión Permanente de Nicaragua',
#       'id': 1253359299893616646,
#       'id_str': '1253359299893616646',
#       'indices': [101, 114]}],
#     'urls': [{'url': 'https://t.co/oWfTzx9a8C',
#       'expanded_url': 'https://twitter.com/i/web/status/1321940039220289537',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 16,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '009944',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1305967317839417347/m4J8v8gs_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1305967317839417347/m4J8v8gs_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/867351037/1600201847',
#   'profile_link_color': '005B7F',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'user_5': {'id': 23556859,
#   'id_str': '23556859',
#   'name': 'GENESIS RODRIGUEZ is wearing a mask',
#   'screen_name': 'genirodriguez',
#   'location': 'LA',
#   'description': 'Actor. 305. Miami Heat. Trying to make sense of this with you guys. #BLACKLIVESMATTER #resist also, send memes.',
#   'url': 'https://t.co/dA5AxMQb65',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/dA5AxMQb65',
#       'expanded_url': 'http://Instagram.com/genirodriguez',
#       'display_url': 'Instagram.com/genirodriguez',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 145413,
#   'friends_count': 770,
#   'listed_count': 1034,
#   'created_at': 'Tue Mar 10 04:32:09 +0000 2009',
#   'favourites_count': 16336,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 9726,
#   'lang': None,
#   'status': {'created_at': 'Tue Oct 27 17:34:37 +0000 2020',
#    'id': 1321143278750846977,
#    'id_str': '1321143278750846977',
#    'text': 'Yes!!! Huge endorsement https://t.co/Wiqol1MgS5',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/Wiqol1MgS5',
#       'expanded_url': 'https://twitter.com/amandionair/status/1321116936420425731',
#       'display_url': 'twitter.com/amandionair/st…',
#       'indices': [24, 47]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1321116936420425731,
#    'quoted_status_id_str': '1321116936420425731',
#    'retweet_count': 30,
#    'favorite_count': 126,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'fr'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '9AE4E8',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1273788826322862081/50yg9Xd7_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1273788826322862081/50yg9Xd7_normal.jpg',
#   'profile_link_color': '0084B4',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'DDFFCC',
#   'profile_text_color': '333333',
#   'profile_use_background_image': False,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'user_6': {'id': 1357130180,
#   'id_str': '1357130180',
#   'name': 'Miroslav Lajčák',
#   'screen_name': 'MiroslavLajcak',
#   'location': 'Brussels, Belgium',
#   'description': 'EU Special Representative for the Belgrade-Pristina Dialogue and other Western Balkan regional issues',
#   'url': 'https://t.co/7XwM95d4vm',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/7XwM95d4vm',
#       'expanded_url': 'https://eeas.europa.eu/headquarters/headquarters-homepage_en/3606/EU%20Special%20Representatives',
#       'display_url': 'eeas.europa.eu/headquarters/h…',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 30969,
#   'friends_count': 790,
#   'listed_count': 349,
#   'created_at': 'Tue Apr 16 15:17:17 +0000 2013',
#   'favourites_count': 912,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 4214,
#   'lang': None,
#   'status': {'created_at': 'Thu Oct 29 16:05:40 +0000 2020',
#    'id': 1321845665547325440,
#    'id_str': '1321845665547325440',
#    'text': 'Today we made another step towards a comprehensive normalization agreement by holding a second round of talks on fi… https://t.co/mTnN0HceGM',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/mTnN0HceGM',
#       'expanded_url': 'https://twitter.com/i/web/status/1321845665547325440',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 14,
#    'favorite_count': 33,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '022330',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1314864929455910912/5y7mFvdS_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1314864929455910912/5y7mFvdS_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1357130180/1447059067',
#   'profile_link_color': '0084B4',
#   'profile_sidebar_border_color': 'A8C7F7',
#   'profile_sidebar_fill_color': 'C0DFEC',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'user_7': {'id': 222156383,
#   'id_str': '222156383',
#   'name': 'Georgia Tech Basketball',
#   'screen_name': 'GTMBB',
#   'location': 'Atlanta, GA',
#   'description': 'Official account of Georgia Tech Basketball /// 3 ACC Championships | 2 Final Fours | 16 NCAA Tournaments #BuiltDifferent /// #TogetherWeSwarm 🐝',
#   'url': 'https://t.co/2M1AtSHShj',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/2M1AtSHShj',
#       'expanded_url': 'http://ramblinwreck.com/sports/m-baskbl/',
#       'display_url': 'ramblinwreck.com/sports/m-baskb…',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 18341,
#   'friends_count': 264,
#   'listed_count': 312,
#   'created_at': 'Thu Dec 02 16:29:55 +0000 2010',
#   'favourites_count': 3311,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 19335,
#   'lang': None,
#   'status': {'created_at': 'Thu Oct 29 21:49:42 +0000 2020',
#    'id': 1321932247360925696,
#    'id_str': '1321932247360925696',
#    'text': 'Good things happen when you share the ball. \n\n@GigiberiaSaba ➡️ @AlvaradoJose15 \n\n@AlvaradoJose15 ➡️ @GigiberiaSaba… https://t.co/SZGGfSvtSt',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'GigiberiaSaba',
#       'name': 'saba gigiberia',
#       'id': 1138873622427127808,
#       'id_str': '1138873622427127808',
#       'indices': [46, 60]},
#      {'screen_name': 'AlvaradoJose15',
#       'name': 'RealRyteJose',
#       'id': 2362079219,
#       'id_str': '2362079219',
#       'indices': [64, 79]},
#      {'screen_name': 'AlvaradoJose15',
#       'name': 'RealRyteJose',
#       'id': 2362079219,
#       'id_str': '2362079219',
#       'indices': [82, 97]},
#      {'screen_name': 'GigiberiaSaba',
#       'name': 'saba gigiberia',
#       'id': 1138873622427127808,
#       'id_str': '1138873622427127808',
#       'indices': [101, 115]}],
#     'urls': [{'url': 'https://t.co/SZGGfSvtSt',
#       'expanded_url': 'https://twitter.com/i/web/status/1321932247360925696',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 6,
#    'favorite_count': 32,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/987300037213405187/X8FhVUec_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/987300037213405187/X8FhVUec_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/222156383/1559676110',
#   'profile_link_color': 'B4A269',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'user_8': {'id': 1024901149390921728,
#   'id_str': '1024901149390921728',
#   'name': 'Bad Boys',
#   'screen_name': 'BadBoys',
#   'location': '',
#   'description': '#BADBOYSFORLIFE, starring Will Smith and @RealMartyMar, on\nDigital, 4K UHD, Blu-ray & DVD NOW!',
#   'url': 'https://t.co/bcZyEHu6aE',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/bcZyEHu6aE',
#       'expanded_url': 'http://bit.ly/BadBoysForLifeTW',
#       'display_url': 'bit.ly/BadBoysForLife…',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 21890,
#   'friends_count': 11,
#   'listed_count': 56,
#   'created_at': 'Thu Aug 02 06:14:10 +0000 2018',
#   'favourites_count': 107,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 357,
#   'lang': None,
#   'status': {'created_at': 'Sat Oct 03 00:58:37 +0000 2020',
#    'id': 1312195317698375685,
#    'id_str': '1312195317698375685',
#    'text': '#VanessaHudgens is also in it to win it for the PCAs! ✨ Retweet to vote for her to win #TheFemaleMovieStar and… https://t.co/jInaWNQqMf',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'VanessaHudgens', 'indices': [0, 15]},
#      {'text': 'TheFemaleMovieStar', 'indices': [87, 106]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/jInaWNQqMf',
#       'expanded_url': 'https://twitter.com/i/web/status/1312195317698375685',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [112, 135]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1312195310198812672,
#    'in_reply_to_status_id_str': '1312195310198812672',
#    'in_reply_to_user_id': 1024901149390921728,
#    'in_reply_to_user_id_str': '1024901149390921728',
#    'in_reply_to_screen_name': 'BadBoys',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 99,
#    'favorite_count': 105,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1242168258393821184/lKjcP-3K_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1242168258393821184/lKjcP-3K_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1024901149390921728/1587487860',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'user_9': {'id': 3239365390,
#   'id_str': '3239365390',
#   'name': "GSU Men's Basketball",
#   'screen_name': 'GeorgiaStateMBB',
#   'location': 'Atlanta, GA',
#   'description': 'Official Twitter account for the 2018-19 Sun Belt Conference Regular Season and Tournament Champions 🏆🏆',
#   'url': 'https://t.co/tPYoDar2FD',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/tPYoDar2FD',
#       'expanded_url': 'http://www.georgiastatesports.com/SportSelect.dbml?DB_OEM_ID=12700&SPID=5655&SPSID=53527&DB_OEM_ID=1',
#       'display_url': 'georgiastatesports.com/SportSelect.db…',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 6201,
#   'friends_count': 163,
#   'listed_count': 90,
#   'created_at': 'Wed May 06 19:25:46 +0000 2015',
#   'favourites_count': 799,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 6976,
#   'lang': None,
#   'status': {'created_at': 'Thu Oct 29 21:22:47 +0000 2020',
#    'id': 1321925471861428224,
#    'id_str': '1321925471861428224',
#    'text': 'We have a new #SunBelt Conference schedule that begins Jan. 1.\n\nhttps://t.co/qbML4pW25S\n\n#GSUnited | #OurCity https://t.co/acad2QaEZF',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'SunBelt', 'indices': [14, 22]},
#      {'text': 'GSUnited', 'indices': [89, 98]},
#      {'text': 'OurCity', 'indices': [101, 109]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/qbML4pW25S',
#       'expanded_url': 'https://bit.ly/3e6zUan',
#       'display_url': 'bit.ly/3e6zUan',
#       'indices': [64, 87]}],
#     'media': [{'id': 1321925304366096393,
#       'id_str': '1321925304366096393',
#       'indices': [110, 133],
#       'media_url': 'http://pbs.twimg.com/media/ElhsD3pXYAk2DI0.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/ElhsD3pXYAk2DI0.jpg',
#       'url': 'https://t.co/acad2QaEZF',
#       'display_url': 'pic.twitter.com/acad2QaEZF',
#       'expanded_url': 'https://twitter.com/GeorgiaStateMBB/status/1321925471861428224/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1400, 'h': 788, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1321925304366096393,
#       'id_str': '1321925304366096393',
#       'indices': [110, 133],
#       'media_url': 'http://pbs.twimg.com/media/ElhsD3pXYAk2DI0.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/ElhsD3pXYAk2DI0.jpg',
#       'url': 'https://t.co/acad2QaEZF',
#       'display_url': 'pic.twitter.com/acad2QaEZF',
#       'expanded_url': 'https://twitter.com/GeorgiaStateMBB/status/1321925471861428224/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1400, 'h': 788, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}}}]},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/900444770933379072/I95HoEom_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/900444770933379072/I95HoEom_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3239365390/1573657120',
#   'profile_link_color': '005DAA',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'user_10': {'id': 21336038,
#   'id_str': '21336038',
#   'name': 'City of Atlanta, GA',
#   'screen_name': 'CityofAtlanta',
#   'location': 'Atlanta, GA',
#   'description': 'The Official Twitter account for City of Atlanta government.',
#   'url': 'https://t.co/jeQzJSgP2j',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/jeQzJSgP2j',
#       'expanded_url': 'https://www.atlantaga.gov/',
#       'display_url': 'atlantaga.gov',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 603663,
#   'friends_count': 818,
#   'listed_count': 1588,
#   'created_at': 'Thu Feb 19 20:34:40 +0000 2009',
#   'favourites_count': 9874,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 14606,
#   'lang': None,
#   'status': {'created_at': 'Thu Oct 29 23:00:10 +0000 2020',
#    'id': 1321949978323869696,
#    'id_str': '1321949978323869696',
#    'text': 'TOMORROW (10/30) is the last day to early #vote\xa0 in Georgia. Find your polling place here: https://t.co/ysSjuAKLBS https://t.co/dtTSjPzscn',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'vote', 'indices': [42, 47]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/ysSjuAKLBS',
#       'expanded_url': 'https://www.mvp.sos.ga.gov/MVP/mvp.do',
#       'display_url': 'mvp.sos.ga.gov/MVP/mvp.do',
#       'indices': [91, 114]}],
#     'media': [{'id': 1321949973492236290,
#       'id_str': '1321949973492236290',
#       'indices': [115, 138],
#       'media_url': 'http://pbs.twimg.com/media/EliCfzTXgAIWr_b.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EliCfzTXgAIWr_b.jpg',
#       'url': 'https://t.co/dtTSjPzscn',
#       'display_url': 'pic.twitter.com/dtTSjPzscn',
#       'expanded_url': 'https://twitter.com/CityofAtlanta/status/1321949978323869696/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 936, 'h': 525, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 936, 'h': 525, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 381, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1321949973492236290,
#       'id_str': '1321949973492236290',
#       'indices': [115, 138],
#       'media_url': 'http://pbs.twimg.com/media/EliCfzTXgAIWr_b.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EliCfzTXgAIWr_b.jpg',
#       'url': 'https://t.co/dtTSjPzscn',
#       'display_url': 'pic.twitter.com/dtTSjPzscn',
#       'expanded_url': 'https://twitter.com/CityofAtlanta/status/1321949978323869696/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 936, 'h': 525, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 936, 'h': 525, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 381, 'resize': 'fit'}}}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 26,
#    'favorite_count': 31,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '311BF3',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1118589600539336704/-dRVqqg__normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1118589600539336704/-dRVqqg__normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/21336038/1559703920',
#   'profile_link_color': 'E6CB51',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': '58A8F3',
#   'profile_text_color': '311BF3',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'user_11': {'id': 19360809,
#   'id_str': '19360809',
#   'name': 'GA Dept of Education',
#   'screen_name': 'georgiadeptofed',
#   'location': '',
#   'description': "Follow GA's Superintendent: @SuptWoods. If you're a GA school or district & we don't follow you, tweet & let us know. Fill out your 2020 Census today! ↓",
#   'url': 'https://t.co/QHXLicozzm',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/QHXLicozzm',
#       'expanded_url': 'https://my2020census.gov/',
#       'display_url': 'my2020census.gov',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 38126,
#   'friends_count': 1447,
#   'listed_count': 470,
#   'created_at': 'Thu Jan 22 20:57:39 +0000 2009',
#   'favourites_count': 7646,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 14399,
#   'lang': None,
#   'status': {'created_at': 'Wed Oct 28 20:54:10 +0000 2020',
#    'id': 1321555883168571397,
#    'id_str': '1321555883168571397',
#    'text': 'RT @ValarieLawson15: Professional development with Mary Salvatore from GADOE on Integrated Wellness. Maintaining a healthy, safe, engaged a…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ValarieLawson15',
#       'name': 'Valarie Lawson',
#       'id': 747191825715331073,
#       'id_str': '747191825715331073',
#       'indices': [3, 19]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 28 19:23:13 +0000 2020',
#     'id': 1321532996273451008,
#     'id_str': '1321532996273451008',
#     'text': 'Professional development with Mary Salvatore from GADOE on Integrated Wellness. Maintaining a healthy, safe, engage… https://t.co/ixlIK1Bfne',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ixlIK1Bfne',
#        'expanded_url': 'https://twitter.com/i/web/status/1321532996273451008',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 5,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '4A8C27',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/830061049604890625/TjpDr01O_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/830061049604890625/TjpDr01O_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19360809/1584547528',
#   'profile_link_color': '4A8C27',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'user_12': {'id': 881222783170228224,
#   'id_str': '881222783170228224',
#   'name': 'Carolyn Bourdeaux',
#   'screen_name': 'Carolyn4GA7',
#   'location': 'Suwanee, GA',
#   'description': 'Mom, wife, professor @aysps, former GA Senate budget director, Democrat running to #FinishTheJob in #GA07. Donate here ➡️ https://t.co/FswUd6V6Cs',
#   'url': 'https://t.co/koRHtT20cg',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/koRHtT20cg',
#       'expanded_url': 'http://www.carolyn4congress.com',
#       'display_url': 'carolyn4congress.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': [{'url': 'https://t.co/FswUd6V6Cs',
#       'expanded_url': 'http://bit.ly/FinishTheJob_GA07',
#       'display_url': 'bit.ly/FinishTheJob_G…',
#       'indices': [122, 145]}]}},
#   'protected': False,
#   'followers_count': 71236,
#   'friends_count': 1152,
#   'listed_count': 311,
#   'created_at': 'Sat Jul 01 18:47:38 +0000 2017',
#   'favourites_count': 1100,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 2488,
#   'lang': None,
#   'status': {'created_at': 'Fri Oct 30 00:00:26 +0000 2020',
#    'id': 1321965145338355712,
#    'id_str': '1321965145338355712',
#    'text': "Happy 5 days until Election Day from my nieces! I'm fighting for a world where they have clean air to breath, great… https://t.co/RiGSaAgUhY",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/RiGSaAgUhY',
#       'expanded_url': 'https://twitter.com/i/web/status/1321965145338355712',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 70,
#    'favorite_count': 237,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1234502372459732993/dK9E-wBt_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1234502372459732993/dK9E-wBt_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/881222783170228224/1538429957',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'user_13': {'id': 121546530,
#   'id_str': '121546530',
#   'name': 'Everything Georgia',
#   'screen_name': 'GAFollowers',
#   'location': 'Georgia, USA',
#   'description': 'Tweets for Georgians and other lovers of the Peach State. 📧 info@gafollowers.com DM FOR PROMO',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 1550772,
#   'friends_count': 59727,
#   'listed_count': 1341,
#   'created_at': 'Tue Mar 09 21:07:28 +0000 2010',
#   'favourites_count': 1616,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 75916,
#   'lang': None,
#   'status': {'created_at': 'Thu Oct 29 23:20:00 +0000 2020',
#    'id': 1321954970598473728,
#    'id_str': '1321954970598473728',
#    'text': 'This is the reality I choose to live in. https://t.co/cBywABw5TA',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
# ...
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 6,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'FFFFFF',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1441100920/castingga6_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1441100920/castingga6_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/282583021/1398659604',
#   'profile_link_color': 'F06E18',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'FAAF3F',
#   'profile_text_color': '0A0A0A',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'user_17': {'id': 1003862198,
#   'id_str': '1003862198',
#   'name': 'Ga a fele maatla link on bio. Be blessed 🙏🏽',
#   'screen_name': 'DrWinnieMashaba',
#   'location': 'South Africa ',
#   'description': 'Winnie Mashaba: Ga A fele maatla video https://t.co/djYS6sG4ev 📧 bookings@tswakomusic.co.za',
#   'url': 'https://t.co/viF32zcUt3',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/viF32zcUt3',
#       'expanded_url': 'http://www.winniemashaba.com',
#       'display_url': 'winniemashaba.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': [{'url': 'https://t.co/djYS6sG4ev',
#       'expanded_url': 'https://youtu.be/Gtyhwgv4yy4',
#       'display_url': 'youtu.be/Gtyhwgv4yy4',
#       'indices': [39, 62]}]}},
#   'protected': False,
#   'followers_count': 47231,
#   'friends_count': 1887,
#   'listed_count': 112,
#   'created_at': 'Tue Dec 11 11:41:31 +0000 2012',
#   'favourites_count': 3414,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 8598,
#   'lang': None,
#   'status': {'created_at': 'Tue Oct 27 08:32:55 +0000 2020',
#    'id': 1321006954391785473,
#    'id_str': '1321006954391785473',
#    'text': 'https://t.co/hyIVymV23W\n\nPlease follow the link above and select my name to vote 🙏🏽🙏🏽 https://t.co/lLmDlwOQtB',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/hyIVymV23W',
#       'expanded_url': 'https://vote.africanentertainmentawards.org/',
#       'display_url': 'vote.africanentertainmentawards.org',
#       'indices': [0, 23]}],
#     'media': [{'id': 1321006948448423936,
#       'id_str': '1321006948448423936',
#       'indices': [86, 109],
#       'media_url': 'http://pbs.twimg.com/media/ElUo0hQXUAAoutl.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/ElUo0hQXUAAoutl.jpg',
#       'url': 'https://t.co/lLmDlwOQtB',
#       'display_url': 'pic.twitter.com/lLmDlwOQtB',
#       'expanded_url': 'https://twitter.com/DrWinnieMashaba/status/1321006954391785473/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 400, 'h': 400, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 400, 'h': 400, 'resize': 'fit'},
#        'small': {'w': 400, 'h': 400, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1321006948448423936,
#       'id_str': '1321006948448423936',
#       'indices': [86, 109],
#       'media_url': 'http://pbs.twimg.com/media/ElUo0hQXUAAoutl.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/ElUo0hQXUAAoutl.jpg',
#       'url': 'https://t.co/lLmDlwOQtB',
#       'display_url': 'pic.twitter.com/lLmDlwOQtB',
#       'expanded_url': 'https://twitter.com/DrWinnieMashaba/status/1321006954391785473/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 400, 'h': 400, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 400, 'h': 400, 'resize': 'fit'},
#        'small': {'w': 400, 'h': 400, 'resize': 'fit'}}}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': 'a6de57f8441398d4',
#     'url': 'https://api.twitter.com/1.1/geo/id/a6de57f8441398d4.json',
#     'place_type': 'city',
#     'name': 'Soshanguve',
#     'full_name': 'Soshanguve, South Africa',
#     'country_code': 'ZA',
#     'country': 'South Africa',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[28.0390226, -25.6078888],
#        [28.1503403, -25.6078888],
#        [28.1503403, -25.367145],
#        [28.0390226, -25.367145]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 13,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1321005786722684929/BNGqWzL8_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1321005786722684929/BNGqWzL8_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1003862198/1584428990',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'user_18': {'id': 751067894,
#   'id_str': '751067894',
#   'name': 'Gagan Narang',
#   'screen_name': 'gaGunNarang',
#   'location': 'India',
#   'description': 'Rifle Shooter| Olympic medallist|4x Olympian| 15 Commonwealth and Asian Games medals |Former World No 1| World record Holder |Padmashri,KhelRatna,Arjuna Awardee',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 181649,
#   'friends_count': 733,
#   'listed_count': 111,
#   'created_at': 'Sat Aug 11 10:34:47 +0000 2012',
#   'favourites_count': 5259,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 1082,
#   'lang': None,
#   'status': {'created_at': 'Thu Oct 15 12:41:56 +0000 2020',
#    'id': 1316720964353155072,
#    'id_str': '1316720964353155072',
#    'text': 'These guns were to be used for our Telangana range project. Rain in the last 2 days dealt a heavy blow to our plans… https://t.co/LQsbESCW1G',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/LQsbESCW1G',
#       'expanded_url': 'https://twitter.com/i/web/status/1316720964353155072',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 49,
#    'favorite_count': 119,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1214640941056708610/ljoTxLOE_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1214640941056708610/ljoTxLOE_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/751067894/1587176761',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'user_19': {'id': 30928148,
#   'id_str': '30928148',
#   'name': 'GAForestryCommission',
#   'screen_name': 'GaTrees',
#   'location': 'Macon, GA',
#   'description': "State agency providing leadership, service and education in the protection and conservation of GA's forest resources",
#   'url': 'https://t.co/rGvem5kIZ7',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/rGvem5kIZ7',
#       'expanded_url': 'http://www.GaTrees.org',
#       'display_url': 'GaTrees.org',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 4222,
#   'friends_count': 620,
#   'listed_count': 131,
#   'created_at': 'Mon Apr 13 18:50:24 +0000 2009',
#   'favourites_count': 2083,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 4271,
#   'lang': None,
#   'status': {'created_at': 'Sun Oct 25 12:56:40 +0000 2020',
#    'id': 1320348551432540161,
#    'id_str': '1320348551432540161',
#    'text': 'It’s a highlight for us, too. Thanks for having us on!! 🍁 🍂 https://t.co/WVMN4kJUVr',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/WVMN4kJUVr',
#       'expanded_url': 'https://twitter.com/AshleyFrascaWSB/status/1319958076104073216',
#       'display_url': 'twitter.com/AshleyFrascaWS…',
#       'indices': [60, 83]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1319958076104073216,
#    'quoted_status_id_str': '1319958076104073216',
#    'retweet_count': 0,
#    'favorite_count': 9,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '0099B9',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/596901474/Final_GFC_Logo.PMS_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/596901474/Final_GFC_Logo.PMS_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/30928148/1561483233',
#   'profile_link_color': '0099B9',
#   'profile_sidebar_border_color': '5ED4DC',
#   'profile_sidebar_fill_color': '95E8EC',
#   'profile_text_color': '3C3940',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'user_20': {'id': 2811455407,
#   'id_str': '2811455407',
#   'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'location': 'Georgia, USA',
#   'description': 'Good tweets are my own. Bad tweets are written by my junior staffer.',
#   'url': 'https://t.co/44B4yu8c2V',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/44B4yu8c2V',
#       'expanded_url': 'http://joebiden.com/donate',
#       'display_url': 'joebiden.com/donate',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 20727,
#   'friends_count': 8055,
#   'listed_count': 268,
#   'created_at': 'Mon Sep 15 14:31:44 +0000 2014',
#   'favourites_count': 100450,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 39189,
#   'lang': None,
#   'status': {'created_at': 'Fri Oct 30 03:47:06 +0000 2020',
#    'id': 1322022189584011264,
#    'id_str': '1322022189584011264',
#    'text': 'RT @jdmaccoby: The Dem strategy is to vote and the GOP strategy is to stop people voting and we should quit acting like these are equally v…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'jdmaccoby',
#       'name': 'Jake Maccoby',
#       'id': 102745381,
#       'id_str': '102745381',
#       'indices': [3, 13]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 29 12:47:27 +0000 2020',
#     'id': 1321795785898557440,
#     'id_str': '1321795785898557440',
#     'text': 'The Dem strategy is to vote and the GOP strategy is to stop people voting and we should quit acting like these are equally valid',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 15497,
#     'favorite_count': 63857,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 15497,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1319430244135280646/8suOeWFO_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1319430244135280646/8suOeWFO_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2811455407/1598976840',
#   'profile_link_color': '3B94D9',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'}}

# %%
function1_test1.keys()
# Out:
# dict_keys(['user_1', 'user_2', 'user_3', 'user_4', 'user_5', 'user_6', 'user_7', 'user_8', 'user_9', 'user_10', 'user_11', 'user_12', 'user_13', 'user_14', 'user_15', 'user_16', 'user_17', 'user_18', 'user_19', 'user_20'])

# %%
for i in function1_test1:
    print(function1_test1[i]['name'])
# Out:
# General Assembly
# R/GA
# Georgia Southern Football
# UN GA President
# GENESIS RODRIGUEZ is wearing a mask
# Miroslav Lajčák
# Georgia Tech Basketball
# Bad Boys
# GSU Men's Basketball
# City of Atlanta, GA
# GA Dept of Education
# Carolyn Bourdeaux
# Everything Georgia
# Georgia House of Representatives
# Stany G A
# Casting GA
# Ga a fele maatla link on bio. Be blessed 🙏🏽
# Gagan Narang
# GAForestryCommission
# Adam VOTE EARLY Smith

# %%
function1_test2.keys()
# Out:
# dict_keys(['user_1', 'user_2', 'user_3', 'user_4', 'user_5', 'user_6', 'user_7', 'user_8', 'user_9', 'user_10', 'user_11', 'user_12', 'user_13', 'user_14', 'user_15', 'user_16', 'user_17', 'user_18', 'user_19', 'user_20'])

# %%
for i in function1_test2:
    print(function1_test2[i]['name'])
# Out:
# General Assembly
# R/GA
# Georgia Southern Football
# UN GA President
# GENESIS RODRIGUEZ is wearing a mask
# Miroslav Lajčák
# Georgia Tech Basketball
# Bad Boys
# GSU Men's Basketball
# City of Atlanta, GA
# GA Dept of Education
# Carolyn Bourdeaux
# Everything Georgia
# Georgia House of Representatives
# Stany G A
# Casting GA
# Ga a fele maatla link on bio. Be blessed 🙏🏽
# Gagan Narang
# GAForestryCommission
# Adam VOTE EARLY Smith

# %%
for i in function1_test3:
    print(function1_test3[i]['name'])
# Out:
# Adam VOTE EARLY Smith
# Adam VOTE EARLY Smith
# Adam VOTE EARLY Smith
# Adam VOTE EARLY Smith
# Adam VOTE EARLY Smith
# Adam VOTE EARLY Smith
# Adam VOTE EARLY Smith
# Adam VOTE EARLY Smith
# Adam VOTE EARLY Smith
# Adam VOTE EARLY Smith
# Adam VOTE EARLY Smith
# Adam VOTE EARLY Smith
# Adam VOTE EARLY Smith
# Adam VOTE EARLY Smith
# Adam VOTE EARLY Smith
# Adam VOTE EARLY Smith
# Adam VOTE EARLY Smith
# Adam VOTE EARLY Smith
# Adam VOTE EARLY Smith
# Adam VOTE EARLY Smith

# %%
function1_test3.keys()
# Out:
# dict_keys(['user_1', 'user_2', 'user_3', 'user_4', 'user_5', 'user_6', 'user_7', 'user_8', 'user_9', 'user_10', 'user_11', 'user_12', 'user_13', 'user_14', 'user_15', 'user_16', 'user_17', 'user_18', 'user_19', 'user_20'])

# %%
function1_test3
# Out:
# {'user_1': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055},
#  'user_2': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055},
#  'user_3': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055},
#  'user_4': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055},
#  'user_5': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055},
#  'user_6': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055},
#  'user_7': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055},
#  'user_8': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055},
#  'user_9': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055},
#  'user_10': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055},
#  'user_11': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055},
#  'user_12': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055},
#  'user_13': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055},
#  'user_14': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055},
#  'user_15': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055},
#  'user_16': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055},
#  'user_17': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055},
#  'user_18': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055},
#  'user_19': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055},
#  'user_20': {'name': 'Adam VOTE EARLY Smith',
#   'screen_name': 'AdamJSmithGA',
#   'followers_count': 20727,
#   'friends_count': 8055}}

# %%
# Up to trying to figure out how to sort out the keys in the first function
