# %%
# Set up key libraries / tokens

# %%
import requests 
from requests_oauthlib import OAuth1
import os
import pandas as pd

# %%
API_PUBLIC = os.environ.get("TW_API_KEY")
API_SECRET = os.environ.get("TW_API_SECRET_KEY")
APP_PUBLIC = os.environ.get("TW_PRS_GA_HW_ACCESS_TOKEN")
APP_SECRET = os.environ.get("TW_PRS_GA_HW_ACCESS_TOKEN_SECRET")

# %%
url = 'https://api.twitter.com/1.1/account/verify_credentials.json'
auth = OAuth1(
            API_PUBLIC, #'USER_OAUTH_TOKEN', 
            API_SECRET, #'USER_OAUTH_TOKEN_SECRET'
            APP_PUBLIC, #'YOUR_APP_KEY', 
            APP_SECRET #'YOUR_APP_SECRET',
            )

# %%
# Check authorisation is working properly

# %%
check_auth = requests.get(url, auth=auth)

# %%
check_auth.reason
# Out:
# 'OK'

# %%
check_auth.status_code
# Out:
# 200

# %% [markdown]
# # Function 4

# %% [markdown]
# **Name:** `friends_of_friends`
#
# **Returns:** list of data objects for each user that two Twitter users have in common
#
# **Arguments:**
#
#  - `names`: list, required; list of two Twitter users to compare friends list with
#  - `keys`: list, optional; list of keys to return for information about each user.  Default value should be to return the entire data object.
#  - `to_df`: bool, required; default value: False; if True, returns results in a dataframe.
#
# **To Test:** We'll test your function in the following ways:
#
#  - `friends_of_friends(['Beyonce', 'MariahCarey'])`
#  - `friends_of_friends(['@Beyonce', '@MariahCarey'], to_df=True)`
#  - `friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'])`
#  - `friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'], to_df=True)`
#
# Each of these should return 3 results. (Assuming they haven't followed the same people since this was last written).
#
# **Hint:** The `id` key is the unique identifier for someone, so if you want to check if two people are the same this is the best way to do it.

# %%
def friend_of_friends(
    names,
    keys = [], 
    to_df = False,
    auth=auth
    ):
    
    if len(names) != 2:
        print("You can only enter two names as a list.")
    
    # Checks on screen_name input
    if names[0][0] == '@':
        names[0] = names[0][1:]    

    if names[1][0] == '@':
        names[1] = names[1][1:]       

        
    # Get overall list for first name
    # Go and get results, adding users to an overall list
    friends_list_0 = []
    cursor = -1
    while cursor != 0:
        find_friends_0_url = (
                        'https://api.twitter.com/1.1/friends/list.json'
                         + "?screen_name=" + names[0]
                         + "&cursor=" + str(cursor)
                         + "&count=200" 
                        )
        friends_0_output = requests.get(find_friends_0_url, auth=auth)
        if friends_0_output.status_code == 429:
            print("Reached max API requests.\n"
                  + "Setting cursor to 0 to exit loop.\n"
                  + "friends_0s found so far will be output."
                 )
            cursor = 0
        else:
            friends_0_output_dict = friends_0_output.json()
            cursor = friends_0_output_dict['next_cursor']
            [friends_list_0.append(user) for user in friends_0_output_dict['users']]

            
    # Get overall list for second name
    friends_list_1 = []
    cursor = -1
    while cursor != 0:
        find_friends_1_url = (
                        'https://api.twitter.com/1.1/friends/list.json'
                         + "?screen_name=" + names[1]
                         + "&cursor=" + str(cursor)
                         + "&count=200" 
                        )
        friends_1_output = requests.get(find_friends_1_url, auth=auth)
        if friends_1_output.status_code == 429:
            print("Reached max API requests.\n"
                  + "Setting cursor to 0 to exit loop.\n"
                  + "friends_1s found so far will be output."
                 )
            cursor = 0
        else:
            friends_1_output_dict = friends_1_output.json()
            cursor = friends_1_output_dict['next_cursor']
            [friends_list_1.append(user) for user in friends_1_output_dict['users']]
    
    # Get list of ids for both sets of friends
    name_0_friends_ids = [i['id'] for i in friends_list_0]
    name_1_friends_ids = [i['id'] for i in friends_list_1]

    # Find common ids
    common_friends_list = []
    if len(name_0_friends_ids) < len(name_1_friends_ids):
        common_friend_ids = [i for i in name_0_friends_ids if i in name_1_friends_ids]
        common_friends_list = [i for i in friends_list_0 if i['id'] in common_friend_ids]
        
    else:
        common_friend_ids = [i for i in name_1_friends_ids if i in name_0_friends_ids]
        common_friends_list = [i for i in friends_list_1 if i['id'] in common_friend_ids]
        
    # Limit the friends_list_0 to the specific keys required
    common_friends_list_keys = []
    
    if not keys:
        common_friends_list_keys = common_friends_list
    else:
        for user in common_friends_list:
            temp_dict = {}
            for k in keys:
                temp_dict.update({k:user[k]})
            common_friends_list_keys.append(temp_dict)    
    
    # Put results into a pandas dataframe
    
    
    # Allow for pandas data frame
    if to_df == False:
        return_object = common_friends_list_keys
    elif to_df == True:
        # Loop through each potential column, and add to dictionary
        prep_df_dict = {}
        
        # Check if keys have been designated, if not add them back
        if not keys:
            keys_found = []
            for u in common_friends_list_keys:
                for k in u.keys():
                    keys_found.append(k)
            keys = list(set(keys_found)) # dedupe the keys
            keys.sort()
            
        # Set up the columns
        for k in keys:
            temp_list = [i.get(k,'No value returned.') for i in common_friends_list_keys]
            prep_df_dict.update({k:temp_list})
        
        #Add data to the data frame
        user_df = pd.DataFrame(data=prep_df_dict)
        
        return_object = user_df
    else:
        return_object = 'to_df argument only accpets True or False'
                
    return return_object

# %%
friend_of_friends(['@Beyonce', 'MariahCarey'])
# Out:
# Beyonce
# MariahCarey

# %%
url_friends_list_1 = (
    'https://api.twitter.com/1.1/friends/list.json'
    + '?screen_name=' + 'prsinkis'
    + '&count=200'
    + '&curosr=' + str(-1)
)

friends_list_sample = requests.get(url_friends_list_1, auth=auth)

# %%
friends_list_sample.status_code
# Out:
# 200

# %%
friends_list_sample.json()
# Out:
# {'users': [{'id': 2584388417,
#    'id_str': '2584388417',
#    'name': 'HarryMTG',
#    'screen_name': 'harrymtg',
#    'location': 'England',
#    'description': 'https://t.co/74p2Rg6Ayq | Talker @MidweekMetagame | https://t.co/WAqRVq021W | harrymtgtwitch@gmail.com | @Mana_Traders Code: HarryMTG |',
#    'url': 'https://t.co/1XYJAMkvkM',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/1XYJAMkvkM',
#        'expanded_url': 'http://www.youtube.com/c/harrymtg',
#        'display_url': 'youtube.com/c/harrymtg',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/74p2Rg6Ayq',
#        'expanded_url': 'http://twitch.tv/harrymtg',
#        'display_url': 'twitch.tv/harrymtg',
#        'indices': [0, 23]},
#       {'url': 'https://t.co/WAqRVq021W',
#        'expanded_url': 'http://discord.gg/tWuhYwp',
#        'display_url': 'discord.gg/tWuhYwp',
#        'indices': [52, 75]}]}},
#    'protected': False,
#    'followers_count': 1499,
#    'friends_count': 187,
#    'listed_count': 20,
#    'created_at': 'Thu Jun 05 14:49:18 +0000 2014',
#    'favourites_count': 4056,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1739,
#    'lang': None,
#    'status': {'created_at': 'Sun Nov 01 14:57:16 +0000 2020',
#     'id': 1322915615682793472,
#     'id_str': '1322915615682793472',
#     'text': 'Managed to win round 1 against rogues but then quickly died to Mono Red &amp; then Gruul!\n\nWill be talking about the to… https://t.co/5PTQPIyLaP',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/5PTQPIyLaP',
#        'expanded_url': 'https://twitter.com/i/web/status/1322915615682793472',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [121, 144]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1322717644286550016,
#     'quoted_status_id_str': '1322717644286550016',
#     'retweet_count': 0,
#     'favorite_count': 8,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1296894051698999296/8j-cq0I0_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1296894051698999296/8j-cq0I0_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2584388417/1601560553',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1109902312296857602,
#    'id_str': '1109902312296857602',
#    'name': 'Midweek Metagame',
#    'screen_name': 'MidweekMetagame',
#    'location': '',
#    'description': 'A weekly Competitive MTG podcast by @gabnassif, @ghett_smart & @harrymtg, available on all Podcast Apps! \n\nInquiries: midweekmodern@gmail.com',
#    'url': 'https://t.co/8qlSNPPDmX',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8qlSNPPDmX',
#        'expanded_url': 'https://fanlink.to/MidweekMetagame',
#        'display_url': 'fanlink.to/MidweekMetagame',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 817,
#    'friends_count': 3,
#    'listed_count': 7,
#    'created_at': 'Sun Mar 24 19:38:27 +0000 2019',
#    'favourites_count': 320,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 262,
#    'lang': None,
#    'status': {'created_at': 'Sun Nov 01 01:52:24 +0000 2020',
#     'id': 1322718097804066816,
#     'id_str': '1322718097804066816',
#     'text': 'RT @harrymtg: Hey @gabnassif have I done you proud? https://t.co/V7h1dmUTTZ',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'harrymtg',
#        'name': 'HarryMTG',
#        'id': 2584388417,
#        'id_str': '2584388417',
#        'indices': [3, 12]},
#       {'screen_name': 'gabnassif',
#        'name': 'Gabriel Nassif',
#        'id': 108835475,
#        'id_str': '108835475',
#        'indices': [18, 28]}],
#      'urls': [],
#      'media': [{'id': 1322717367915417601,
#        'id_str': '1322717367915417601',
#        'indices': [52, 75],
#        'media_url': 'http://pbs.twimg.com/media/Els8cCTWkAE67hr.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Els8cCTWkAE67hr.jpg',
#        'url': 'https://t.co/V7h1dmUTTZ',
#        'display_url': 'pic.twitter.com/V7h1dmUTTZ',
#        'expanded_url': 'https://twitter.com/harrymtg/status/1322717644286550016/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1895, 'h': 1080, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 684, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 388, 'resize': 'fit'}},
#        'source_status_id': 1322717644286550016,
#        'source_status_id_str': '1322717644286550016',
#        'source_user_id': 2584388417,
#        'source_user_id_str': '2584388417'}]},
#     'extended_entities': {'media': [{'id': 1322717367915417601,
#        'id_str': '1322717367915417601',
#        'indices': [52, 75],
#        'media_url': 'http://pbs.twimg.com/media/Els8cCTWkAE67hr.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Els8cCTWkAE67hr.jpg',
#        'url': 'https://t.co/V7h1dmUTTZ',
#        'display_url': 'pic.twitter.com/V7h1dmUTTZ',
#        'expanded_url': 'https://twitter.com/harrymtg/status/1322717644286550016/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1895, 'h': 1080, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 684, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 388, 'resize': 'fit'}},
#        'source_status_id': 1322717644286550016,
#        'source_status_id_str': '1322717644286550016',
#        'source_user_id': 2584388417,
#        'source_user_id_str': '2584388417'}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sun Nov 01 01:50:35 +0000 2020',
#      'id': 1322717644286550016,
#      'id_str': '1322717644286550016',
#      'text': 'Hey @gabnassif have I done you proud? https://t.co/V7h1dmUTTZ',
#      'truncated': False,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [{'screen_name': 'gabnassif',
#         'name': 'Gabriel Nassif',
#         'id': 108835475,
#         'id_str': '108835475',
#         'indices': [4, 14]}],
#       'urls': [],
#       'media': [{'id': 1322717367915417601,
#         'id_str': '1322717367915417601',
#         'indices': [38, 61],
#         'media_url': 'http://pbs.twimg.com/media/Els8cCTWkAE67hr.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/Els8cCTWkAE67hr.jpg',
#         'url': 'https://t.co/V7h1dmUTTZ',
#         'display_url': 'pic.twitter.com/V7h1dmUTTZ',
#         'expanded_url': 'https://twitter.com/harrymtg/status/1322717644286550016/photo/1',
#         'type': 'photo',
#         'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'large': {'w': 1895, 'h': 1080, 'resize': 'fit'},
#          'medium': {'w': 1200, 'h': 684, 'resize': 'fit'},
#          'small': {'w': 680, 'h': 388, 'resize': 'fit'}}}]},
#      'extended_entities': {'media': [{'id': 1322717367915417601,
#         'id_str': '1322717367915417601',
#         'indices': [38, 61],
#         'media_url': 'http://pbs.twimg.com/media/Els8cCTWkAE67hr.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/Els8cCTWkAE67hr.jpg',
#         'url': 'https://t.co/V7h1dmUTTZ',
#         'display_url': 'pic.twitter.com/V7h1dmUTTZ',
#         'expanded_url': 'https://twitter.com/harrymtg/status/1322717644286550016/photo/1',
#         'type': 'photo',
#         'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'large': {'w': 1895, 'h': 1080, 'resize': 'fit'},
#          'medium': {'w': 1200, 'h': 684, 'resize': 'fit'},
#          'small': {'w': 680, 'h': 388, 'resize': 'fit'}}}]},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 1,
#      'favorite_count': 25,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1257328282229448709/4KGfjcqd_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1257328282229448709/4KGfjcqd_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1109902312296857602/1574199467',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1095142349468913664,
#    'id_str': '1095142349468913664',
#    'name': 'Kyle Gibson',
#    'screen_name': 'KyleGbsn',
#    'location': 'Melbourne, Victoria',
#    'description': 'Chemical Engineering Graduate.\nChemistry Honours Student.\nMany interests.\nWinner of MTG Grand Prix Brisbane 2019!\nHe/Him',
#    'url': 'https://t.co/yMz0k3iZ9i',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/yMz0k3iZ9i',
#        'expanded_url': 'http://twitch.tv/ninja__kyle',
#        'display_url': 'twitch.tv/ninja__kyle',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 45,
#    'friends_count': 112,
#    'listed_count': 0,
#    'created_at': 'Tue Feb 12 02:07:37 +0000 2019',
#    'favourites_count': 203,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 59,
#    'lang': None,
#    'status': {'created_at': 'Wed Aug 26 08:35:32 +0000 2020',
#     'id': 1298539563850194944,
#     'id_str': '1298539563850194944',
#     'text': "RT @FactionMTGPod: After a week off, we're back now with episode 5! \nFind it on Spotify, iTunes, Soundcloud or wherever else you listen to…",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'FactionMTGPod',
#        'name': 'The Faction MTG Podcast',
#        'id': 1286309146950696960,
#        'id_str': '1286309146950696960',
#        'indices': [3, 17]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Wed Aug 26 05:47:20 +0000 2020',
#      'id': 1298497236469342211,
#      'id_str': '1298497236469342211',
#      'text': "After a week off, we're back now with episode 5! \nFind it on Spotify, iTunes, Soundcloud or wherever else you liste… https://t.co/Gbj314nv9c",
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/Gbj314nv9c',
#         'expanded_url': 'https://twitter.com/i/web/status/1298497236469342211',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 1,
#      'favorite_count': 3,
#      'favorited': False,
#      'retweeted': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1227517168180285440/stFIbJC1_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1227517168180285440/stFIbJC1_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 19050000,
#    'id_str': '19050000',
#    'name': 'Financial Review',
#    'screen_name': 'FinancialReview',
#    'location': 'Australia',
#    'description': 'For 60 years, The Australian Financial Review has been the authority on business, finance and political news in Australia.',
#    'url': 'https://t.co/052NrHCuPX',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/052NrHCuPX',
#        'expanded_url': 'http://www.afr.com/',
#        'display_url': 'afr.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 309797,
#    'friends_count': 399,
#    'listed_count': 3425,
#    'created_at': 'Fri Jan 16 01:56:49 +0000 2009',
#    'favourites_count': 365,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 197042,
#    'lang': None,
#    'status': {'created_at': 'Sun Nov 01 21:53:42 +0000 2020',
#     'id': 1323020415414009864,
#     'id_str': '1323020415414009864',
#     'text': 'Female workers bore the brunt of the economic shutdowns, but as male-dominated industries atrophy men will be hit h… https://t.co/jnzg99pHu9',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/jnzg99pHu9',
#        'expanded_url': 'https://twitter.com/i/web/status/1323020415414009864',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="https://www.echobox.com" rel="nofollow">Echobox</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/818701236086018050/SlypZOjt_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/818701236086018050/SlypZOjt_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19050000/1589246337',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '84C9EB',
#    'profile_sidebar_fill_color': 'EDEDED',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 14787749,
#    'id_str': '14787749',
#    'name': 'CommBank',
#    'screen_name': 'CommBank',
#    'location': 'Australia',
#    'description': 'Follow @CommBank for the latest news, offers, and support. Community guidelines at https://t.co/WFpwBBPJVe.',
#    'url': 'http://t.co/InqHwfD7ku',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/InqHwfD7ku',
#        'expanded_url': 'http://www.commbank.com.au/social',
#        'display_url': 'commbank.com.au/social',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'https://t.co/WFpwBBPJVe',
#        'expanded_url': 'http://cba.co/CommunityGuidelines',
#        'display_url': 'cba.co/CommunityGuide…',
#        'indices': [83, 106]}]}},
#    'protected': False,
#    'followers_count': 93641,
#    'friends_count': 4235,
#    'listed_count': 496,
#    'created_at': 'Thu May 15 15:53:53 +0000 2008',
#    'favourites_count': 1068,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 58577,
#    'lang': None,
#    'status': {'created_at': 'Sun Nov 01 11:12:48 +0000 2020',
#     'id': 1322859126997749761,
#     'id_str': '1322859126997749761',
#     'text': '@18ocram Hi Stanley, please log on to NetBank and option will be there under Transfers and BPay tab.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': '18ocram',
#        'name': 'Stanley',
#        'id': 2478346212,
#        'id_str': '2478346212',
#        'indices': [0, 8]}],
#      'urls': []},
#     'source': '<a href="https://www.lithium.com" rel="nofollow">Lithium Tech.</a>',
#     'in_reply_to_status_id': 1322858391325167617,
#     'in_reply_to_status_id_str': '1322858391325167617',
#     'in_reply_to_user_id': 2478346212,
#     'in_reply_to_user_id_str': '2478346212',
#     'in_reply_to_screen_name': '18ocram',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1315155996965138432/JPaYOg7t_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1315155996965138432/JPaYOg7t_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14787749/1602392601',
#    'profile_link_color': 'F2B935',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': 'BDBBBD',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'regular'},
#   {'id': 300538480,
#    'id_str': '300538480',
#    'name': 'ANZ Australia',
#    'screen_name': 'ANZ_AU',
#    'location': 'Australia',
#    'description': 'Our team is here to share updates & offer assistance so reach out to us online or give us a call on 13 13 14.',
#    'url': 'https://t.co/VJcpopQH66',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/VJcpopQH66',
#        'expanded_url': 'http://anz.com/covid-19',
#        'display_url': 'anz.com/covid-19',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 126591,
#    'friends_count': 8000,
#    'listed_count': 563,
#    'created_at': 'Tue May 17 23:01:02 +0000 2011',
#    'favourites_count': 5882,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 41665,
#    'lang': None,
#    'status': {'created_at': 'Sun Nov 01 21:22:56 +0000 2020',
#     'id': 1323012673848553473,
#     'id_str': '1323012673848553473',
#     'text': '@mthomps3  Hi Matthew, we’re sorry to hear you have not received your funds , we’re working to get your money to yo… https://t.co/8BgnfqLg5G',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'mthomps3',
#        'name': 'Matthew Thompson',
#        'id': 46436291,
#        'id_str': '46436291',
#        'indices': [0, 9]}],
#      'urls': [{'url': 'https://t.co/8BgnfqLg5G',
#        'expanded_url': 'https://twitter.com/i/web/status/1323012673848553473',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="http://lexer.io" rel="nofollow">Lexer </a>',
#     'in_reply_to_status_id': 1322996557638062080,
#     'in_reply_to_status_id_str': '1322996557638062080',
#     'in_reply_to_user_id': 46436291,
#     'in_reply_to_user_id_str': '46436291',
#     'in_reply_to_screen_name': 'mthomps3',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1235074934486863873/eg1LRJgo_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1235074934486863873/eg1LRJgo_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300538480/1597035850',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'regular'},
#   {'id': 14686881,
#    'id_str': '14686881',
#    'name': 'Westpac Bank',
#    'screen_name': 'Westpac',
#    'location': 'Australia',
#    'description': 'Proudly supporting Australians for 200 years, here with news and support 24/7.   Social guidelines: https://t.co/VjFHD2m0LF  ABN 33007457141 AFSL/ACL 233714',
#    'url': 'https://t.co/Uss4XOb6vF',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/Uss4XOb6vF',
#        'expanded_url': 'http://www.westpac.com.au',
#        'display_url': 'westpac.com.au',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/VjFHD2m0LF',
#        'expanded_url': 'http://westpac.com.au/socialmedia',
#        'display_url': 'westpac.com.au/socialmedia',
#        'indices': [100, 123]}]}},
#    'protected': False,
#    'followers_count': 59357,
#    'friends_count': 2212,
#    'listed_count': 645,
#    'created_at': 'Wed May 07 14:19:22 +0000 2008',
#    'favourites_count': 1839,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 35927,
#    'lang': None,
#    'status': {'created_at': 'Sun Nov 01 02:03:24 +0000 2020',
#     'id': 1322720868473032704,
#     'id_str': '1322720868473032704',
#     'text': '@PipStocks Thanks, Pip. I’ve responded to your PM. ^Sami',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'PipStocks',
#        'name': 'Pip Stocks, GAICD',
#        'id': 222682211,
#        'id_str': '222682211',
#        'indices': [0, 10]}],
#      'urls': []},
#     'source': '<a href="http://lexer.io" rel="nofollow">Lexer </a>',
#     'in_reply_to_status_id': 1322719295927808002,
#     'in_reply_to_status_id_str': '1322719295927808002',
#     'in_reply_to_user_id': 222682211,
#     'in_reply_to_user_id_str': '222682211',
#     'in_reply_to_screen_name': 'PipStocks',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'EFE9E5',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme7/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme7/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1135693176243597312/mE_lUXFY_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1135693176243597312/mE_lUXFY_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14686881/1571116897',
#    'profile_link_color': '631A4B',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'C9C1B8',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 7302852,
#    'id_str': '7302852',
#    'name': 'NAB',
#    'screen_name': 'NAB',
#    'location': 'Australia',
#    'description': 'The official NAB account. More than money. Let us know how we can help.',
#    'url': 'http://t.co/lP65MsplII',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/lP65MsplII',
#        'expanded_url': 'http://www.nab.com.au',
#        'display_url': 'nab.com.au',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 70484,
#    'friends_count': 9,
#    'listed_count': 592,
#    'created_at': 'Fri Jul 06 22:15:39 +0000 2007',
#    'favourites_count': 674,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 49443,
#    'lang': None,
#    'status': {'created_at': 'Sun Nov 01 20:14:32 +0000 2020',
#     'id': 1322995460059979776,
#     'id_str': '1322995460059979776',
#     'text': '@toddbridgland Keen to get your accounts sorted out Todd! So we can chat about this, please send a DM ^TC',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'toddbridgland',
#        'name': 'Todd Bridgland',
#        'id': 55544062,
#        'id_str': '55544062',
#        'indices': [0, 14]}],
#      'urls': []},
#     'source': '<a href="https://khoros.com/" rel="nofollow">Khoros Care APAC</a>',
#     'in_reply_to_status_id': 1322953753104916481,
#     'in_reply_to_status_id_str': '1322953753104916481',
#     'in_reply_to_user_id': 55544062,
#     'in_reply_to_user_id_str': '55544062',
#     'in_reply_to_screen_name': 'toddbridgland',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'EEEEEE',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1086907839820398592/h_bUA0T6_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1086907839820398592/h_bUA0T6_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/7302852/1594594619',
#    'profile_link_color': 'E20000',
#    'profile_sidebar_border_color': 'DCDCDC',
#    'profile_sidebar_fill_color': 'EEEEEE',
#    'profile_text_color': '4D4D4D',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 592563175,
#    'id_str': '592563175',
#    'name': 'Trent Clarke.',
#    'screen_name': 'XxdarkhorseX',
#    'location': 'Melbourne, Victoria',
#    'description': 'Australian Mtg enthusiast, full time flog.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 106,
#    'friends_count': 469,
#    'listed_count': 0,
#    'created_at': 'Mon May 28 09:15:36 +0000 2012',
#    'favourites_count': 3833,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 419,
#    'lang': None,
#    'status': {'created_at': 'Mon Sep 21 02:44:23 +0000 2020',
#     'id': 1307873280812933120,
#     'id_str': '1307873280812933120',
#     'text': 'RT @lizZardDota2: I grew up here https://t.co/hxpU5jowaD',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'lizZardDota2',
#        'name': 'lizZard',
#        'id': 2879514418,
#        'id_str': '2879514418',
#        'indices': [3, 16]}],
#      'urls': [],
#      'media': [{'id': 1307637441717821441,
#        'id_str': '1307637441717821441',
#        'indices': [33, 56],
#        'media_url': 'http://pbs.twimg.com/media/EiWpUziXYAErmep.png',
#        'media_url_https': 'https://pbs.twimg.com/media/EiWpUziXYAErmep.png',
#        'url': 'https://t.co/hxpU5jowaD',
#        'display_url': 'pic.twitter.com/hxpU5jowaD',
#        'expanded_url': 'https://twitter.com/lizZardDota2/status/1307637516586098693/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 500, 'h': 281, 'resize': 'fit'},
#         'small': {'w': 500, 'h': 281, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 500, 'h': 281, 'resize': 'fit'}},
#        'source_status_id': 1307637516586098693,
#        'source_status_id_str': '1307637516586098693',
#        'source_user_id': 2879514418,
#        'source_user_id_str': '2879514418'}]},
#     'extended_entities': {'media': [{'id': 1307637441717821441,
#        'id_str': '1307637441717821441',
#        'indices': [33, 56],
#        'media_url': 'http://pbs.twimg.com/media/EiWpUziXYAErmep.png',
#        'media_url_https': 'https://pbs.twimg.com/media/EiWpUziXYAErmep.png',
#        'url': 'https://t.co/hxpU5jowaD',
#        'display_url': 'pic.twitter.com/hxpU5jowaD',
#        'expanded_url': 'https://twitter.com/lizZardDota2/status/1307637516586098693/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 500, 'h': 281, 'resize': 'fit'},
#         'small': {'w': 500, 'h': 281, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 500, 'h': 281, 'resize': 'fit'}},
#        'source_status_id': 1307637516586098693,
#        'source_status_id_str': '1307637516586098693',
#        'source_user_id': 2879514418,
#        'source_user_id_str': '2879514418'}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sun Sep 20 11:07:33 +0000 2020',
#      'id': 1307637516586098693,
#      'id_str': '1307637516586098693',
#      'text': 'I grew up here https://t.co/hxpU5jowaD',
#      'truncated': False,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [],
#       'media': [{'id': 1307637441717821441,
#         'id_str': '1307637441717821441',
#         'indices': [15, 38],
#         'media_url': 'http://pbs.twimg.com/media/EiWpUziXYAErmep.png',
#         'media_url_https': 'https://pbs.twimg.com/media/EiWpUziXYAErmep.png',
#         'url': 'https://t.co/hxpU5jowaD',
#         'display_url': 'pic.twitter.com/hxpU5jowaD',
#         'expanded_url': 'https://twitter.com/lizZardDota2/status/1307637516586098693/photo/1',
#         'type': 'photo',
#         'sizes': {'medium': {'w': 500, 'h': 281, 'resize': 'fit'},
#          'small': {'w': 500, 'h': 281, 'resize': 'fit'},
#          'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'large': {'w': 500, 'h': 281, 'resize': 'fit'}}}]},
#      'extended_entities': {'media': [{'id': 1307637441717821441,
#         'id_str': '1307637441717821441',
#         'indices': [15, 38],
#         'media_url': 'http://pbs.twimg.com/media/EiWpUziXYAErmep.png',
#         'media_url_https': 'https://pbs.twimg.com/media/EiWpUziXYAErmep.png',
#         'url': 'https://t.co/hxpU5jowaD',
#         'display_url': 'pic.twitter.com/hxpU5jowaD',
#         'expanded_url': 'https://twitter.com/lizZardDota2/status/1307637516586098693/photo/1',
#         'type': 'photo',
#         'sizes': {'medium': {'w': 500, 'h': 281, 'resize': 'fit'},
#          'small': {'w': 500, 'h': 281, 'resize': 'fit'},
#          'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'large': {'w': 500, 'h': 281, 'resize': 'fit'}}}]},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 169,
#      'favorite_count': 753,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/979667320627806209/XBnsrtRm_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/979667320627806209/XBnsrtRm_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/592563175/1528870752',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 14190796,
#    'id_str': '14190796',
#    'name': 'Chris Skinner',
#    'screen_name': 'Chris_Skinner',
#    'location': 'ÜT: 51.511924,-0.22414',
#    'description': 'Shaping the future of financial services',
#    'url': 'https://t.co/4YEC3ad1TU',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/4YEC3ad1TU',
#        'expanded_url': 'http://chrisskinner.global',
#        'display_url': 'chrisskinner.global',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 52234,
#    'friends_count': 1576,
#    'listed_count': 2029,
#    'created_at': 'Fri Mar 21 11:58:39 +0000 2008',
#    'favourites_count': 40830,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 44512,
#    'lang': None,
#    'status': {'created_at': 'Sun Nov 01 19:30:05 +0000 2020',
#     'id': 1322984275210285056,
#     'id_str': '1322984275210285056',
#     'text': "@davidbrear @sytaylor And, instead, they're worried about sky rocketing aliens from Mars who might infect their employees working at home",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'davidbrear',
#        'name': 'David M. Brear',
#        'id': 23218742,
#        'id_str': '23218742',
#        'indices': [0, 11]},
#       {'screen_name': 'sytaylor',
#        'name': 'Simon Taylor',
#        'id': 19651231,
#        'id_str': '19651231',
#        'indices': [12, 21]}],
#      'urls': []},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': 1322466898123120640,
#     'in_reply_to_status_id_str': '1322466898123120640',
#     'in_reply_to_user_id': 23218742,
#     'in_reply_to_user_id_str': '23218742',
#     'in_reply_to_screen_name': 'davidbrear',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1322967647449919489/aZe8GJZy_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1322967647449919489/aZe8GJZy_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14190796/1587042096',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 363591541,
#    'id_str': '363591541',
#    'name': 'Mark R Johnson',
#    'screen_name': 'mrj_games',
#    'location': 'Sydney, Australia',
#    'description': 'Lecturer in Digital Cultures @Sydney_Uni | Researching Twitch streaming, esports, playbour, game monetisation & consumption | Also game developer | 🇪🇺 🇦🇺',
#    'url': 'https://t.co/Fv9BYSHp6m',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/Fv9BYSHp6m',
#        'expanded_url': 'https://www.markrjohnsongames.com/',
#        'display_url': 'markrjohnsongames.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 3432,
#    'friends_count': 1389,
#    'listed_count': 107,
#    'created_at': 'Sun Aug 28 10:32:10 +0000 2011',
#    'favourites_count': 1042,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 6900,
#    'lang': None,
#    'status': {'created_at': 'Sat Oct 31 10:22:27 +0000 2020',
#     'id': 1322484069825826816,
#     'id_str': '1322484069825826816',
#     'text': 'RT @nathanjcjackson: Looking forward to joining @mrj_games and @howells_lachlan for this. Thanks to the organisers for doing such a stellar…',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'nathanjcjackson',
#        'name': 'Nathan J Jackson',
#        'id': 1125899056855674880,
#        'id_str': '1125899056855674880',
#        'indices': [3, 19]},
#       {'screen_name': 'mrj_games',
#        'name': 'Mark R Johnson',
#        'id': 363591541,
#        'id_str': '363591541',
#        'indices': [48, 58]},
#       {'screen_name': 'howells_lachlan',
#        'name': 'Lachlan Howells',
#        'id': 998797473756794880,
#        'id_str': '998797473756794880',
#        'indices': [63, 79]}],
#      'urls': []},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sat Oct 31 05:26:19 +0000 2020',
#      'id': 1322409545004539904,
#      'id_str': '1322409545004539904',
#      'text': 'Looking forward to joining @mrj_games and @howells_lachlan for this. Thanks to the organisers for doing such a stel… https://t.co/aKEdWtXH9i',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [{'screen_name': 'mrj_games',
#         'name': 'Mark R Johnson',
#         'id': 363591541,
#         'id_str': '363591541',
#         'indices': [27, 37]},
#        {'screen_name': 'howells_lachlan',
#         'name': 'Lachlan Howells',
#         'id': 998797473756794880,
#         'id_str': '998797473756794880',
#         'indices': [42, 58]}],
#       'urls': [{'url': 'https://t.co/aKEdWtXH9i',
#         'expanded_url': 'https://twitter.com/i/web/status/1322409545004539904',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': True,
#      'quoted_status_id': 1322048264170995712,
#      'quoted_status_id_str': '1322048264170995712',
#      'retweet_count': 2,
#      'favorite_count': 2,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': True,
#     'quoted_status_id': 1322048264170995712,
#     'quoted_status_id_str': '1322048264170995712',
#     'retweet_count': 2,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1188713518435954688/AkrxOYzy_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1188713518435954688/AkrxOYzy_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/363591541/1512325928',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 854862563619688448,
#    'id_str': '854862563619688448',
#    'name': 'Bronson190',
#    'screen_name': 'Bronson190mtg',
#    'location': 'Melbourne, Victoria',
#    'description': 'Hello! Streaming Monday and Tuesday nights 8pm AEST  \n\n\n\n\nTeam member of @TheFactionMTG',
#    'url': 'https://t.co/nkefa3OWi6',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/nkefa3OWi6',
#        'expanded_url': 'http://twitch.tv/bronson190',
#        'display_url': 'twitch.tv/bronson190',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 211,
#    'friends_count': 619,
#    'listed_count': 3,
#    'created_at': 'Thu Apr 20 01:01:32 +0000 2017',
#    'favourites_count': 1009,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 912,
#    'lang': None,
#    'status': {'created_at': 'Sat Oct 31 04:23:37 +0000 2020',
#     'id': 1322393765215006723,
#     'id_str': '1322393765215006723',
#     'text': 'RT @OriginalFunko: RT &amp; follow @OriginalFunko for the chance to win this Corpse Bride- Emily Pop!  #Giveaway #FunkoGiveaway #Funkoween http…',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'Giveaway', 'indices': [103, 112]},
#       {'text': 'FunkoGiveaway', 'indices': [113, 127]},
#       {'text': 'Funkoween', 'indices': [128, 138]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'OriginalFunko',
#        'name': 'Funko',
#        'id': 1378000488,
#        'id_str': '1378000488',
#        'indices': [3, 17]},
#       {'screen_name': 'OriginalFunko',
#        'name': 'Funko',
#        'id': 1378000488,
#        'id_str': '1378000488',
# ...
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '91AAB5',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1134100887666941957/d2bxMYhc_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1134100887666941957/d2bxMYhc_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18393773/1601656112',
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DAECF4',
#    'profile_text_color': '663B12',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 15439395,
#    'id_str': '15439395',
#    'name': 'Stephen Fry',
#    'screen_name': 'stephenfry',
#    'location': 'Los Angeles, CA/ London UK',
#    'description': 'Hello there .… this Stephen. I don’t read Direct Messages I’m afraid. TROY available here https://t.co/l3c5kPjXja or as an audiobook',
#    'url': None,
#    'entities': {'description': {'urls': [{'url': 'https://t.co/l3c5kPjXja',
#        'expanded_url': 'http://hyperurl.co/TroyWaterstones',
#        'display_url': 'hyperurl.co/TroyWaterstones',
#        'indices': [90, 113]}]}},
#    'protected': False,
#    'followers_count': 12639561,
#    'friends_count': 48935,
#    'listed_count': 52215,
#    'created_at': 'Tue Jul 15 11:45:30 +0000 2008',
#    'favourites_count': 2047,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 24676,
#    'lang': None,
#    'status': {'created_at': 'Sun Nov 01 09:20:19 +0000 2020',
#     'id': 1322830822987177989,
#     'id_str': '1322830822987177989',
#     'text': 'RT @HeywoodHill: Collaborators in civilisation damn this virus to hell. Who deserves a boost this year? By 8 Nov nominate someone YOU admir…',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'HeywoodHill',
#        'name': 'Heywood Hill',
#        'id': 202157056,
#        'id_str': '202157056',
#        'indices': [3, 15]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Thu Oct 29 23:45:20 +0000 2020',
#      'id': 1321961346464927745,
#      'id_str': '1321961346464927745',
#      'text': 'Collaborators in civilisation damn this virus to hell. Who deserves a boost this year? By 8 Nov nominate someone YO… https://t.co/YSu7cgL1hC',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/YSu7cgL1hC',
#         'expanded_url': 'https://twitter.com/i/web/status/1321961346464927745',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 346,
#      'favorite_count': 546,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 346,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme3/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme3/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/842053173757984768/ZYLuzKYt_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/842053173757984768/ZYLuzKYt_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15439395/1603968725',
#    'profile_link_color': '005192',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 112562526,
#    'id_str': '112562526',
#    'name': 'Samkil L. Mier',
#    'screen_name': 'samkillmier',
#    'location': 'Washington, DC',
#    'description': 'Interests include economics, finance, politics, the future of humanity... that sort of thing.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 18,
#    'friends_count': 244,
#    'listed_count': 0,
#    'created_at': 'Mon Feb 08 23:29:38 +0000 2010',
#    'favourites_count': 1677,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1368,
#    'lang': None,
#    'status': {'created_at': 'Sun Nov 01 21:47:23 +0000 2020',
#     'id': 1323018828670857216,
#     'id_str': '1323018828670857216',
#     'text': '@TrumpWave1776 @RalstonReports In order to earn unlimited terms I think folks should at least know how to spell it.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'TrumpWave1776',
#        'name': 'Trump for Unlimted Terms!!',
#        'id': 1318246837908869122,
#        'id_str': '1318246837908869122',
#        'indices': [0, 14]},
#       {'screen_name': 'RalstonReports',
#        'name': 'Jon Ralston',
#        'id': 14413466,
#        'id_str': '14413466',
#        'indices': [15, 30]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1323018265808015361,
#     'in_reply_to_status_id_str': '1323018265808015361',
#     'in_reply_to_user_id': 1318246837908869122,
#     'in_reply_to_user_id_str': '1318246837908869122',
#     'in_reply_to_screen_name': 'TrumpWave1776',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/767644154138546176/XsxeammJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/767644154138546176/XsxeammJ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/112562526/1465991899',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 14373916,
#    'id_str': '14373916',
#    'name': 'Rob Hamilton',
#    'screen_name': 'vfxhamilton',
#    'location': 'Melbourne, Australia',
#    'description': 'Freelance VFX Artist and film maker.',
#    'url': 'http://t.co/3gEzezixsw',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/3gEzezixsw',
#        'expanded_url': 'http://www.imdb.com/name/nm3298973/?mode=desktop',
#        'display_url': 'imdb.com/name/nm3298973…',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 79,
#    'friends_count': 229,
#    'listed_count': 3,
#    'created_at': 'Sun Apr 13 09:03:20 +0000 2008',
#    'favourites_count': 86,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 1358,
#    'lang': None,
#    'status': {'created_at': 'Sun Oct 18 01:52:39 +0000 2015',
#     'id': 655562101973364737,
#     'id_str': '655562101973364737',
#     'text': 'My YouTube gaming channel now has a Twitter account. @CaptDeadmeat and a face book page http://t.co/exCTeicnj7. #gamingchannel #YouTube',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'gamingchannel', 'indices': [112, 126]},
#       {'text': 'YouTube', 'indices': [127, 135]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'CaptDeadmeat',
#        'name': 'Captain Deadmeat',
#        'id': 3930612918,
#        'id_str': '3930612918',
#        'indices': [53, 66]}],
#      'urls': [{'url': 'http://t.co/exCTeicnj7',
#        'expanded_url': 'http://facebook.com/CaptDeadmeat',
#        'display_url': 'facebook.com/CaptDeadmeat',
#        'indices': [88, 110]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 4,
#     'favorite_count': 19,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/3634297216/48319f859d7e350522f28c843e39b64a_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3634297216/48319f859d7e350522f28c843e39b64a_normal.jpeg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 37076621,
#    'id_str': '37076621',
#    'name': 'Adam Kirchner🌐',
#    'screen_name': 'AKirch09',
#    'location': 'Sioux Falls, SD',
#    'description': 'Father of 3 boys and a lucky husband. #DC4L #MinnesotaTwins',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 149,
#    'friends_count': 1054,
#    'listed_count': 3,
#    'created_at': 'Fri May 01 23:34:37 +0000 2009',
#    'favourites_count': 5821,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 2022,
#    'lang': None,
#    'status': {'created_at': 'Sun Nov 01 21:12:15 +0000 2020',
#     'id': 1323009986574782465,
#     'id_str': '1323009986574782465',
#     'text': 'RT @TheRightMelissa: If you are voting for Mass Black incarnation Joe Biden who is responsible for the destruction of millions of black liv…',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'TheRightMelissa',
#        'name': 'Melissa Tate',
#        'id': 762389795037294592,
#        'id_str': '762389795037294592',
#        'indices': [3, 19]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sun Nov 01 16:31:06 +0000 2020',
#      'id': 1322939233166893074,
#      'id_str': '1322939233166893074',
#      'text': 'If you are voting for Mass Black incarnation Joe Biden who is responsible for the destruction of millions of black… https://t.co/olMWON8c70',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/olMWON8c70',
#         'expanded_url': 'https://twitter.com/i/web/status/1322939233166893074',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [116, 139]}]},
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 722,
#      'favorite_count': 1623,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 722,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '022330',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1306262240710897669/7ezOoKoj_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1306262240710897669/7ezOoKoj_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/37076621/1600272162',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'A8C7F7',
#    'profile_sidebar_fill_color': 'C0DFEC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'}],
#  'next_cursor': 0,
#  'next_cursor_str': '0',
#  'previous_cursor': 0,
#  'previous_cursor_str': '0',
#  'total_count': None}

# %%
len(friends_list_sample.json()['users'])
# Out:
# 80

# %%
test_b = friend_of_friends(['@Beyonce', 'MariahCarey'])

# %%
len(test_b)
# Out:
# 3

# %%
test_b
# Out:
# [{'id': 40908929,
#   'id_str': '40908929',
#   'name': 'Usher Raymond IV',
#   'screen_name': 'Usher',
#   'location': '',
#   'description': 'USHER: The Vegas Experience | Text me at (404) 737-1821',
#   'url': 'https://t.co/6YDCXWcGDI',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/6YDCXWcGDI',
#       'expanded_url': 'https://linktr.ee/usherofficial',
#       'display_url': 'linktr.ee/usherofficial',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 12186065,
#   'friends_count': 564,
#   'listed_count': 26144,
#   'created_at': 'Mon May 18 16:36:50 +0000 2009',
#   'favourites_count': 1336,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 6041,
#   'lang': None,
#   'status': {'created_at': 'Thu Oct 29 16:06:41 +0000 2020',
#    'id': 1321845921752125440,
#    'id_str': '1321845921752125440',
#    'text': 'RT @marshmellomusic: behind the scenes w/ @Usher &amp; #Imanbek \n\nToo Much 🎥 https://t.co/MSOsXqOfa8 https://t.co/mvjdb2JRJj',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Imanbek', 'indices': [55, 63]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'marshmellomusic',
#       'name': 'marshmello',
#       'id': 2987922767,
#       'id_str': '2987922767',
#       'indices': [3, 19]},
#      {'screen_name': 'Usher',
#       'name': 'Usher Raymond IV',
#       'id': 40908929,
#       'id_str': '40908929',
#       'indices': [42, 48]}],
#     'urls': [{'url': 'https://t.co/MSOsXqOfa8',
#       'expanded_url': 'http://youtu.be/Fzgf0ddV7HE',
#       'display_url': 'youtu.be/Fzgf0ddV7HE',
#       'indices': [77, 100]}],
#     'media': [{'id': 1321843959086243841,
#       'id_str': '1321843959086243841',
#       'indices': [101, 124],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1321843959086243841/pu/img/Ri1TTxeft7WxXI2w.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1321843959086243841/pu/img/Ri1TTxeft7WxXI2w.jpg',
#       'url': 'https://t.co/mvjdb2JRJj',
#       'display_url': 'pic.twitter.com/mvjdb2JRJj',
#       'expanded_url': 'https://twitter.com/marshmellomusic/status/1321844016481136641/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 960, 'h': 1200, 'resize': 'fit'},
#        'large': {'w': 1024, 'h': 1280, 'resize': 'fit'}},
#       'source_status_id': 1321844016481136641,
#       'source_status_id_str': '1321844016481136641',
#       'source_user_id': 2987922767,
#       'source_user_id_str': '2987922767'}]},
#    'extended_entities': {'media': [{'id': 1321843959086243841,
#       'id_str': '1321843959086243841',
#       'indices': [101, 124],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1321843959086243841/pu/img/Ri1TTxeft7WxXI2w.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1321843959086243841/pu/img/Ri1TTxeft7WxXI2w.jpg',
#       'url': 'https://t.co/mvjdb2JRJj',
#       'display_url': 'pic.twitter.com/mvjdb2JRJj',
#       'expanded_url': 'https://twitter.com/marshmellomusic/status/1321844016481136641/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 960, 'h': 1200, 'resize': 'fit'},
#        'large': {'w': 1024, 'h': 1280, 'resize': 'fit'}},
#       'source_status_id': 1321844016481136641,
#       'source_status_id_str': '1321844016481136641',
#       'source_user_id': 2987922767,
#       'source_user_id_str': '2987922767',
#       'video_info': {'aspect_ratio': [4, 5],
#        'duration_millis': 14829,
#        'variants': [{'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1321843959086243841/pu/vid/720x900/p4By_lhjU8JlmjdH.mp4?tag=10'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1321843959086243841/pu/vid/360x450/2FRIBISm9DvuiyQk.mp4?tag=10'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/1321843959086243841/pu/pl/WgM-K6wa6-raxoY4.m3u8?tag=10'},
#         {'bitrate': 632000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1321843959086243841/pu/vid/320x400/ZMipchVTtMzKJAEM.mp4?tag=10'}]},
#       'additional_media_info': {'monetizable': False}}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 29 15:59:06 +0000 2020',
#     'id': 1321844016481136641,
#     'id_str': '1321844016481136641',
#     'text': 'behind the scenes w/ @Usher &amp; #Imanbek \n\nToo Much 🎥 https://t.co/MSOsXqOfa8 https://t.co/mvjdb2JRJj',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'Imanbek', 'indices': [34, 42]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'Usher',
#        'name': 'Usher Raymond IV',
#        'id': 40908929,
#        'id_str': '40908929',
#        'indices': [21, 27]}],
#      'urls': [{'url': 'https://t.co/MSOsXqOfa8',
#        'expanded_url': 'http://youtu.be/Fzgf0ddV7HE',
#        'display_url': 'youtu.be/Fzgf0ddV7HE',
#        'indices': [56, 79]}],
#      'media': [{'id': 1321843959086243841,
#        'id_str': '1321843959086243841',
#        'indices': [80, 103],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1321843959086243841/pu/img/Ri1TTxeft7WxXI2w.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1321843959086243841/pu/img/Ri1TTxeft7WxXI2w.jpg',
#        'url': 'https://t.co/mvjdb2JRJj',
#        'display_url': 'pic.twitter.com/mvjdb2JRJj',
#        'expanded_url': 'https://twitter.com/marshmellomusic/status/1321844016481136641/video/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 960, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 1024, 'h': 1280, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1321843959086243841,
#        'id_str': '1321843959086243841',
#        'indices': [80, 103],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1321843959086243841/pu/img/Ri1TTxeft7WxXI2w.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1321843959086243841/pu/img/Ri1TTxeft7WxXI2w.jpg',
#        'url': 'https://t.co/mvjdb2JRJj',
#        'display_url': 'pic.twitter.com/mvjdb2JRJj',
#        'expanded_url': 'https://twitter.com/marshmellomusic/status/1321844016481136641/video/1',
#        'type': 'video',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 960, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 1024, 'h': 1280, 'resize': 'fit'}},
#        'video_info': {'aspect_ratio': [4, 5],
#         'duration_millis': 14829,
#         'variants': [{'bitrate': 2176000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1321843959086243841/pu/vid/720x900/p4By_lhjU8JlmjdH.mp4?tag=10'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1321843959086243841/pu/vid/360x450/2FRIBISm9DvuiyQk.mp4?tag=10'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/1321843959086243841/pu/pl/WgM-K6wa6-raxoY4.m3u8?tag=10'},
#          {'bitrate': 632000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1321843959086243841/pu/vid/320x400/ZMipchVTtMzKJAEM.mp4?tag=10'}]},
#        'additional_media_info': {'monetizable': False}}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 148,
#     'favorite_count': 1556,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 148,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': True,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1301860838165291008/5QZft_k1_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1301860838165291008/5QZft_k1_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40908929/1599222787',
#   'profile_link_color': 'ABB8C2',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'DDFFCC',
#   'profile_text_color': '333333',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'regular'},
#  {'id': 30782495,
#   'id_str': '30782495',
#   'name': 'KELENDRIA ROWLAND',
#   'screen_name': 'KELLYROWLAND',
#   'location': '',
#   'description': 'Crazy – available everywhere!',
#   'url': 'https://t.co/k3PEdX7tqa',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/k3PEdX7tqa',
#       'expanded_url': 'https://linktr.ee/KellyRowlandxo',
#       'display_url': 'linktr.ee/KellyRowlandxo',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 6906138,
#   'friends_count': 1703,
#   'listed_count': 13602,
#   'created_at': 'Mon Apr 13 02:15:13 +0000 2009',
#   'favourites_count': 1376,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 13445,
#   'lang': None,
#   'status': {'created_at': 'Sun Nov 01 04:12:08 +0000 2020',
#    'id': 1322753264933195777,
#    'id_str': '1322753264933195777',
#    'text': "RT @hulu: It's always more than just hair. Bad Hair is now streaming, only on Hulu. #BadHairHulu",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BadHairHulu', 'indices': [84, 96]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'hulu',
#       'name': 'Hulu',
#       'id': 15033883,
#       'id_str': '15033883',
#       'indices': [3, 8]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Oct 20 17:38:04 +0000 2020',
#     'id': 1318607430364717056,
#     'id_str': '1318607430364717056',
#     'text': "It's always more than just hair. Bad Hair is now streaming, only on Hulu. #BadHairHulu",
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'BadHairHulu', 'indices': [74, 86]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'source': '<a href="https://twitter.com" rel="nofollow">Twitter for Advertisers</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 238,
#     'favorite_count': 2172,
#     'favorited': False,
#     'retweeted': False,
#     'scopes': {'followers': False},
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 238,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '072E59',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1314439890268909569/aoKrI71H_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1314439890268909569/aoKrI71H_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/30782495/1602218587',
#   'profile_link_color': '8A8C8C',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '95E8EC',
#   'profile_text_color': '3C3940',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 18395177,
#   'id_str': '18395177',
#   'name': 'solange knowles',
#   'screen_name': 'solangeknowles',
#   'location': '',
#   'description': 'water, melanin, bones, blood.',
#   'url': 'https://t.co/8F2cZD8D37',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/8F2cZD8D37',
#       'expanded_url': 'http://www.saintheron.com',
#       'display_url': 'saintheron.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 4167951,
#   'friends_count': 166,
#   'listed_count': 8877,
#   'created_at': 'Fri Dec 26 20:54:15 +0000 2008',
#   'favourites_count': 3362,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 572,
#   'lang': None,
#   'status': {'created_at': 'Wed Oct 28 02:09:35 +0000 2020',
#    'id': 1321272870912360448,
#    'id_str': '1321272870912360448',
#    'text': 'RT @solangepics: 🖤 https://t.co/wNBzwn1dIi',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'solangepics',
#       'name': 'Solange Pictures',
#       'id': 1100475756990349317,
#       'id_str': '1100475756990349317',
#       'indices': [3, 15]}],
#     'urls': [],
#     'media': [{'id': 1321261870439944195,
#       'id_str': '1321261870439944195',
#       'indices': [19, 42],
#       'media_url': 'http://pbs.twimg.com/media/ElYQq7rXUAMP1lM.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/ElYQq7rXUAMP1lM.jpg',
#       'url': 'https://t.co/wNBzwn1dIi',
#       'display_url': 'pic.twitter.com/wNBzwn1dIi',
#       'expanded_url': 'https://twitter.com/solangepics/status/1321261922675757056/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 1242, 'h': 1242, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 680, 'resize': 'fit'}},
#       'source_status_id': 1321261922675757056,
#       'source_status_id_str': '1321261922675757056',
#       'source_user_id': 1100475756990349317,
#       'source_user_id_str': '1100475756990349317'}]},
#    'extended_entities': {'media': [{'id': 1321261870439944195,
#       'id_str': '1321261870439944195',
#       'indices': [19, 42],
#       'media_url': 'http://pbs.twimg.com/media/ElYQq7rXUAMP1lM.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/ElYQq7rXUAMP1lM.jpg',
#       'url': 'https://t.co/wNBzwn1dIi',
#       'display_url': 'pic.twitter.com/wNBzwn1dIi',
#       'expanded_url': 'https://twitter.com/solangepics/status/1321261922675757056/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 1242, 'h': 1242, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 680, 'resize': 'fit'}},
#       'source_status_id': 1321261922675757056,
#       'source_status_id_str': '1321261922675757056',
#       'source_user_id': 1100475756990349317,
#       'source_user_id_str': '1100475756990349317'},
#      {'id': 1321261909157568513,
#       'id_str': '1321261909157568513',
#       'indices': [19, 42],
#       'media_url': 'http://pbs.twimg.com/media/ElYQtL6XYAE2kuN.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/ElYQtL6XYAE2kuN.jpg',
#       'url': 'https://t.co/wNBzwn1dIi',
#       'display_url': 'pic.twitter.com/wNBzwn1dIi',
#       'expanded_url': 'https://twitter.com/solangepics/status/1321261922675757056/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 510, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 900, 'resize': 'fit'},
#        'large': {'w': 1242, 'h': 931, 'resize': 'fit'}},
#       'source_status_id': 1321261922675757056,
#       'source_status_id_str': '1321261922675757056',
#       'source_user_id': 1100475756990349317,
#       'source_user_id_str': '1100475756990349317'}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 28 01:26:04 +0000 2020',
#     'id': 1321261922675757056,
#     'id_str': '1321261922675757056',
#     'text': '🖤 https://t.co/wNBzwn1dIi',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1321261870439944195,
#        'id_str': '1321261870439944195',
#        'indices': [2, 25],
#        'media_url': 'http://pbs.twimg.com/media/ElYQq7rXUAMP1lM.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/ElYQq7rXUAMP1lM.jpg',
#        'url': 'https://t.co/wNBzwn1dIi',
#        'display_url': 'pic.twitter.com/wNBzwn1dIi',
#        'expanded_url': 'https://twitter.com/solangepics/status/1321261922675757056/photo/1',
#        'type': 'photo',
#        'sizes': {'large': {'w': 1242, 'h': 1242, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1321261870439944195,
#        'id_str': '1321261870439944195',
#        'indices': [2, 25],
#        'media_url': 'http://pbs.twimg.com/media/ElYQq7rXUAMP1lM.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/ElYQq7rXUAMP1lM.jpg',
#        'url': 'https://t.co/wNBzwn1dIi',
#        'display_url': 'pic.twitter.com/wNBzwn1dIi',
#        'expanded_url': 'https://twitter.com/solangepics/status/1321261922675757056/photo/1',
#        'type': 'photo',
#        'sizes': {'large': {'w': 1242, 'h': 1242, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'}}},
#       {'id': 1321261909157568513,
#        'id_str': '1321261909157568513',
#        'indices': [2, 25],
#        'media_url': 'http://pbs.twimg.com/media/ElYQtL6XYAE2kuN.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/ElYQtL6XYAE2kuN.jpg',
#        'url': 'https://t.co/wNBzwn1dIi',
#        'display_url': 'pic.twitter.com/wNBzwn1dIi',
#        'expanded_url': 'https://twitter.com/solangepics/status/1321261922675757056/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 510, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 900, 'resize': 'fit'},
#         'large': {'w': 1242, 'h': 931, 'resize': 'fit'}}}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2593,
#     'favorite_count': 17751,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'und'},
#    'is_quote_status': False,
#    'retweet_count': 2593,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'FFF04D',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1109657367577133057/44jmIiZ6_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1109657367577133057/44jmIiZ6_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18395177/1528451677',
#   'profile_link_color': 'EDE31F',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'EFEFEF',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'}]

# %%
test_c = friend_of_friends(['@Beyonce', 'MariahCarey'],keys=['id','screen_name'])

# %%
test_c
# Out:
# [{'id': 40908929, 'screen_name': 'Usher'},
#  {'id': 30782495, 'screen_name': 'KELLYROWLAND'},
#  {'id': 18395177, 'screen_name': 'solangeknowles'}]

# %%
test_d = friend_of_friends(['@prsinkis', 'ickbat'],keys=['id','screen_name'])

# %%
test_d
# Out:
# [{'id': 6207162, 'screen_name': 'TheDecemberists'},
#  {'id': 2011081, 'screen_name': 'rdonoghue'},
#  {'id': 15439395, 'screen_name': 'stephenfry'},
#  {'id': 14373916, 'screen_name': 'vfxhamilton'}]

# %%
test_e = friend_of_friends(['@prsinkis', 'XxdarkhorseX'],keys=['id','screen_name'])
# Out:
# Reached max API requests.
# Setting cursor to 0 to exit loop.
# friends_1s found so far will be output.

# %%
test_e
# Out:
# [{'id': 2584388417, 'screen_name': 'harrymtg'},
#  {'id': 1109902312296857602, 'screen_name': 'MidweekMetagame'},
#  {'id': 1095142349468913664, 'screen_name': 'KyleGbsn'},
#  {'id': 854862563619688448, 'screen_name': 'Bronson190mtg'},
#  {'id': 982935621969694720, 'screen_name': 'TheFactionMTG'},
#  {'id': 167072801, 'screen_name': 'Gfabs5'},
#  {'id': 20003820, 'screen_name': 'rbuehler'},
#  {'id': 900694717, 'screen_name': 'MagicOnline'},
#  {'id': 40323163, 'screen_name': 'simongoertzen'}]

# %%
test_f = friend_of_friends(['@Beyonce', 'MariahCarey'],keys=['id','screen_name','name','friends_count','followers_count'],to_df = True)

# %%
test_f
# Out:
#          id     screen_name               name  friends_count  followers_count
# 0  40908929           Usher   Usher Raymond IV            564         12186067
# 1  30782495    KELLYROWLAND  KELENDRIA ROWLAND           1703          6906140
# 2  18395177  solangeknowles    solange knowles            166          4167920

# %%
test_g = friend_of_friends(['@Beyonce', 'MariahCarey'],keys=['id','screen_name','name','friends_count','followers_count'],to_df = False)
# Out:
# Reached max API requests.
# Setting cursor to 0 to exit loop.
# friends_1s found so far will be output.

# %%
# Out:
# []

# %% [markdown]
# # Up to here - getting an error when outputting a dataframe object
# ## SOLVED!
#
# * This is becuase there is no default list of keys to build from
# * So solution: go through each user, extract each level 1 key, remove duplicates, create list of keys to use as column heading
# * This also means there is a need to handle errors where no value is present for that key for that user

# %%
test_h = friend_of_friends(['@Beyonce', 'MariahCarey'],to_df = False)

# %%
test_h
# Out:
# [{'id': 40908929,
#   'id_str': '40908929',
#   'name': 'Usher Raymond IV',
#   'screen_name': 'Usher',
#   'location': '',
#   'description': 'USHER: The Vegas Experience | Text me at (404) 737-1821',
#   'url': 'https://t.co/6YDCXWcGDI',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/6YDCXWcGDI',
#       'expanded_url': 'https://linktr.ee/usherofficial',
#       'display_url': 'linktr.ee/usherofficial',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 12186177,
#   'friends_count': 564,
#   'listed_count': 26144,
#   'created_at': 'Mon May 18 16:36:50 +0000 2009',
#   'favourites_count': 1336,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 6041,
#   'lang': None,
#   'status': {'created_at': 'Thu Oct 29 16:06:41 +0000 2020',
#    'id': 1321845921752125440,
#    'id_str': '1321845921752125440',
#    'text': 'RT @marshmellomusic: behind the scenes w/ @Usher &amp; #Imanbek \n\nToo Much 🎥 https://t.co/MSOsXqOfa8 https://t.co/mvjdb2JRJj',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Imanbek', 'indices': [55, 63]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'marshmellomusic',
#       'name': 'marshmello',
#       'id': 2987922767,
#       'id_str': '2987922767',
#       'indices': [3, 19]},
#      {'screen_name': 'Usher',
#       'name': 'Usher Raymond IV',
#       'id': 40908929,
#       'id_str': '40908929',
#       'indices': [42, 48]}],
#     'urls': [{'url': 'https://t.co/MSOsXqOfa8',
#       'expanded_url': 'http://youtu.be/Fzgf0ddV7HE',
#       'display_url': 'youtu.be/Fzgf0ddV7HE',
#       'indices': [77, 100]}],
#     'media': [{'id': 1321843959086243841,
#       'id_str': '1321843959086243841',
#       'indices': [101, 124],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1321843959086243841/pu/img/Ri1TTxeft7WxXI2w.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1321843959086243841/pu/img/Ri1TTxeft7WxXI2w.jpg',
#       'url': 'https://t.co/mvjdb2JRJj',
#       'display_url': 'pic.twitter.com/mvjdb2JRJj',
#       'expanded_url': 'https://twitter.com/marshmellomusic/status/1321844016481136641/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 960, 'h': 1200, 'resize': 'fit'},
#        'large': {'w': 1024, 'h': 1280, 'resize': 'fit'}},
#       'source_status_id': 1321844016481136641,
#       'source_status_id_str': '1321844016481136641',
#       'source_user_id': 2987922767,
#       'source_user_id_str': '2987922767'}]},
#    'extended_entities': {'media': [{'id': 1321843959086243841,
#       'id_str': '1321843959086243841',
#       'indices': [101, 124],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1321843959086243841/pu/img/Ri1TTxeft7WxXI2w.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1321843959086243841/pu/img/Ri1TTxeft7WxXI2w.jpg',
#       'url': 'https://t.co/mvjdb2JRJj',
#       'display_url': 'pic.twitter.com/mvjdb2JRJj',
#       'expanded_url': 'https://twitter.com/marshmellomusic/status/1321844016481136641/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 960, 'h': 1200, 'resize': 'fit'},
#        'large': {'w': 1024, 'h': 1280, 'resize': 'fit'}},
#       'source_status_id': 1321844016481136641,
#       'source_status_id_str': '1321844016481136641',
#       'source_user_id': 2987922767,
#       'source_user_id_str': '2987922767',
#       'video_info': {'aspect_ratio': [4, 5],
#        'duration_millis': 14829,
#        'variants': [{'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1321843959086243841/pu/vid/720x900/p4By_lhjU8JlmjdH.mp4?tag=10'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1321843959086243841/pu/vid/360x450/2FRIBISm9DvuiyQk.mp4?tag=10'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/1321843959086243841/pu/pl/WgM-K6wa6-raxoY4.m3u8?tag=10'},
#         {'bitrate': 632000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1321843959086243841/pu/vid/320x400/ZMipchVTtMzKJAEM.mp4?tag=10'}]},
#       'additional_media_info': {'monetizable': False}}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 29 15:59:06 +0000 2020',
#     'id': 1321844016481136641,
#     'id_str': '1321844016481136641',
#     'text': 'behind the scenes w/ @Usher &amp; #Imanbek \n\nToo Much 🎥 https://t.co/MSOsXqOfa8 https://t.co/mvjdb2JRJj',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'Imanbek', 'indices': [34, 42]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'Usher',
#        'name': 'Usher Raymond IV',
#        'id': 40908929,
#        'id_str': '40908929',
#        'indices': [21, 27]}],
#      'urls': [{'url': 'https://t.co/MSOsXqOfa8',
#        'expanded_url': 'http://youtu.be/Fzgf0ddV7HE',
#        'display_url': 'youtu.be/Fzgf0ddV7HE',
#        'indices': [56, 79]}],
#      'media': [{'id': 1321843959086243841,
#        'id_str': '1321843959086243841',
#        'indices': [80, 103],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1321843959086243841/pu/img/Ri1TTxeft7WxXI2w.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1321843959086243841/pu/img/Ri1TTxeft7WxXI2w.jpg',
#        'url': 'https://t.co/mvjdb2JRJj',
#        'display_url': 'pic.twitter.com/mvjdb2JRJj',
#        'expanded_url': 'https://twitter.com/marshmellomusic/status/1321844016481136641/video/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 960, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 1024, 'h': 1280, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1321843959086243841,
#        'id_str': '1321843959086243841',
#        'indices': [80, 103],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1321843959086243841/pu/img/Ri1TTxeft7WxXI2w.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1321843959086243841/pu/img/Ri1TTxeft7WxXI2w.jpg',
#        'url': 'https://t.co/mvjdb2JRJj',
#        'display_url': 'pic.twitter.com/mvjdb2JRJj',
#        'expanded_url': 'https://twitter.com/marshmellomusic/status/1321844016481136641/video/1',
#        'type': 'video',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 960, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 1024, 'h': 1280, 'resize': 'fit'}},
#        'video_info': {'aspect_ratio': [4, 5],
#         'duration_millis': 14829,
#         'variants': [{'bitrate': 2176000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1321843959086243841/pu/vid/720x900/p4By_lhjU8JlmjdH.mp4?tag=10'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1321843959086243841/pu/vid/360x450/2FRIBISm9DvuiyQk.mp4?tag=10'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/1321843959086243841/pu/pl/WgM-K6wa6-raxoY4.m3u8?tag=10'},
#          {'bitrate': 632000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1321843959086243841/pu/vid/320x400/ZMipchVTtMzKJAEM.mp4?tag=10'}]},
#        'additional_media_info': {'monetizable': False}}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 151,
#     'favorite_count': 1574,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 151,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': True,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1301860838165291008/5QZft_k1_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1301860838165291008/5QZft_k1_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40908929/1599222787',
#   'profile_link_color': 'ABB8C2',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'DDFFCC',
#   'profile_text_color': '333333',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'regular'},
#  {'id': 30782495,
#   'id_str': '30782495',
#   'name': 'KELENDRIA ROWLAND',
#   'screen_name': 'KELLYROWLAND',
#   'location': '',
#   'description': 'Crazy – available everywhere!',
#   'url': 'https://t.co/k3PEdX7tqa',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/k3PEdX7tqa',
#       'expanded_url': 'https://linktr.ee/KellyRowlandxo',
#       'display_url': 'linktr.ee/KellyRowlandxo',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 6906203,
#   'friends_count': 1702,
#   'listed_count': 13601,
#   'created_at': 'Mon Apr 13 02:15:13 +0000 2009',
#   'favourites_count': 1376,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 13446,
#   'lang': None,
#   'status': {'created_at': 'Sun Nov 01 18:55:53 +0000 2020',
#    'id': 1322975669064663040,
#    'id_str': '1322975669064663040',
#    'text': 'RT @KELLYROWLAND: Take a look behind the scenes of my cover shoot for “Crazy” – out now! https://t.co/gh4s6KpZiI',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'KELLYROWLAND',
#       'name': 'KELENDRIA ROWLAND',
#       'id': 30782495,
#       'id_str': '30782495',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/gh4s6KpZiI',
#       'expanded_url': 'http://youtu.be/kOcOkJhQTZE',
#       'display_url': 'youtu.be/kOcOkJhQTZE',
#       'indices': [89, 112]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Oct 30 21:47:18 +0000 2020',
#     'id': 1322294031787847680,
#     'id_str': '1322294031787847680',
#     'text': 'Take a look behind the scenes of my cover shoot for “Crazy” – out now! https://t.co/gh4s6KpZiI',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/gh4s6KpZiI',
#        'expanded_url': 'http://youtu.be/kOcOkJhQTZE',
#        'display_url': 'youtu.be/kOcOkJhQTZE',
#        'indices': [71, 94]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 32,
#     'favorite_count': 173,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 32,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '072E59',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1314439890268909569/aoKrI71H_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1314439890268909569/aoKrI71H_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/30782495/1602218587',
#   'profile_link_color': '8A8C8C',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '95E8EC',
#   'profile_text_color': '3C3940',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 18395177,
#   'id_str': '18395177',
#   'name': 'solange knowles',
#   'screen_name': 'solangeknowles',
#   'location': '',
#   'description': 'water, melanin, bones, blood.',
#   'url': 'https://t.co/8F2cZD8D37',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/8F2cZD8D37',
#       'expanded_url': 'http://www.saintheron.com',
#       'display_url': 'saintheron.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 4167933,
#   'friends_count': 166,
#   'listed_count': 8876,
#   'created_at': 'Fri Dec 26 20:54:15 +0000 2008',
#   'favourites_count': 3362,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 572,
#   'lang': None,
#   'status': {'created_at': 'Wed Oct 28 02:09:35 +0000 2020',
#    'id': 1321272870912360448,
#    'id_str': '1321272870912360448',
#    'text': 'RT @solangepics: 🖤 https://t.co/wNBzwn1dIi',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'solangepics',
#       'name': 'Solange Pictures',
#       'id': 1100475756990349317,
#       'id_str': '1100475756990349317',
#       'indices': [3, 15]}],
#     'urls': [],
#     'media': [{'id': 1321261870439944195,
#       'id_str': '1321261870439944195',
#       'indices': [19, 42],
#       'media_url': 'http://pbs.twimg.com/media/ElYQq7rXUAMP1lM.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/ElYQq7rXUAMP1lM.jpg',
#       'url': 'https://t.co/wNBzwn1dIi',
#       'display_url': 'pic.twitter.com/wNBzwn1dIi',
#       'expanded_url': 'https://twitter.com/solangepics/status/1321261922675757056/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 1242, 'h': 1242, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 680, 'resize': 'fit'}},
#       'source_status_id': 1321261922675757056,
#       'source_status_id_str': '1321261922675757056',
#       'source_user_id': 1100475756990349317,
#       'source_user_id_str': '1100475756990349317'}]},
#    'extended_entities': {'media': [{'id': 1321261870439944195,
#       'id_str': '1321261870439944195',
#       'indices': [19, 42],
#       'media_url': 'http://pbs.twimg.com/media/ElYQq7rXUAMP1lM.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/ElYQq7rXUAMP1lM.jpg',
#       'url': 'https://t.co/wNBzwn1dIi',
#       'display_url': 'pic.twitter.com/wNBzwn1dIi',
#       'expanded_url': 'https://twitter.com/solangepics/status/1321261922675757056/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 1242, 'h': 1242, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 680, 'resize': 'fit'}},
#       'source_status_id': 1321261922675757056,
#       'source_status_id_str': '1321261922675757056',
#       'source_user_id': 1100475756990349317,
#       'source_user_id_str': '1100475756990349317'},
#      {'id': 1321261909157568513,
#       'id_str': '1321261909157568513',
#       'indices': [19, 42],
#       'media_url': 'http://pbs.twimg.com/media/ElYQtL6XYAE2kuN.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/ElYQtL6XYAE2kuN.jpg',
#       'url': 'https://t.co/wNBzwn1dIi',
#       'display_url': 'pic.twitter.com/wNBzwn1dIi',
#       'expanded_url': 'https://twitter.com/solangepics/status/1321261922675757056/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 510, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 900, 'resize': 'fit'},
#        'large': {'w': 1242, 'h': 931, 'resize': 'fit'}},
#       'source_status_id': 1321261922675757056,
#       'source_status_id_str': '1321261922675757056',
#       'source_user_id': 1100475756990349317,
#       'source_user_id_str': '1100475756990349317'}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 28 01:26:04 +0000 2020',
#     'id': 1321261922675757056,
#     'id_str': '1321261922675757056',
#     'text': '🖤 https://t.co/wNBzwn1dIi',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1321261870439944195,
#        'id_str': '1321261870439944195',
#        'indices': [2, 25],
#        'media_url': 'http://pbs.twimg.com/media/ElYQq7rXUAMP1lM.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/ElYQq7rXUAMP1lM.jpg',
#        'url': 'https://t.co/wNBzwn1dIi',
#        'display_url': 'pic.twitter.com/wNBzwn1dIi',
#        'expanded_url': 'https://twitter.com/solangepics/status/1321261922675757056/photo/1',
#        'type': 'photo',
#        'sizes': {'large': {'w': 1242, 'h': 1242, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1321261870439944195,
#        'id_str': '1321261870439944195',
#        'indices': [2, 25],
#        'media_url': 'http://pbs.twimg.com/media/ElYQq7rXUAMP1lM.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/ElYQq7rXUAMP1lM.jpg',
#        'url': 'https://t.co/wNBzwn1dIi',
#        'display_url': 'pic.twitter.com/wNBzwn1dIi',
#        'expanded_url': 'https://twitter.com/solangepics/status/1321261922675757056/photo/1',
#        'type': 'photo',
#        'sizes': {'large': {'w': 1242, 'h': 1242, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'}}},
#       {'id': 1321261909157568513,
#        'id_str': '1321261909157568513',
#        'indices': [2, 25],
#        'media_url': 'http://pbs.twimg.com/media/ElYQtL6XYAE2kuN.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/ElYQtL6XYAE2kuN.jpg',
#        'url': 'https://t.co/wNBzwn1dIi',
#        'display_url': 'pic.twitter.com/wNBzwn1dIi',
#        'expanded_url': 'https://twitter.com/solangepics/status/1321261922675757056/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 510, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 900, 'resize': 'fit'},
#         'large': {'w': 1242, 'h': 931, 'resize': 'fit'}}}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2633,
#     'favorite_count': 18017,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'und'},
#    'is_quote_status': False,
#    'retweet_count': 2633,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'FFF04D',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1109657367577133057/44jmIiZ6_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1109657367577133057/44jmIiZ6_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18395177/1528451677',
#   'profile_link_color': 'EDE31F',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'EFEFEF',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'}]

# %%
keys_found = []

print(test_h[0].keys())
# Out:
# dict_keys(['id', 'id_str', 'name', 'screen_name', 'location', 'description', 'url', 'entities', 'protected', 'followers_count', 'friends_count', 'listed_count', 'created_at', 'favourites_count', 'utc_offset', 'time_zone', 'geo_enabled', 'verified', 'statuses_count', 'lang', 'status', 'contributors_enabled', 'is_translator', 'is_translation_enabled', 'profile_background_color', 'profile_background_image_url', 'profile_background_image_url_https', 'profile_background_tile', 'profile_image_url', 'profile_image_url_https', 'profile_banner_url', 'profile_link_color', 'profile_sidebar_border_color', 'profile_sidebar_fill_color', 'profile_text_color', 'profile_use_background_image', 'has_extended_profile', 'default_profile', 'default_profile_image', 'following', 'live_following', 'follow_request_sent', 'notifications', 'muting', 'blocking', 'blocked_by', 'translator_type'])

# %%
# Get all the keys
for u in test_h:
    for k in u.keys():
        keys_found.append(k)

print(len(keys_found))
print(keys_found)
# Out:
# 282
# ['id', 'id_str', 'name', 'screen_name', 'location', 'description', 'url', 'entities', 'protected', 'followers_count', 'friends_count', 'listed_count', 'created_at', 'favourites_count', 'utc_offset', 'time_zone', 'geo_enabled', 'verified', 'statuses_count', 'lang', 'status', 'contributors_enabled', 'is_translator', 'is_translation_enabled', 'profile_background_color', 'profile_background_image_url', 'profile_background_image_url_https', 'profile_background_tile', 'profile_image_url', 'profile_image_url_https', 'profile_banner_url', 'profile_link_color', 'profile_sidebar_border_color', 'profile_sidebar_fill_color', 'profile_text_color', 'profile_use_background_image', 'has_extended_profile', 'default_profile', 'default_profile_image', 'following', 'live_following', 'follow_request_sent', 'notifications', 'muting', 'blocking', 'blocked_by', 'translator_type', 'id', 'id_str', 'name', 'screen_name', 'location', 'description', 'url', 'entities', 'protected', 'followers_count', 'friends_count', 'listed_count', 'created_at', 'favourites_count', 'utc_offset', 'time_zone', 'geo_enabled', 'verified', 'statuses_count', 'lang', 'status', 'contributors_enabled', 'is_translator', 'is_translation_enabled', 'profile_background_color', 'profile_background_image_url', 'profile_background_image_url_https', 'profile_background_tile', 'profile_image_url', 'profile_image_url_https', 'profile_banner_url', 'profile_link_color', 'profile_sidebar_border_color', 'profile_sidebar_fill_color', 'profile_text_color', 'profile_use_background_image', 'has_extended_profile', 'default_profile', 'default_profile_image', 'following', 'live_following', 'follow_request_sent', 'notifications', 'muting', 'blocking', 'blocked_by', 'translator_type', 'id', 'id_str', 'name', 'screen_name', 'location', 'description', 'url', 'entities', 'protected', 'followers_count', 'friends_count', 'listed_count', 'created_at', 'favourites_count', 'utc_offset', 'time_zone', 'geo_enabled', 'verified', 'statuses_count', 'lang', 'status', 'contributors_enabled', 'is_translator', 'is_translation_enabled', 'profile_background_color', 'profile_background_image_url', 'profile_background_image_url_https', 'profile_background_tile', 'profile_image_url', 'profile_image_url_https', 'profile_banner_url', 'profile_link_color', 'profile_sidebar_border_color', 'profile_sidebar_fill_color', 'profile_text_color', 'profile_use_background_image', 'has_extended_profile', 'default_profile', 'default_profile_image', 'following', 'live_following', 'follow_request_sent', 'notifications', 'muting', 'blocking', 'blocked_by', 'translator_type', 'id', 'id_str', 'name', 'screen_name', 'location', 'description', 'url', 'entities', 'protected', 'followers_count', 'friends_count', 'listed_count', 'created_at', 'favourites_count', 'utc_offset', 'time_zone', 'geo_enabled', 'verified', 'statuses_count', 'lang', 'status', 'contributors_enabled', 'is_translator', 'is_translation_enabled', 'profile_background_color', 'profile_background_image_url', 'profile_background_image_url_https', 'profile_background_tile', 'profile_image_url', 'profile_image_url_https', 'profile_banner_url', 'profile_link_color', 'profile_sidebar_border_color', 'profile_sidebar_fill_color', 'profile_text_color', 'profile_use_background_image', 'has_extended_profile', 'default_profile', 'default_profile_image', 'following', 'live_following', 'follow_request_sent', 'notifications', 'muting', 'blocking', 'blocked_by', 'translator_type', 'id', 'id_str', 'name', 'screen_name', 'location', 'description', 'url', 'entities', 'protected', 'followers_count', 'friends_count', 'listed_count', 'created_at', 'favourites_count', 'utc_offset', 'time_zone', 'geo_enabled', 'verified', 'statuses_count', 'lang', 'status', 'contributors_enabled', 'is_translator', 'is_translation_enabled', 'profile_background_color', 'profile_background_image_url', 'profile_background_image_url_https', 'profile_background_tile', 'profile_image_url', 'profile_image_url_https', 'profile_bann ...

# %%
# Remove duplicates
keys_found_set = set(keys_found)
len(keys_found_set)
keys_found_set
# Out:
# {'blocked_by',
#  'blocking',
#  'contributors_enabled',
#  'created_at',
#  'default_profile',
#  'default_profile_image',
#  'description',
#  'entities',
#  'favourites_count',
#  'follow_request_sent',
#  'followers_count',
#  'following',
#  'friends_count',
#  'geo_enabled',
#  'has_extended_profile',
#  'id',
#  'id_str',
#  'is_translation_enabled',
#  'is_translator',
#  'lang',
#  'listed_count',
#  'live_following',
#  'location',
#  'muting',
#  'name',
#  'notifications',
#  'profile_background_color',
#  'profile_background_image_url',
#  'profile_background_image_url_https',
#  'profile_background_tile',
#  'profile_banner_url',
#  'profile_image_url',
#  'profile_image_url_https',
#  'profile_link_color',
#  'profile_sidebar_border_color',
#  'profile_sidebar_fill_color',
#  'profile_text_color',
#  'profile_use_background_image',
#  'protected',
#  'screen_name',
#  'status',
#  'statuses_count',
#  'time_zone',
#  'translator_type',
#  'url',
#  'utc_offset',
#  'verified'}

# %%
keys_found_deduped = list(keys_found_set)
len(keys_found_deduped)
print(keys_found_deduped)
# Out:
# ['entities', 'default_profile', 'statuses_count', 'description', 'notifications', 'muting', 'profile_background_tile', 'live_following', 'id_str', 'location', 'profile_background_image_url_https', 'listed_count', 'is_translator', 'url', 'favourites_count', 'lang', 'contributors_enabled', 'profile_link_color', 'id', 'created_at', 'profile_sidebar_fill_color', 'has_extended_profile', 'follow_request_sent', 'profile_sidebar_border_color', 'profile_banner_url', 'profile_use_background_image', 'profile_text_color', 'blocked_by', 'name', 'followers_count', 'friends_count', 'protected', 'utc_offset', 'time_zone', 'profile_image_url_https', 'is_translation_enabled', 'profile_background_color', 'default_profile_image', 'translator_type', 'blocking', 'following', 'geo_enabled', 'verified', 'profile_image_url', 'screen_name', 'profile_background_image_url', 'status']

# %%
print(test_h[0].get('id',None))
# Out:
# 40908929

# %%
print(test_h[0].get('albert',None))
# Out:
# 40908929

# %%
test_i = friend_of_friends(['@Beyonce', 'MariahCarey'],to_df = True)

# %%
test_i
# Out:
#    blocked_by  blocking  contributors_enabled                      created_at  \
# 0       False     False                 False  Mon May 18 16:36:50 +0000 2009
# 1       False     False                 False  Mon Apr 13 02:15:13 +0000 2009
# 2       False     False                 False  Fri Dec 26 20:54:15 +0000 2008
#
#    default_profile  default_profile_image  \
# 0            False                  False
# 1            False                  False
# 2            False                  False
#
#                                          description  \
# 0  USHER: The Vegas Experience | Text me at (404)...
# 1                      Crazy – available everywhere!
# 2                      water, melanin, bones, blood.
#
#                                             entities  favourites_count  \
# 0  {'url': {'urls': [{'url': 'https://t.co/6YDCXW...              1336
# 1  {'url': {'urls': [{'url': 'https://t.co/k3PEdX...              1376
# 2  {'url': {'urls': [{'url': 'https://t.co/8F2cZD...              3362
#
#    follow_request_sent  ...  profile_use_background_image  protected  \
# 0                False  ...                         False      False
# 1                False  ...                         False      False
# 2                False  ...                          True      False
#
#       screen_name                                             status  \
# 0           Usher  {'created_at': 'Thu Oct 29 16:06:41 +0000 2020...
# 1    KELLYROWLAND  {'created_at': 'Sun Nov 01 18:55:53 +0000 2020...
# 2  solangeknowles  {'created_at': 'Wed Oct 28 02:09:35 +0000 2020...
#
#    statuses_count  time_zone translator_type                      url  \
# 0            6041       None         regular  https://t.co/6YDCXWcGDI
# 1           13446       None            none  https://t.co/k3PEdX7tqa
# 2             572       None            none  https://t.co/8F2cZD8D37
#
#    utc_offset verified
# 0        None     True
# 1        None     True
# 2        None     True
#
# [3 rows x 47 columns]

# %%
test_i.head()
# Out:
#    blocked_by  blocking  contributors_enabled                      created_at  \
# 0       False     False                 False  Mon May 18 16:36:50 +0000 2009
# 1       False     False                 False  Mon Apr 13 02:15:13 +0000 2009
# 2       False     False                 False  Fri Dec 26 20:54:15 +0000 2008
#
#    default_profile  default_profile_image  \
# 0            False                  False
# 1            False                  False
# 2            False                  False
#
#                                          description  \
# 0  USHER: The Vegas Experience | Text me at (404)...
# 1                      Crazy – available everywhere!
# 2                      water, melanin, bones, blood.
#
#                                             entities  favourites_count  \
# 0  {'url': {'urls': [{'url': 'https://t.co/6YDCXW...              1336
# 1  {'url': {'urls': [{'url': 'https://t.co/k3PEdX...              1376
# 2  {'url': {'urls': [{'url': 'https://t.co/8F2cZD...              3362
#
#    follow_request_sent  ...  profile_use_background_image  protected  \
# 0                False  ...                         False      False
# 1                False  ...                         False      False
# 2                False  ...                          True      False
#
#       screen_name                                             status  \
# 0           Usher  {'created_at': 'Thu Oct 29 16:06:41 +0000 2020...
# 1    KELLYROWLAND  {'created_at': 'Sun Nov 01 18:55:53 +0000 2020...
# 2  solangeknowles  {'created_at': 'Wed Oct 28 02:09:35 +0000 2020...
#
#    statuses_count  time_zone translator_type                      url  \
# 0            6041       None         regular  https://t.co/6YDCXWcGDI
# 1           13446       None            none  https://t.co/k3PEdX7tqa
# 2             572       None            none  https://t.co/8F2cZD8D37
#
#    utc_offset verified
# 0        None     True
# 1        None     True
# 2        None     True
#
# [3 rows x 47 columns]

# %%
for col in test_i.columns:
    print(col)
# Out:
# blocked_by
# blocking
# contributors_enabled
# created_at
# default_profile
# default_profile_image
# description
# entities
# favourites_count
# follow_request_sent
# followers_count
# following
# friends_count
# geo_enabled
# has_extended_profile
# id
# id_str
# is_translation_enabled
# is_translator
# lang
# listed_count
# live_following
# location
# muting
# name
# notifications
# profile_background_color
# profile_background_image_url
# profile_background_image_url_https
# profile_background_tile
# profile_banner_url
# profile_image_url
# profile_image_url_https
# profile_link_color
# profile_sidebar_border_color
# profile_sidebar_fill_color
# profile_text_color
# profile_use_background_image
# protected
# screen_name
# status
# statuses_count
# time_zone
# translator_type
# url
# utc_offset
# verified

# %%
test_j = friend_of_friends(['@ickbat', '@prsinkis'],to_df = True)

# %%
test_j
# Out:
#    blocked_by  blocking  contributors_enabled                      created_at  \
# 0       False     False                 False  Mon May 21 19:28:00 +0000 2007
# 1       False     False                 False  Fri Mar 23 13:27:42 +0000 2007
# 2       False     False                 False  Tue Jul 15 11:45:30 +0000 2008
# 3       False     False                 False  Sun Apr 13 09:03:20 +0000 2008
#
#    default_profile  default_profile_image  \
# 0            False                  False
# 1            False                  False
# 2            False                  False
# 3             True                  False
#
#                                          description  \
# 0  ‘Live Home Library vol. I’ is out December 4 o...
# 1  Agile Nerd, Bag Nerd, Pen Nerd, Productivity N...
# 2  Hello there .… this Stephen. I don’t read Dire...
# 3               Freelance VFX Artist and film maker.
#
#                                             entities  favourites_count  \
# 0  {'url': {'urls': [{'url': 'https://t.co/W53sHO...                55
# 1  {'url': {'urls': [{'url': 'http://t.co/Xs9TUJj...             48587
# 2  {'description': {'urls': [{'url': 'https://t.c...              2047
# 3  {'url': {'urls': [{'url': 'http://t.co/3gEzezi...                86
#
#    follow_request_sent  ...  profile_use_background_image  protected  \
# 0                False  ...                         False      False
# 1                False  ...                          True      False
# 2                False  ...                         False      False
# 3                False  ...                          True      False
#
#        screen_name                                             status  \
# 0  TheDecemberists  {'created_at': 'Wed Oct 28 19:11:58 +0000 2020...
# 1        rdonoghue  {'created_at': 'Sun Nov 01 22:17:09 +0000 2020...
# 2       stephenfry  {'created_at': 'Sun Nov 01 09:20:19 +0000 2020...
# 3      vfxhamilton  {'created_at': 'Sun Oct 18 01:52:39 +0000 2015...
#
#    statuses_count  time_zone translator_type                      url  \
# 0            1021       None            none  https://t.co/W53sHOkNs9
# 1          114515       None            none   http://t.co/Xs9TUJjyBG
# 2           24676       None            none                     None
# 3            1358       None            none   http://t.co/3gEzezixsw
#
#    utc_offset verified
# 0        None     True
# 1        None    False
# 2        None     True
# 3        None    False
#
# [4 rows x 47 columns]

# %%
for col in test_j.columns:
    print(col)
# Out:
# blocked_by
# blocking
# contributors_enabled
# created_at
# default_profile
# default_profile_image
# description
# entities
# favourites_count
# follow_request_sent
# followers_count
# following
# friends_count
# geo_enabled
# has_extended_profile
# id
# id_str
# is_translation_enabled
# is_translator
# lang
# listed_count
# live_following
# location
# muting
# name
# notifications
# profile_background_color
# profile_background_image_url
# profile_background_image_url_https
# profile_background_tile
# profile_banner_url
# profile_image_url
# profile_image_url_https
# profile_link_color
# profile_sidebar_border_color
# profile_sidebar_fill_color
# profile_text_color
# profile_use_background_image
# protected
# screen_name
# status
# statuses_count
# time_zone
# translator_type
# url
# utc_offset
# verified

# %%
test_l = friend_of_friends(['ezraklein', 'tylercowen']) #TEST L not TEST 1

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-a57edfa16a58> in <module>
# ----> 1 test_1
#
# NameError: name 'test_1' is not defined

# %%
test_l
# Out:
# [{'id': 17119688,
#   'id_str': '17119688',
#   'name': 'Zach Carter',
#   'screen_name': 'zachdcarter',
#   'location': 'Pandemic, USA',
#   'description': 'HuffPoster. Author, The Price of Peace: Money, Democracy and the Life of John Maynard Keynes, available now from Random House: https://t.co/eGlezqpTH9',
#   'url': 'https://t.co/w0w1iqQfNA',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/w0w1iqQfNA',
#       'expanded_url': 'http://www.zacharydcarter.com',
#       'display_url': 'zacharydcarter.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': [{'url': 'https://t.co/eGlezqpTH9',
#       'expanded_url': 'http://bit.ly/2ReiZbI',
#       'display_url': 'bit.ly/2ReiZbI',
#       'indices': [127, 150]}]}},
#   'protected': False,
#   'followers_count': 33255,
#   'friends_count': 3692,
#   'listed_count': 680,
#   'created_at': 'Sun Nov 02 20:56:57 +0000 2008',
#   'favourites_count': 16646,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 10580,
#   'lang': None,
#   'status': {'created_at': 'Sat Oct 31 00:00:08 +0000 2020',
#    'id': 1322327456825696258,
#    'id_str': '1322327456825696258',
#    'text': '@BMillRep Brad is a good person, @zach_carey_ and @blloyd8298 — a good person who has requested to be dunked upon',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'BMillRep',
#       'name': 'Brad Miller',
#       'id': 1052187297662283782,
#       'id_str': '1052187297662283782',
#       'indices': [0, 9]},
#      {'screen_name': 'zach_carey_',
#       'name': 'Zach Carey',
#       'id': 1114935463779893248,
#       'id_str': '1114935463779893248',
#       'indices': [33, 45]},
#      {'screen_name': 'blloyd8298',
#       'name': 'Brandon Lloyd',
#       'id': 38377107,
#       'id_str': '38377107',
#       'indices': [50, 61]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1322323664851869701,
#    'in_reply_to_status_id_str': '1322323664851869701',
#    'in_reply_to_user_id': 1052187297662283782,
#    'in_reply_to_user_id_str': '1052187297662283782',
#    'in_reply_to_screen_name': 'BMillRep',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 6,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1306662298560401410/4rBxlnZq_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1306662298560401410/4rBxlnZq_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17119688/1568155238',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 5418912,
#   'id_str': '5418912',
#   'name': 'John Collison',
#   'screen_name': 'collision',
#   'location': 'San Francisco',
#   'description': 'Co-founder of @stripe.',
#   'url': 'http://t.co/SjMCy56bjS',
#   'entities': {'url': {'urls': [{'url': 'http://t.co/SjMCy56bjS',
#       'expanded_url': 'http://johncollison.ie',
#       'display_url': 'johncollison.ie',
#       'indices': [0, 22]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 86245,
#   'friends_count': 1391,
#   'listed_count': 1418,
#   'created_at': 'Mon Apr 23 02:53:59 +0000 2007',
#   'favourites_count': 33533,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 8844,
#   'lang': None,
#   'status': {'created_at': 'Fri Oct 30 20:41:24 +0000 2020',
#    'id': 1322277443974189057,
#    'id_str': '1322277443974189057',
#    'text': "@sacca @GoPro I just don't see why the Max can't take external audio.",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'sacca',
#       'name': 'Chris Sacca 🇺🇸',
#       'id': 586,
#       'id_str': '586',
#       'indices': [0, 6]},
#      {'screen_name': 'GoPro',
#       'name': 'GoPro',
#       'id': 32340023,
#       'id_str': '32340023',
#       'indices': [7, 13]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1322270601122181120,
#    'in_reply_to_status_id_str': '1322270601122181120',
#    'in_reply_to_user_id': 586,
#    'in_reply_to_user_id_str': '586',
#    'in_reply_to_screen_name': 'sacca',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 14,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '323232',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/2464132281/jbbxl9p7ratdyuposrif_normal.jpeg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2464132281/jbbxl9p7ratdyuposrif_normal.jpeg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/5418912/1392613775',
#   'profile_link_color': '0000FF',
#   'profile_sidebar_border_color': '87BC44',
#   'profile_sidebar_fill_color': 'E0FF92',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 3311286493,
#   'id_str': '3311286493',
#   'name': 'Adam Tooze',
#   'screen_name': 'adam_tooze',
#   'location': 'New York, NY',
#   'description': 'History, economics, politics, climate. Columbia University. Director of European Institute. Born UK, raised FRG, live US. Mensch mit Migrationshintergrund.',
#   'url': 'https://t.co/LcKkHmWNTD',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/LcKkHmWNTD',
#       'expanded_url': 'https://www.adamtooze.com/',
#       'display_url': 'adamtooze.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 102088,
#   'friends_count': 5230,
#   'listed_count': 2086,
#   'created_at': 'Mon Aug 10 07:35:58 +0000 2015',
#   'favourites_count': 7455,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 39784,
#   'lang': None,
#   'status': {'created_at': 'Sun Nov 01 20:49:46 +0000 2020',
#    'id': 1323004325451436036,
#    'id_str': '1323004325451436036',
#    'text': 'RT @bucephalus424: Probably posted this before but something I think about a lot is how over half of all the people killed in WWII were eit…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'bucephalus424',
#       'name': 'Mathias',
#       'id': 946551958076235776,
#       'id_str': '946551958076235776',
#       'indices': [3, 17]}],
#     'urls': []},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Nov 01 20:47:09 +0000 2020',
#     'id': 1323003669047054336,
#     'id_str': '1323003669047054336',
#     'text': 'Probably posted this before but something I think about a lot is how over half of all the people killed in WWII wer… https://t.co/0UxFwtCl3x',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/0UxFwtCl3x',
#        'expanded_url': 'https://twitter.com/i/web/status/1323003669047054336',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 11,
#     'favorite_count': 62,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 11,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/630662078731149314/3jeG3FAH_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/630662078731149314/3jeG3FAH_normal.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3311286493/1529884695',
#   'profile_link_color': '91D2FA',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 75937326,
#   'id_str': '75937326',
#   'name': 'Marc Lipsitch',
#   'screen_name': 'mlipsitch',
#   'location': 'Boston, MA',
#   'description': 'Infectious disease epidemiologist and microbiologist, aspirational barista.     \nmlipsitc@hsph.harvard.edu Director @CCDD_HSPH',
#   'url': 'http://t.co/w36Q2xMUOk',
#   'entities': {'url': {'urls': [{'url': 'http://t.co/w36Q2xMUOk',
#       'expanded_url': 'http://www.hsph.harvard.edu/faculty/marc-lipsitch/',
#       'display_url': 'hsph.harvard.edu/faculty/marc-l…',
#       'indices': [0, 22]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 215297,
#   'friends_count': 1603,
#   'listed_count': 5226,
#   'created_at': 'Mon Sep 21 02:23:41 +0000 2009',
#   'favourites_count': 3427,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 9514,
#   'lang': None,
#   'status': {'created_at': 'Fri Oct 30 08:26:00 +0000 2020',
#    'id': 1322092374508580865,
#    'id_str': '1322092374508580865',
#    'text': 'Delighted that our review of age and SARS-CoV-2 susceptibility/infectiousness is now out led by @EdwardGoldste16 an… https://t.co/sCEIdkLCUX',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'EdwardGoldste16',
#       'name': 'Edward Goldstein',
#       'id': 1255395219828334598,
#       'id_str': '1255395219828334598',
#       'indices': [96, 112]}],
#     'urls': [{'url': 'https://t.co/sCEIdkLCUX',
#       'expanded_url': 'https://twitter.com/i/web/status/1322092374508580865',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 65,
#    'favorite_count': 217,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/437266123029901312/3sTkBOCO_normal.jpeg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/437266123029901312/3sTkBOCO_normal.jpeg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/75937326/1584759307',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 40156330,
#   'id_str': '40156330',
#   'name': 'Scott Gottlieb, MD',
#   'screen_name': 'ScottGottliebMD',
#   'location': 'Washington, DC',
#   'description': 'Resident Fellow @AEI. Partner @NEA. Contributor @CNBC. 23rd Commissioner @US_FDA 2017 to 2019. Boards: @Pfizer @Illumina @AetionInc @TempusLabs',
#   'url': 'https://t.co/CsvXyacSip',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/CsvXyacSip',
#       'expanded_url': 'https://www.aei.org/profile/scott-gottlieb/',
#       'display_url': 'aei.org/profile/scott-…',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 438929,
#   'friends_count': 916,
#   'listed_count': 6756,
#   'created_at': 'Fri May 15 02:39:37 +0000 2009',
#   'favourites_count': 3522,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 17226,
#   'lang': None,
#   'status': {'created_at': 'Sun Nov 01 21:51:47 +0000 2020',
#    'id': 1323019933484257291,
#    'id_str': '1323019933484257291',
#    'text': "RT @CBSNewsPress: Listen: Catch up on today's @FaceTheNation with moderator @margbrennan's interviews with @GOPChairwoman, @RepValDemings,…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'CBSNewsPress',
#       'name': 'CBS News PR',
#       'id': 331211313,
#       'id_str': '331211313',
#       'indices': [3, 16]},
#      {'screen_name': 'FaceTheNation',
#       'name': 'Face The Nation',
#       'id': 205392468,
#       'id_str': '205392468',
#       'indices': [46, 60]},
#      {'screen_name': 'margbrennan',
#       'name': 'Margaret Brennan',
#       'id': 50011708,
#       'id_str': '50011708',
#       'indices': [76, 88]},
#      {'screen_name': 'GOPChairwoman',
#       'name': 'Ronna McDaniel',
#       'id': 2353605901,
#       'id_str': '2353605901',
#       'indices': [107, 121]},
#      {'screen_name': 'RepValDemings',
#       'name': 'Rep. Val Demings',
#       'id': 798973032362606600,
#       'id_str': '798973032362606600',
#       'indices': [123, 137]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Nov 01 21:45:03 +0000 2020',
#     'id': 1323018240818253831,
#     'id_str': '1323018240818253831',
#     'text': "Listen: Catch up on today's @FaceTheNation with moderator @margbrennan's interviews with @GOPChairwoman,… https://t.co/vnG1wyw4Ow",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'FaceTheNation',
#        'name': 'Face The Nation',
#        'id': 205392468,
#        'id_str': '205392468',
#        'indices': [28, 42]},
#       {'screen_name': 'margbrennan',
#        'name': 'Margaret Brennan',
#        'id': 50011708,
#        'id_str': '50011708',
#        'indices': [58, 70]},
#       {'screen_name': 'GOPChairwoman',
#        'name': 'Ronna McDaniel',
#        'id': 2353605901,
#        'id_str': '2353605901',
#        'indices': [89, 103]}],
#      'urls': [{'url': 'https://t.co/vnG1wyw4Ow',
#        'expanded_url': 'https://twitter.com/i/web/status/1323018240818253831',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [106, 129]}]},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 4,
#     'favorite_count': 10,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/939996832574435329/cQICPkCh_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/939996832574435329/cQICPkCh_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40156330/1603589948',
#   'profile_link_color': '0084B4',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 384238210,
#   'id_str': '384238210',
#   'name': 'Philip E. Tetlock',
#   'screen_name': 'PTetlock',
#   'location': 'Philadelphia, PA',
#   'description': 'Annenberg University Professor, Wharton & School of Arts and Sciences. Likes = interesting; Retweets = very interesting; Interesting ≠ endorsement',
#   'url': 'http://t.co/TbgTkPStTm',
#   'entities': {'url': {'urls': [{'url': 'http://t.co/TbgTkPStTm',
#       'expanded_url': 'http://amzn.to/1FWLGAD',
#       'display_url': 'amzn.to/1FWLGAD',
#       'indices': [0, 22]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 35031,
#   'friends_count': 301,
#   'listed_count': 779,
#   'created_at': 'Mon Oct 03 10:02:05 +0000 2011',
#   'favourites_count': 38883,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 1802,
#   'lang': None,
#   'status': {'created_at': 'Sun Nov 01 13:48:16 +0000 2020',
#    'id': 1322898251754983424,
#    'id_str': '1322898251754983424',
#    'text': 'HoaxEye adheres to a touchingly old-fashioned, objectivist epistemology.\nIf a large enough community of co-believer… https://t.co/72qZtdRFcq',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/72qZtdRFcq',
#       'expanded_url': 'https://twitter.com/i/web/status/1322898251754983424',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 11,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/646164135386808320/LEzSRQl0_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/646164135386808320/LEzSRQl0_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/384238210/1504898770',
#   'profile_link_color': '3B94D9',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 75890868,
#   'id_str': '75890868',
#   'name': 'Julia Belluz',
#   'screen_name': 'juliaoftoronto',
#   'location': 'Vienna, Austria',
#   'description': "Health correspondent @voxdotcom #publichealth #globalhealth including #covid19 MIT Knight Fellow '14. Contact me securely @ jbelluz on KeyBase or DM for Signal",
#   'url': 'https://t.co/gELsg9XzIm',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/gELsg9XzIm',
#       'expanded_url': 'https://www.juliabelluz.com/',
#       'display_url': 'juliabelluz.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 37989,
#   'friends_count': 2777,
#   'listed_count': 2060,
#   'created_at': 'Sun Sep 20 22:27:02 +0000 2009',
#   'favourites_count': 6306,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 16754,
#   'lang': None,
#   'status': {'created_at': 'Sun Nov 01 12:50:03 +0000 2020',
#    'id': 1322883603131441152,
#    'id_str': '1322883603131441152',
#    'text': 'Eternally impressed by both @JifferBourg1’s German and her bravery for shining a light with @Ingo_Zamperoni on the… https://t.co/mlN8V3bDVi',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'JifferBourg1',
#       'name': 'Jiffer Bourguignon',
#       'id': 755090449203888128,
#       'id_str': '755090449203888128',
#       'indices': [28, 41]},
#      {'screen_name': 'Ingo_Zamperoni',
#       'name': 'Ingo Zamperoni',
#       'id': 630311520,
#       'id_str': '630311520',
#       'indices': [92, 107]}],
#     'urls': [{'url': 'https://t.co/mlN8V3bDVi',
#       'expanded_url': 'https://twitter.com/i/web/status/1322883603131441152',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F7F4F4',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1138431217731289088/rfEzGpfd_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1138431217731289088/rfEzGpfd_normal.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/75890868/1488594086',
#   'profile_link_color': '3B94D9',
#   'profile_sidebar_border_color': 'E01B87',
#   'profile_sidebar_fill_color': '6BE2ED',
#   'profile_text_color': '000000',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 28838219,
#   'id_str': '28838219',
#   'name': 'Helen Branswell',
#   'screen_name': 'HelenBranswell',
#   'location': 'Boston, MA',
#   'description': 'Sr writer, infectious diseases @statnews. Conspiracy theory free zone; I block rude, racism. Please consider Googling first. #coronavirus #Covid19 #Ebola🇨🇦',
#   'url': 'https://t.co/r0p8qNvYkJ',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/r0p8qNvYkJ',
#       'expanded_url': 'http://www.statnews.com',
#       'display_url': 'statnews.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 197680,
#   'friends_count': 1893,
#   'listed_count': 6230,
#   'created_at': 'Sat Apr 04 18:00:23 +0000 2009',
#   'favourites_count': 12782,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 42284,
#   'lang': None,
#   'status': {'created_at': 'Sun Nov 01 18:51:46 +0000 2020',
#    'id': 1322974633386278914,
#    'id_str': '1322974633386278914',
#    'text': 'Read this, please. https://t.co/cDCV5dZPbd',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/cDCV5dZPbd',
#       'expanded_url': 'https://twitter.com/DrTomFrieden/status/1322324967795662854',
#       'display_url': 'twitter.com/DrTomFrieden/s…',
#       'indices': [19, 42]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1322324967795662854,
#    'quoted_status_id_str': '1322324967795662854',
#    'retweet_count': 27,
#    'favorite_count': 60,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '0056B9',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/478637253481086977/aE2OOz5k_normal.jpeg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/478637253481086977/aE2OOz5k_normal.jpeg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/28838219/1360759841',
#   'profile_link_color': '1200B9',
#   'profile_sidebar_border_color': 'F3F91A',
#   'profile_sidebar_fill_color': '4F85F3',
#   'profile_text_color': '0A080D',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 633980404,
#   'id_str': '633980404',
#   'name': 'David Brooks',
#   'screen_name': 'nytdavidbrooks',
#   'location': 'Washington, DC',
#   'description': 'Op-Ed columnist, @nytopinion. Author of The Road to Character, The Social Animal, and Bobos in Paradise.',
#   'url': 'https://t.co/zqq8Uwjn14',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/zqq8Uwjn14',
#       'expanded_url': 'http://nytimes.com/brooks',
#       'display_url': 'nytimes.com/brooks',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 234308,
#   'friends_count': 768,
#   'listed_count': 3677,
#   'created_at': 'Thu Jul 12 19:18:25 +0000 2012',
#   'favourites_count': 165,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 1944,
#   'lang': None,
#   'status': {'created_at': 'Sat Oct 31 20:55:01 +0000 2020',
#    'id': 1322643261429895169,
#    'id_str': '1322643261429895169',
#    'text': 'Forsyth County went for Trump 72-24 over Clinton.  Evidently some strong pro-Trump turnout this year? https://t.co/lIHp8ohchI',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/lIHp8ohchI',
#       'expanded_url': 'https://twitter.com/Redistrict/status/1322637916313735168',
#       'display_url': 'twitter.com/Redistrict/sta…',
#       'indices': [102, 125]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1322637916313735168,
#    'quoted_status_id_str': '1322637916313735168',
#    'retweet_count': 7,
#    'favorite_count': 59,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/2391855040/Brooks_New-articleInline_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2391855040/Brooks_New-articleInline_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/633980404/1553614438',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1605,
#   'id_str': '1605',
#   'name': 'Sam Altman',
#   'screen_name': 'sama',
#   'location': 'SF',
#   'description': 'ready player sama',
#   'url': 'https://t.co/pfxBFQYy58',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/pfxBFQYy58',
#       'expanded_url': 'http://blog.samaltman.com',
#       'display_url': 'blog.samaltman.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 741792,
#   'friends_count': 526,
#   'listed_count': 5872,
#   'created_at': 'Sun Jul 16 22:01:55 +0000 2006',
#   'favourites_count': 733,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 4839,
#   'lang': None,
#   'status': {'created_at': 'Sun Nov 01 18:20:37 +0000 2020',
#    'id': 1322966792625516545,
#    'id_str': '1322966792625516545',
#    'text': 'The amount of dilution early-stage startups now take (to be fair, for lots of capital) feels like malpractice on th… https://t.co/yGh5Ci6qnR',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/yGh5Ci6qnR',
#       'expanded_url': 'https://twitter.com/i/web/status/1322966792625516545',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 120,
#    'favorite_count': 1038,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '3B94D9',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/804990434455887872/BG0Xh7Oa_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/804990434455887872/BG0Xh7Oa_normal.jpg',
#   'profile_link_color': '89C9FA',
#   'profile_sidebar_border_color': '87BC44',
#   'profile_sidebar_fill_color': 'E0FF92',
#   'profile_text_color': '000000',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 2366113867,
#   'id_str': '2366113867',
#   'name': 'Matt Grossmann',
#   'screen_name': 'MattGrossmann',
#   'location': 'East Lansing, MI',
#   'description': 'Michigan State political scientist & @ippsr director; @niskanencenter fellow; @fivethirtyeight contributor; Science Of Politics host; New Book: Red State Blues',
#   'url': 'https://t.co/D7uIwMY83T',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/D7uIwMY83T',
#       'expanded_url': 'http://www.mattg.org',
#       'display_url': 'mattg.org',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 25109,
#   'friends_count': 2553,
#   'listed_count': 653,
#   'created_at': 'Fri Feb 28 21:20:48 +0000 2014',
#   'favourites_count': 8323,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 21382,
#   'lang': None,
#   'status': {'created_at': 'Sun Nov 01 19:13:42 +0000 2020',
#    'id': 1322980149613203458,
#    'id_str': '1322980149613203458',
#    'text': 'RT @b_schaffner: We also see some evidence in the C(C)ES data of a shrinking racial gap in presidential voting this year. Look at the trend…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'b_schaffner',
#       'name': 'Brian Schaffner',
#       'id': 3330758063,
#       'id_str': '3330758063',
#       'indices': [3, 15]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Oct 31 15:10:43 +0000 2020',
#     'id': 1322556614759665666,
#     'id_str': '1322556614759665666',
#     'text': 'We also see some evidence in the C(C)ES data of a shrinking racial gap in presidential voting this year. Look at th… https://t.co/U9qM9EcYC7',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/U9qM9EcYC7',
#        'expanded_url': 'https://twitter.com/i/web/status/1322556614759665666',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1321401717972471809,
#     'quoted_status_id_str': '1321401717972471809',
#     'retweet_count': 6,
#     'favorite_count': 16,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1321401717972471809,
#    'quoted_status_id_str': '1321401717972471809',
#    'retweet_count': 6,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1057412800778305538/zperxJJs_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1057412800778305538/zperxJJs_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2366113867/1603240948',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 38190583,
#   'id_str': '38190583',
#   'name': 'Daniel Gross',
#   'screen_name': 'danielgross',
#   'location': 'California',
#   'description': 'Pioneer (https://t.co/6JJPSpNvTh). Started Cue, acquired by Apple. Uber, GitHub, Figma, Opendoor, Airtable, Cruise, others. Forgot my IRC login so now I’m here.',
#   'url': 'https://t.co/RWeAxTxoFy',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/RWeAxTxoFy',
#       'expanded_url': 'https://dcgross.com',
#       'display_url': 'dcgross.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': [{'url': 'https://t.co/6JJPSpNvTh',
#       'expanded_url': 'http://pioneer.app',
#       'display_url': 'pioneer.app',
#       'indices': [9, 32]}]}},
#   'protected': False,
#   'followers_count': 39365,
#   'friends_count': 0,
#   'listed_count': 850,
#   'created_at': 'Wed May 06 14:39:30 +0000 2009',
#   'favourites_count': 1266,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 606,
#   'lang': None,
#   'status': {'created_at': 'Sun Nov 01 18:29:22 +0000 2020',
#    'id': 1322968993041448962,
#    'id_str': '1322968993041448962',
#    'text': 'Feynman’s papers a lovely mix of theoretical physics and Cartoon Network. \n\nHere he is on nanotechnology. “Why shou… https://t.co/X1VXZKMAYy',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/X1VXZKMAYy',
#       'expanded_url': 'https://twitter.com/i/web/status/1322968993041448962',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 26,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'FFFFFF',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/3138755755/d5a784ba09507ecf86785b7bad5d87a9_normal.jpeg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3138755755/d5a784ba09507ecf86785b7bad5d87a9_normal.jpeg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/38190583/1521080127',
#   'profile_link_color': 'FAB81E',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 709644992,
#   'id_str': '709644992',
#   'name': 'Devon ☀️',
#   'screen_name': 'devonzuegel',
#   'location': 'San Francisco',
#   'description': "I've gone to look for myself. If I return before I get back, please ask me to wait.\nProduct: @GitHub Code: @Bloom @Affirm Words: @StanfordReview @a16z @NotionHQ",
#   'url': 'https://t.co/Mut8ghOyHS',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/Mut8ghOyHS',
#       'expanded_url': 'http://www.devonzuegel.com/',
#       'display_url': 'devonzuegel.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 34733,
#   'friends_count': 980,
#   'listed_count': 721,
#   'created_at': 'Sat Jul 21 22:03:16 +0000 2012',
#   'favourites_count': 41294,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 11405,
#   'lang': None,
#   'status': {'created_at': 'Sun Nov 01 21:43:44 +0000 2020',
#    'id': 1323017908860063744,
#    'id_str': '1323017908860063744',
#    'text': 'RT @modacitylife: In far too many cities, walking across side streets involves stepping down into “car space”.\n\nDutch engineers keep pedest…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'modacitylife',
#       'name': 'Modacity',
#       'id': 44974922,
#       'id_str': '44974922',
#       'indices': [3, 16]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Oct 30 07:51:46 +0000 2020',
#     'id': 1322083762725888001,
#     'id_str': '1322083762725888001',
#     'text': 'In far too many cities, walking across side streets involves stepping down into “car space”.\n\nDutch engineers keep… https://t.co/iOYWs2jIYJ',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/iOYWs2jIYJ',
#        'expanded_url': 'https://twitter.com/i/web/status/1322083762725888001',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': {'id': '4e696bef7e24d378',
#      'url': 'https://api.twitter.com/1.1/geo/id/4e696bef7e24d378.json',
#      'place_type': 'city',
#      'name': 'Delft',
#      'full_name': 'Delft, Nederland',
#      'country_code': 'NL',
#      'country': 'The Netherlands',
#      'contained_within': [],
#      'bounding_box': {'type': 'Polygon',
#       'coordinates': [[[4.3202114, 51.9663664],
#         [4.407964, 51.9663664],
#         [4.407964, 52.032543],
#         [4.3202114, 52.032543]]]},
#      'attributes': {}},
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 300,
#     'favorite_count': 1190,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 300,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '333333',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme6/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme6/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1157349348541210624/V8l8duun_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1157349348541210624/V8l8duun_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/709644992/1439179171',
#   'profile_link_color': '4099FF',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 14230772,
#   'id_str': '14230772',
#   'name': 'Matt Levine',
#   'screen_name': 'matt_levine',
#   'location': 'New York',
#   'description': 'lunch valuation analyst',
#   'url': 'https://t.co/I4EDMpoIgg',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/I4EDMpoIgg',
#       'expanded_url': 'https://www.bloomberg.com/opinion/matt-levine',
#       'display_url': 'bloomberg.com/opinion/matt-l…',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 125905,
#   'friends_count': 1114,
#   'listed_count': 2345,
#   'created_at': 'Wed Mar 26 23:08:52 +0000 2008',
#   'favourites_count': 26371,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
# ...
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/2756243281/6d3d0ade1bd4364b75d7d0151dce38e5_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2756243281/6d3d0ade1bd4364b75d7d0151dce38e5_normal.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15626406/1602881124',
#   'profile_link_color': '1B95E0',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 73430853,
#   'id_str': '73430853',
#   'name': 'TCEthnicDiningGuide',
#   'screen_name': 'TCEDG',
#   'location': 'Washington, DC',
#   'description': "Tyler Cowen's Ethnic Dining Guide: All food is ethnic food.   http://t.co/wBt2yh5q92",
#   'url': 'http://t.co/wBt2yh5q92',
#   'entities': {'url': {'urls': [{'url': 'http://t.co/wBt2yh5q92',
#       'expanded_url': 'http://TCEDG.com',
#       'display_url': 'TCEDG.com',
#       'indices': [0, 22]}]},
#    'description': {'urls': [{'url': 'http://t.co/wBt2yh5q92',
#       'expanded_url': 'http://TCEDG.com',
#       'display_url': 'TCEDG.com',
#       'indices': [62, 84]}]}},
#   'protected': False,
#   'followers_count': 1785,
#   'friends_count': 6,
#   'listed_count': 81,
#   'created_at': 'Fri Sep 11 17:06:31 +0000 2009',
#   'favourites_count': 1,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 376,
#   'lang': None,
#   'status': {'created_at': 'Sun Oct 04 17:10:22 +0000 2020',
#    'id': 1312802254194343936,
#    'id_str': '1312802254194343936',
#    'text': 'Hedzole, food stand, web site, at Angelika Mosaic for the Farmer’s Market on Sundays, 2910 District Ave., Fairfax,… https://t.co/qy5gyVVScQ',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/qy5gyVVScQ',
#       'expanded_url': 'https://twitter.com/i/web/status/1312802254194343936',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'FFCC4D',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/411569005/TCEDG_profile_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/411569005/TCEDG_profile_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/73430853/1411255129',
#   'profile_link_color': 'FA743E',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'DDFFCC',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 20626452,
#   'id_str': '20626452',
#   'name': 'Tim Bartlett',
#   'screen_name': 'tjbart01',
#   'location': 'New York, NY',
#   'description': 'Philly native, book editor.',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 1665,
#   'friends_count': 2138,
#   'listed_count': 122,
#   'created_at': 'Wed Feb 11 20:51:57 +0000 2009',
#   'favourites_count': 3424,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 2310,
#   'lang': None,
#   'status': {'created_at': 'Sat Oct 24 01:08:43 +0000 2020',
#    'id': 1319808004867371009,
#    'id_str': '1319808004867371009',
#    'text': "RT @rickhasen: I've been calling on my conservative friends to condemn Leonard Leo, one of the key players in building the Federalist Socie…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'rickhasen',
#       'name': 'Rick Hasen',
#       'id': 47034524,
#       'id_str': '47034524',
#       'indices': [3, 13]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Oct 23 17:03:28 +0000 2020',
#     'id': 1319685887685394432,
#     'id_str': '1319685887685394432',
#     'text': "I've been calling on my conservative friends to condemn Leonard Leo, one of the key players in building the Federal… https://t.co/peSZHAvmFd",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/peSZHAvmFd',
#        'expanded_url': 'https://twitter.com/i/web/status/1319685887685394432',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1691,
#     'favorite_count': 3712,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1691,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/713485673/image_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/713485673/image_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 15446531,
#   'id_str': '15446531',
#   'name': 'Matthew Yglesias',
#   'screen_name': 'mattyglesias',
#   'location': 'Washington, DC',
#   'description': 'Author of One Billion Americans. Host of The Weeds. These tweets are worth what you pay for them.',
#   'url': 'https://t.co/nOeiO7sYh8',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/nOeiO7sYh8',
#       'expanded_url': 'http://www.applepodcasts.com/mattyglesias',
#       'display_url': 'applepodcasts.com/mattyglesias',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 478221,
#   'friends_count': 1087,
#   'listed_count': 11152,
#   'created_at': 'Tue Jul 15 21:44:28 +0000 2008',
#   'favourites_count': 23692,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 4115,
#   'lang': None,
#   'status': {'created_at': 'Sun Nov 01 22:05:10 +0000 2020',
#    'id': 1323023300273049600,
#    'id_str': '1323023300273049600',
#    'text': 'I find the idea that there will be any sort of structured debate about this instead of just a chaotic jumble of sta… https://t.co/01jBuze7RJ',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/01jBuze7RJ',
#       'expanded_url': 'https://twitter.com/i/web/status/1323023300273049600',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1322950300660047873,
#    'quoted_status_id_str': '1322950300660047873',
#    'retweet_count': 6,
#    'favorite_count': 103,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'ABB8C2',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1301472914290733056/Kzw7dAZY_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1301472914290733056/Kzw7dAZY_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15446531/1593192544',
#   'profile_link_color': '89C9FA',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 17668696,
#   'id_str': '17668696',
#   'name': 'Natasha C',
#   'screen_name': 'unreformed13',
#   'location': '',
#   'description': 'Love to read and travel.',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 289,
#   'friends_count': 148,
#   'listed_count': 14,
#   'created_at': 'Thu Nov 27 03:43:33 +0000 2008',
#   'favourites_count': 625,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 1267,
#   'lang': None,
#   'status': {'created_at': 'Sat Oct 31 03:01:10 +0000 2020',
#    'id': 1322373019218694144,
#    'id_str': '1322373019218694144',
#    'text': 'RT @PreetBharara: I will either gain or lose 25 lbs between now and Tuesday night',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'PreetBharara',
#       'name': 'Preet Bharara',
#       'id': 834081571493785600,
#       'id_str': '834081571493785600',
#       'indices': [3, 16]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Oct 31 00:21:23 +0000 2020',
#     'id': 1322332808623382529,
#     'id_str': '1322332808623382529',
#     'text': 'I will either gain or lose 25 lbs between now and Tuesday night',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3686,
#     'favorite_count': 68729,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3686,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1275889274714537985/4FsHbDWh_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1275889274714537985/4FsHbDWh_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17668696/1424989582',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 8380442,
#   'id_str': '8380442',
#   'name': 'janegalt',
#   'screen_name': 'janegalt',
#   'location': 'Washington, DC',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': True,
#   'followers_count': 118,
#   'friends_count': 186,
#   'listed_count': 7,
#   'created_at': 'Thu Aug 23 11:34:54 +0000 2007',
#   'favourites_count': 143,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 3954,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '9AE4E8',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/21196242/meganmcwildthing_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/21196242/meganmcwildthing_normal.jpg',
#   'profile_link_color': '0000FF',
#   'profile_sidebar_border_color': '87BC44',
#   'profile_sidebar_fill_color': 'E0FF92',
#   'profile_text_color': '000000',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'}]

# %%
for u in test_l:
    print(u.get('name'))
# Out:
# Zach Carter
# John Collison
# Adam Tooze
# Marc Lipsitch
# Scott Gottlieb, MD
# Philip E. Tetlock
# Julia Belluz
# Helen Branswell
# David Brooks
# Sam Altman
# Matt Grossmann
# Daniel Gross
# Devon ☀️
# Matt Levine
# Ben Horowitz
# Cardiff Garcia
# Ben Thompson
# Julia Galef
# Robert Costa
# Jason Furman
# David Wolpe
# Patrick Collison
# Paul Krugman
# Chris Dixon
# Edward Luce
# Catherine Rampell
# ian bremmer
# Garry Kasparov
# Conor Sen
# Binyamin Appelbaum
# Jonathan Rauch
# Paul Romer
# Cass Sunstein
# Evan Soltas
# Robin Hanson
# Megan McArdle
# Dani Rodrik
# Ross Douthat
# Henry Farrell
# Peter Coy
# Don Rockwell
# Justin Wolfers
# Adam Ozimek
# HugoLindgren
# Lawrence H. Summers
# Monkey Cage
# Rafael Yglesias
# Tim Harford
# David Leonhardt
# TheBrowser
# David Wessel
# Erik Brynjolfsson
# Michael Nielsen
# TCEthnicDiningGuide
# Tim Bartlett
# Matthew Yglesias
# Natasha C
# janegalt

# %%
len(u)
# Out:
# 45
