# %% [markdown]
# ## Homework 1: Advanced Track -- Harvest the Twitter API

# %% [markdown]
# **Objective:** Write a series of functions that allow you to dynamically harvest Twitter data.
#
# **Estimated Time to Complete:** 4-12 hours
#
# #### Sections
#
#  - **Section 1:** Setting up your developer account, using OAuth1 authentication (approx 45-120 minutes)
#  - **Sections 2 & 3:** Navigating the API documentation, getting your first query strings (approx 45-120 minutes)
#  - **Section 3:** Writing your API calls (approx 90 - 360 minutes)
#
# #### What You'll Turn In:
#  - A `.py` (not a Notebook!) file that contains the functions that you were prompted to create.  These should contain comments demonstrating why your code does what it does, and after it's run, the instructor should be able to make the appropriate function calls in Spyder or any other IDE.

# %% [markdown]
# ## Section 1:  Setting Up Your Developer Account

# %% [markdown]
# Most API's require you to do a little pre-work in order to be able to use them, so the first part of this homework assignment will be spent setting up your developer account so you have API Access.

# %% [markdown]
# **Step 1:  Create a Twitter Developer Account**
#
#  - Make sure you have a regular twitter account before you do this
#  - You can apply for a developer account here:  https://developer.twitter.com/en/apply-for-access
#   - Choose either a student or hobbyist/personal account
#   - **note:** these typically get approved right away, but it's possible you might have to wait a little bit......if 15 minutes pass, it might be best to take a break and come back in an hour or so.

# %% [markdown]
# **Step 2:  Create An App**
#
# You don't have to intend to build an official software program to have an app.....this is just a way for you to get authentication keys to use with the API.
#
#  - Go to the menu in the upper right hand corner and click on **Your Name** > **Apps**
#  - Choose **Create An App**
#  - You'll be prompted to enter some information about your app.  Don't worry too much about this, it can say almost anything.  You'll be prompted to list websites where it will be hosted...this can be anything for now.  Use https://generalassemb.ly if you're undecided about what to put.

# %% [markdown]
# **Step 3: Create Your API Tokens**
#
# Now that you have an app, you can use its API tokens to go ahead and make requests like we did in class 3.  Like a lot of API's, the Twitter API uses something called OAuth authentication.
#
# If you didn't wait until the night before this assignment was due and have a spare 30 minutes, you can read a little about it here: https://oauth.net/
#
# In any event, you need API tokens in order to make requests.  Do the following:
#
#  - Go to the **Apps** section of your developer portal
#  - Click on the **Details** button for the app that you just created
#  - Click on the **Keys & Tokens** tab:
#    - Two keys should already be given to you:  **API Key** & **API Secret Key**
#    - Two you have to generate:  **Access token** & **Access token secret**
#  - Generate your Access Token and Access Token Secret keys.  You'll need to write these down when you're done -- you can only see them once.
#
# Now you're ready to make requests to the Twitter api.  Everytime you make a request, you'll need to include the 4 tokens you just created.  (You can always regenerate them for whatever reason).

# %% [markdown]
# **Step 4:  Your First Request**
#
# To make requests to the Twitter API you're going to need a module which is **not** already pre-installed in Anaconda. You'll need to install it via PIP, which is python's package manager.  It's called `requests_oauthlib`.  You can install this via Anaconda Prompt or Terminal by simply typing in the command `pip install requests_oauthlib`, and then you'll be finished.
#
# The logistics of making an OAuth1 authenticated request are very similar to what was done in class 3, but with a few additional steps.  You can see how to do it here:  https://requests.readthedocs.io/en/master/user/authentication/#oauth-1-authentication.  The only thing you'll need to change is the info for your API tokens that are passed into the `OAuth1()` function.
#
# Try making a request to the following URL to confirm that you have things set up correctly: 'https://api.twitter.com/1.1/account/verify_credentials.json'

# %%
# your code here
import requests 
from requests_oauthlib import OAuth1

import os

# %%
API_PUBLIC = os.environ.get("TW_API_KEY")
API_SECRET = os.environ.get("TW_API_SECRET_KEY")
APP_PUBLIC = os.environ.get("TW_PRS_GA_HW_ACCESS_TOKEN")
APP_SECRET = os.environ.get("TW_PRS_GA_HW_ACCESS_TOKEN_SECRET")

# %%
print(f'API_PUBLIC: {type(API_PUBLIC)}')
print(f'API_SECRET: {type(API_SECRET)}')
print(f'APP_PUBLIC: {type(APP_PUBLIC)}')
print(f'APP_SECRET: {type(APP_SECRET)}')
# Out:
# API_PUBLIC: <class 'str'>
# API_SECRET: <class 'str'>
# APP_PUBLIC: <class 'str'>
# APP_SECRET: <class 'str'>

# %%
url = 'https://api.twitter.com/1.1/account/verify_credentials.json'
my_auth = OAuth1(
            API_PUBLIC, #'USER_OAUTH_TOKEN', 
            API_SECRET, #'USER_OAUTH_TOKEN_SECRET'
            APP_PUBLIC, #'YOUR_APP_KEY', 
            APP_SECRET #'YOUR_APP_SECRET',
            )

# %%
type(my_auth)
# Out:
# requests_oauthlib.oauth1_auth.OAuth1

# %%
check_auth = requests.get(url, auth=my_auth)

# %%
check_auth.reason
# Out:
# 'OK'

# %%
check_auth
# Out:
# <Response [200]>

# %%
check_auth.json()
# Out:
# {'id': 1107668042,
#  'id_str': '1107668042',
#  'name': 'Peter Sinkis',
#  'screen_name': 'prsinkis',
#  'location': 'Melbourne, Australia',
#  'description': '',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 15,
#  'friends_count': 80,
#  'listed_count': 0,
#  'created_at': 'Mon Jan 21 00:32:28 +0000 2013',
#  'favourites_count': 12,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 64,
#  'lang': None,
#  'status': {'created_at': 'Fri Jun 29 23:50:41 +0000 2018',
#   'id': 1012845842842116097,
#   'id_str': '1012845842842116097',
#   'text': '@Spikefeedmtg Thanks for the recent MtG finance segment - looking forward to hearing how The Box goes! Question for… https://t.co/Yez24ACtSD',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'Spikefeedmtg',
#      'name': 'Cameron/Curtis',
#      'id': 2350902758,
#      'id_str': '2350902758',
#      'indices': [0, 13]}],
#    'urls': [{'url': 'https://t.co/Yez24ACtSD',
#      'expanded_url': 'https://twitter.com/i/web/status/1012845842842116097',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': 2350902758,
#   'in_reply_to_user_id_str': '2350902758',
#   'in_reply_to_screen_name': 'Spikefeedmtg',
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'C0DEED',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/3137894123/86a2973e95e6764a8fefc99dce53a6ad_normal.jpeg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3137894123/86a2973e95e6764a8fefc99dce53a6ad_normal.jpeg',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none',
#  'suspended': False,
#  'needs_phone_verification': False}

# %% [markdown]
# If you get your json object back, then you're good to go.

# %% [markdown]
# ## Section 2: Searching Tweets

# %% [markdown]
# Most websites you access will have a long string attached to the end of them that look something like this:  `http://thewebsite.com/?year=2019&color=golden%20yellow&user_id=48549395959438`.
#
# Most people have no reason to pay attention to any of this, but all the special symbols at the end are basically encoded commands that say 'return a website that displays x,y,z characteristics.'
#
# When accessing api data, it basically works the same way.

# %% [markdown]
# **Step 1:  Set Up Your First Query String**

# %% [markdown]
# If you go into Twitter and search for the term `Data Science`, you should be brought to a url that looks like this:  `https://twitter.com/search?q=Data%20Science&src=typed_query`
#
# If you'd like, you can drop the `&src=typed_query` from the url and still get the same results.
#
# There are some important details to pay attention to:
#
#  - Like class 3 when we worked with GitHub, there is a **base url**.  In this case it's `https://twitter.com/search`
#  - Whenever you enter a search for something, the base url will be followed by something that looks like `?q=My%20Search%20Term`
#   - The `?` marks the beginning of the query string.  This basically says 'initiate a request with whatever parameters that follow'
#   - The `q` is a **parameter**, essentially some condition to pass into the query string that determines what results will be given back to you.  In this case, `q` encodes the text you typed in into something the API can understand.
#
# **Useful Thing To Do Right Now:** Go back to the Twitter search page, and just try searching for different things, and notice what shows up after the `q=`.  Here are some questions to ask yourself:
#
#  - How are white spaces encoded?  Ie, if you search for `Jonathan Bechtel` in the search box, what shows up to account for the space between the two words?
#  - What about hash symbols?  If you search for `#MeToo`, `#GirlsWhoCode` or `#DataScience`, what happens with that `#` symbol?
#  - Once you get the hang of this, see if you can just re-create some searches yourself by creating the url directly, and bypassing the search box altogether.  Ie, be familiar enough with how searches are formatted that you know `https://twitter.com/search?q=%23DataScience` will take you to the same page as typing in `#DataScience` into the search box.
#
# Now, let's try and make a request for a search for `Data Science`.
#
# If you look at Twitter's docs, you'll see that the base url for the search API is `'https://api.twitter.com/1.1/search/tweets.json`
#
# This means you have to add the `?q=Whatever%20Word%20%Goes%20Here` to the end to complete the search.
#
# So go ahead, and see if you can create your API call for a search for the term `Data Science`.
#
# If you did it correctly, you should have a dictionary with a key called `statuses`, and it'll be a list with all of the tweets returned by your search.

# %%
# Things found out during search:

# Spaces Encoded: %20
# Hashtag encoded: %23
# @ encoded: %40

# %%
# your answer here
search_url = "https://api.twitter.com/1.1/search/tweets.json?q=Data%20Science"
data_sci_api_search = requests.get(search_url, auth=my_auth)

# %%
data_sci_api_search
# Out:
# <Response [200]>

# %%
data_sci_api_search.json()
# Out:
# {'statuses': [{'created_at': 'Thu Oct 29 06:02:01 +0000 2020',
#    'id': 1321693754709868544,
#    'id_str': '1321693754709868544',
#    'text': 'RT @ShekharGupta: ICMR data shows BCG vaccine raises immune response in elderly, could protect against Covid\n\n@MohanaBasu reports\n\n#ThePrin…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ShekharGupta',
#       'name': 'Shekhar Gupta',
#       'id': 2574072036,
#       'id_str': '2574072036',
#       'indices': [3, 16]},
#      {'screen_name': 'MohanaBasu',
#       'name': 'Not A Scientist',
#       'id': 778625737737678848,
#       'id_str': '778625737737678848',
#       'indices': [110, 121]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1271137600565161984,
#     'id_str': '1271137600565161984',
#     'name': 'm sethi',
#     'screen_name': 'msethi16',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 5,
#     'friends_count': 120,
#     'listed_count': 0,
#     'created_at': 'Thu Jun 11 17:50:40 +0000 2020',
#     'favourites_count': 4131,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 428,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 29 05:41:12 +0000 2020',
#     'id': 1321688515898269697,
#     'id_str': '1321688515898269697',
#     'text': 'ICMR data shows BCG vaccine raises immune response in elderly, could protect against Covid\n\n@MohanaBasu reports… https://t.co/Gj8E0iTIFz',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'MohanaBasu',
#        'name': 'Not A Scientist',
#        'id': 778625737737678848,
#        'id_str': '778625737737678848',
#        'indices': [92, 103]}],
#      'urls': [{'url': 'https://t.co/Gj8E0iTIFz',
#        'expanded_url': 'https://twitter.com/i/web/status/1321688515898269697',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [113, 136]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2574072036,
#      'id_str': '2574072036',
#      'name': 'Shekhar Gupta',
#      'screen_name': 'ShekharGupta',
#      'location': ' sg@ThePrint.in',
#      'description': 'Founder, ThePrint. Politics, governance, non-hyphenated liberalism. Warning: Typos are my fingerprints.',
#      'url': 'https://t.co/7QiiZksVzN',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/7QiiZksVzN',
#          'expanded_url': 'http://www.ThePrint.in',
#          'display_url': 'ThePrint.in',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2382664,
#      'friends_count': 1133,
#      'listed_count': 1652,
#      'created_at': 'Wed Jun 18 04:01:13 +0000 2014',
#      'favourites_count': 22685,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 41879,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/563599478653857793/pcq2GJJP_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/563599478653857793/pcq2GJJP_normal.jpeg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2574072036/1603794506',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 11,
#     'favorite_count': 44,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 11,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 06:01:53 +0000 2020',
#    'id': 1321693718814978048,
#    'id_str': '1321693718814978048',
#    'text': 'RT @yaletung: Data suggests that more than 90% of seroconverters make detectible neutralizing antibody responses. These titers remain relat…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'yaletung',
#       'name': 'Yale Tung Chen',
#       'id': 273063195,
#       'id_str': '273063195',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1029496778855309312,
#     'id_str': '1029496778855309312',
#     'name': 'Sabina Walker, Master Appl Science (Neuroscience)',
#     'screen_name': 'SabinaWalker18',
#     'location': 'Sydney NSW Australia',
#     'description': '#PainMatters\nAntibodies\nTCells\nInfectious/presympt\nvs\n#NON_INFECTIOUS\n#Ct_Cutoff\n#FalsePositives\n#AntigenTest\n#NoLockdown\nhttps://t.co/jYDbIL6su6',
#     'url': 'https://t.co/xYeJnR0diQ',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/xYeJnR0diQ',
#         'expanded_url': 'https://painmatters.wordpress.com',
#         'display_url': 'painmatters.wordpress.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/jYDbIL6su6',
#         'expanded_url': 'http://linkedin.com/in/sabinawalker',
#         'display_url': 'linkedin.com/in/sabinawalker',
#         'indices': [122, 145]}]}},
#     'protected': False,
#     'followers_count': 437,
#     'friends_count': 561,
#     'listed_count': 6,
#     'created_at': 'Tue Aug 14 22:35:33 +0000 2018',
#     'favourites_count': 6310,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 6999,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1029498587531493376/uybU-enP_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1029498587531493376/uybU-enP_normal.jpg',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 29 05:55:52 +0000 2020',
#     'id': 1321692205485039616,
#     'id_str': '1321692205485039616',
#     'text': 'Data suggests that more than 90% of seroconverters make detectible neutralizing antibody responses. These titers re… https://t.co/dcZ2xyLLHj',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/dcZ2xyLLHj',
#        'expanded_url': 'https://twitter.com/i/web/status/1321692205485039616',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 273063195,
#      'id_str': '273063195',
#      'name': 'Yale Tung Chen',
#      'screen_name': 'yaletung',
#      'location': 'La Paz, Madrid, España',
#      'description': 'Christian. Husband. Proud dad. In life, U never lose, either U win or U learn. EM physician. U/S addict. [Night-shift Pearl]’s. #FOAMed #POCUS',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 61197,
#      'friends_count': 90,
#      'listed_count': 280,
#      'created_at': 'Sun Mar 27 19:10:11 +0000 2011',
#      'favourites_count': 4675,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 2944,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1067306602678689792/ZUoe5EkR_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1067306602678689792/ZUoe5EkR_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/273063195/1542522567',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 4,
#     'favorite_count': 5,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': True,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 06:01:34 +0000 2020',
#    'id': 1321693639995785222,
#    'id_str': '1321693639995785222',
#    'text': 'RT @byLilyV: #FEATURED #COURSES\nThe #Data #Science Course 2020: Complete #DataScience Bootcamp\nIn demand skills: #Statistical #analysis\n#Py…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'FEATURED', 'indices': [13, 22]},
#      {'text': 'COURSES', 'indices': [23, 31]},
#      {'text': 'Data', 'indices': [36, 41]},
#      {'text': 'Science', 'indices': [42, 50]},
#      {'text': 'DataScience', 'indices': [73, 85]},
#      {'text': 'Statistical', 'indices': [113, 125]},
#      {'text': 'analysis', 'indices': [126, 135]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'byLilyV',
#       'name': "Lily's Education4you.online",
#       'id': 134434122,
#       'id_str': '134434122',
#       'indices': [3, 11]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://www.alteregos.com" rel="nofollow">AlterEgosWorld TW Int</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 417970919,
#     'id_str': '417970919',
#     'name': 'Lydia',
#     'screen_name': 'BiApprentice',
#     'location': 'Tallahassee',
#     'description': 'An excited Business Intelligence Apprentice. Its all about the data!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 690,
#     'friends_count': 209,
#     'listed_count': 11,
#     'created_at': 'Mon Nov 21 15:52:52 +0000 2011',
#     'favourites_count': 1514,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 768,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1650426688/LOPPA-1724_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1650426688/LOPPA-1724_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/417970919/1512772662',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 29 05:17:00 +0000 2020',
#     'id': 1321682425035001858,
#     'id_str': '1321682425035001858',
#     'text': '#FEATURED #COURSES\nThe #Data #Science Course 2020: Complete #DataScience Bootcamp\nIn demand skills: #Statistical… https://t.co/zI3o40tiom',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'FEATURED', 'indices': [0, 9]},
#       {'text': 'COURSES', 'indices': [10, 18]},
#       {'text': 'Data', 'indices': [23, 28]},
#       {'text': 'Science', 'indices': [29, 37]},
#       {'text': 'DataScience', 'indices': [60, 72]},
#       {'text': 'Statistical', 'indices': [100, 112]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/zI3o40tiom',
#        'expanded_url': 'https://twitter.com/i/web/status/1321682425035001858',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [114, 137]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://app.socialpilot.co/" rel="nofollow">SocialPilot.co</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 134434122,
#      'id_str': '134434122',
#      'name': "Lily's Education4you.online",
#      'screen_name': 'byLilyV',
#      'location': 'Bradford, Yorkshire',
#      'description': 'Education affiliate marketer & lifelong learning coach! I can coach you to a learning experience that strengthens your skills and enhances your personality.',
#      'url': 'https://t.co/s4SwMa3ILp',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/s4SwMa3ILp',
#          'expanded_url': 'https://media4you.social/career-development.html',
#          'display_url': 'media4you.social/career-develop…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 22513,
#      'friends_count': 17459,
#      'listed_count': 374,
#      'created_at': 'Sun Apr 18 11:58:09 +0000 2010',
#      'favourites_count': 3648,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 168622,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C3D4D1',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1286667414873276416/1J-cKwoj_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1286667414873276416/1J-cKwoj_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/134434122/1603099299',
#      'profile_link_color': 'E81C4F',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'EADEAA',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 4,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 06:01:12 +0000 2020',
#    'id': 1321693547976904704,
#    'id_str': '1321693547976904704',
#    'text': 'RT @SWAtlasHoover: Epic failure of "experts" Death cert: “social isolation/fail. to thrive rel\'d to COVID-19 restrictions.”  Nh res: “I wou…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SWAtlasHoover',
#       'name': 'Scott W. Atlas',
#       'id': 900174026441580545,
#       'id_str': '900174026441580545',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 372368029,
#     'id_str': '372368029',
#     'name': 'Lisa C',
#     'screen_name': 'classicsgal27',
#     'location': 'Medford, MA',
#     'description': 'Greek, Latin, hockey, writing, politics, and contrarianism (not necessarily in that order)',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 16,
#     'friends_count': 189,
#     'listed_count': 0,
#     'created_at': 'Mon Sep 12 17:01:13 +0000 2011',
#     'favourites_count': 3062,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2129,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C6E2EE',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1539975714/75px-Cyanocitta-cristata-004_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1539975714/75px-Cyanocitta-cristata-004_normal.jpg',
#     'profile_link_color': '1F98C7',
#     'profile_sidebar_border_color': 'C6E2EE',
#     'profile_sidebar_fill_color': 'DAECF4',
#     'profile_text_color': '663B12',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 28 13:58:55 +0000 2020',
#     'id': 1321451382680018947,
#     'id_str': '1321451382680018947',
#     'text': 'Epic failure of "experts" Death cert: “social isolation/fail. to thrive rel\'d to COVID-19 restrictions.”  Nh res: “… https://t.co/xuWKZhcn2H',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/xuWKZhcn2H',
#        'expanded_url': 'https://twitter.com/i/web/status/1321451382680018947',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 900174026441580545,
#      'id_str': '900174026441580545',
#      'name': 'Scott W. Atlas',
#      'screen_name': 'SWAtlasHoover',
#      'location': 'Stanford, CA',
#      'description': 'Robert Wesson Senior Fellow @HooverInst. Author: "Restoring Quality Health Care" https://t.co/jwAcpiDNXz & "In Excellent Health" https://t.co/NFpb0ob4L9 #FactsMatter',
#      'url': 'https://t.co/TSNwq6tWtt',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/TSNwq6tWtt',
#          'expanded_url': 'http://hvr.co/ScottAtlas',
#          'display_url': 'hvr.co/ScottAtlas',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/jwAcpiDNXz',
#          'expanded_url': 'http://hvr.co/RQHC',
#          'display_url': 'hvr.co/RQHC',
#          'indices': [81, 104]},
#         {'url': 'https://t.co/NFpb0ob4L9',
#          'expanded_url': 'http://hvr.co/IEH',
#          'display_url': 'hvr.co/IEH',
#          'indices': [129, 152]}]}},
#      'protected': False,
#      'followers_count': 78115,
#      'friends_count': 60,
#      'listed_count': 553,
#      'created_at': 'Wed Aug 23 01:53:07 +0000 2017',
#      'favourites_count': 681,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 866,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/911351072559554562/-BVffmWy_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/911351072559554562/-BVffmWy_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/900174026441580545/1508975626',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1321422980505837570,
#     'quoted_status_id_str': '1321422980505837570',
#     'quoted_status': {'created_at': 'Wed Oct 28 12:06:04 +0000 2020',
#      'id': 1321422980505837570,
#      'id_str': '1321422980505837570',
#      'text': 'The hidden coronavirus health crisis: Elderly people are dying of isolation in nursing homes.… https://t.co/xroqfSZOzC',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/xroqfSZOzC',
#         'expanded_url': 'https://twitter.com/i/web/status/1321422980505837570',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [95, 118]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 14173315,
#       'id_str': '14173315',
#       'name': 'NBC News',
#       'screen_name': 'NBCNews',
#       'location': 'New York, NY',
#       'description': 'News updates from around the 🌎, all day, every day. Home of @NBCBLK, @NBCLatino, @NBCAsianAmerica, @NBCOUT & more.',
#       'url': 'https://t.co/HOBYJP3M3J',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/HOBYJP3M3J',
#           'expanded_url': 'http://NBCNews.com/PlanYourVote',
#           'display_url': 'NBCNews.com/PlanYourVote',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 7856768,
#       'friends_count': 1844,
#       'listed_count': 44328,
#       'created_at': 'Tue Mar 18 23:19:17 +0000 2008',
#       'favourites_count': 785,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': True,
#       'verified': True,
#       'statuses_count': 278246,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': '062131',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_tile': True,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1108426393287868423/CyLn5GVQ_normal.png',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1108426393287868423/CyLn5GVQ_normal.png',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14173315/1593479928',
#       'profile_link_color': '5172A0',
#       'profile_sidebar_border_color': 'FFFFFF',
#       'profile_sidebar_fill_color': 'FFFFFF',
#       'profile_text_color': '000000',
#       'profile_use_background_image': True,
#       'has_extended_profile': False,
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 161,
#      'favorite_count': 311,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'retweet_count': 892,
#     'favorite_count': 2347,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1321422980505837570,
#    'quoted_status_id_str': '1321422980505837570',
#    'retweet_count': 892,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 06:01:11 +0000 2020',
#    'id': 1321693542461394945,
#    'id_str': '1321693542461394945',
#    'text': 'RT @OBusybody: INCREDIBLE, @IDPH &amp; @Govpritzker:\n\n👨\u200d💼Using % positive after advisors said it “should not be used"\n💵Paid a firm (also workin…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'OBusybody',
#       'name': 'Omnipotent Moral Busybody',
#       'id': 1250647983097614336,
#       'id_str': '1250647983097614336',
#       'indices': [3, 13]},
#      {'screen_name': 'IDPH',
#       'name': 'IDPH',
#       'id': 71652085,
#       'id_str': '71652085',
#       'indices': [27, 32]},
#      {'screen_name': 'GovPritzker',
#       'name': 'Governor JB Pritzker',
#       'id': 1084817523378454529,
#       'id_str': '1084817523378454529',
#       'indices': [39, 51]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1392450798,
#     'id_str': '1392450798',
#     'name': 'anne hage',
#     'screen_name': 'abbavitch',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1839,
#     'friends_count': 797,
#     'listed_count': 5,
#     'created_at': 'Tue Apr 30 16:31:06 +0000 2013',
#     'favourites_count': 303081,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 315729,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 29 03:50:13 +0000 2020',
#     'id': 1321660583461163008,
#     'id_str': '1321660583461163008',
#     'text': 'INCREDIBLE, @IDPH &amp; @Govpritzker:\n\n👨\u200d💼Using % positive after advisors said it “should not be used"\n💵Paid a firm (al… https://t.co/lG6OCsjhDw',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'IDPH',
#        'name': 'IDPH',
#        'id': 71652085,
#        'id_str': '71652085',
#        'indices': [12, 17]},
#       {'screen_name': 'GovPritzker',
#        'name': 'Governor JB Pritzker',
#        'id': 1084817523378454529,
#        'id_str': '1084817523378454529',
#        'indices': [24, 36]}],
#      'urls': [{'url': 'https://t.co/lG6OCsjhDw',
#        'expanded_url': 'https://twitter.com/i/web/status/1321660583461163008',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [121, 144]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1250647983097614336,
#      'id_str': '1250647983097614336',
#      'name': 'Omnipotent Moral Busybody',
#      'screen_name': 'OBusybody',
#      'location': '',
#      'description': 'One of the few remaining politically neutral social scientists.  Married to a smarter, politically neutral social scientist.',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4570,
#      'friends_count': 382,
#      'listed_count': 63,
#      'created_at': 'Thu Apr 16 04:51:38 +0000 2020',
#      'favourites_count': 6936,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 4701,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1252420612724678657/QyshkGvn_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1252420612724678657/QyshkGvn_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1250647983097614336/1587403943',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 31,
#     'favorite_count': 68,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 31,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 06:01:09 +0000 2020',
#    'id': 1321693534454489090,
#    'id_str': '1321693534454489090',
#    'text': 'RT @yaletung: Data suggests that more than 90% of seroconverters make detectible neutralizing antibody responses. These titers remain relat…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'yaletung',
#       'name': 'Yale Tung Chen',
#       'id': 273063195,
#       'id_str': '273063195',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1293245557054504961,
#     'id_str': '1293245557054504961',
#     'name': 'DataScienceSentiment_Bot',
#     'screen_name': 'SigularityHub',
#     'location': '',
#     'description': 'We will serve you with everything revolving around Datascience and Machine Learning. How is the world feeling about your field',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 142,
#     'friends_count': 0,
#     'listed_count': 2,
#     'created_at': 'Tue Aug 11 17:59:09 +0000 2020',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 10788,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1293246094923780098/RxN0fj-W_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1293246094923780098/RxN0fj-W_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 29 05:55:52 +0000 2020',
#     'id': 1321692205485039616,
#     'id_str': '1321692205485039616',
#     'text': 'Data suggests that more than 90% of seroconverters make detectible neutralizing antibody responses. These titers re… https://t.co/dcZ2xyLLHj',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/dcZ2xyLLHj',
#        'expanded_url': 'https://twitter.com/i/web/status/1321692205485039616',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 273063195,
#      'id_str': '273063195',
#      'name': 'Yale Tung Chen',
#      'screen_name': 'yaletung',
#      'location': 'La Paz, Madrid, España',
#      'description': 'Christian. Husband. Proud dad. In life, U never lose, either U win or U learn. EM physician. U/S addict. [Night-shift Pearl]’s. #FOAMed #POCUS',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 61197,
#      'friends_count': 90,
#      'listed_count': 280,
#      'created_at': 'Sun Mar 27 19:10:11 +0000 2011',
#      'favourites_count': 4675,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 2944,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1067306602678689792/ZUoe5EkR_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1067306602678689792/ZUoe5EkR_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/273063195/1542522567',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 4,
#     'favorite_count': 5,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': True,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 06:00:43 +0000 2020',
#    'id': 1321693427193425922,
#    'id_str': '1321693427193425922',
#    'text': 'RT @GavinNewsom: Washington, Oregon, and Nevada have joined California’s Scientific Safety Review Workgroup -- filled with top health exper…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'GavinNewsom',
#       'name': 'Gavin Newsom',
#       'id': 11347122,
#       'id_str': '11347122',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 10362072,
#     'id_str': '10362072',
#     'name': 'tajones 🌊🌎💞🏳️\u200d🌈',
#     'screen_name': 'ceili_woman',
#     'location': 'The Emerald City',
#     'description': 'Librarian🌳☘️📚👊#Resist💙 #DefendDACA #GunReformNow #FamiliesBelongTogether #BLM #LoveIsLove #TeamPelosi #BidenHarris2020',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3651,
#     'friends_count': 3985,
#     'listed_count': 14,
#     'created_at': 'Sun Nov 18 19:19:06 +0000 2007',
#     'favourites_count': 178557,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 159023,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'EDECE9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme3/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme3/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1316446061930508288/Jsh2awKH_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1316446061930508288/Jsh2awKH_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/10362072/1597190419',
#     'profile_link_color': '088253',
#     'profile_sidebar_border_color': 'D3D2CF',
#     'profile_sidebar_fill_color': 'E3E2DE',
#     'profile_text_color': '634047',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Oct 27 19:20:34 +0000 2020',
#     'id': 1321169940192194561,
#     'id_str': '1321169940192194561',
#     'text': 'Washington, Oregon, and Nevada have joined California’s Scientific Safety Review Workgroup -- filled with top healt… https://t.co/9vZLdhRciz',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/9vZLdhRciz',
#        'expanded_url': 'https://twitter.com/i/web/status/1321169940192194561',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 11347122,
#      'id_str': '11347122',
#      'name': 'Gavin Newsom',
#      'screen_name': 'GavinNewsom',
#      'location': 'California',
#      'description': 'Husband and father. 40th Governor of California. Former Lt. Governor of California. Former San Francisco Mayor. Personal account.',
#      'url': 'https://t.co/FY42VMHC5n',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/FY42VMHC5n',
#          'expanded_url': 'http://www.instagram.com/gavinnewsom',
#          'display_url': 'instagram.com/gavinnewsom',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1930511,
#      'friends_count': 22943,
#      'listed_count': 9033,
#      'created_at': 'Wed Dec 19 19:53:42 +0000 2007',
#      'favourites_count': 4788,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 13376,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000D48',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1275898304358789121/9dE59bQp_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1275898304358789121/9dE59bQp_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/11347122/1593149984',
#      'profile_link_color': '000D48',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'B28251',
#      'profile_text_color': '8A795F',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1318272700343709696,
#     'quoted_status_id_str': '1318272700343709696',
#     'quoted_status': {'created_at': 'Mon Oct 19 19:27:58 +0000 2020',
#      'id': 1318272700343709696,
#      'id_str': '1318272700343709696',
#      'text': 'Like our approach to #COVID19, when it comes to a vaccine, CA will be guided by science.\n\nToday, we announced our S… https://t.co/SdETFb4Pp6',
#      'truncated': True,
#      'entities': {'hashtags': [{'text': 'COVID19', 'indices': [21, 29]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/SdETFb4Pp6',
#         'expanded_url': 'https://twitter.com/i/web/status/1318272700343709696',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
# ...
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 05:59:55 +0000 2020',
#    'id': 1321693225850032128,
#    'id_str': '1321693225850032128',
#    'text': "RT @discerndatapp: Discern's Data Science Value-Add Tracker discovers how companies are benefiting from data science tools.\n@ModeAnalytics…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'discerndatapp',
#       'name': 'Discern Data',
#       'id': 1309157844084764672,
#       'id_str': '1309157844084764672',
#       'indices': [3, 17]},
#      {'screen_name': 'ModeAnalytics',
#       'name': 'Mode',
#       'id': 1650684756,
#       'id_str': '1650684756',
#       'indices': [124, 138]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/epuujee" rel="nofollow">Puujee Puje</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 108248850,
#     'id_str': '108248850',
#     'name': 'Purevdorj Enkhjargal',
#     'screen_name': 'epuujee',
#     'location': 'Mongolia',
#     'description': 'Data Science Enthusiast \n#KeepLearning #ML #NLP #DL #DataScience #AI #MN',
#     'url': 'https://t.co/jYrVhNfjlD',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/jYrVhNfjlD',
#         'expanded_url': 'https://github.com/epuujee/data_science',
#         'display_url': 'github.com/epuujee/data_s…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2356,
#     'friends_count': 285,
#     'listed_count': 29,
#     'created_at': 'Mon Jan 25 09:49:57 +0000 2010',
#     'favourites_count': 14728,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 77681,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'BBD9DE',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1265477579504406530/7U6WV3Eu_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1265477579504406530/7U6WV3Eu_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/108248850/1410248485',
#     'profile_link_color': 'A5C6C1',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '44585E',
#     'profile_text_color': '86B7B1',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 29 05:59:48 +0000 2020',
#     'id': 1321693196154400768,
#     'id_str': '1321693196154400768',
#     'text': "Discern's Data Science Value-Add Tracker discovers how companies are benefiting from data science tools.… https://t.co/X3MBr7DKhS",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/X3MBr7DKhS',
#        'expanded_url': 'https://twitter.com/i/web/status/1321693196154400768',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [106, 129]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1309157844084764672,
#      'id_str': '1309157844084764672',
#      'name': 'Discern Data',
#      'screen_name': 'discerndatapp',
#      'location': '',
#      'description': 'Data science community ; discovering real-world use cases and the best tools.\nDM open.',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 42,
#      'friends_count': 513,
#      'listed_count': 0,
#      'created_at': 'Thu Sep 24 15:48:59 +0000 2020',
#      'favourites_count': 16,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 32,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1309281855523270658/xZKwj-Vz_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1309281855523270658/xZKwj-Vz_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 05:59:48 +0000 2020',
#    'id': 1321693196154400768,
#    'id_str': '1321693196154400768',
#    'text': "Discern's Data Science Value-Add Tracker discovers how companies are benefiting from data science tools.… https://t.co/X3MBr7DKhS",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/X3MBr7DKhS',
#       'expanded_url': 'https://twitter.com/i/web/status/1321693196154400768',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [106, 129]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1309157844084764672,
#     'id_str': '1309157844084764672',
#     'name': 'Discern Data',
#     'screen_name': 'discerndatapp',
#     'location': '',
#     'description': 'Data science community ; discovering real-world use cases and the best tools.\nDM open.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 42,
#     'friends_count': 513,
#     'listed_count': 0,
#     'created_at': 'Thu Sep 24 15:48:59 +0000 2020',
#     'favourites_count': 16,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 32,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1309281855523270658/xZKwj-Vz_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1309281855523270658/xZKwj-Vz_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 05:59:30 +0000 2020',
#    'id': 1321693119985844225,
#    'id_str': '1321693119985844225',
#    'text': 'RT @ShekharGupta: ICMR data shows BCG vaccine raises immune response in elderly, could protect against Covid\n\n@MohanaBasu reports\n\n#ThePrin…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ShekharGupta',
#       'name': 'Shekhar Gupta',
#       'id': 2574072036,
#       'id_str': '2574072036',
#       'indices': [3, 16]},
#      {'screen_name': 'MohanaBasu',
#       'name': 'Not A Scientist',
#       'id': 778625737737678848,
#       'id_str': '778625737737678848',
#       'indices': [110, 121]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 37713499,
#     'id_str': '37713499',
#     'name': 'Nithyanand',
#     'screen_name': 'niths_v',
#     'location': 'bangalore India',
#     'description': 'Atheists fear almighty god more than polytheist idolaters!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 20,
#     'friends_count': 64,
#     'listed_count': 0,
#     'created_at': 'Mon May 04 17:54:54 +0000 2009',
#     'favourites_count': 7692,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 1654,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1000072114/Marvin_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1000072114/Marvin_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 29 05:41:12 +0000 2020',
#     'id': 1321688515898269697,
#     'id_str': '1321688515898269697',
#     'text': 'ICMR data shows BCG vaccine raises immune response in elderly, could protect against Covid\n\n@MohanaBasu reports… https://t.co/Gj8E0iTIFz',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'MohanaBasu',
#        'name': 'Not A Scientist',
#        'id': 778625737737678848,
#        'id_str': '778625737737678848',
#        'indices': [92, 103]}],
#      'urls': [{'url': 'https://t.co/Gj8E0iTIFz',
#        'expanded_url': 'https://twitter.com/i/web/status/1321688515898269697',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [113, 136]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2574072036,
#      'id_str': '2574072036',
#      'name': 'Shekhar Gupta',
#      'screen_name': 'ShekharGupta',
#      'location': ' sg@ThePrint.in',
#      'description': 'Founder, ThePrint. Politics, governance, non-hyphenated liberalism. Warning: Typos are my fingerprints.',
#      'url': 'https://t.co/7QiiZksVzN',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/7QiiZksVzN',
#          'expanded_url': 'http://www.ThePrint.in',
#          'display_url': 'ThePrint.in',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2382664,
#      'friends_count': 1133,
#      'listed_count': 1652,
#      'created_at': 'Wed Jun 18 04:01:13 +0000 2014',
#      'favourites_count': 22685,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 41879,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/563599478653857793/pcq2GJJP_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/563599478653857793/pcq2GJJP_normal.jpeg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2574072036/1603794506',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 11,
#     'favorite_count': 44,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 11,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.112,
#   'max_id': 1321693754709868544,
#   'max_id_str': '1321693754709868544',
#   'next_results': '?max_id=1321693119985844224&q=Data%20Science&include_entities=1',
#   'query': 'Data+Science',
#   'refresh_url': '?since_id=1321693754709868544&q=Data%20Science&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# For good measure, try doing a search for tweets relating to `#MeToo` as well.

# %%
# your answer here
# your answer here
search_url = "https://api.twitter.com/1.1/search/tweets.json?q=%23MeToo"
metoo_api_search = requests.get(search_url, auth=my_auth)

# %%
metoo_api_search
# Out:
# <Response [200]>

# %%
metoo_api_search.reason
# Out:
# 'OK'

# %%
metoo_api_search.json()
# Out:
# {'statuses': [{'created_at': 'Thu Oct 29 06:04:28 +0000 2020',
#    'id': 1321694369846489089,
#    'id_str': '1321694369846489089',
#    'text': 'RT @Adithya_tweets: திருமாவளவன் தீட்டிய அரிவாள் தென்னவர் சுழற்றியதே - வைரமுத்து \n\nமுதல்ல நீ போய் அந்த #MeToo பஞ்சாயத்த முடிச்சிட்டு வந்து…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [102, 108]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Adithya_tweets',
#       'name': 'Adithya',
#       'id': 1283688396490043392,
#       'id_str': '1283688396490043392',
#       'indices': [3, 18]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ta', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 800187739031228416,
#     'id_str': '800187739031228416',
#     'name': 'Venkatakrishnan',
#     'screen_name': 'Venkata15902763',
#     'location': 'Tirunelveli,Tamilnadu, India',
#     'description': 'NO ARGUMENT. ..ONLY JUDGEMENT. . .',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 351,
#     'friends_count': 949,
#     'listed_count': 1,
#     'created_at': 'Sun Nov 20 04:03:18 +0000 2016',
#     'favourites_count': 29763,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 29575,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1283417160975396865/TwW36vRz_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1283417160975396865/TwW36vRz_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/800187739031228416/1517494508',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 29 00:56:39 +0000 2020',
#     'id': 1321616907439542273,
#     'id_str': '1321616907439542273',
#     'text': 'திருமாவளவன் தீட்டிய அரிவாள் தென்னவர் சுழற்றியதே - வைரமுத்து \n\nமுதல்ல நீ போய் அந்த #MeToo பஞ்சாயத்த முடிச்சிட்டு வந்… https://t.co/HsoiidVnAS',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'MeToo', 'indices': [82, 88]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/HsoiidVnAS',
#        'expanded_url': 'https://twitter.com/i/web/status/1321616907439542273',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'ta', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1283688396490043392,
#      'id_str': '1283688396490043392',
#      'name': 'Adithya',
#      'screen_name': 'Adithya_tweets',
#      'location': '',
#      'description': 'The World Is Not Enough..!\n📸Photography Lover\n📐Civil Engineer',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 412,
#      'friends_count': 151,
#      'listed_count': 1,
#      'created_at': 'Thu Jul 16 09:02:32 +0000 2020',
#      'favourites_count': 9667,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 2217,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1321363727615057920/gNN6unEa_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1321363727615057920/gNN6unEa_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1283688396490043392/1603932465',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 9,
#     'favorite_count': 41,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'ta'},
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ta'},
#   {'created_at': 'Thu Oct 29 06:03:10 +0000 2020',
#    'id': 1321694043571544064,
#    'id_str': '1321694043571544064',
#    'text': '@amohit17 #MeToo',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [10, 16]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'amohit17',
#       'name': 'Mohit Anand',
#       'id': 53631661,
#       'id_str': '53631661',
#       'indices': [0, 9]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1321466815747424279,
#    'in_reply_to_status_id_str': '1321466815747424279',
#    'in_reply_to_user_id': 53631661,
#    'in_reply_to_user_id_str': '53631661',
#    'in_reply_to_screen_name': 'amohit17',
#    'user': {'id': 444656678,
#     'id_str': '444656678',
#     'name': 'Nikhil Maruthi™️🇮🇳',
#     'screen_name': 'nikhilmaruthi',
#     'location': 'Mysore, India',
#     'description': "ಕನ್ನಡಿಗ | MBA in Media Management |Amitian | Social Media Strategist | Staunchly Believe That We Don't Have To Love The Government To Love Our Country",
#     'url': 'https://t.co/HxINEOuzOa',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/HxINEOuzOa',
#         'expanded_url': 'http://nikhilmaruthi.com',
#         'display_url': 'nikhilmaruthi.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 286,
#     'friends_count': 846,
#     'listed_count': 1,
#     'created_at': 'Fri Dec 23 13:56:43 +0000 2011',
#     'favourites_count': 2981,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 3005,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1019921321654808576/VSVfuCt-_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1019921321654808576/VSVfuCt-_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/444656678/1532003289',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'und'},
#   {'created_at': 'Thu Oct 29 06:01:03 +0000 2020',
#    'id': 1321693509720657920,
#    'id_str': '1321693509720657920',
#    'text': "RT @WChivhanga: Rape apologists are rapists!\nMen who 'joke' about rape are rapists!\nIf your default setting when you hear about a rape case…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'WChivhanga',
#       'name': 'Willson Chivhanga',
#       'id': 3004023149,
#       'id_str': '3004023149',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1111681350082482178,
#     'id_str': '1111681350082482178',
#     'name': 'Lakers🏆',
#     'screen_name': 'ThatoMwendo',
#     'location': 'Zomba, Malawi',
#     'description': 'Lakeshow',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 379,
#     'friends_count': 353,
#     'listed_count': 1,
#     'created_at': 'Fri Mar 29 17:27:42 +0000 2019',
#     'favourites_count': 3903,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 3352,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1299312089886945280/kj71E2hv_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1299312089886945280/kj71E2hv_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1111681350082482178/1598202266',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 29 05:06:38 +0000 2020',
#     'id': 1321679815670407169,
#     'id_str': '1321679815670407169',
#     'text': "Rape apologists are rapists!\nMen who 'joke' about rape are rapists!\nIf your default setting when you hear about a r… https://t.co/bQZJJ0SzAX",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/bQZJJ0SzAX',
#        'expanded_url': 'https://twitter.com/i/web/status/1321679815670407169',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3004023149,
#      'id_str': '3004023149',
#      'name': 'Willson Chivhanga',
#      'screen_name': 'WChivhanga',
#      'location': 'Malawi',
#      'description': 'By changing the social order that oppresses women, the revolution creates the conditions for their genuine emancipation - Thomas Sankara',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1730,
#      'friends_count': 4157,
#      'listed_count': 5,
#      'created_at': 'Thu Jan 29 08:02:25 +0000 2015',
#      'favourites_count': 6636,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 7329,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': True,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1312841016932786176/uHnwvYlO_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1312841016932786176/uHnwvYlO_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3004023149/1596653158',
#      'profile_link_color': '19CF86',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5,
#     'favorite_count': 6,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 05:59:48 +0000 2020',
#    'id': 1321693195017756672,
#    'id_str': '1321693195017756672',
#    'text': '. @AahanaKumra said that even though she has seen a shift in conversation due to #MeToo, she isn’t sure how much of… https://t.co/o66yVlPQU0',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [81, 87]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'AahanaKumra',
#       'name': 'Aahana Kumra ll۞𝑻𝒂𝒎𝒆𝒏𝒂 𝑯𝒂𝒎𝒊𝒅۞',
#       'id': 78191269,
#       'id_str': '78191269',
#       'indices': [2, 14]}],
#     'urls': [{'url': 'https://t.co/o66yVlPQU0',
#       'expanded_url': 'https://twitter.com/i/web/status/1321693195017756672',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 204461353,
#     'id_str': '204461353',
#     'name': 'Hauterfly',
#     'screen_name': 'TheHauterfly',
#     'location': 'Mumbai',
#     'description': 'Hauterfly is the millennial woman’s space. Unapologetic, proud and opinionated Hauterfly is taking a stand on all things relevant and trending.',
#     'url': 'https://t.co/rvU4LX9LML',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/rvU4LX9LML',
#         'expanded_url': 'https://thehauterfly.com/',
#         'display_url': 'thehauterfly.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3561,
#     'friends_count': 3374,
#     'listed_count': 59,
#     'created_at': 'Mon Oct 18 19:04:12 +0000 2010',
#     'favourites_count': 2511,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 10921,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1220259440378540032/RJlYbTBk_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1220259440378540032/RJlYbTBk_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/204461353/1575530883',
#     'profile_link_color': 'F00A71',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 05:59:25 +0000 2020',
#    'id': 1321693098154561536,
#    'id_str': '1321693098154561536',
#    'text': 'RT @AlinejadMasih: The woman called me last night &amp; said she was raped. Today she was forced to issue a public denial on national TV.  Her…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'AlinejadMasih',
#       'name': 'Masih Alinejad 🏳️',
#       'id': 947924373029171200,
#       'id_str': '947924373029171200',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 121278681,
#     'id_str': '121278681',
#     'name': 'mahsa pelosky',
#     'screen_name': 'mahsapelosky',
#     'location': 'New York City',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 503,
#     'friends_count': 2458,
#     'listed_count': 8,
#     'created_at': 'Tue Mar 09 00:55:00 +0000 2010',
#     'favourites_count': 10789,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 12607,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1807458250/mpphoto_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1807458250/mpphoto_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Oct 23 15:21:27 +0000 2020',
#     'id': 1319660213704794114,
#     'id_str': '1319660213704794114',
#     'text': 'The woman called me last night &amp; said she was raped. Today she was forced to issue a public denial on national TV.… https://t.co/0nHSdlvTuc',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/0nHSdlvTuc',
#        'expanded_url': 'https://twitter.com/i/web/status/1319660213704794114',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [120, 143]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 947924373029171200,
#      'id_str': '947924373029171200',
#      'name': 'Masih Alinejad 🏳️',
#      'screen_name': 'AlinejadMasih',
#      'location': '',
#      'description': 'Iranian journalist and activist. Founder of #United4Navid, #WhiteWednesdays & #MyStealthyFreedom. My Email address: masih.author@gmail.com',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 207004,
#      'friends_count': 919,
#      'listed_count': 946,
#      'created_at': 'Mon Jan 01 20:15:56 +0000 2018',
#      'favourites_count': 12356,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 14628,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1294283123249885184/MHuA2zZm_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1294283123249885184/MHuA2zZm_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/947924373029171200/1596809135',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1926,
#     'favorite_count': 4435,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1926,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 05:59:13 +0000 2020',
#    'id': 1321693049865601026,
#    'id_str': '1321693049865601026',
#    'text': "RT @peterdaou: WHY I'M VOTING GREEN (cont.)\n\nThe Democratic Party trashed the #MeToo movement without hesitation. They've fought #MedicareF…",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [78, 84]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'peterdaou',
#       'name': 'Peter Daou',
#       'id': 18464266,
#       'id_str': '18464266',
#       'indices': [3, 13]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 598973191,
#     'id_str': '598973191',
#     'name': 'TRANSform',
#     'screen_name': 'tates5a',
#     'location': 'Austin, TX',
#     'description': "Let's TRANSform society for the better! Creator #StormTheDNC, #EndTheDNC hashtags. #FreeAssange #ShahidVsPelosi #UnitedLeft #GreenParty #HawkinsWalker2020",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 9999,
#     'friends_count': 3972,
#     'listed_count': 355,
#     'created_at': 'Mon Jun 04 05:47:03 +0000 2012',
#     'favourites_count': 468258,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 469772,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/752919688208801792/UEvxcONE_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/752919688208801792/UEvxcONE_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/598973191/1468344993',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Oct 27 23:32:00 +0000 2020',
#     'id': 1321233217094062080,
#     'id_str': '1321233217094062080',
#     'text': "WHY I'M VOTING GREEN (cont.)\n\nThe Democratic Party trashed the #MeToo movement without hesitation. They've fought… https://t.co/vvjVo4FFeC",
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'MeToo', 'indices': [63, 69]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/vvjVo4FFeC',
#        'expanded_url': 'https://twitter.com/i/web/status/1321233217094062080',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [115, 138]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': 1321233216125227008,
#     'in_reply_to_status_id_str': '1321233216125227008',
#     'in_reply_to_user_id': 18464266,
#     'in_reply_to_user_id_str': '18464266',
#     'in_reply_to_screen_name': 'peterdaou',
#     'user': {'id': 18464266,
#      'id_str': '18464266',
#      'name': 'Peter Daou',
#      'screen_name': 'peterdaou',
#      'location': '',
#      'description': "Survived Lebanon's civil war in the 80s. Remixer/keyboardist for major labels in the 90s. Political activist & adviser in the 2000s. Proud husband to @leeladaou",
#      'url': 'http://t.co/PAymxiYMXb',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/PAymxiYMXb',
#          'expanded_url': 'http://peterdaou.com',
#          'display_url': 'peterdaou.com',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 289466,
#      'friends_count': 1155,
#      'listed_count': 3225,
#      'created_at': 'Tue Dec 30 00:21:14 +0000 2008',
#      'favourites_count': 41881,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 91377,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '709397',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1267229546308415491/ry3UeIBs_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1267229546308415491/ry3UeIBs_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18464266/1601982138',
#      'profile_link_color': '30547D',
#      'profile_sidebar_border_color': '86A4A6',
#      'profile_sidebar_fill_color': 'A0C5C7',
#      'profile_text_color': '4E6D83',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 87,
#     'favorite_count': 627,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 87,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 05:57:19 +0000 2020',
#    'id': 1321692569177264128,
#    'id_str': '1321692569177264128',
#    'text': 'RT @Iqraq4: Sexual liberalism is a false idol (a thread)\n\nIt appears that Malaysia is having its very own #metoo moment following a flurry…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'metoo', 'indices': [106, 112]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Iqraq4',
#       'name': 'Umm UZ',
#       'id': 1240214894424678401,
#       'id_str': '1240214894424678401',
#       'indices': [3, 10]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 844527249013391360,
#     'id_str': '844527249013391360',
#     'name': 'azam',
#     'screen_name': 'azamuddin_azman',
#     'location': 'Malaysia',
#     'description': 'menumbuk sambal',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 208,
#     'friends_count': 201,
#     'listed_count': 0,
#     'created_at': 'Wed Mar 22 12:32:41 +0000 2017',
#     'favourites_count': 11950,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 513,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1314892560318361600/C8Q1XU3m_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1314892560318361600/C8Q1XU3m_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/844527249013391360/1585236683',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Jun 24 05:53:43 +0000 2020',
#     'id': 1275668405820022785,
#     'id_str': '1275668405820022785',
#     'text': 'Sexual liberalism is a false idol (a thread)\n\nIt appears that Malaysia is having its very own #metoo moment followi… https://t.co/9V6W9jEAnQ',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'metoo', 'indices': [94, 100]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/9V6W9jEAnQ',
#        'expanded_url': 'https://twitter.com/i/web/status/1275668405820022785',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1240214894424678401,
#      'id_str': '1240214894424678401',
#      'name': 'Umm UZ',
#      'screen_name': 'Iqraq4',
#      'location': '',
#      'description': 'Joined Twitter to check the COVID news. Cardiologist & mom on a career break. Cambridge graduate, Mayo Clinic alumni, FNHAM FASE.',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 113,
#      'friends_count': 480,
#      'listed_count': 0,
#      'created_at': 'Wed Mar 18 09:54:19 +0000 2020',
#      'favourites_count': 2793,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 1427,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1246970913255374848/YYFpmd85_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1246970913255374848/YYFpmd85_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1240214894424678401/1586136041',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 26,
#     'favorite_count': 42,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 26,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 05:57:08 +0000 2020',
#    'id': 1321692524478636032,
#    'id_str': '1321692524478636032',
#    'text': "RT @WChivhanga: Rape apologists are rapists!\nMen who 'joke' about rape are rapists!\nIf your default setting when you hear about a rape case…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'WChivhanga',
#       'name': 'Willson Chivhanga',
#       'id': 3004023149,
#       'id_str': '3004023149',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 902399577701179392,
#     'id_str': '902399577701179392',
#     'name': 'NOMZIE B ™',
#     'screen_name': 'NomzieN',
#     'location': 'Malawi',
#     'description': '🕊less ego, more soul. Christian and a firm believer in positivity\nhttps://t.co/5fyQz1amVJ',
#     'url': None,
#     'entities': {'description': {'urls': [{'url': 'https://t.co/5fyQz1amVJ',
#         'expanded_url': 'https://www.youtube.com/channel/UC6Si9Ty5T76tDZCE05jW7iA',
#         'display_url': 'youtube.com/channel/UC6Si9…',
#         'indices': [66, 89]}]}},
#     'protected': False,
#     'followers_count': 1734,
#     'friends_count': 694,
#     'listed_count': 0,
#     'created_at': 'Tue Aug 29 05:16:39 +0000 2017',
#     'favourites_count': 71644,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 24504,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1316407516755046401/BpwXk9ef_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1316407516755046401/BpwXk9ef_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/902399577701179392/1601410149',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 29 05:06:38 +0000 2020',
#     'id': 1321679815670407169,
#     'id_str': '1321679815670407169',
#     'text': "Rape apologists are rapists!\nMen who 'joke' about rape are rapists!\nIf your default setting when you hear about a r… https://t.co/bQZJJ0SzAX",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/bQZJJ0SzAX',
#        'expanded_url': 'https://twitter.com/i/web/status/1321679815670407169',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3004023149,
#      'id_str': '3004023149',
#      'name': 'Willson Chivhanga',
#      'screen_name': 'WChivhanga',
#      'location': 'Malawi',
#      'description': 'By changing the social order that oppresses women, the revolution creates the conditions for their genuine emancipation - Thomas Sankara',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1730,
#      'friends_count': 4157,
#      'listed_count': 5,
#      'created_at': 'Thu Jan 29 08:02:25 +0000 2015',
#      'favourites_count': 6636,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 7329,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': True,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1312841016932786176/uHnwvYlO_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1312841016932786176/uHnwvYlO_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3004023149/1596653158',
#      'profile_link_color': '19CF86',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5,
#     'favorite_count': 6,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 05:56:35 +0000 2020',
#    'id': 1321692387970875393,
#    'id_str': '1321692387970875393',
#    'text': "RT @WChivhanga: Rape apologists are rapists!\nMen who 'joke' about rape are rapists!\nIf your default setting when you hear about a rape case…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'WChivhanga',
#       'name': 'Willson Chivhanga',
#       'id': 3004023149,
#       'id_str': '3004023149',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 999377283633831937,
#     'id_str': '999377283633831937',
#     'name': 'Queen Dark Shadow',
#     'screen_name': '265DarkShadow',
#     'location': 'Lilongwe, Malawi',
#     'description': 'Spoken Word Poet| |Dark and Twisty| | Poetry is my Life♡ |Bleed Words| IG: @265DarkShadow | | 🌹LOST🌹 available on major streaming sites🙏🏾',
#     'url': 'https://t.co/ufgx8L3W4E',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/ufgx8L3W4E',
#         'expanded_url': 'https://fanlink.to/Lost-dark-shadow',
#         'display_url': 'fanlink.to/Lost-dark-shad…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 5895,
#     'friends_count': 1679,
#     'listed_count': 10,
#     'created_at': 'Wed May 23 19:51:26 +0000 2018',
#     'favourites_count': 42602,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 47684,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1321535789558321154/xlCysnEs_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1321535789558321154/xlCysnEs_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/999377283633831937/1602005345',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 29 05:06:38 +0000 2020',
#     'id': 1321679815670407169,
#     'id_str': '1321679815670407169',
#     'text': "Rape apologists are rapists!\nMen who 'joke' about rape are rapists!\nIf your default setting when you hear about a r… https://t.co/bQZJJ0SzAX",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/bQZJJ0SzAX',
#        'expanded_url': 'https://twitter.com/i/web/status/1321679815670407169',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3004023149,
#      'id_str': '3004023149',
#      'name': 'Willson Chivhanga',
#      'screen_name': 'WChivhanga',
#      'location': 'Malawi',
#      'description': 'By changing the social order that oppresses women, the revolution creates the conditions for their genuine emancipation - Thomas Sankara',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1730,
#      'friends_count': 4157,
#      'listed_count': 5,
#      'created_at': 'Thu Jan 29 08:02:25 +0000 2015',
#      'favourites_count': 6636,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 7329,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': True,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1312841016932786176/uHnwvYlO_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1312841016932786176/uHnwvYlO_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3004023149/1596653158',
#      'profile_link_color': '19CF86',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5,
#     'favorite_count': 6,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 05:56:33 +0000 2020',
#    'id': 1321692377635938305,
#    'id_str': '1321692377635938305',
#    'text': 'RT @KaceyKells: "KELLCEY is a story everyone should read. It is especially timely in today’s \'MeToo\' era; this narrative about the effects…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
# ...
#      {'screen_name': 'USPS',
#       'name': 'U.S. Postal Service',
#       'id': 386507775,
#       'id_str': '386507775',
#       'indices': [28, 33]},
#      {'screen_name': 'RadioFreeTom',
#       'name': 'Tom Nichols',
#       'id': 459872442,
#       'id_str': '459872442',
#       'indices': [34, 47]}],
#     'urls': [{'url': 'https://t.co/I1AHAahETL',
#       'expanded_url': 'https://twitter.com/i/web/status/1321692325937074176',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1321640116620853248,
#    'in_reply_to_status_id_str': '1321640116620853248',
#    'in_reply_to_user_id': 2677056631,
#    'in_reply_to_user_id_str': '2677056631',
#    'in_reply_to_screen_name': 'ColtSTaylor',
#    'user': {'id': 986612412009910277,
#     'id_str': '986612412009910277',
#     'name': 'BubbleWhatBubble',
#     'screen_name': 'CherryPipeFoto',
#     'location': 'Eatontown, NJ',
#     'description': 'when a photo doesn’t say enough; Twitter is always there for you.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2,
#     'friends_count': 38,
#     'listed_count': 0,
#     'created_at': 'Wed Apr 18 14:28:24 +0000 2018',
#     'favourites_count': 29,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 48,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1321669996481777664/ZUpV8F7c_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1321669996481777664/ZUpV8F7c_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/986612412009910277/1603945658',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 05:51:45 +0000 2020',
#    'id': 1321691169437356032,
#    'id_str': '1321691169437356032',
#    'text': 'RT @rorarininyo: 台湾の中学一年生の社会科の教科書、#MeToo 運動やジェンダーステレオタイプ、ジェンダー平等実現にむけて、ハラスメントに関する偏見や誤解、思い込みなどもゴリゴリにいっぱい解説されていて大変頼もしい。\n「もっと考えてみよう」のコーナーでは韓国や…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [34, 40]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'rorarininyo',
#       'name': '栖来ひかり＠『時をかける台湾Ｙ字路』発売中！！！',
#       'id': 119654303,
#       'id_str': '119654303',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1289316306294935552,
#     'id_str': '1289316306294935552',
#     'name': '𝑴𝒖𝒎𝒖',
#     'screen_name': 'geu_nyan',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3,
#     'friends_count': 0,
#     'listed_count': 0,
#     'created_at': 'Fri Jul 31 21:45:44 +0000 2020',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 152,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1320871611059195910/oq5261MU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1320871611059195910/oq5261MU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1289316306294935552/1603755308',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Oct 10 10:19:24 +0000 2020',
#     'id': 1314873155609976832,
#     'id_str': '1314873155609976832',
#     'text': '台湾の中学一年生の社会科の教科書、#MeToo 運動やジェンダーステレオタイプ、ジェンダー平等実現にむけて、ハラスメントに関する偏見や誤解、思い込みなどもゴリゴリにいっぱい解説されていて大変頼もしい。\n「もっと考えてみよう」のコー… https://t.co/K3Rhg7V5lD',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'MeToo', 'indices': [17, 23]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/K3Rhg7V5lD',
#        'expanded_url': 'https://twitter.com/i/web/status/1314873155609976832',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 119654303,
#      'id_str': '119654303',
#      'name': '栖来ひかり＠『時をかける台湾Ｙ字路』発売中！！！',
#      'screen_name': 'rorarininyo',
#      'location': 'taipei',
#      'description': '文筆家，道草者。2006年より台湾台北市在住。\n著書『時をかける台湾Ｙ字路ーー記憶のワンダーランドへようこそ』（図書出版ヘウレーカ），『台湾と山口をつなぐ旅』（西日本出版社/2019）など。\nＦＦのない鍵アカウントの方は、ブロックすることがあります',
#      'url': 'https://t.co/NPZEtXn5JQ',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/NPZEtXn5JQ',
#          'expanded_url': 'https://taipeimonogatari.blogspot.tw/',
#          'display_url': 'taipeimonogatari.blogspot.tw',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2473,
#      'friends_count': 684,
#      'listed_count': 54,
#      'created_at': 'Thu Mar 04 07:36:50 +0000 2010',
#      'favourites_count': 11154,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 13446,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1231497271167946752/pthPw68z_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1231497271167946752/pthPw68z_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/119654303/1572452658',
#      'profile_link_color': 'ABB8C2',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 598,
#     'favorite_count': 1841,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'ja'},
#    'is_quote_status': False,
#    'retweet_count': 598,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Thu Oct 29 05:50:43 +0000 2020',
#    'id': 1321690909247893505,
#    'id_str': '1321690909247893505',
#    'text': 'Was Alyssa Milano there?  Face it, you all are faux feminists. Eight other women have alleged that Biden sexually h… https://t.co/scbwOKd8sc',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/scbwOKd8sc',
#       'expanded_url': 'https://twitter.com/i/web/status/1321690909247893505',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 38378898,
#     'id_str': '38378898',
#     'name': 'sabrina4bernie #Biden Is An Illegitimate Nominee',
#     'screen_name': 'sabrina68',
#     'location': 'New York, USA',
#     'description': 'Interests include politics, education, ice-skating, animals, tennis, dance.\n\n#Greens because of Dem Voter Suppression\n#BernieYellsForUs\nhttps://t.co/T9nGa0VAEi',
#     'url': None,
#     'entities': {'description': {'urls': [{'url': 'https://t.co/T9nGa0VAEi',
#         'expanded_url': 'http://peoplesparty.org',
#         'display_url': 'peoplesparty.org',
#         'indices': [136, 159]}]}},
#     'protected': False,
#     'followers_count': 9911,
#     'friends_count': 9079,
#     'listed_count': 160,
#     'created_at': 'Thu May 07 05:41:14 +0000 2009',
#     'favourites_count': 213622,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 185716,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '0099B9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/647858168630870016/8PZ-sbq3_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/647858168630870016/8PZ-sbq3_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/38378898/1443296304',
#     'profile_link_color': '0099B9',
#     'profile_sidebar_border_color': '5ED4DC',
#     'profile_sidebar_fill_color': '95E8EC',
#     'profile_text_color': '3C3940',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1321661765491384320,
#    'quoted_status_id_str': '1321661765491384320',
#    'quoted_status': {'created_at': 'Thu Oct 29 03:54:54 +0000 2020',
#     'id': 1321661765491384320,
#     'id_str': '1321661765491384320',
#     'text': "@prettynobodyco @ReadeAlexandra I consider myself a feminist-if I believed Tara Reade's allegations, I would suppor… https://t.co/IKLtVuU1E5",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'prettynobodyco',
#        'name': '𝑏𝑖𝑑𝑒𝑛 🎃 𝑘𝑖𝑙𝑙𝑒𝑑 🎃 𝑚𝑒𝑡𝑜𝑜',
#        'id': 3355586265,
#        'id_str': '3355586265',
#        'indices': [0, 15]},
#       {'screen_name': 'ReadeAlexandra',
#        'name': 'Tara Reade 🦋',
#        'id': 1057029255362531330,
#        'id_str': '1057029255362531330',
#        'indices': [16, 31]}],
#      'urls': [{'url': 'https://t.co/IKLtVuU1E5',
#        'expanded_url': 'https://twitter.com/i/web/status/1321661765491384320',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': 1321655880601931776,
#     'in_reply_to_status_id_str': '1321655880601931776',
#     'in_reply_to_user_id': 3355586265,
#     'in_reply_to_user_id_str': '3355586265',
#     'in_reply_to_screen_name': 'prettynobodyco',
#     'user': {'id': 27395368,
#      'id_str': '27395368',
#      'name': 'Sarah Thomas',
#      'screen_name': 'saturdaysun2009',
#      'location': '',
#      'description': "BE KIND-2 urself +others+THE WORLD WILL CHANGE-came here 4 my loss/grief biz but the DISASTEROUS electing of DT's calling all good people 2 FIGHT 4 SOUL of USA!",
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 370,
#      'friends_count': 1094,
#      'listed_count': 2,
#      'created_at': 'Sun Mar 29 07:14:27 +0000 2009',
#      'favourites_count': 9639,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 19373,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1292154059319726080/KPxIBU5s_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1292154059319726080/KPxIBU5s_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/27395368/1596908510',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.098,
#   'max_id': 1321694369846489089,
#   'max_id_str': '1321694369846489089',
#   'next_results': '?max_id=1321690909247893504&q=%23MeToo&include_entities=1',
#   'query': '%23MeToo',
#   'refresh_url': '?since_id=1321694369846489089&q=%23MeToo&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# **Step 2:  Adding Parameters to Your Query String**

# %% [markdown]
# Query strings basically have two parts:
#
#  - The `?` initiates the beginning of the API call, and basically says 'everything that follows this will encode something about the information that's going to get returned to you'.
#  - What follows that is are a bunch of symbols followed by `=` signs.  These are parameters.
#  - So when you make an api call to `'https://api.twitter.com/1.1/search/tweets.json?q=My%20Search%20Term`, the `q` is a paremeter.
#  - You can add multiple paremeters to a query string. They are separated by `&`. They dictate what kinds of results are returned.
#   - For example, a parameter you can use in Twitter's search API is `count`, which tells you how many results to return.  The default is 15, but you can return up to 100.  So if we wanted to search for tweets and return 50 results our query string would look like the following:
#     `https://api.twitter.com/1.1/search/tweets.json?q=My%20Search%20String&count=50`
#   - You can add as many of these parameters to your string as you'd like.  So for example, if we wanted to include parameters for `count` and `result_type`, we could do the following: `https://api.twitter.com/1.1/search/tweets.json?q=My%20Search%20String&count=50&result_type=mixed`
#
# To get the hang of this, try searching for tweets that mention the hashtag `#DeepLearning`, and return 75 results.

# %%
search_url = "https://api.twitter.com/1.1/search/tweets.json?q=%23DeepLearning&count=75"
deep_learning_api_search = requests.get(search_url, auth=my_auth)

# %%
deep_learning_api_search.reason
# Out:
# 'OK'

# %%
deep_learning_api_search.json()
# Out:
# {'statuses': [{'created_at': 'Thu Oct 29 06:06:54 +0000 2020',
#    'id': 1321694984333103104,
#    'id_str': '1321694984333103104',
#    'text': 'RT @marcusborba: Detecting Financial Fraud Using #GraphAnalytics [Solution Brief by @TigerGraphDB]\n \nhttps://t.co/0sU2ljICvj via @DataScien…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'GraphAnalytics', 'indices': [49, 64]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'marcusborba',
#       'name': 'Marcus Borba',
#       'id': 18068926,
#       'id_str': '18068926',
#       'indices': [3, 15]},
#      {'screen_name': 'TigerGraphDB',
#       'name': 'TigerGraph',
#       'id': 509849786,
#       'id_str': '509849786',
#       'indices': [84, 97]}],
#     'urls': [{'url': 'https://t.co/0sU2ljICvj',
#       'expanded_url': 'https://bit.ly/3l8Sh0y',
#       'display_url': 'bit.ly/3l8Sh0y',
#       'indices': [101, 124]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 53931730,
#     'id_str': '53931730',
#     'name': 'Lucrecia Paolini',
#     'screen_name': 'lpaoliespin',
#     'location': 'Montréal, Québec',
#     'description': 'Live Love Laugh',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 376,
#     'friends_count': 3376,
#     'listed_count': 5,
#     'created_at': 'Sun Jul 05 15:30:03 +0000 2009',
#     'favourites_count': 9159,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 43664,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '0099B9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1085039622881710080/5aIATWMU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1085039622881710080/5aIATWMU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/53931730/1419171668',
#     'profile_link_color': '0099B9',
#     'profile_sidebar_border_color': '5ED4DC',
#     'profile_sidebar_fill_color': '95E8EC',
#     'profile_text_color': '3C3940',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Oct 27 11:05:57 +0000 2020',
#     'id': 1321045465861885954,
#     'id_str': '1321045465861885954',
#     'text': 'Detecting Financial Fraud Using #GraphAnalytics [Solution Brief by @TigerGraphDB]\n \nhttps://t.co/0sU2ljICvj via… https://t.co/ye0tkJk3MD',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'GraphAnalytics', 'indices': [32, 47]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'TigerGraphDB',
#        'name': 'TigerGraph',
#        'id': 509849786,
#        'id_str': '509849786',
#        'indices': [67, 80]}],
#      'urls': [{'url': 'https://t.co/0sU2ljICvj',
#        'expanded_url': 'https://bit.ly/3l8Sh0y',
#        'display_url': 'bit.ly/3l8Sh0y',
#        'indices': [84, 107]},
#       {'url': 'https://t.co/ye0tkJk3MD',
#        'expanded_url': 'https://twitter.com/i/web/status/1321045465861885954',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [113, 136]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 18068926,
#      'id_str': '18068926',
#      'name': 'Marcus Borba',
#      'screen_name': 'marcusborba',
#      'location': '',
#      'description': 'Global Thought Leader & Influencer: #AI #MachineLearning #DataScience #BI #BigData #Analytics #IoT #ArtificialIntelligence #DigitalTransformation | #BBBT Member',
#      'url': 'https://t.co/QWV2hmLlSY',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/QWV2hmLlSY',
#          'expanded_url': 'https://www.linkedin.com/in/marcusborba',
#          'display_url': 'linkedin.com/in/marcusborba',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 40279,
#      'friends_count': 3006,
#      'listed_count': 2082,
#      'created_at': 'Fri Dec 12 03:32:44 +0000 2008',
#      'favourites_count': 16805,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 34866,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/423471047/MarcusBorba_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/423471047/MarcusBorba_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18068926/1442686907',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 7,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 06:06:28 +0000 2020',
#    'id': 1321694872622059520,
#    'id_str': '1321694872622059520',
#    'text': 'RT @SpirosMargaris: Artificial intelligence model #detects #asymptomatic #Covid19 infections \n\nthrough #cellphone-recorded #coughs\n\nhttps:/…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'detects', 'indices': [50, 58]},
#      {'text': 'asymptomatic', 'indices': [59, 72]},
#      {'text': 'Covid19', 'indices': [73, 81]},
#      {'text': 'cellphone', 'indices': [103, 113]},
#      {'text': 'coughs', 'indices': [123, 130]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SpirosMargaris',
#       'name': 'Spiros Margaris',
#       'id': 2711212681,
#       'id_str': '2711212681',
#       'indices': [3, 18]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 706165628726546433,
#     'id_str': '706165628726546433',
#     'name': 'The Digital Kingdom',
#     'screen_name': 'iDigitalKingdom',
#     'location': '',
#     'description': 'The Digital Kingdom tweet only quality content from top publishers about #AI #IoT #CyberSecurity #Cloud #DigitalTransformation.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1271,
#     'friends_count': 1245,
#     'listed_count': 9,
#     'created_at': 'Sat Mar 05 17:13:00 +0000 2016',
#     'favourites_count': 7052,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 6931,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1159124050498637824/kEZQzDHB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1159124050498637824/kEZQzDHB_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/706165628726546433/1565191685',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 29 05:23:34 +0000 2020',
#     'id': 1321684075745333248,
#     'id_str': '1321684075745333248',
#     'text': 'Artificial intelligence model #detects #asymptomatic #Covid19 infections \n\nthrough #cellphone-recorded #coughs… https://t.co/6vkdUys4Co',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'detects', 'indices': [30, 38]},
#       {'text': 'asymptomatic', 'indices': [39, 52]},
#       {'text': 'Covid19', 'indices': [53, 61]},
#       {'text': 'cellphone', 'indices': [83, 93]},
#       {'text': 'coughs', 'indices': [103, 110]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/6vkdUys4Co',
#        'expanded_url': 'https://twitter.com/i/web/status/1321684075745333248',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [112, 135]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2711212681,
#      'id_str': '2711212681',
#      'name': 'Spiros Margaris',
#      'screen_name': 'SpirosMargaris',
#      'location': 'All Over the World',
#      'description': '#VC #Futurist @wefoxHQ @SparkLabsGlobal @ai_mediastalker @canopyrent @stcpay_ksa @F10_accelerator | No.1 #Fintech Influencer @Refinitiv & @Onalytica | #AI @TEDx',
#      'url': 'https://t.co/PeTBLwijX6',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/PeTBLwijX6',
#          'expanded_url': 'http://www.MargarisVentures.com',
#          'display_url': 'MargarisVentures.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 103965,
#      'friends_count': 15095,
#      'listed_count': 5602,
#      'created_at': 'Wed Aug 06 05:20:16 +0000 2014',
#      'favourites_count': 175645,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 203242,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '3B94D9',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1080518156932825089/Elhx7SXw_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1080518156932825089/Elhx7SXw_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2711212681/1597474916',
#      'profile_link_color': '1C2841',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 5,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 06:05:00 +0000 2020',
#    'id': 1321694503808413697,
#    'id_str': '1321694503808413697',
#    'text': 'RT @Analytics_699: Tokenization in NLP▶️\n#Analytics #BigData #DataScience\n#MachineLearning #javascript  #CloudComputing #RStats #reactjs\n#I…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Analytics', 'indices': [41, 51]},
#      {'text': 'BigData', 'indices': [52, 60]},
#      {'text': 'DataScience', 'indices': [61, 73]},
#      {'text': 'MachineLearning', 'indices': [74, 90]},
#      {'text': 'javascript', 'indices': [91, 102]},
#      {'text': 'CloudComputing', 'indices': [104, 119]},
#      {'text': 'RStats', 'indices': [120, 127]},
#      {'text': 'reactjs', 'indices': [128, 136]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Analytics_699',
#       'name': 'Maac',
#       'id': 1155470031225884675,
#       'id_str': '1155470031225884675',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://github.com/vlipatdev" rel="nofollow">Code Newbie Server</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1267052345822572545,
#     'id_str': '1267052345822572545',
#     'name': 'Code Newbie Bot',
#     'screen_name': '_codenewbiebot',
#     'location': '',
#     'description': 'Beep boop. I am a bot created by https://t.co/i0ytpsE5Sj to support code newbies.',
#     'url': None,
#     'entities': {'description': {'urls': [{'url': 'https://t.co/i0ytpsE5Sj',
#         'expanded_url': 'http://github.com/vlipatdev',
#         'display_url': 'github.com/vlipatdev',
#         'indices': [33, 56]}]}},
#     'protected': False,
#     'followers_count': 867,
#     'friends_count': 9,
#     'listed_count': 19,
#     'created_at': 'Sun May 31 11:17:02 +0000 2020',
#     'favourites_count': 19,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 90263,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1270342281430777858/4ExBd_dP_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270342281430777858/4ExBd_dP_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Oct 25 18:56:59 +0000 2020',
#     'id': 1320439228522622976,
#     'id_str': '1320439228522622976',
#     'text': 'Tokenization in NLP▶️\n#Analytics #BigData #DataScience\n#MachineLearning #javascript  #CloudComputing #RStats… https://t.co/7GpEDahhWV',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Analytics', 'indices': [22, 32]},
#       {'text': 'BigData', 'indices': [33, 41]},
#       {'text': 'DataScience', 'indices': [42, 54]},
#       {'text': 'MachineLearning', 'indices': [55, 71]},
#       {'text': 'javascript', 'indices': [72, 83]},
#       {'text': 'CloudComputing', 'indices': [85, 100]},
#       {'text': 'RStats', 'indices': [101, 108]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/7GpEDahhWV',
#        'expanded_url': 'https://twitter.com/i/web/status/1320439228522622976',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [110, 133]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1155470031225884675,
#      'id_str': '1155470031225884675',
#      'name': 'Maac',
#      'screen_name': 'Analytics_699',
#      'location': '',
#      'description': 'Healthcare Program Head - NW & CA         @aboutKP | \n#AI #BI #BigData #DataScience #IoT #Robotics #AR #VR  | \nTravel - Art - Poetry',
#      'url': 'https://t.co/6laz24KCCn',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/6laz24KCCn',
#          'expanded_url': 'https://thrive.kaiserpermanente.org/',
#          'display_url': 'thrive.kaiserpermanente.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4637,
#      'friends_count': 4408,
#      'listed_count': 11,
#      'created_at': 'Sun Jul 28 13:28:17 +0000 2019',
#      'favourites_count': 10521,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 3891,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1270928144229437440/Ie08vEBd_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270928144229437440/Ie08vEBd_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1155470031225884675/1595503868',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 23,
#     'favorite_count': 7,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 23,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 06:04:58 +0000 2020',
#    'id': 1321694496476876800,
#    'id_str': '1321694496476876800',
#    'text': 'Top Artificial Intelligence Influencers to Follow On LinkedIn \n\nREAD MORE: https://t.co/3xizNExIlv\n\n#AI… https://t.co/iC4yrjFg3G',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'AI', 'indices': [100, 103]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/3xizNExIlv',
#       'expanded_url': 'https://blog.iammarketingmedia.com/top-artificial-intelligence-influencers-to-follow-on-linkedin/?utm_campaign=twitter&utm_medium=twitter&utm_source=twitter',
#       'display_url': 'blog.iammarketingmedia.com/top-artificial…',
#       'indices': [75, 98]},
#      {'url': 'https://t.co/iC4yrjFg3G',
#       'expanded_url': 'https://twitter.com/i/web/status/1321694496476876800',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [105, 128]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.blog.iammarketingmedia.com" rel="nofollow">IAMBLOG2TWITTER</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 226310002,
#     'id_str': '226310002',
#     'name': 'IAM Platform',
#     'screen_name': 'IAM__Network',
#     'location': 'Worldwide',
#     'description': 'Curation | Tools | Tips | Services\n\nIAM Platform powers IAM Network:\n\nGO: https://t.co/wZabw3lJog\n\nBlog | Social | Podcast | Code Trove',
#     'url': 'https://t.co/T1FCdoOFoB',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/T1FCdoOFoB',
#         'expanded_url': 'https://www.iammarketingmedia.com',
#         'display_url': 'iammarketingmedia.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/wZabw3lJog',
#         'expanded_url': 'http://bit.ly/iam-network',
#         'display_url': 'bit.ly/iam-network',
#         'indices': [74, 97]}]}},
#     'protected': False,
#     'followers_count': 17834,
#     'friends_count': 15149,
#     'listed_count': 3251,
#     'created_at': 'Mon Dec 13 21:24:29 +0000 2010',
#     'favourites_count': 65497,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 890058,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '94D487',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/701708113653669888/Nzm67hhC_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/701708113653669888/Nzm67hhC_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/226310002/1584072260',
#     'profile_link_color': '3366CC',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 06:04:46 +0000 2020',
#    'id': 1321694446380081152,
#    'id_str': '1321694446380081152',
#    'text': 'RT @Analytics_699: Tokenization in NLP▶️\n#Analytics #BigData #DataScience\n#MachineLearning #javascript  #CloudComputing #RStats #reactjs\n#I…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Analytics', 'indices': [41, 51]},
#      {'text': 'BigData', 'indices': [52, 60]},
#      {'text': 'DataScience', 'indices': [61, 73]},
#      {'text': 'MachineLearning', 'indices': [74, 90]},
#      {'text': 'javascript', 'indices': [91, 102]},
#      {'text': 'CloudComputing', 'indices': [104, 119]},
#      {'text': 'RStats', 'indices': [120, 127]},
#      {'text': 'reactjs', 'indices': [128, 136]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Analytics_699',
#       'name': 'Maac',
#       'id': 1155470031225884675,
#       'id_str': '1155470031225884675',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://occlude.netlify.app/" rel="nofollow">OccludejsBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1275056773443973124,
#     'id_str': '1275056773443973124',
#     'name': 'Jessica shoonover',
#     'screen_name': 'Women_who_code',
#     'location': 'bootcamp',
#     'description': '24 🧬 ~ Javascript ❤️ ~ Mern Stack Developer ~ Next JS 🦄 ~ @nytimes ~ Books 📚 + coffee ☕',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 886,
#     'friends_count': 25,
#     'listed_count': 22,
#     'created_at': 'Mon Jun 22 13:23:34 +0000 2020',
#     'favourites_count': 281,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 110865,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1319806256513646592/S1f4A7_A_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1319806256513646592/S1f4A7_A_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1275056773443973124/1603501540',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Oct 25 18:56:59 +0000 2020',
#     'id': 1320439228522622976,
#     'id_str': '1320439228522622976',
#     'text': 'Tokenization in NLP▶️\n#Analytics #BigData #DataScience\n#MachineLearning #javascript  #CloudComputing #RStats… https://t.co/7GpEDahhWV',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Analytics', 'indices': [22, 32]},
#       {'text': 'BigData', 'indices': [33, 41]},
#       {'text': 'DataScience', 'indices': [42, 54]},
#       {'text': 'MachineLearning', 'indices': [55, 71]},
#       {'text': 'javascript', 'indices': [72, 83]},
#       {'text': 'CloudComputing', 'indices': [85, 100]},
#       {'text': 'RStats', 'indices': [101, 108]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/7GpEDahhWV',
#        'expanded_url': 'https://twitter.com/i/web/status/1320439228522622976',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [110, 133]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1155470031225884675,
#      'id_str': '1155470031225884675',
#      'name': 'Maac',
#      'screen_name': 'Analytics_699',
#      'location': '',
#      'description': 'Healthcare Program Head - NW & CA         @aboutKP | \n#AI #BI #BigData #DataScience #IoT #Robotics #AR #VR  | \nTravel - Art - Poetry',
#      'url': 'https://t.co/6laz24KCCn',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/6laz24KCCn',
#          'expanded_url': 'https://thrive.kaiserpermanente.org/',
#          'display_url': 'thrive.kaiserpermanente.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4637,
#      'friends_count': 4408,
#      'listed_count': 11,
#      'created_at': 'Sun Jul 28 13:28:17 +0000 2019',
#      'favourites_count': 10521,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 3891,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1270928144229437440/Ie08vEBd_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270928144229437440/Ie08vEBd_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1155470031225884675/1595503868',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 23,
#     'favorite_count': 7,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 23,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 06:04:46 +0000 2020',
#    'id': 1321694446191321088,
#    'id_str': '1321694446191321088',
#    'text': 'RT @Analytics_699: Tokenization in NLP▶️\n#Analytics #BigData #DataScience\n#MachineLearning #javascript  #CloudComputing #RStats #reactjs\n#I…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Analytics', 'indices': [41, 51]},
#      {'text': 'BigData', 'indices': [52, 60]},
#      {'text': 'DataScience', 'indices': [61, 73]},
#      {'text': 'MachineLearning', 'indices': [74, 90]},
#      {'text': 'javascript', 'indices': [91, 102]},
#      {'text': 'CloudComputing', 'indices': [104, 119]},
#      {'text': 'RStats', 'indices': [120, 127]},
#      {'text': 'reactjs', 'indices': [128, 136]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Analytics_699',
#       'name': 'Maac',
#       'id': 1155470031225884675,
#       'id_str': '1155470031225884675',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://nlogn.in" rel="nofollow">nlognrobot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1260062769543434240,
#     'id_str': '1260062769543434240',
#     'name': '#100DaysOfCode',
#     'screen_name': 'nlognbot',
#     'location': 'Server',
#     'description': "Hi, I'm a bot that retweets #100daysofcode     \n                 \nP.S. I was created by @NlognHQ follow them.",
#     'url': 'https://t.co/PujHDQomPA',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/PujHDQomPA',
#         'expanded_url': 'http://nlogn.in',
#         'display_url': 'nlogn.in',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4480,
#     'friends_count': 3,
#     'listed_count': 52,
#     'created_at': 'Tue May 12 04:22:53 +0000 2020',
#     'favourites_count': 768,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 371341,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1306825824104898560/F1I_GcS1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1306825824104898560/F1I_GcS1_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1260062769543434240/1593858684',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Oct 25 18:56:59 +0000 2020',
#     'id': 1320439228522622976,
#     'id_str': '1320439228522622976',
#     'text': 'Tokenization in NLP▶️\n#Analytics #BigData #DataScience\n#MachineLearning #javascript  #CloudComputing #RStats… https://t.co/7GpEDahhWV',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Analytics', 'indices': [22, 32]},
#       {'text': 'BigData', 'indices': [33, 41]},
#       {'text': 'DataScience', 'indices': [42, 54]},
#       {'text': 'MachineLearning', 'indices': [55, 71]},
#       {'text': 'javascript', 'indices': [72, 83]},
#       {'text': 'CloudComputing', 'indices': [85, 100]},
#       {'text': 'RStats', 'indices': [101, 108]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/7GpEDahhWV',
#        'expanded_url': 'https://twitter.com/i/web/status/1320439228522622976',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [110, 133]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1155470031225884675,
#      'id_str': '1155470031225884675',
#      'name': 'Maac',
#      'screen_name': 'Analytics_699',
#      'location': '',
#      'description': 'Healthcare Program Head - NW & CA         @aboutKP | \n#AI #BI #BigData #DataScience #IoT #Robotics #AR #VR  | \nTravel - Art - Poetry',
#      'url': 'https://t.co/6laz24KCCn',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/6laz24KCCn',
#          'expanded_url': 'https://thrive.kaiserpermanente.org/',
#          'display_url': 'thrive.kaiserpermanente.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4637,
#      'friends_count': 4408,
#      'listed_count': 11,
#      'created_at': 'Sun Jul 28 13:28:17 +0000 2019',
#      'favourites_count': 10521,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 3891,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1270928144229437440/Ie08vEBd_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270928144229437440/Ie08vEBd_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1155470031225884675/1595503868',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 23,
#     'favorite_count': 7,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 23,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 06:04:39 +0000 2020',
#    'id': 1321694418194165760,
#    'id_str': '1321694418194165760',
#    'text': 'RT @Analytics_699: Tokenization in NLP▶️\n#Analytics #BigData #DataScience\n#MachineLearning #javascript  #CloudComputing #RStats #reactjs\n#I…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Analytics', 'indices': [41, 51]},
#      {'text': 'BigData', 'indices': [52, 60]},
#      {'text': 'DataScience', 'indices': [61, 73]},
#      {'text': 'MachineLearning', 'indices': [74, 90]},
#      {'text': 'javascript', 'indices': [91, 102]},
#      {'text': 'CloudComputing', 'indices': [104, 119]},
#      {'text': 'RStats', 'indices': [120, 127]},
#      {'text': 'reactjs', 'indices': [128, 136]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Analytics_699',
#       'name': 'Maac',
#       'id': 1155470031225884675,
#       'id_str': '1155470031225884675',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1155470031225884675,
#     'id_str': '1155470031225884675',
#     'name': 'Maac',
#     'screen_name': 'Analytics_699',
#     'location': '',
#     'description': 'Healthcare Program Head - NW & CA         @aboutKP | \n#AI #BI #BigData #DataScience #IoT #Robotics #AR #VR  | \nTravel - Art - Poetry',
#     'url': 'https://t.co/6laz24KCCn',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/6laz24KCCn',
#         'expanded_url': 'https://thrive.kaiserpermanente.org/',
#         'display_url': 'thrive.kaiserpermanente.org',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4637,
#     'friends_count': 4408,
#     'listed_count': 11,
#     'created_at': 'Sun Jul 28 13:28:17 +0000 2019',
#     'favourites_count': 10521,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3891,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1270928144229437440/Ie08vEBd_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270928144229437440/Ie08vEBd_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1155470031225884675/1595503868',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Oct 25 18:56:59 +0000 2020',
#     'id': 1320439228522622976,
#     'id_str': '1320439228522622976',
#     'text': 'Tokenization in NLP▶️\n#Analytics #BigData #DataScience\n#MachineLearning #javascript  #CloudComputing #RStats… https://t.co/7GpEDahhWV',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Analytics', 'indices': [22, 32]},
#       {'text': 'BigData', 'indices': [33, 41]},
#       {'text': 'DataScience', 'indices': [42, 54]},
#       {'text': 'MachineLearning', 'indices': [55, 71]},
#       {'text': 'javascript', 'indices': [72, 83]},
#       {'text': 'CloudComputing', 'indices': [85, 100]},
#       {'text': 'RStats', 'indices': [101, 108]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/7GpEDahhWV',
#        'expanded_url': 'https://twitter.com/i/web/status/1320439228522622976',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [110, 133]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1155470031225884675,
#      'id_str': '1155470031225884675',
#      'name': 'Maac',
#      'screen_name': 'Analytics_699',
#      'location': '',
#      'description': 'Healthcare Program Head - NW & CA         @aboutKP | \n#AI #BI #BigData #DataScience #IoT #Robotics #AR #VR  | \nTravel - Art - Poetry',
#      'url': 'https://t.co/6laz24KCCn',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/6laz24KCCn',
#          'expanded_url': 'https://thrive.kaiserpermanente.org/',
#          'display_url': 'thrive.kaiserpermanente.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4637,
#      'friends_count': 4408,
#      'listed_count': 11,
#      'created_at': 'Sun Jul 28 13:28:17 +0000 2019',
#      'favourites_count': 10521,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 3891,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1270928144229437440/Ie08vEBd_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270928144229437440/Ie08vEBd_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1155470031225884675/1595503868',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 23,
#     'favorite_count': 7,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 23,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 06:03:55 +0000 2020',
#    'id': 1321694233498177541,
#    'id_str': '1321694233498177541',
#    'text': 'RT @mvollmer1: This is what #Tesla Autopilot sees using #neuralnetworks that take 70.000 GPU hours to train and output 1,000 tensors (predi…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Tesla', 'indices': [28, 34]},
#      {'text': 'neuralnetworks', 'indices': [56, 71]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'mvollmer1',
#       'name': 'Dr. Marcell Vollmer #StayHome #StaySafe',
#       'id': 99674560,
#       'id_str': '99674560',
#       'indices': [3, 13]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 124807146,
#     'id_str': '124807146',
#     'name': 'Fatai Lasisi',
#     'screen_name': 'flasisi',
#     'location': 'everywhere ',
#     'description': 'I am the good news from Nigeria',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 427,
#     'friends_count': 1132,
#     'listed_count': 1,
#     'created_at': 'Sat Mar 20 16:43:52 +0000 2010',
#     'favourites_count': 31862,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 24959,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/2373915237/IMG-20120630-00216_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2373915237/IMG-20120630-00216_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 29 04:31:11 +0000 2020',
#     'id': 1321670895711195136,
#     'id_str': '1321670895711195136',
#     'text': 'This is what #Tesla Autopilot sees using #neuralnetworks that take 70.000 GPU hours to train and output 1,000 tenso… https://t.co/u7Z1os73GN',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Tesla', 'indices': [13, 19]},
#       {'text': 'neuralnetworks', 'indices': [41, 56]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/u7Z1os73GN',
#        'expanded_url': 'https://twitter.com/i/web/status/1321670895711195136',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
# ...
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 19123904,
#      'id_str': '19123904',
#      'name': 'Dr. Joseph Santoro',
#      'screen_name': 'Joseph_Santoro',
#      'location': 'Washington, DC 20009',
#      'description': 'Neuro PhD, #Innovator, #Technologist, #Startup Angel, Fmr White House/OFA Honcho | #Politics #Data #Adventure | StartingBloc & Fulbright | @DMVstartup @Forbes',
#      'url': 'https://t.co/bmdChfG4g2',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/bmdChfG4g2',
#          'expanded_url': 'http://linkedin.com/in/josephsantoro',
#          'display_url': 'linkedin.com/in/josephsanto…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 18996,
#      'friends_count': 20895,
#      'listed_count': 2495,
#      'created_at': 'Sat Jan 17 21:10:13 +0000 2009',
#      'favourites_count': 133670,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 143806,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FFFFFF',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/683044513665912832/AfyOCz4e_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/683044513665912832/AfyOCz4e_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19123904/1459989219',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDFFCC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': {'type': 'Point', 'coordinates': [38.9394589, -77.0253676]},
#     'coordinates': {'type': 'Point', 'coordinates': [-77.0253676, 38.9394589]},
#     'place': {'id': '01fbe706f872cb32',
#      'url': 'https://api.twitter.com/1.1/geo/id/01fbe706f872cb32.json',
#      'place_type': 'city',
#      'name': 'Washington',
#      'full_name': 'Washington, DC',
#      'country_code': 'US',
#      'country': 'United States',
#      'contained_within': [],
#      'bounding_box': {'type': 'Polygon',
#       'coordinates': [[[-77.119401, 38.801826],
#         [-76.909396, 38.801826],
#         [-76.909396, 38.9953797],
#         [-77.119401, 38.9953797]]]},
#      'attributes': {}},
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 8,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 8,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 05:31:45 +0000 2020',
#    'id': 1321686137736433664,
#    'id_str': '1321686137736433664',
#    'text': 'My Journey To Understanding Machine Learning, Autopilot, &amp; FSD \n\nREAD MORE: https://t.co/LQZZHad0vb\n\n#AI #algorithm… https://t.co/cyifwYTNTZ',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'AI', 'indices': [105, 108]},
#      {'text': 'algorithm', 'indices': [109, 119]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/LQZZHad0vb',
#       'expanded_url': 'https://blog.iammarketingmedia.com/my-journey-to-understanding-machine-learning-autopilot-fsd/?utm_campaign=twitter&utm_medium=twitter&utm_source=twitter',
#       'display_url': 'blog.iammarketingmedia.com/my-journey-to-…',
#       'indices': [80, 103]},
#      {'url': 'https://t.co/cyifwYTNTZ',
#       'expanded_url': 'https://twitter.com/i/web/status/1321686137736433664',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [121, 144]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.blog.iammarketingmedia.com" rel="nofollow">IAMBLOG2TWITTER</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 226310002,
#     'id_str': '226310002',
#     'name': 'IAM Platform',
#     'screen_name': 'IAM__Network',
#     'location': 'Worldwide',
#     'description': 'Curation | Tools | Tips | Services\n\nIAM Platform powers IAM Network:\n\nGO: https://t.co/wZabw3lJog\n\nBlog | Social | Podcast | Code Trove',
#     'url': 'https://t.co/T1FCdoOFoB',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/T1FCdoOFoB',
#         'expanded_url': 'https://www.iammarketingmedia.com',
#         'display_url': 'iammarketingmedia.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/wZabw3lJog',
#         'expanded_url': 'http://bit.ly/iam-network',
#         'display_url': 'bit.ly/iam-network',
#         'indices': [74, 97]}]}},
#     'protected': False,
#     'followers_count': 17834,
#     'friends_count': 15149,
#     'listed_count': 3251,
#     'created_at': 'Mon Dec 13 21:24:29 +0000 2010',
#     'favourites_count': 65497,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 890058,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '94D487',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/701708113653669888/Nzm67hhC_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/701708113653669888/Nzm67hhC_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/226310002/1584072260',
#     'profile_link_color': '3366CC',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 05:31:36 +0000 2020',
#    'id': 1321686098234494977,
#    'id_str': '1321686098234494977',
#    'text': 'RT @Xbond49: @DeepLearn007 @Gartner_inc @SpirosMargaris @psb_dc @jblefevre60 @nigewillson @Paula_Piccard @ipfconline1 @pierrepinna @HaroldS…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Xbond49',
#       'name': 'Xavier Gomez',
#       'id': 235684766,
#       'id_str': '235684766',
#       'indices': [3, 11]},
#      {'screen_name': 'DeepLearn007',
#       'name': 'AI',
#       'id': 841437061,
#       'id_str': '841437061',
#       'indices': [13, 26]},
#      {'screen_name': 'Gartner_inc',
#       'name': 'Gartner',
#       'id': 15231287,
#       'id_str': '15231287',
#       'indices': [27, 39]},
#      {'screen_name': 'SpirosMargaris',
#       'name': 'Spiros Margaris',
#       'id': 2711212681,
#       'id_str': '2711212681',
#       'indices': [40, 55]},
#      {'screen_name': 'psb_dc',
#       'name': 'Theo - 劉䂀曼',
#       'id': 2908107542,
#       'id_str': '2908107542',
#       'indices': [56, 63]},
#      {'screen_name': 'jblefevre60',
#       'name': 'Jean-Baptiste Lefevre',
#       'id': 4374719908,
#       'id_str': '4374719908',
#       'indices': [64, 76]},
#      {'screen_name': 'nigewillson',
#       'name': 'Nige Willson 🌍✌',
#       'id': 228040559,
#       'id_str': '228040559',
#       'indices': [77, 89]},
#      {'screen_name': 'Paula_Piccard',
#       'name': 'Paula Piccard 🇵🇷 🇺🇸',
#       'id': 291831562,
#       'id_str': '291831562',
#       'indices': [90, 104]},
#      {'screen_name': 'ipfconline1',
#       'name': 'ipfconline',
#       'id': 705539763349164032,
#       'id_str': '705539763349164032',
#       'indices': [105, 117]},
#      {'screen_name': 'pierrepinna',
#       'name': 'Pinna Pierre',
#       'id': 2325704833,
#       'id_str': '2325704833',
#       'indices': [118, 130]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 890844439442325504,
#     'id_str': '890844439442325504',
#     'name': 'S. S. Xman',
#     'screen_name': 'SSXman2',
#     'location': 'Benin-City, Nigeria',
#     'description': "I'm a biologist",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4600,
#     'friends_count': 5010,
#     'listed_count': 162,
#     'created_at': 'Fri Jul 28 08:00:40 +0000 2017',
#     'favourites_count': 369552,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 419338,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1304049284338376705/PoCqSCxd_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1304049284338376705/PoCqSCxd_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 29 05:22:27 +0000 2020',
#     'id': 1321683798283767809,
#     'id_str': '1321683798283767809',
#     'text': '@DeepLearn007 @Gartner_inc @SpirosMargaris @psb_dc @jblefevre60 @nigewillson @Paula_Piccard @ipfconline1… https://t.co/DjwEFguKNp',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'DeepLearn007',
#        'name': 'AI',
#        'id': 841437061,
#        'id_str': '841437061',
#        'indices': [0, 13]},
#       {'screen_name': 'Gartner_inc',
#        'name': 'Gartner',
#        'id': 15231287,
#        'id_str': '15231287',
#        'indices': [14, 26]},
#       {'screen_name': 'SpirosMargaris',
#        'name': 'Spiros Margaris',
#        'id': 2711212681,
#        'id_str': '2711212681',
#        'indices': [27, 42]},
#       {'screen_name': 'psb_dc',
#        'name': 'Theo - 劉䂀曼',
#        'id': 2908107542,
#        'id_str': '2908107542',
#        'indices': [43, 50]},
#       {'screen_name': 'jblefevre60',
#        'name': 'Jean-Baptiste Lefevre',
#        'id': 4374719908,
#        'id_str': '4374719908',
#        'indices': [51, 63]},
#       {'screen_name': 'nigewillson',
#        'name': 'Nige Willson 🌍✌',
#        'id': 228040559,
#        'id_str': '228040559',
#        'indices': [64, 76]},
#       {'screen_name': 'Paula_Piccard',
#        'name': 'Paula Piccard 🇵🇷 🇺🇸',
#        'id': 291831562,
#        'id_str': '291831562',
#        'indices': [77, 91]},
#       {'screen_name': 'ipfconline1',
#        'name': 'ipfconline',
#        'id': 705539763349164032,
#        'id_str': '705539763349164032',
#        'indices': [92, 104]}],
#      'urls': [{'url': 'https://t.co/DjwEFguKNp',
#        'expanded_url': 'https://twitter.com/i/web/status/1321683798283767809',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [106, 129]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1321462402962120705,
#     'in_reply_to_status_id_str': '1321462402962120705',
#     'in_reply_to_user_id': 841437061,
#     'in_reply_to_user_id_str': '841437061',
#     'in_reply_to_screen_name': 'DeepLearn007',
#     'user': {'id': 235684766,
#      'id_str': '235684766',
#      'name': 'Xavier Gomez',
#      'screen_name': 'Xbond49',
#      'location': 'Global',
#      'description': 'Thought Leader Speaker #Banking #Fintech #insurtech #AI #Finserv #Bigdata |#VC #PrivateEquity | @invyo_analytics |Ex @CreditSuisse | @MITFinTech @HECParisExecEd',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 18716,
#      'friends_count': 3521,
#      'listed_count': 1247,
#      'created_at': 'Sat Jan 08 21:00:12 +0000 2011',
#      'favourites_count': 29505,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 33728,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1135171816597725185/CX0mmH2t_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1135171816597725185/CX0mmH2t_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/235684766/1559481028',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.168,
#   'max_id': 1321694984333103104,
#   'max_id_str': '1321694984333103104',
#   'next_results': '?max_id=1321686098234494976&q=%23DeepLearning&count=75&include_entities=1',
#   'query': '%23DeepLearning',
#   'refresh_url': '?since_id=1321694984333103104&q=%23DeepLearning&include_entities=1',
#   'count': 75,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# Try adding a second parameter.  You can find the list here:  https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets

# %%
search_url = "https://api.twitter.com/1.1/search/tweets.json?q=%23DeepLearning&count=10&result_type=popular"
deep_learning_api_search = requests.get(search_url, auth=my_auth)

# %%
deep_learning_api_search.reason
# Out:
# 'OK'

# %%
deep_learning_api_search.json()
# Out:
# {'statuses': [{'created_at': 'Wed Oct 28 11:24:15 +0000 2020',
#    'id': 1321412457424932864,
#    'id_str': '1321412457424932864',
#    'text': 'Have a look at a platform called Ostogram that transforms images into works of art using a neural network:… https://t.co/tpCxA7i1CA',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/tpCxA7i1CA',
#       'expanded_url': 'https://twitter.com/i/web/status/1321412457424932864',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [108, 131]}]},
#    'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2913699628,
#     'id_str': '2913699628',
#     'name': '80 LEVEL',
#     'screen_name': '80Level',
#     'location': 'Los Angeles',
#     'description': 'https://t.co/TxSqrhGe2F is the best place for game developers, digital artists, animators, video game enthusiasts, CGI and VFX talents.',
#     'url': 'http://t.co/TxSqrhGe2F',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/TxSqrhGe2F',
#         'expanded_url': 'http://80.lv',
#         'display_url': '80.lv',
#         'indices': [0, 22]}]},
#      'description': {'urls': [{'url': 'https://t.co/TxSqrhGe2F',
#         'expanded_url': 'http://80.lv',
#         'display_url': '80.lv',
#         'indices': [0, 23]}]}},
#     'protected': False,
#     'followers_count': 63914,
#     'friends_count': 1580,
#     'listed_count': 765,
#     'created_at': 'Wed Dec 10 12:06:32 +0000 2014',
#     'favourites_count': 5775,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 8638,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1179033238792093698/7iZDiQf2_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1179033238792093698/7iZDiQf2_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2913699628/1569917503',
#     'profile_link_color': '94D487',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 40,
#    'favorite_count': 148,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 28 04:34:01 +0000 2020',
#    'id': 1321309221011542016,
#    'id_str': '1321309221011542016',
#    'text': '20+ Articles &amp; Tutorials on Classification Methods for #DataScientists at @DataScienceCtrl 👉https://t.co/rZOkrIkwQ0… https://t.co/xannkqAn2y',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'DataScientists', 'indices': [59, 74]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'DataScienceCtrl',
#       'name': 'Data Science Central',
#       'id': 393033324,
#       'id_str': '393033324',
#       'indices': [78, 94]}],
#     'urls': [{'url': 'https://t.co/rZOkrIkwQ0',
#       'expanded_url': 'https://dy.si/oafqqR',
#       'display_url': 'dy.si/oafqqR',
#       'indices': [96, 119]},
#      {'url': 'https://t.co/xannkqAn2y',
#       'expanded_url': 'https://twitter.com/i/web/status/1321309221011542016',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [121, 144]}]},
#    'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 534563976,
#     'id_str': '534563976',
#     'name': 'Kirk Borne',
#     'screen_name': 'KirkDBorne',
#     'location': 'Maryland, USA',
#     'description': 'Principal Data Scientist @BoozAllen. Global Speaker. Top #BigData #DataScience #AI Influencer. PhD Astrophysicist. (Views = my own) https://t.co/abP8DkYJY2 📊🔭',
#     'url': 'https://t.co/tWlmeuTlR7',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/tWlmeuTlR7',
#         'expanded_url': 'http://www.linkedin.com/in/kirkdborne',
#         'display_url': 'linkedin.com/in/kirkdborne',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/abP8DkYJY2',
#         'expanded_url': 'http://rocketdatascience.org',
#         'display_url': 'rocketdatascience.org',
#         'indices': [132, 155]}]}},
#     'protected': False,
#     'followers_count': 270598,
#     'friends_count': 9930,
#     'listed_count': 8184,
#     'created_at': 'Fri Mar 23 16:35:17 +0000 2012',
#     'favourites_count': 205451,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 126995,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/534563976/1590790599',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 37,
#    'favorite_count': 72,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Oct 27 10:58:46 +0000 2020',
#    'id': 1321043658699931648,
#    'id_str': '1321043658699931648',
#    'text': '35 new #deeplearning examples! https://t.co/tFbhUQqxw2 https://t.co/GRxUHpKdf3',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'deeplearning', 'indices': [7, 20]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/tFbhUQqxw2',
#       'expanded_url': 'http://spr.ly/6013GNRHP',
#       'display_url': 'spr.ly/6013GNRHP',
#       'indices': [31, 54]}],
#     'media': [{'id': 1321043656669880320,
#       'id_str': '1321043656669880320',
#       'indices': [55, 78],
#       'media_url': 'http://pbs.twimg.com/media/ElVKNOCXYAATYbJ.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/ElVKNOCXYAATYbJ.jpg',
#       'url': 'https://t.co/GRxUHpKdf3',
#       'display_url': 'pic.twitter.com/GRxUHpKdf3',
#       'expanded_url': 'https://twitter.com/MATLAB/status/1321043658699931648/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 1024, 'h': 536, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 356, 'resize': 'fit'},
#        'large': {'w': 1024, 'h': 536, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1321043656669880320,
#       'id_str': '1321043656669880320',
#       'indices': [55, 78],
#       'media_url': 'http://pbs.twimg.com/media/ElVKNOCXYAATYbJ.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/ElVKNOCXYAATYbJ.jpg',
#       'url': 'https://t.co/GRxUHpKdf3',
#       'display_url': 'pic.twitter.com/GRxUHpKdf3',
#       'expanded_url': 'https://twitter.com/MATLAB/status/1321043658699931648/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 1024, 'h': 536, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 356, 'resize': 'fit'},
#        'large': {'w': 1024, 'h': 536, 'resize': 'fit'}}}]},
#    'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#    'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 156645608,
#     'id_str': '156645608',
#     'name': 'MATLAB',
#     'screen_name': 'MATLAB',
#     'location': 'Natick, MA, USA',
#     'description': 'MATLAB is a high-level language and interactive environment for numerical computation, visualization, and programming 🖥️ Follow us on Instagram @MATLAB',
#     'url': 'http://t.co/L5x7tpBW7V',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/L5x7tpBW7V',
#         'expanded_url': 'http://www.mathworks.com',
#         'display_url': 'mathworks.com',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 73570,
#     'friends_count': 944,
#     'listed_count': 1110,
#     'created_at': 'Thu Jun 17 14:06:04 +0000 2010',
#     'favourites_count': 1178,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 9013,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1041686882915155968/qw90wxxo_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1041686882915155968/qw90wxxo_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/156645608/1551293315',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 45,
#    'favorite_count': 122,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 01:15:04 +0000 2020',
#    'id': 1321621542564933632,
#    'id_str': '1321621542564933632',
#    'text': 'Four Ways #ArtificialIntelligence \n\nIs Hidden In Our Daily Lives \n\nhttps://t.co/5vv1yRp5hU #fintech #AI… https://t.co/A2AcwGgEe6',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'ArtificialIntelligence',
#       'indices': [10, 33]},
#      {'text': 'fintech', 'indices': [91, 99]},
#      {'text': 'AI', 'indices': [100, 103]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/5vv1yRp5hU',
#       'expanded_url': 'https://buff.ly/37RfNvQ',
#       'display_url': 'buff.ly/37RfNvQ',
#       'indices': [67, 90]},
#      {'url': 'https://t.co/A2AcwGgEe6',
#       'expanded_url': 'https://twitter.com/i/web/status/1321621542564933632',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [105, 128]}]},
#    'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#    'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2711212681,
#     'id_str': '2711212681',
#     'name': 'Spiros Margaris',
#     'screen_name': 'SpirosMargaris',
#     'location': 'All Over the World',
#     'description': '#VC #Futurist @wefoxHQ @SparkLabsGlobal @ai_mediastalker @canopyrent @stcpay_ksa @F10_accelerator | No.1 #Fintech Influencer @Refinitiv & @Onalytica | #AI @TEDx',
#     'url': 'https://t.co/PeTBLwijX6',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/PeTBLwijX6',
#         'expanded_url': 'http://www.MargarisVentures.com',
#         'display_url': 'MargarisVentures.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 103964,
#     'friends_count': 15095,
#     'listed_count': 5602,
#     'created_at': 'Wed Aug 06 05:20:16 +0000 2014',
#     'favourites_count': 175645,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 203242,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '3B94D9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1080518156932825089/Elhx7SXw_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1080518156932825089/Elhx7SXw_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2711212681/1597474916',
#     'profile_link_color': '1C2841',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 18,
#    'favorite_count': 20,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 00:28:02 +0000 2020',
#    'id': 1321609703101779970,
#    'id_str': '1321609703101779970',
#    'text': 'Deloitte Survey: \n\nThe Impact of #ArtificialIntelligence on #HealthCare \n\nhttps://t.co/fFBXTDTfab #fintech… https://t.co/SDhLl9Eop8',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'ArtificialIntelligence',
#       'indices': [33, 56]},
#      {'text': 'HealthCare', 'indices': [60, 71]},
#      {'text': 'fintech', 'indices': [98, 106]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/fFBXTDTfab',
#       'expanded_url': 'https://buff.ly/2HGWjPy',
#       'display_url': 'buff.ly/2HGWjPy',
#       'indices': [74, 97]},
#      {'url': 'https://t.co/SDhLl9Eop8',
#       'expanded_url': 'https://twitter.com/i/web/status/1321609703101779970',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [108, 131]}]},
#    'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#    'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2711212681,
#     'id_str': '2711212681',
#     'name': 'Spiros Margaris',
#     'screen_name': 'SpirosMargaris',
#     'location': 'All Over the World',
#     'description': '#VC #Futurist @wefoxHQ @SparkLabsGlobal @ai_mediastalker @canopyrent @stcpay_ksa @F10_accelerator | No.1 #Fintech Influencer @Refinitiv & @Onalytica | #AI @TEDx',
#     'url': 'https://t.co/PeTBLwijX6',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/PeTBLwijX6',
#         'expanded_url': 'http://www.MargarisVentures.com',
#         'display_url': 'MargarisVentures.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 103964,
#     'friends_count': 15095,
#     'listed_count': 5602,
#     'created_at': 'Wed Aug 06 05:20:16 +0000 2014',
#     'favourites_count': 175645,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 203242,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '3B94D9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1080518156932825089/Elhx7SXw_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1080518156932825089/Elhx7SXw_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2711212681/1597474916',
#     'profile_link_color': '1C2841',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 19,
#    'favorite_count': 14,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 01:01:01 +0000 2020',
#    'id': 1321618003990073344,
#    'id_str': '1321618003990073344',
#    'text': 'Why #DeepNeuralNetworks Help \n\nto #Explain Living #Brains \n\nhttps://t.co/P5oO0GauPi #fintech #AI… https://t.co/CKreUrgpIU',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'DeepNeuralNetworks',
#       'indices': [4, 23]},
#      {'text': 'Explain', 'indices': [34, 42]},
#      {'text': 'Brains', 'indices': [50, 57]},
#      {'text': 'fintech', 'indices': [84, 92]},
#      {'text': 'AI', 'indices': [93, 96]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/P5oO0GauPi',
#       'expanded_url': 'https://buff.ly/3mxzL2I',
#       'display_url': 'buff.ly/3mxzL2I',
#       'indices': [60, 83]},
#      {'url': 'https://t.co/CKreUrgpIU',
#       'expanded_url': 'https://twitter.com/i/web/status/1321618003990073344',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [98, 121]}]},
#    'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#    'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2711212681,
#     'id_str': '2711212681',
#     'name': 'Spiros Margaris',
#     'screen_name': 'SpirosMargaris',
#     'location': 'All Over the World',
#     'description': '#VC #Futurist @wefoxHQ @SparkLabsGlobal @ai_mediastalker @canopyrent @stcpay_ksa @F10_accelerator | No.1 #Fintech Influencer @Refinitiv & @Onalytica | #AI @TEDx',
#     'url': 'https://t.co/PeTBLwijX6',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/PeTBLwijX6',
#         'expanded_url': 'http://www.MargarisVentures.com',
#         'display_url': 'MargarisVentures.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 103964,
#     'friends_count': 15095,
#     'listed_count': 5602,
#     'created_at': 'Wed Aug 06 05:20:16 +0000 2014',
#     'favourites_count': 175645,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 203242,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '3B94D9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1080518156932825089/Elhx7SXw_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1080518156932825089/Elhx7SXw_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2711212681/1597474916',
#     'profile_link_color': '1C2841',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 10,
#    'favorite_count': 8,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Oct 29 03:52:23 +0000 2020',
#    'id': 1321661130142568448,
#    'id_str': '1321661130142568448',
#    'text': '#MachineLearning Guide &amp; Tutorial for #ML Engineers: https://t.co/hFM2Rg8oAa\n——————\n#abdsc #BigData #DataScience… https://t.co/Yfe2bOZ6Fk',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'MachineLearning', 'indices': [0, 16]},
#      {'text': 'ML', 'indices': [42, 45]},
#      {'text': 'abdsc', 'indices': [88, 94]},
#      {'text': 'BigData', 'indices': [95, 103]},
#      {'text': 'DataScience', 'indices': [104, 116]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/hFM2Rg8oAa',
#       'expanded_url': 'http://bit.ly/2D9UeIJ',
#       'display_url': 'bit.ly/2D9UeIJ',
#       'indices': [57, 80]},
#      {'url': 'https://t.co/Yfe2bOZ6Fk',
#       'expanded_url': 'https://twitter.com/i/web/status/1321661130142568448',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [118, 141]}]},
#    'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 534563976,
#     'id_str': '534563976',
#     'name': 'Kirk Borne',
#     'screen_name': 'KirkDBorne',
#     'location': 'Maryland, USA',
#     'description': 'Principal Data Scientist @BoozAllen. Global Speaker. Top #BigData #DataScience #AI Influencer. PhD Astrophysicist. (Views = my own) https://t.co/abP8DkYJY2 📊🔭',
#     'url': 'https://t.co/tWlmeuTlR7',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/tWlmeuTlR7',
#         'expanded_url': 'http://www.linkedin.com/in/kirkdborne',
#         'display_url': 'linkedin.com/in/kirkdborne',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/abP8DkYJY2',
#         'expanded_url': 'http://rocketdatascience.org',
#         'display_url': 'rocketdatascience.org',
#         'indices': [132, 155]}]}},
#     'protected': False,
#     'followers_count': 270598,
#     'friends_count': 9930,
#     'listed_count': 8184,
#     'created_at': 'Fri Mar 23 16:35:17 +0000 2012',
#     'favourites_count': 205451,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 126995,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/534563976/1590790599',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 14,
#    'favorite_count': 9,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.039,
#   'max_id': 0,
#   'max_id_str': '0',
#   'next_results': '?max_id=1321043658699931647&q=%23DeepLearning&count=10&include_entities=1&result_type=popular',
#   'query': '%23DeepLearning',
#   'count': 10,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
len(deep_learning_api_search.json())
# Out:
# 2

# %% [markdown]
# ## Section 3: Searching Users

# %% [markdown]
# The last section of the API you'll need to get the hang of before you're let loose is the users API, which allows you to search for users and get their followers, friends, etc, as opposed to tweets which fit a particular criteria.  This part is pretty similar to the advanced lab in class 3, so if you saw how that worked then you shouldn't need much instruction.
#
# But if you're seeing this with fresh eyes, you'll want to spend 15-20 minutes to make sure you understand this part.
#
# Official documentation can be found here:  https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/overview
#
# So, as an example, if you want to get a list of someone's followers, you use the base url `https://api.twitter.com/1.1/followers/list.json` and then enter your query string to get a list of that person's followers.
#
# List of parameters to use can be found here:  https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference/get-followers-list
#
# One possible parameter to use is `screen_name`, so if you wanted to get a list of someone's followers based on their screen name (the handle that begins with an @), then you would set up your API call to look something like:
#
# `https://api.twitter.com/1.1/followers/list.json?screen_name=persons_screenname`
#
# Note that you exclude the `@`.
#
# **Your turn:** Pull in the list of General Assembly's followers.  General Assembly's handle is `@GA`.
#
# Note that this won't return the whole list of GA's users.  If you want to do that you have to use cursoring:  https://developer.twitter.com/en/docs/basics/cursoring.  This is the topic of your bonus assignment.

# %%
# your answer here
url_ga_followers = "https://api.twitter.com/1.1/followers/list.json?screen_name=GA&count=5"

ga_followers = requests.get(url_ga_followers, auth=my_auth)

# %%
ga_followers
# Out:
# <Response [200]>

# %%
ga_followers.json()
# Out:
# {'users': [{'id': 1708470212,
#    'id_str': '1708470212',
#    'name': 'Frank Joseph🔱🇳🇬🛫🇷🇼Mochievous 1st son',
#    'screen_name': 'josephfrank05',
#    'location': 'Lagos, Nigeria',
#    'description': 'FrontendDev.\nDigital Marketing/Ecom \n\n@frank  on @abeg_app incase',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 313,
#    'friends_count': 1371,
#    'listed_count': 1,
#    'created_at': 'Wed Aug 28 22:55:57 +0000 2013',
#    'favourites_count': 8892,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1421,
#    'lang': None,
#    'status': {'created_at': 'Thu Oct 29 22:14:26 +0000 2020',
#     'id': 1321938469791375362,
#     'id_str': '1321938469791375362',
#     'text': 'This Photoshop generation, nothing we no go see.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1179076222866907136/VsVeRwKi_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1179076222866907136/VsVeRwKi_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1708470212/1539876315',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 19724901,
#    'id_str': '19724901',
#    'name': 'Gooblythe',
#    'screen_name': 'gooblythe',
#    'location': 'New York, NY',
#    'description': 'pr @SpotX & writer! (formerly @innovid @taboola @gameloft). love 📺📽🎼⚾️☔️❄️👽, cocker spaniels, & ☕. lived in dc, smell-a, now in the big 🍎. tweets R my own.',
#    'url': 'https://t.co/80aQ5M9gW9',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/80aQ5M9gW9',
#        'expanded_url': 'http://www.tammyblythegoodman.com',
#        'display_url': 'tammyblythegoodman.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 971,
#    'friends_count': 3506,
#    'listed_count': 82,
#    'created_at': 'Thu Jan 29 18:27:25 +0000 2009',
#    'favourites_count': 6719,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 11497,
#    'lang': None,
#    'status': {'created_at': 'Fri Oct 30 05:24:49 +0000 2020',
#     'id': 1322046779815350272,
#     'id_str': '1322046779815350272',
#     'text': 'This is a must-read. Mass Death in South Texas - via \u2066@TheAtlantic\u2069  https://t.co/pWJJAGTi4t',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'TheAtlantic',
#        'name': 'The Atlantic',
#        'id': 35773039,
#        'id_str': '35773039',
#        'indices': [54, 66]}],
#      'urls': [{'url': 'https://t.co/pWJJAGTi4t',
#        'expanded_url': 'https://www.theatlantic.com/ideas/archive/2020/10/mass-death-in-south-texas/616907/',
#        'display_url': 'theatlantic.com/ideas/archive/…',
#        'indices': [69, 92]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '709397',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme6/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme6/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1048840910476365824/SPXozeyg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1048840910476365824/SPXozeyg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19724901/1482699409',
#    'profile_link_color': 'FF3300',
#    'profile_sidebar_border_color': '86A4A6',
#    'profile_sidebar_fill_color': 'A0C5C7',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1321163062611709957,
#    'id_str': '1321163062611709957',
#    'name': 'Michelle',
#    'screen_name': 'GoForMich',
#    'location': 'Miami, FL',
#    'description': '🖥 Aspiring Software Engineer - #100Devs 🎭 Stage Manager/Theatre Professional- #MiamiMotelStories',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 85,
#    'friends_count': 334,
#    'listed_count': 0,
#    'created_at': 'Tue Oct 27 18:53:25 +0000 2020',
#    'favourites_count': 29,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 12,
#    'lang': None,
#    'status': {'created_at': 'Fri Oct 30 03:24:36 +0000 2020',
#     'id': 1322016527508508672,
#     'id_str': '1322016527508508672',
#     'text': '@C1_10P Totally!',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'C1_10P',
#        'name': '🎃 Jessi 🎃',
#        'id': 1220327664,
#        'id_str': '1220327664',
#        'indices': [0, 7]}],
#      'urls': []},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': 1322015946077188096,
#     'in_reply_to_status_id_str': '1322015946077188096',
#     'in_reply_to_user_id': 1220327664,
#     'in_reply_to_user_id_str': '1220327664',
#     'in_reply_to_screen_name': 'C1_10P',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1321163281634119680/SCw2nrAX_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1321163281634119680/SCw2nrAX_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1321163062611709957/1603850094',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 10861852,
#    'id_str': '10861852',
#    'name': 'domo',
#    'screen_name': 'Domo_kun_nyc',
#    'location': 'New York, NY',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 32,
#    'friends_count': 464,
#    'listed_count': 0,
#    'created_at': 'Wed Dec 05 04:56:05 +0000 2007',
#    'favourites_count': 2380,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 395,
#    'lang': None,
#    'status': {'created_at': 'Thu Oct 29 17:47:46 +0000 2020',
#     'id': 1321871359862054916,
#     'id_str': '1321871359862054916',
#     'text': 'Yasssssss https://t.co/8OqDHazegA',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/8OqDHazegA',
#        'expanded_url': 'https://twitter.com/daniarv25/status/1321870972647952385',
#        'display_url': 'twitter.com/daniarv25/stat…',
#        'indices': [10, 33]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': {'id': '00c39537733fa112',
#      'url': 'https://api.twitter.com/1.1/geo/id/00c39537733fa112.json',
#      'place_type': 'city',
#      'name': 'Queens',
#      'full_name': 'Queens, NY',
#      'country_code': 'US',
#      'country': 'United States',
#      'contained_within': [],
#      'bounding_box': {'type': 'Polygon',
#       'coordinates': [[[-73.962582, 40.541722],
#         [-73.699793, 40.541722],
#         [-73.699793, 40.8000371],
#         [-73.962582, 40.8000371]]]},
#      'attributes': {}},
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1321870972647952385,
#     'quoted_status_id_str': '1321870972647952385',
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'und'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1321871142517395458/29pFPjnV_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1321871142517395458/29pFPjnV_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 241065930,
#    'id_str': '241065930',
#    'name': 'Michael Keaveney',
#    'screen_name': 'Keaveneymichael',
#    'location': 'Ireland Britain',
#    'description': 'Irish in London, interested in all things Irish and Global, former diplomat.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 420,
#    'friends_count': 312,
#    'listed_count': 9,
#    'created_at': 'Fri Jan 21 11:18:07 +0000 2011',
#    'favourites_count': 503,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 1767,
#    'lang': None,
#    'status': {'created_at': 'Tue Oct 27 20:11:29 +0000 2020',
#     'id': 1321182752973217796,
#     'id_str': '1321182752973217796',
#     'text': 'After 2 weeks of multiple health screens and asking everyone to quarantine, I surprised my closest inner circle wit… https://t.co/dfKHOwEW8Y',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/dfKHOwEW8Y',
#        'expanded_url': 'https://twitter.com/i/web/status/1321182752973217796',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1302001744126373892/_mw3P7R6_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1302001744126373892/_mw3P7R6_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/241065930/1599256326',
#    'profile_link_color': '94D487',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'}],
#  'next_cursor': 1681887382445455439,
#  'next_cursor_str': '1681887382445455439',
#  'previous_cursor': 0,
#  'previous_cursor_str': '0',
#  'total_count': None}

# %% [markdown]
# ## Section 4: Functions

# %% [markdown]
# This section details the functions you have to write and turn in as part of your homework assignment.
#
# Please read the requirements carefully.
#
# **What you'll turn in:** A `.py` file with all of the functions written.  We should be able to load this into an IDE, run the file, and then call your functions to verify how and if they work. This file should also be properly commented so we can follow your line of reasoning.
#
# The functions you'll be prompted to write will be defined in the following ways:
#
#  - **name:** the name of the function
#  - **returns:** what the function should return
#  - **arguments:** arguments to include inside the function in order to specify how it should behave.
#
#  **Note:** The free API has limitations built into it, so this means from time-to-time you'll only be able to return some of the results from the API.  This is fine.  It's understood and recognized that your functions won't be able to return an entire list of someone's users or other such things, so as long as your work delivers the best it can under present circumstances you'll be in good shape.
#
#  **Other Note:** Every aspect of the API that you need to use can be found on either of these pages.
#
#  Search API:  https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets
#
#  Users API: https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference
#
# **Remarks About Your Final Work**
#
#  - It's okay if you get stuck somewhere.  If there's one item that you can't figure out and it doesn't quite work right, it's probably best to move on and try other things.  Again, try and explain what you were looking to do.  You'll pass if you give an honest effort.
#  - There's potentially a lot of error handling you could do to verify user input is correct, but you can leave that alone for now.  Just make sure the core purpose of the function works the way it's supposed to.
#  - While you're working on this, it's possible you may bump into your API limits.  Keep this in mind if you have a function that's working, but 45 minutes later it doesn't and you haven't changed anything.  This usually means the data you're getting back from your API calls isn't what it's supposed to be because you've exhausted your limits. We won't hold you to double checking for all of this in your functions.
#  - In the file you turn in, make sure your requests are referencing your API tokens, so that way we can run your file right away.  Ie, make sure somewhere in your script you have a variable at the top that reads `tokens = OAuth1('token1', 'token2', 'token3', 'token4')` so it can be used for your requests inside the file.

# %% [markdown]
# ##### Function 1 (Required)

# %% [markdown]
# **Name:** `find_user`
#
# **Returns:** dictionary that represents user object returned by Twitter's API
#
# **Arguments:**
#  - `screen_name`: str, required; Twitter handle to search for.  **Can include the @ symbol.  The function should check for this and remove it if necessary.**
#  - `keys`: list, optional; list that contains keys to return about user object.  If not specified, then function should return the entire user object.  **These only need to be outer keys.** If they are keys nested within another key, you don't have to account for this.
#
# **To test:** We'll test your function in the following ways:
#
#  - `find_user('@GA')`
#  - `find_user('GA')`
#  - `find_user('GA', keys=['name', 'screen_name', 'followers_count', 'friends_count'])`

# %% [markdown]
# ##### Function 2 (Required)

# %% [markdown]
# **Name:** `find_hashtag`
#
# **Returns:** list of data objects that contain information about each tweet that matches the hashtag provided as input.
#
# **Arguments:**
#  - `hashtag`: str, required; text to use as a hashtag search.
#  - `count`: int, optional; number of results to return
#  - `search_type`: str, optional; type of results to return.  should accept 3 different values:
#    - `mixed`:   return mix of most recent and most popular results
#    - `recent`:  return most recent results
#    - `popular`: return most popular results
#
# **Note:** User should **not** have to actually use the `#` character for the `hashtag` argument.  The function should check to see if it's there, and if not, add it in for them.
#
# **To Test:**  We'll check your function in the following ways:
#  - `find_hashtag('DataScience')`
#  - `find_hashtag('#DataScience')`
#  - `find_hashtag('#DataScience', count=100)`, and double check the length of the `statuses` key to make sure it contains the right amount of results.  **Note:** Due to the version of the API we're using, the number of results returned will **not** necessarily match the value passed into the `count` parameter.  So if you specify 50 and it only returns 45, you are likely still doing it correctly.
#  - `find_hashtag('#DataScience', search_type='recent/mixed/popular')`

# %% [markdown]
# ##### Function 3 (Required)

# %% [markdown]
# **Name:** `get_followers`
#
# **Returns:** list of data objects for each of the users followers, returning values for the `name`, `followers_count`, `friends_count`, and `screen_name` key for each user.
#
# **Arguments:**
#
#  - `screen_name`: str, required; Twitter handle to search for.  **Results should not depend on user inputting the @ symbol.**
#  - `keys`: list, required;  keys to return for each user.  default value: [`name`, `followers_count`, `friends_count`, `screen_name`]; if something else is listed, values for those keys should be returned
#  - `to_df`: bool, required; default value: False; if True, return results in a dataframe.  Every value provided in the `keys` argument should be its own column, with rows populated by the corresponding values for each one for every user.
#
# **To Test:** We'll test your functions in the following ways:
#
#  - `get_followers('@GA')`
#  - `get_followers('GA')`
#  - `get_followers('GA', keys=['name', 'followers_count'])`
#  - `get_followers('GA', keys=['name', 'followers_count'], to_df=True)`
#  - `get_followers('GA', to_df=True)`

# %% [markdown]
# ##### Function 4 (Optional)

# %% [markdown]
# **Name:** `friends_of_friends`
#
# **Returns:** list of data objects for each user that two Twitter users have in common
#
# **Arguments:**
#
#  - `names`: list, required; list of two Twitter users to compare friends list with
#  - `keys`: list, optional; list of keys to return for information about each user.  Default value should be to return the entire data object.
#  - `to_df`: bool, required; default value: False; if True, returns results in a dataframe.
#
# **To Test:** We'll test your function in the following ways:
#
#  - `friends_of_friends(['Beyonce', 'MariahCarey'])`
#  - `friends_of_friends(['@Beyonce', '@MariahCarey'], to_df=True)`
#  - `friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'])`
#  - `friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'], to_df=True)`
#
# Each of these should return 3 results. (Assuming they haven't followed the same people since this was last written).
#
# **Hint:** The `id` key is the unique identifier for someone, so if you want to check if two people are the same this is the best way to do it.

# %% [markdown]
#  ##### Function 5 (Optional)

# %% [markdown]
# Rewrite the `friends_of_friends` function, except this time include an argument called `full_search`, which accepts a boolean value.  If set to `True`, use cursoring to cycle through the complete set of users for the users provided.
#
# The twitter API only returns a subset of users in your results to save bandwidth, so you have to cycle through multiple result sets to get all of the values.
#
# You can read more about how this works here:  https://developer.twitter.com/en/docs/basics/cursoring
#
# Basically you have to do a `while` loop to continually make a new request using the values stored in the `next_cursor` key as part of your next query string until there's nothing left to search.
#
# **Note:** We're using the free API, so we're operating under some limitations.  One of them being that you can only make 15 API calls in a 15 minute span to this portion of the API.  You can also only return up to 200 results per cursor, so this means you won't be able to completely search for everyone even if you set this up correctly.
#
# That's fine, just do what you can under the circumstances.
#
# **To Test:** To test your function, we'll run the following function calls:
#
#  - `friends_of_friends(['ezraklein', 'tylercowen'])` -- should return 4 results if you do an API call that returns 200 results
#  - `friends_of_friends(['ezraklein', 'tylercowen'], full_search=True)` -- should return 54 results if you do an API call that returns 200 results
#
# **Hint:** Chances are you will exhaust your API limits quite easily in this function depending on who you search for.  Depending on how you have things set up, this could cause error messages to arise when things are otherwise fine.  Remember in class 3 when we were getting those weird dictionaries back because our limits were used up?  We won't hold you accountable for handling this inside your function, although it could make some things easier for your own testing.
#
# Good luck!
