# %% [markdown]
# # Data Preperation

# %% [markdown]
# Overall steps for data preparation will be:
# 1. Deal with any null values
# 2. Create additional bespoke data features
# 3. Create manual OneHotEncoding
# 4. Extract file for use in model pipeline (enables target encoding parameters to be manipulated)
# 5. Design code for target_encoded columns
# 6. Design code for ordinal_encoded columns
# 7. Design code for onehot encoded columns
# 8. Run individual code sets and expected modelling data set (noting params in pipeline that may change)

# %% [markdown]
# ## 0. Import modules and data set, adjust pandas settings

# %%
import numpy as np
import pandas as pd
import category_encoders as ce

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df_orig = pd.read_csv('../data/iowa_full.csv')

# %%
df = df_orig.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
df.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %% [markdown]
# ***

# %% [markdown]
# ## 1. Deal with any null values

# %%
# Use function to add in indicators for presence of null values

# %%
def denote_null_values(df):
    """Denotes whether or not there are null values or not"""
    empty_cols_query = df.isnull().sum() > 0
    empty_df_cols = df.loc[:, empty_cols_query].columns.tolist()
    for col in empty_df_cols:
        col_name = f"{col}_missing"
        df[col_name] = pd.isnull(df[col])
    return df

# %%
df = denote_null_values(df)

# %%
df.info()
# This shwos an additional 19 "_missing" columns so the function work properly.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 100 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    1460 non-null   int64
#  1   MSSubClass            1460 non-null   int64
#  2   MSZoning              1460 non-null   object
#  3   LotFrontage           1201 non-null   float64
#  4   LotArea               1460 non-null   int64
#  5   Street                1460 non-null   object
#  6   Alley                 91 non-null     object
#  7   LotShape              1460 non-null   object
#  8   LandContour           1460 non-null   object
#  9   Utilities             1460 non-null   object
#  10  LotConfig             1460 non-null   object
#  11  LandSlope             1460 non-null   object
#  12  Neighborhood          1460 non-null   object
#  13  Condition1            1460 non-null   object
#  14  Condition2            1460 non-null   object
#  15  BldgType              1460 non-null   object
#  16  HouseStyle            1460 non-null   object
#  17  OverallQual           1460 non-null   int64
#  18  OverallCond           1460 non-null   int64
#  19  YearBuilt             1460 non-null   int64
#  20  YearRemodAdd          1460 non-null   int64
#  21  RoofStyle             1460 non-null   object
#  22  RoofMatl              1460 non-null   object
#  23  Exterior1st           1460 non-null   object
#  24  Exterior2nd           1460 non-null   object
#  25  MasVnrType            1452 non-null   object
#  26  MasVnrArea            1452 non-null   float64
#  27  ExterQual             1460 non-null   object
#  28  ExterCond             1460 non-null   object
#  29  Foundation            1460 non-null   object
#  30  BsmtQual              1423 non-null   object
#  31  BsmtCond              1423 non-null   object
#  32  BsmtExposure          1422 non-null   object
#  33  BsmtFinType1          1423 non-null   object
#  34  BsmtFinSF1            1460 non-null   int64
#  35  BsmtFinType2          1422 non-null   object
#  36  BsmtFinSF2            1460 non-null   int64
#  37  BsmtUnfSF             1460 non-null   int64
#  38  TotalBsmtSF           1460 non-null   int64
#  39  Heating               1460 non-null   object
#  40  HeatingQC             1460 non-null   object
#  41  CentralAir            1460 non-null   object
#  42  Electrical            1459 non-null   object
#  43  1stFlrSF              1460 non-null   int64
#  44  2ndFlrSF              1460 non-null   int64
#  45  LowQualFinSF          1460 non-null   int64
#  46  GrLivArea             1460 non-null   int64
#  47  BsmtFullBath          1460 non-null   int64
#  48  BsmtHalfBath          1460 non-null   int64
#  49  FullBath              1460 non-null   int64
#  50  HalfBath              1460 non-null   int64
#  51  BedroomAbvGr          1460 non-null   int64
#  52  KitchenAbvGr          1460 non-null   int64
#  53  KitchenQual           1460 non-null   object
#  54  TotRmsAbvGrd          1460 non-null   int64
#  55  Functional            1460 non-null   object
#  56  Fireplaces            1460 non-null   int64
#  57  FireplaceQu           770 non-null    object
#  58  GarageType            1379 non-null   object
#  59  GarageYrBlt           1379 non-null   float64
#  60  GarageFinish          1379 non-null   object
#  61  GarageCars            1460 non-null   int64
#  62  GarageArea            1460 non-null   int64
#  63  GarageQual            1379 non-null   object
#  64  GarageCond            1379 non-null   object
#  65  PavedDrive            1460 non-null   object
#  66  WoodDeckSF            1460 non-null   int64
#  67  OpenPorchSF           1460 non-null   int64
#  68  EnclosedPorch         1460 non-null   int64
#  69  3SsnPorch             1460 non-null   int64
#  70  ScreenPorch           1460 non-null   int64
#  71  PoolArea              1460 non-null   int64
#  72  PoolQC                7 non-null      object
#  73  Fence                 281 non-null    object
#  74  MiscFeature           54 non-null     object
#  75  MiscVal               1460 non-null   int64
#  76  MoSold                1460 non-null   int64
#  77  YrSold                1460 non-null   int64
#  78  SaleType              1460 non-null   object
#  79  SaleCondition         1460 non-null   object
#  80  SalePrice             1460 non-null   int64
#  81  LotFrontage_missing   1460 non-null   bool
#  82  Alley_missing         1460 non-null   bool
#  83  MasVnrType_missing    1460 non-null   bool
#  84  MasVnrArea_missing    1460 non-null   bool
#  85  BsmtQual_missing      1460 non-null   bool
#  86  BsmtCond_missing      1460 non-null   bool
#  87  BsmtExposure_missing  1460 non-null   bool
#  88  BsmtFinType1_missing  1460 non-null   bool
#  89  BsmtFinType2_missing  1460 non-null   bool
#  90  Electrical_missing    1460 non-null   bool
#  91  FireplaceQu_missing   1460 non-null   bool
#  92  GarageType_missing    1460 non-null   bool
#  93  GarageYrBlt_missing   1460 non-null   bool
#  94  GarageFinish_missing  1460 non-null   bool
#  95  GarageQual_missing    1460 non-null   bool
#  96  GarageCond_missing    1460 non-null   bool
#  97  PoolQC_missing        1460 non-null   bool
#  98  Fence_missing         1460 non-null   bool
#  99  MiscFeature_missing   1460 non-null   bool
# dtypes: bool(19), float64(3), int64(35), object(43)
# memory usage: 951.1+ KB

# %% [markdown]
# ***

# %%
# LotFrontage - replace nulls using average for the neighbourhood.
# get a DF to join to the data set as a new column
lotfrontage_neighborhood_mean = df.groupby(by=['Neighborhood'])[['LotFrontage']].mean().reset_index()
lotfrontage_neighborhood_mean.columns = ['Neighborhood','LotFrontage_Neighborhood_Mean']
lotfrontage_neighborhood_mean
# Out:
#    Neighborhood  LotFrontage_Neighborhood_Mean
# 0       Blmngtn                      47.142857
# 1       Blueste                      24.000000
# 2        BrDale                      21.562500
# 3       BrkSide                      57.509804
# 4       ClearCr                      83.461538
# 5       CollgCr                      71.682540
# 6       Crawfor                      71.804878
# 7       Edwards                      68.217391
# 8       Gilbert                      79.877551
# 9        IDOTRR                      62.500000
# 10      MeadowV                      27.800000
# 11      Mitchel                      70.083333
# 12        NAmes                      76.462366
# 13      NPkVill                      32.285714
# 14       NWAmes                      81.288889
# 15      NoRidge                      91.878788
# 16      NridgHt                      81.881579
# 17      OldTown                      62.788991
# 18        SWISU                      58.913043
# 19       Sawyer                      74.437500
# 20      SawyerW                      71.500000
# 21      Somerst                      64.666667
# 22      StoneBr                      62.700000
# 23       Timber                      80.133333
# 24      Veenker                      59.714286

# %%
df = df.merge(lotfrontage_neighborhood_mean,how='left',left_on='Neighborhood',right_on='Neighborhood')

# %%
df['LotFrontage'] = df['LotFrontage'].fillna(df.LotFrontage_Neighborhood_Mean)

# %%
df.drop('LotFrontage_Neighborhood_Mean',axis=1,inplace=True)

# %% [markdown]
# ***

# %%
# Create AlleyAccess_Flag
df['Alley'].value_counts()
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64

# %%
# ?np.where

# %%
df['AlleyAccess_Flag'] = np.where(df['Alley'].isnull(),0,1)

# %%
df.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice  LotFrontage_missing  Alley_missing  \
# 0       WD        Normal     208500                False           True
# 1       WD        Normal     181500                False           True
# 2       WD        Normal     223500                False           True
# 3       WD       Abnorml     140000                False           True
# 4       WD        Normal     250000                False           True
#
#    MasVnrType_missing  MasVnrArea_missing  BsmtQual_missing  BsmtCond_missing  \
# 0               False               False             False             False
# 1               False               False             False             False
# 2               False               False             False             False
# 3               False               False             False             False
# 4               False               False             False             False
#
#    BsmtExposure_missing  BsmtFinType1_missing  BsmtFinType2_missing  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    Electrical_missing  FireplaceQu_missing  GarageType_missing  \
# 0               False                 True               False
# 1               False                False               False
# 2               False                False               False
# 3               False                False               False
# 4               False                False               False
#
#    GarageYrBlt_missing  GarageFinish_missing  GarageQual_missing  \
# 0                False                 False               False
# 1                False                 False               False
# 2                False                 False               False
# 3                False                 False               False
# 4                False                 False               False
#
#    GarageCond_missing  PoolQC_missing  Fence_missing  MiscFeature_missing  \
# 0               False            True           True                 True
# 1               False            True           True                 True
# 2               False            True           True                 True
# 3               False            True           True                 True
# 4               False            True           True                 True
#
#    AlleyAccess_Flag
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
df[(df['AlleyAccess_Flag']==1)].head(5)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 21  22          45       RM         57.0     7449   Pave  Grvl      Reg
# 30  31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 56  57         160       FV         24.0     2645   Pave  Pave      Reg
# 79  80          50       RM         60.0    10440   Pave  Grvl      Reg
# 87  88         160       FV         40.0     3951   Pave  Pave      Reg
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 21         Bnk    AllPub    Inside       Gtl       IDOTRR       Norm
# 30         Lvl    AllPub    Inside       Gtl       IDOTRR      Feedr
# 56         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 79         Lvl    AllPub    Corner       Gtl      OldTown       Norm
# 87         Lvl    AllPub    Corner       Gtl      Somerst       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 21       Norm     1Fam     1.5Unf            7            7       1930
# 30       Norm     1Fam     2Story            4            4       1920
# 56       Norm    Twnhs     2Story            8            5       1999
# 79       Norm     1Fam     2Story            5            6       1910
# 87       Norm   TwnhsE     2Story            6            5       2009
#
#     YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 21          1950     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 30          1950   Gambrel  CompShg     BrkFace     BrkFace       None
# 56          2000     Gable  CompShg     MetalSd     MetalSd    BrkFace
# 79          1981     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 87          2009     Gable  CompShg     VinylSd     VinylSd      Stone
#
#     MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 21         0.0        TA        TA      PConc       TA       TA           No
# 30         0.0        TA        Fa     BrkTil       TA       TA           No
# 56       456.0        Gd        TA      PConc       Gd       TA           No
# 79         0.0        TA        TA      PConc       TA       TA           No
# 87        76.0        Gd        TA      PConc       Gd       TA           Av
#
#    BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 21          Unf           0          Unf           0        637          637
# 30          Unf           0          Unf           0        649          649
# 56          GLQ         649          Unf           0        321          970
# 79          Unf           0          Unf           0        440          440
# 87          Unf           0          Unf           0        612          612
#
#    Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 21    GasA        Ex          Y      FuseF      1108         0             0
# 30    GasA        TA          N      SBrkr       649       668             0
# 56    GasA        Ex          Y      SBrkr       983       756             0
# 79    GasA        Gd          Y      SBrkr       682       548             0
# 87    GasA        Ex          Y      SBrkr       612       612             0
#
#     GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 21       1108             0             0         1         0             3
# 30       1317             0             0         1         0             3
# 56       1739             1             0         2         1             3
# 79       1230             0             0         1         1             2
# 87       1224             0             0         2         1             2
#
#     KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 21             1          Gd             6        Typ           1          Gd
# 30             1          TA             6        Typ           0         NaN
# 56             1          Gd             7        Typ           0         NaN
# 79             1          TA             5        Typ           0         NaN
# 87             1          Gd             4        Typ           0         NaN
#
#    GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 21     Attchd       1930.0          Unf           1         280         TA
# 30     Detchd       1920.0          Unf           1         250         TA
# 56     Attchd       1999.0          Fin           2         480         TA
# 79     Detchd       1966.0          Unf           2         440         TA
# 87     Detchd       2009.0          RFn           2         528         TA
#
#    GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 21         TA          N           0            0            205          0
# 30         Fa          N           0           54            172          0
# 56         TA          Y         115            0              0          0
# 79         TA          Y          74            0            128          0
# 87         TA          Y           0          234              0          0
#
#     ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 21            0         0    NaN  GdPrv         NaN        0       6    2007
# 30            0         0    NaN  MnPrv         NaN        0       7    2008
# 56            0         0    NaN    NaN         NaN        0       8    2009
# 79            0         0    NaN  MnPrv         NaN        0       5    2009
# 87            0         0    NaN    NaN         NaN        0       6    2009
#
#    SaleType SaleCondition  SalePrice  LotFrontage_missing  Alley_missing  \
# 21       WD        Normal     139400                False          False
# 30       WD        Normal      40000                False          False
# 56       WD       Abnorml     172500                False          False
# 79       WD        Normal     110000                False          False
# 87      New       Partial     164500                False          False
#
#     MasVnrType_missing  MasVnrArea_missing  BsmtQual_missing  \
# 21               False               False             False
# 30               False               False             False
# 56               False               False             False
# 79               False               False             False
# 87               False               False             False
#
#     BsmtCond_missing  BsmtExposure_missing  BsmtFinType1_missing  \
# 21             False                 False                 False
# 30             False                 False                 False
# 56             False                 False                 False
# 79             False                 False                 False
# 87             False                 False                 False
#
#     BsmtFinType2_missing  Electrical_missing  FireplaceQu_missing  \
# 21                 False               False                False
# 30                 False               False                 True
# 56                 False               False                 True
# 79                 False               False                 True
# 87                 False               False                 True
#
#     GarageType_missing  GarageYrBlt_missing  GarageFinish_missing  \
# 21               False                False                 False
# 30               False                False                 False
# 56               False                False                 False
# 79               False                False                 False
# 87               False                False                 False
#
#     GarageQual_missing  GarageCond_missing  PoolQC_missing  Fence_missing  \
# 21               False               False            True          False
# 30               False               False            True          False
# 56               False               False            True           True
# 79               False               False            True          False
# 87               False               False            True           True
#
#     MiscFeature_missing  AlleyAccess_Flag
# 21                 True                 1
# 30                 True                 1
# 56                 True                 1
# 79                 True                 1
# 87                 True                 1

# %%
df['Alley'] = df['Alley'].fillna('no_access')

# %%
df['MasVnrType'].value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
df['MasVnrType'] = df['MasVnrType'].fillna('None')

# %%
df['MasVnrArea'] = df['MasVnrArea'].fillna(0)

# %% [markdown]
# ***

# %%
df[(df.BsmtQual_missing==True)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street      Alley  \
# 17      18          90       RL    72.000000    10791   Pave  no_access
# 39      40          90       RL    65.000000     6040   Pave  no_access
# 90      91          20       RL    60.000000     7200   Pave  no_access
# 102    103          90       RL    64.000000     7018   Pave  no_access
# 156    157          20       RL    60.000000     7200   Pave  no_access
# 182    183          20       RL    60.000000     9060   Pave  no_access
# 259    260          20       RM    70.000000    12702   Pave  no_access
# 342    343          90       RL    76.462366     8544   Pave  no_access
# 362    363          85       RL    64.000000     7301   Pave  no_access
# 371    372          50       RL    80.000000    17120   Pave  no_access
# 392    393          20       RL    76.462366     8339   Pave  no_access
# 520    521         190       RL    60.000000    10800   Pave       Grvl
# 532    533          20       RL    60.000000     7200   Pave  no_access
# 533    534          20       RL    50.000000     5000   Pave  no_access
# 553    554          20       RL    67.000000     8777   Pave  no_access
# 646    647          20       RL    60.000000     7200   Pave  no_access
# 705    706         190       RM    70.000000     5600   Pave  no_access
# 736    737          90       RL    60.000000     8544   Pave  no_access
# 749    750          50       RL    50.000000     8405   Pave  no_access
# 778    779          90       RH    60.000000     8400   Pave  no_access
# 868    869          60       RL    79.877551    14762   Pave  no_access
# 894    895          90       RL    64.000000     7018   Pave  no_access
# 897    898          90       RL    64.000000     7018   Pave  no_access
# 984    985          90       RL    75.000000    10125   Pave  no_access
# 1000  1001          20       RL    74.000000    10206   Pave  no_access
# 1011  1012          90       RL    75.000000     9825   Pave  no_access
# 1035  1036          20       RL    68.217391    11500   Pave  no_access
# 1045  1046          20       RL    68.217391    13680   Pave  no_access
# 1048  1049          20       RL   100.000000    21750   Pave  no_access
# 1049  1050          20       RL    60.000000    11100   Pave  no_access
# 1090  1091          90       RL    60.000000     8544   Pave  no_access
# 1179  1180          20       RL    77.000000     8335   Pave  no_access
# 1216  1217          90       RM    68.000000     8930   Pave  no_access
# 1218  1219          50       RM    52.000000     6240   Pave  no_access
# 1232  1233          90       RL    70.000000     9842   Pave  no_access
# 1321  1322          20       RL    57.509804     6627   Pave  no_access
# 1412  1413          90       RL    60.000000     7200   Pave  no_access
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 17        Reg         Lvl    AllPub    Inside       Gtl       Sawyer
# 39        Reg         Lvl    AllPub    Inside       Gtl      Edwards
# 90        Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 102       Reg         Bnk    AllPub    Inside       Gtl      SawyerW
# 156       Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 182       Reg         Lvl    AllPub    Inside       Gtl      Edwards
# 259       Reg         Lvl    AllPub    Inside       Gtl      OldTown
# 342       Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 362       Reg         Lvl    AllPub    Corner       Gtl      Edwards
# 371       Reg         Lvl    AllPub    Inside       Gtl      ClearCr
# 392       IR1         Lvl    AllPub    Inside       Gtl        NAmes
# 520       Reg         Lvl    AllPub    Inside       Gtl      OldTown
# 532       Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 533       Reg         Low    AllPub    Inside       Mod      BrkSide
# 553       Reg         Lvl    AllPub    Inside       Gtl      Edwards
# 646       Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 705       Reg         Lvl    AllPub    Inside       Gtl       IDOTRR
# 736       Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 749       Reg         Lvl    AllPub    Inside       Gtl      Edwards
# 778       Reg         Lvl    AllPub    Inside       Gtl      SawyerW
# 868       IR2         Lvl    AllPub    Corner       Gtl      Gilbert
# 894       Reg         Bnk    AllPub    Inside       Gtl      SawyerW
# 897       Reg         Lvl    AllPub    Inside       Gtl      SawyerW
# 984       Reg         Lvl    AllPub    Inside       Gtl      Mitchel
# 1000      Reg         Lvl    AllPub    Corner       Gtl      Edwards
# 1011      Reg         Lvl    AllPub    Inside       Gtl      Edwards
# 1035      IR1         Lvl    AllPub   CulDSac       Gtl      Edwards
# 1045      IR1         Lvl    AllPub   CulDSac       Gtl      Edwards
# 1048      Reg         Lvl    AllPub    Inside       Gtl      Mitchel
# 1049      Reg         Low    AllPub    Inside       Gtl      Edwards
# 1090      Reg         Lvl    AllPub    Corner       Gtl        NAmes
# 1179      Reg         Lvl    AllPub    Corner       Gtl      Edwards
# 1216      Reg         Lvl    AllPub    Inside       Gtl       Sawyer
# 1218      Reg         Lvl    AllPub    Inside       Gtl      BrkSide
# 1232      Reg         Lvl    AllPub       FR2       Gtl        NAmes
# 1321      IR1         Lvl    AllPub    Corner       Gtl      BrkSide
# 1412      Reg         Lvl    AllPub    Inside       Gtl        NAmes
#
#      Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 17         Norm       Norm   Duplex     1Story            4            5
# 39         Norm       Norm   Duplex     1Story            4            5
# 90         Norm       Norm     1Fam     1Story            4            5
# 102        Norm       Norm   Duplex     1Story            5            5
# 156        Norm       Norm     1Fam     1Story            5            7
# 182      Artery       Norm     1Fam     1Story            5            6
# 259        Norm       Norm     1Fam     1Story            5            5
# 342        Norm       Norm   Duplex     1Story            3            4
# 362        Norm       Norm     1Fam     SFoyer            7            5
# 371       Feedr       Norm     1Fam     1.5Fin            4            4
# 392        Norm       Norm     1Fam     1Story            5            7
# 520        Norm       Norm   2fmCon     2Story            4            7
# 532        Norm       Norm     1Fam     1Story            5            7
# 533        Norm       Norm     1Fam     1Story            1            3
# 553       Feedr       Norm     1Fam     1Story            4            5
# 646        Norm       Norm     1Fam     1Story            5            5
# 705        Norm       Norm   2fmCon     2Story            4            5
# 736        Norm       Norm   Duplex     1Story            3            4
# 749        Norm       Norm     1Fam     1.5Fin            4            3
# 778       Feedr       Norm   Duplex     1Story            5            5
# 868       Feedr       Norm     1Fam     2Story            5            6
# 894        Norm       Norm   Duplex     1Story            5            5
# 897       Feedr       Norm   Duplex     2Story            5            5
# 984        Norm       Norm   Duplex     1.5Fin            5            5
# 1000       Norm       Norm     1Fam     1Story            3            3
# 1011       Norm       Norm   Duplex     1Story            5            5
# 1035       Norm       Norm     1Fam     1Story            4            3
# 1045       Norm       Norm     1Fam     1Story            3            5
# 1048       Norm       Norm     1Fam     1Story            5            4
# 1049       Norm       Norm     1Fam     1Story            4            7
# 1090       Norm       Norm   Duplex     1Story            3            4
# 1179       Norm       Norm     1Fam     1Story            5            5
# 1216       RRAe       Norm   Duplex     1.5Fin            6            5
# 1218       Norm       Norm     1Fam     1.5Fin            4            5
# 1232       Norm       Norm   Duplex     1Story            4            5
# 1321      Feedr       Norm     1Fam     1Story            3            6
# 1412       Norm       Norm   Duplex     1Story            4            5
#
#       YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# 17         1967          1967     Gable  CompShg     MetalSd     MetalSd
# 39         1955          1955     Gable  CompShg     AsbShng     Plywood
# 90         1950          1950     Gable  CompShg     BrkFace     Wd Sdng
# 102        1979          1979     Gable  CompShg     HdBoard     HdBoard
# 156        1950          1950       Hip  CompShg     Wd Sdng     Wd Sdng
# 182        1957          2006       Hip  CompShg     Wd Sdng     Wd Sdng
# 259        1956          1956     Gable  CompShg     BrkFace     BrkFace
# 342        1949          1950     Gable  CompShg      Stucco      Stucco
# 362        2003          2003     Gable  CompShg     HdBoard     HdBoard
# 371        1959          1959     Gable  CompShg     WdShing     Plywood
# 392        1959          1959     Gable  CompShg     MetalSd     MetalSd
# 520        1900          2000     Gable  CompShg     MetalSd     MetalSd
# 532        1955          2007     Gable  CompShg     VinylSd     VinylSd
# 533        1946          1950     Gable  CompShg     VinylSd     VinylSd
# 553        1949          2003     Gable  CompShg     VinylSd     VinylSd
# 646        1950          1950       Hip  CompShg     MetalSd     MetalSd
# 705        1930          1950       Hip  CompShg     VinylSd     Wd Shng
# 736        1950          1950     Gable  CompShg      Stucco       Stone
# 749        1945          1950     Gable  CompShg     WdShing     Wd Shng
# 778        1977          1977     Gable  CompShg     Plywood     Plywood
# 868        1948          1950     Gable  CompShg     Plywood     Plywood
# 894        1979          1979     Gable  CompShg     Plywood     Plywood
# 897        1979          1979     Gable  CompShg     Plywood     Plywood
# 984        1977          1977     Gable  CompShg     Plywood     Plywood
# 1000       1952          1952      Flat  Tar&Grv     BrkComm     Brk Cmn
# 1011       1965          1965       Hip  CompShg     AsphShn     AsphShn
# 1035       1957          1957     Gable  CompShg     Wd Sdng     Wd Sdng
# 1045       1955          1955       Hip  CompShg     BrkFace     Wd Sdng
# 1048       1960          2006       Hip  CompShg     HdBoard     HdBoard
# 1049       1946          2006     Gable  CompShg     MetalSd     MetalSd
# 1090       1950          1950     Gable  CompShg     BrkFace     BrkFace
# 1179       1954          1954     Gable  CompShg     Wd Sdng     Wd Sdng
# 1216       1978          1978     Gable  CompShg     VinylSd     VinylSd
# 1218       1947          1950     Gable  CompShg     AsbShng     AsbShng
# 1232       1962          1962     Gable  CompShg     HdBoard     HdBoard
# 1321       1949          1950       Hip  CompShg     VinylSd     VinylSd
# 1412       1949          1950     Gable  CompShg     BrkFace       Stone
#
#      MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 17         None         0.0        TA        TA       Slab       NA       NA
# 39         None         0.0        TA        TA      PConc       NA       NA
# 90         None         0.0        TA        TA       Slab       NA       NA
# 102        None         0.0        TA        Fa       Slab       NA       NA
# 156        None         0.0        TA        TA     CBlock       NA       NA
# 182     BrkFace        98.0        TA        TA      PConc       NA       NA
# 259        None         0.0        TA        TA      PConc       NA       NA
# 342     BrkFace       340.0        TA        TA       Slab       NA       NA
# 362     BrkFace       500.0        Gd        TA       Slab       NA       NA
# 371        None         0.0        TA        TA     CBlock       NA       NA
# 392        None         0.0        TA        TA       Slab       NA       NA
# 520        None         0.0        TA        TA     BrkTil       NA       NA
# 532        None         0.0        TA        TA       Slab       NA       NA
# 533        None         0.0        Fa        Fa       Slab       NA       NA
# 553        None         0.0        TA        TA     CBlock       NA       NA
# 646        None         0.0        TA        TA     CBlock       NA       NA
# 705        None         0.0        Fa        Fa       Slab       NA       NA
# 736        None         0.0        TA        TA     CBlock       NA       NA
# 749        None         0.0        TA        TA       Slab       NA       NA
# 778     BrkFace       320.0        TA        TA       Slab       NA       NA
# 868        None         0.0        TA        TA       Slab       NA       NA
# 894        None         0.0        TA        TA       Slab       NA       NA
# 897        None         0.0        TA        TA       Slab       NA       NA
# 984        None         0.0        TA        TA     CBlock       NA       NA
# 1000       None         0.0        TA        TA       Slab       NA       NA
# 1011       None         0.0        TA        TA     CBlock       NA       NA
# 1035       None         0.0        TA        Gd       Slab       NA       NA
# 1045       None         0.0        TA        TA       Slab       NA       NA
# 1048    BrkFace        75.0        TA        Fa       Slab       NA       NA
# 1049       None         0.0        TA        TA     CBlock       NA       NA
# 1090       None         0.0        TA        TA       Slab       NA       NA
# 1179       None         0.0        TA        TA       Slab       NA       NA
# 1216       None         0.0        TA        TA       Slab       NA       NA
# 1218       None         0.0        TA        TA       Slab       NA       NA
# 1232       None         0.0        TA        TA       Slab       NA       NA
# 1321       None         0.0        TA        TA     CBlock       NA       NA
# 1412       None         0.0        TA        TA       Slab       NA       NA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 17             NA           NA           0           NA           0
# 39             NA           NA           0           NA           0
# 90             NA           NA           0           NA           0
# 102            NA           NA           0           NA           0
# 156            NA           NA           0           NA           0
# 182            NA           NA           0           NA           0
# 259            NA           NA           0           NA           0
# 342            NA           NA           0           NA           0
# 362            NA           NA           0           NA           0
# 371            NA           NA           0           NA           0
# 392            NA           NA           0           NA           0
# 520            NA           NA           0           NA           0
# 532            NA           NA           0           NA           0
# 533            NA           NA           0           NA           0
# 553            NA           NA           0           NA           0
# 646            NA           NA           0           NA           0
# 705            NA           NA           0           NA           0
# 736            NA           NA           0           NA           0
# 749            NA           NA           0           NA           0
# 778            NA           NA           0           NA           0
# 868            NA           NA           0           NA           0
# 894            NA           NA           0           NA           0
# 897            NA           NA           0           NA           0
# 984            NA           NA           0           NA           0
# 1000           NA           NA           0           NA           0
# 1011           NA           NA           0           NA           0
# 1035           NA           NA           0           NA           0
# 1045           NA           NA           0           NA           0
# 1048           NA           NA           0           NA           0
# 1049           NA           NA           0           NA           0
# 1090           NA           NA           0           NA           0
# 1179           NA           NA           0           NA           0
# 1216           NA           NA           0           NA           0
# 1218           NA           NA           0           NA           0
# 1232           NA           NA           0           NA           0
# 1321           NA           NA           0           NA           0
# 1412           NA           NA           0           NA           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 17            0            0    GasA        TA          Y      SBrkr
# 39            0            0    GasA        TA          N      FuseP
# 90            0            0    GasA        TA          Y      FuseA
# 102           0            0    GasA        TA          Y      SBrkr
# 156           0            0    GasA        TA          Y      FuseF
# 182           0            0    GasA        Ex          Y      SBrkr
# 259           0            0    GasA        Gd          Y      FuseA
# 342           0            0    Wall        Fa          N      FuseA
# 362           0            0    GasA        Ex          Y      SBrkr
# 371           0            0    GasA        TA          Y      SBrkr
# 392           0            0    GasA        TA          Y      SBrkr
# 520           0            0    GasA        TA          N      FuseA
# 532           0            0    GasA        Ex          Y      SBrkr
# 533           0            0    GasA        Fa          N      FuseF
# 553           0            0    GasA        Ex          Y      SBrkr
# 646           0            0    GasA        Gd          Y      SBrkr
# 705           0            0    GasA        Fa          N      SBrkr
# 736           0            0    GasA        Gd          N      FuseF
# 749           0            0    Wall        TA          N      FuseF
# 778           0            0    GasA        TA          Y      SBrkr
# 868           0            0    GasA        Gd          Y      SBrkr
# 894           0            0    GasA        TA          Y      SBrkr
# 897           0            0    GasA        TA          Y      SBrkr
# 984           0            0    GasA        TA          Y      SBrkr
# 1000          0            0    GasW        Fa          N      FuseF
# 1011          0            0    GasA        TA          N      SBrkr
# 1035          0            0    GasA        Ex          N      SBrkr
# 1045          0            0    GasA        Ex          Y      FuseA
# 1048          0            0    GasA        TA          Y      SBrkr
# 1049          0            0    GasA        Ex          Y      SBrkr
# 1090          0            0    Wall        Fa          N      FuseA
# 1179          0            0    GasA        Gd          Y      SBrkr
# 1216          0            0    GasA        TA          Y      SBrkr
# 1218          0            0    GasA        Gd          N      SBrkr
# 1232          0            0    GasA        TA          Y      SBrkr
# 1321          0            0   Floor        TA          N      SBrkr
# 1412          0            0    Wall        Fa          N      FuseF
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 17        1296         0             0       1296             0             0
# 39        1152         0             0       1152             0             0
# 90        1040         0             0       1040             0             0
# 102       1535         0             0       1535             0             0
# 156       1040         0             0       1040             0             0
# 182       1340         0             0       1340             0             0
# 259        882         0             0        882             0             0
# 342       1040         0             0       1040             0             0
# 362        495      1427             0       1922             0             0
# 371       1120       468             0       1588             0             0
# 392        882         0             0        882             0             0
# 520        694       600             0       1294             0             0
# 532        827         0             0        827             0             0
# 533        334         0             0        334             0             0
# 553       1126         0             0       1126             0             0
# 646       1048         0             0       1048             0             0
# 705        372       720             0       1092             0             0
# 736       1040         0             0       1040             0             0
# 749       1088       441             0       1529             0             0
# 778       2020         0             0       2020             0             0
# 868       1547       720            53       2320             0             0
# 894       1535         0             0       1535             0             0
# 897       1120      1120             0       2240             0             0
# 984       1302       432             0       1734             0             0
# 1000       944         0             0        944             0             0
# 1011      1664         0             0       1664             0             0
# 1035       845         0             0        845             0             0
# 1045      1733         0             0       1733             0             0
# 1048      1771         0             0       1771             0             0
# 1049       930         0             0        930             0             0
# 1090      1040         0             0       1040             0             0
# 1179      1124         0             0       1124             0             0
# 1216      1318       584             0       1902             0             0
# 1218       672       240             0        912             0             0
# 1232      1224         0             0       1224             0             0
# 1321       720         0             0        720             0             0
# 1412      1040         0             0       1040             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 17           2         0             2             2          TA
# 39           2         0             2             2          Fa
# 90           1         0             2             1          TA
# 102          2         0             4             2          TA
# 156          1         0             2             1          TA
# 182          1         0             3             1          TA
# 259          1         0             2             1          TA
# 342          2         0             2             2          TA
# 362          3         0             4             1          Gd
# 371          2         0             4             1          TA
# 392          1         0             3             1          TA
# 520          2         0             3             2          TA
# 532          1         0             2             1          TA
# 533          1         0             1             1          Fa
# 553          2         0             2             1          Gd
# 646          1         0             3             1          TA
# 705          2         0             3             2          Fa
# 736          2         0             2             2          TA
# 749          2         0             4             1          TA
# 778          2         0             4             2          TA
# 868          2         0             2             1          TA
# 894          2         0             4             2          TA
# 897          2         0             6             2          TA
# 984          2         0             4             2          Gd
# 1000         1         0             2             1          Fa
# 1011         2         0             4             2          TA
# 1035         1         0             3             1          TA
# 1045         2         0             4             1          TA
# 1048         1         0             3             1          TA
# 1049         1         0             2             1          Gd
# 1090         2         0             2             2          TA
# 1179         1         0             3             1          TA
# 1216         2         0             4             2          TA
# 1218         1         0             2             1          TA
# 1232         2         0             2             2          TA
# 1321         1         0             2             1          TA
# 1412         2         0             2             2          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 17               6        Typ           0         NaN    CarPort       1967.0
# 39               6        Typ           0         NaN        NaN          NaN
# 90               4        Typ           0         NaN     Detchd       1950.0
# 102              8        Typ           0         NaN     Attchd       1979.0
# 156              5        Typ           0         NaN     Detchd       1950.0
# 182              7        Typ           1          Gd     Attchd       1957.0
# 259              4        Typ           0         NaN     Detchd       1956.0
# 342              6        Typ           0         NaN     Detchd       1949.0
# 362              7        Typ           1          Ex    BuiltIn       2003.0
# 371              7       Min2           1          Gd     Detchd       1991.0
# 392              5        Typ           0         NaN     Attchd       1959.0
# 520              7        Typ           0         NaN        NaN          NaN
# 532              5        Mod           1          Po     Detchd       1967.0
# 533              2        Typ           0         NaN        NaN          NaN
# 553              5        Typ           0         NaN     Detchd       2002.0
# 646              7       Min1           0         NaN     Detchd       1950.0
# 705              7        Mod           0         NaN        NaN          NaN
# 736              6        Typ           0         NaN     Detchd       1949.0
# 749              9        Mod           0         NaN     Detchd       1945.0
# 778             10        Typ           2          TA     Detchd       1977.0
# 868              7        Typ           1          TA     Attchd       1979.0
# 894              8        Typ           0         NaN     Attchd       1979.0
# 897             12        Typ           0         NaN     Detchd       1979.0
# 984              8        Typ           0         NaN     Attchd       1977.0
# 1000             4       Min1           0         NaN     Detchd       1956.0
# 1011             8        Typ           0         NaN        NaN          NaN
# 1035             5        Typ           0         NaN     Detchd       1957.0
# 1045             8       Min2           1          Gd     Attchd       1955.0
# 1048             9       Min1           1          TA     Attchd       1960.0
# 1049             6        Typ           0         NaN     Detchd       1946.0
# 1090             6        Typ           0         NaN     Detchd       1987.0
# 1179             5       Min2           1          Gd        NaN          NaN
# 1216             8        Typ           0         NaN     Attchd       1978.0
# 1218             3        Typ           0         NaN        NaN          NaN
# 1232             6        Typ           0         NaN    CarPort       1962.0
# 1321             4        Typ           0         NaN     Detchd       1955.0
# 1412             6        Typ           0         NaN     Detchd       1956.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 17            Unf           2         516         TA         TA          Y
# 39            NaN           0           0        NaN        NaN          N
# 90            Unf           2         420         TA         TA          Y
# 102           Unf           2         410         TA         TA          Y
# 156           Unf           2         625         TA         TA          Y
# 182           RFn           1         252         TA         TA          Y
# 259           Unf           1         308         TA         TA          Y
# 342           Unf           2         400         TA         TA          Y
# 362           RFn           2         672         TA         TA          Y
# 371           Fin           2         680         TA         TA          N
# 392           RFn           1         294         TA         TA          Y
# 520           NaN           0           0        NaN        NaN          N
# 532           Unf           1         392         TA         TA          Y
# 533           NaN           0           0        NaN        NaN          N
# 553           Fin           2         520         TA         TA          N
# 646           Unf           2         420         TA         TA          Y
# 705           NaN           0           0        NaN        NaN          N
# 736           Unf           2         400         TA         TA          Y
# 749           Unf           1         240         TA         TA          N
# 778           Unf           2         630         TA         TA          Y
# 868           Unf           2         672         TA         TA          P
# 894           Unf           2         400         TA         TA          Y
# 897           Unf           2         528         TA         TA          Y
# 984           Unf           2         539         TA         TA          Y
# 1000          Unf           2         528         TA         Fa          Y
# 1011          NaN           0           0        NaN        NaN          Y
# 1035          Unf           1         290         TA         TA          N
# 1045          Unf           2         452         TA         TA          Y
# 1048          Unf           2         336         TA         TA          Y
# 1049          Unf           1         308         TA         TA          Y
# 1090          Unf           2         400         TA         TA          Y
# 1179          NaN           0           0        NaN        NaN          N
# 1216          Unf           2         539         TA         TA          Y
# 1218          NaN           0           0        NaN        NaN          N
# 1232          Unf           2         462         TA         TA          Y
# 1321          Unf           1         287         TA         Fa          Y
# 1412          Unf           2         420         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 17             0            0              0          0            0
# 39             0            0              0          0            0
# 90             0           29              0          0            0
# 102            0            0              0          0            0
# 156            0            0              0          0            0
# 182          116            0              0        180            0
# 259            0           45              0          0            0
# 342            0            0              0          0            0
# 362            0            0            177          0            0
# 371            0           59              0          0            0
# 392            0            0              0          0            0
# 520          220          114            210          0            0
# 532            0            0              0          0            0
# 533            0            0              0          0            0
# 553            0           96              0          0            0
# 646            0           27              0          0            0
# 705            0            0              0          0            0
# 736            0            0              0          0            0
# 749           92            0            185          0            0
# 778            0            0              0          0            0
# 868          120          144              0          0            0
# 894            0            0              0          0            0
# 897          154            0              0          0            0
# 984            0            0              0          0            0
# 1000           0            0              0          0            0
# 1011           0            0              0          0            0
# 1035         186            0              0          0            0
# 1045           0            0              0          0            0
# 1048           0            0              0          0            0
# 1049           0            0              0          0            0
# 1090           0            0              0          0            0
# 1179           0           36            190          0            0
# 1216           0            0              0          0            0
# 1218           0            0              0          0            0
# 1232           0            0              0          0            0
# 1321           0            0              0          0            0
# 1412           0            0              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 17           0    NaN    NaN        Shed      500      10    2006       WD
# 39           0    NaN    NaN         NaN        0       6    2008       WD
# 90           0    NaN    NaN         NaN        0       7    2006       WD
# 102          0    NaN    NaN         NaN        0       6    2009       WD
# 156          0    NaN    NaN         NaN        0       6    2006       WD
# 182          0    NaN  MnPrv         NaN        0       6    2007       WD
# 259          0    NaN    NaN         NaN        0      12    2008       WD
# 342          0    NaN    NaN         NaN        0       5    2006       WD
# 362          0    NaN    NaN         NaN        0       7    2009    ConLD
# 371          0    NaN    NaN         NaN        0       7    2008       WD
# 392          0    NaN  MnPrv        Shed     1200       7    2007       WD
# 520          0    NaN    NaN         NaN        0       8    2008       WD
# 532          0    NaN    NaN         NaN        0       4    2010       WD
# 533          0    NaN    NaN         NaN        0       1    2007       WD
# 553          0    NaN  MnPrv         NaN        0       5    2009       WD
# 646          0    NaN    NaN         NaN        0       7    2008       WD
# 705          0    NaN    NaN        Othr     3500       7    2010       WD
# 736          0    NaN    NaN         NaN        0       7    2006       WD
# 749          0    NaN    NaN         NaN        0       4    2009       WD
# 778          0    NaN    NaN         NaN        0      10    2007       WD
# 868          0    NaN    NaN         NaN        0       5    2006       WD
# 894          0    NaN    NaN         NaN        0       6    2009       WD
# 897          0    NaN    NaN         NaN        0       6    2009       WD
# 984          0    NaN    NaN         NaN        0       8    2009      COD
# 1000         0    NaN    NaN         NaN        0       7    2009       WD
# 1011         0    NaN    NaN         NaN        0       5    2010       WD
# 1035         0    NaN    NaN         NaN        0       1    2009       WD
# 1045         0    NaN    NaN         NaN        0       6    2009       WD
# 1048         0    NaN  GdPrv         NaN        0      11    2009       WD
# 1049         0    NaN    NaN         NaN        0       4    2010       WD
# 1090         0    NaN    NaN         NaN        0       6    2009       WD
# 1179         0    NaN    NaN         NaN        0       4    2006       WD
# 1216         0    NaN    NaN         NaN        0       4    2010       WD
# 1218         0    NaN    NaN         NaN        0       7    2006       WD
# 1232         0    NaN    NaN         NaN        0       3    2007       WD
# 1321         0    NaN    NaN         NaN        0       7    2008       WD
# 1412         0    NaN    NaN         NaN        0       6    2009       WD
#
#      SaleCondition  SalePrice  LotFrontage_missing  Alley_missing  \
# 17          Normal      90000                False           True
# 39         AdjLand      82000                False           True
# 90          Normal     109900                False           True
# 102         Alloca     118964                False           True
# 156         Normal     109500                False           True
# 182         Normal     120000                False           True
# 259         Normal      97000                False           True
# 342         Normal      87500                 True           True
# 362         Normal     198500                False           True
# 371         Normal     134432                False           True
# 392         Normal     106500                 True           True
# 520         Normal     106250                False          False
# 532         Normal     107500                False           True
# 533         Normal      39300                False           True
# 553         Normal     108000                False           True
# 646         Normal      98300                False           True
# 705         Normal      55000                False           True
# 736         Normal      93500                False           True
# 749         Normal      98000                False           True
# 778         Normal     144000                False           True
# 868         Normal     169000                 True           True
# 894         Alloca     118858                False           True
# 897         Alloca     142953                False           True
# 984         Normal     126000                False           True
# 1000        Normal      82000                False           True
# 1011        Normal     100000                False           True
# 1035        Normal      84000                 True           True
# 1045        Normal     139600                 True           True
# 1048        Normal     115000                False           True
# 1049       Abnorml      84900                False           True
# 1090        Normal      92900                False           True
# 1179        Normal      93000                False           True
# 1216        Normal     112000                False           True
# 1218        Normal      80500                False           True
# 1232        Normal     101800                False           True
# 1321        Normal      72500                 True           True
# 1412        Normal      90000                False           True
#
#       MasVnrType_missing  MasVnrArea_missing  BsmtQual_missing  \
# 17                 False               False              True
# 39                 False               False              True
# 90                 False               False              True
# 102                False               False              True
# 156                False               False              True
# 182                False               False              True
# 259                False               False              True
# 342                False               False              True
# 362                False               False              True
# 371                False               False              True
# 392                False               False              True
# 520                False               False              True
# 532                False               False              True
# 533                False               False              True
# 553                False               False              True
# 646                False               False              True
# 705                False               False              True
# 736                False               False              True
# 749                False               False              True
# 778                False               False              True
# 868                False               False              True
# 894                False               False              True
# 897                False               False              True
# 984                False               False              True
# 1000               False               False              True
# 1011               False               False              True
# 1035               False               False              True
# 1045               False               False              True
# 1048               False               False              True
# 1049               False               False              True
# 1090               False               False              True
# 1179               False               False              True
# 1216               False               False              True
# 1218               False               False              True
# 1232               False               False              True
# 1321               False               False              True
# 1412               False               False              True
#
#       BsmtCond_missing  BsmtExposure_missing  BsmtFinType1_missing  \
# 17                True                  True                  True
# 39                True                  True                  True
# 90                True                  True                  True
# 102               True                  True                  True
# 156               True                  True                  True
# 182               True                  True                  True
# 259               True                  True                  True
# 342               True                  True                  True
# 362               True                  True                  True
# 371               True                  True                  True
# 392               True                  True                  True
# 520               True                  True                  True
# 532               True                  True                  True
# 533               True                  True                  True
# 553               True                  True                  True
# 646               True                  True                  True
# 705               True                  True                  True
# 736               True                  True                  True
# 749               True                  True                  True
# 778               True                  True                  True
# 868               True                  True                  True
# 894               True                  True                  True
# 897               True                  True                  True
# 984               True                  True                  True
# 1000              True                  True                  True
# 1011              True                  True                  True
# 1035              True                  True                  True
# 1045              True                  True                  True
# 1048              True                  True                  True
# 1049              True                  True                  True
# 1090              True                  True                  True
# 1179              True                  True                  True
# 1216              True                  True                  True
# 1218              True                  True                  True
# 1232              True                  True                  True
# 1321              True                  True                  True
# 1412              True                  True                  True
#
#       BsmtFinType2_missing  Electrical_missing  FireplaceQu_missing  \
# 17                    True               False                 True
# 39                    True               False                 True
# 90                    True               False                 True
# 102                   True               False                 True
# 156                   True               False                 True
# 182                   True               False                False
# 259                   True               False                 True
# 342                   True               False                 True
# 362                   True               False                False
# 371                   True               False                False
# 392                   True               False                 True
# 520                   True               False                 True
# 532                   True               False                False
# 533                   True               False                 True
# 553                   True               False                 True
# 646                   True               False                 True
# 705                   True               False                 True
# 736                   True               False                 True
# 749                   True               False                 True
# 778                   True               False                False
# 868                   True               False                False
# 894                   True               False                 True
# 897                   True               False                 True
# 984                   True               False                 True
# 1000                  True               False                 True
# 1011                  True               False                 True
# 1035                  True               False                 True
# 1045                  True               False                False
# 1048                  True               False                False
# 1049                  True               False                 True
# 1090                  True               False                 True
# 1179                  True               False                False
# 1216                  True               False                 True
# 1218                  True               False                 True
# 1232                  True               False                 True
# 1321                  True               False                 True
# 1412                  True               False                 True
#
#       GarageType_missing  GarageYrBlt_missing  GarageFinish_missing  \
# 17                 False                False                 False
# 39                  True                 True                  True
# 90                 False                False                 False
# 102                False                False                 False
# 156                False                False                 False
# 182                False                False                 False
# 259                False                False                 False
# 342                False                False                 False
# 362                False                False                 False
# 371                False                False                 False
# 392                False                False                 False
# 520                 True                 True                  True
# 532                False                False                 False
# 533                 True                 True                  True
# 553                False                False                 False
# 646                False                False                 False
# 705                 True                 True                  True
# 736                False                False                 False
# 749                False                False                 False
# 778                False                False                 False
# 868                False                False                 False
# 894                False                False                 False
# 897                False                False                 False
# 984                False                False                 False
# 1000               False                False                 False
# 1011                True                 True                  True
# 1035               False                False                 False
# 1045               False                False                 False
# 1048               False                False                 False
# 1049               False                False                 False
# 1090               False                False                 False
# 1179                True                 True                  True
# 1216               False                False                 False
# 1218                True                 True                  True
# 1232               False                False                 False
# 1321               False                False                 False
# 1412               False                False                 False
#
#       GarageQual_missing  GarageCond_missing  PoolQC_missing  Fence_missing  \
# 17                 False               False            True           True
# 39                  True                True            True           True
# 90                 False               False            True           True
# 102                False               False            True           True
# 156                False               False            True           True
# 182                False               False            True          False
# 259                False               False            True           True
# 342                False               False            True           True
# 362                False               False            True           True
# 371                False               False            True           True
# 392                False               False            True          False
# 520                 True                True            True           True
# 532                False               False            True           True
# 533                 True                True            True           True
# 553                False               False            True          False
# 646                False               False            True           True
# 705                 True                True            True           True
# 736                False               False            True           True
# 749                False               False            True           True
# 778                False               False            True           True
# 868                False               False            True           True
# 894                False               False            True           True
# 897                False               False            True           True
# 984                False               False            True           True
# 1000               False               False            True           True
# 1011                True                True            True           True
# 1035               False               False            True           True
# 1045               False               False            True           True
# 1048               False               False            True          False
# 1049               False               False            True           True
# 1090               False               False            True           True
# 1179                True                True            True           True
# 1216               False               False            True           True
# 1218                True                True            True           True
# 1232               False               False            True           True
# 1321               False               False            True           True
# 1412               False               False            True           True
#
#       MiscFeature_missing  AlleyAccess_Flag
# 17                  False                 0
# 39                   True                 0
# 90                   True                 0
# 102                  True                 0
# 156                  True                 0
# 182                  True                 0
# 259                  True                 0
# 342                  True                 0
# 362                  True                 0
# 371                  True                 0
# 392                 False                 0
# 520                  True                 1
# 532                  True                 0
# 533                  True                 0
# 553                  True                 0
# 646                  True                 0
# 705                 False                 0
# 736                  True                 0
# 749                  True                 0
# 778                  True                 0
# 868                  True                 0
# 894                  True                 0
# 897                  True                 0
# 984                  True                 0
# 1000                 True                 0
# 1011                 True                 0
# 1035                 True                 0
# 1045                 True                 0
# 1048                 True                 0
# 1049                 True                 0
# 1090                 True                 0
# 1179                 True                 0
# 1216                 True                 0
# 1218                 True                 0
# 1232                 True                 0
# 1321                 True                 0
# 1412                 True                 0

# %%
df.BsmtCond.value_counts()
# Out:
# TA    1311
# Gd      65
# Fa      45
# NA      37
# Po       2
# Name: BsmtCond, dtype: int64

# %%
df['BsmtQual'] = df['BsmtQual'].fillna('NA')
df['BsmtCond'] = df['BsmtCond'].fillna('NA')
df['BsmtExposure'] = df['BsmtExposure'].fillna('NA')
df['BsmtFinType1'] = df['BsmtFinType1'].fillna('NA')
df['BsmtFinType2'] = df['BsmtFinType2'].fillna('NA')

# %% [markdown]
# ***

# %%
df[(df.Electrical_missing==True)]['Utilities']
# Given the record shows electricity is present, replace with typical electrical system from dataset
# Out:
# 1379    AllPub
# Name: Utilities, dtype: object

# %%
df.Electrical.value_counts()
# Out:
# SBrkr    1335
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %%
df['Electrical'] = df['Electrical'].fillna('SBrkr')

# %% [markdown]
# ***

# %%
df[(df.FireplaceQu_missing == True)]['Fireplaces'].sum()
# Doesn't look there are any fireplaces in places with fireplaces missing
# Out:
# 0

# %%
df['FireplaceQu'] = df['FireplaceQu'].fillna('NA')

# %% [markdown]
# ***

# %%
df[(df.GarageType_missing == True)][['GarageType','GarageYrBlt','GarageFinish','GarageCars','GarageArea','GarageQual','GarageCond']]
# Doesn't look like there are any cases where there is garage relevant data
# Out:
#      GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 39           NA          0.0           NA           0           0         NA
# 48           NA          0.0           NA           0           0         NA
# 78           NA          0.0           NA           0           0         NA
# 88           NA          0.0           NA           0           0         NA
# 89           NA          0.0           NA           0           0         NA
# 99           NA          0.0           NA           0           0         NA
# 108          NA          0.0           NA           0           0         NA
# 125          NA          0.0           NA           0           0         NA
# 127          NA          0.0           NA           0           0         NA
# 140          NA          0.0           NA           0           0         NA
# 148          NA          0.0           NA           0           0         NA
# 155          NA          0.0           NA           0           0         NA
# 163          NA          0.0           NA           0           0         NA
# 165          NA          0.0           NA           0           0         NA
# 198          NA          0.0           NA           0           0         NA
# 210          NA          0.0           NA           0           0         NA
# 241          NA          0.0           NA           0           0         NA
# 250          NA          0.0           NA           0           0         NA
# 287          NA          0.0           NA           0           0         NA
# 291          NA          0.0           NA           0           0         NA
# 307          NA          0.0           NA           0           0         NA
# 375          NA          0.0           NA           0           0         NA
# 386          NA          0.0           NA           0           0         NA
# 393          NA          0.0           NA           0           0         NA
# 431          NA          0.0           NA           0           0         NA
# 434          NA          0.0           NA           0           0         NA
# 441          NA          0.0           NA           0           0         NA
# 464          NA          0.0           NA           0           0         NA
# 495          NA          0.0           NA           0           0         NA
# 520          NA          0.0           NA           0           0         NA
# 528          NA          0.0           NA           0           0         NA
# 533          NA          0.0           NA           0           0         NA
# 535          NA          0.0           NA           0           0         NA
# 562          NA          0.0           NA           0           0         NA
# 582          NA          0.0           NA           0           0         NA
# 613          NA          0.0           NA           0           0         NA
# 614          NA          0.0           NA           0           0         NA
# 620          NA          0.0           NA           0           0         NA
# 635          NA          0.0           NA           0           0         NA
# 636          NA          0.0           NA           0           0         NA
# 638          NA          0.0           NA           0           0         NA
# 649          NA          0.0           NA           0           0         NA
# 705          NA          0.0           NA           0           0         NA
# 710          NA          0.0           NA           0           0         NA
# 738          NA          0.0           NA           0           0         NA
# 750          NA          0.0           NA           0           0         NA
# 784          NA          0.0           NA           0           0         NA
# 826          NA          0.0           NA           0           0         NA
# 843          NA          0.0           NA           0           0         NA
# 921          NA          0.0           NA           0           0         NA
# 942          NA          0.0           NA           0           0         NA
# 954          NA          0.0           NA           0           0         NA
# 960          NA          0.0           NA           0           0         NA
# 968          NA          0.0           NA           0           0         NA
# 970          NA          0.0           NA           0           0         NA
# 976          NA          0.0           NA           0           0         NA
# 1009         NA          0.0           NA           0           0         NA
# 1011         NA          0.0           NA           0           0         NA
# 1030         NA          0.0           NA           0           0         NA
# 1038         NA          0.0           NA           0           0         NA
# 1096         NA          0.0           NA           0           0         NA
# 1123         NA          0.0           NA           0           0         NA
# 1131         NA          0.0           NA           0           0         NA
# 1137         NA          0.0           NA           0           0         NA
# 1143         NA          0.0           NA           0           0         NA
# 1173         NA          0.0           NA           0           0         NA
# 1179         NA          0.0           NA           0           0         NA
# 1218         NA          0.0           NA           0           0         NA
# 1219         NA          0.0           NA           0           0         NA
# 1234         NA          0.0           NA           0           0         NA
# 1257         NA          0.0           NA           0           0         NA
# 1283         NA          0.0           NA           0           0         NA
# 1323         NA          0.0           NA           0           0         NA
# 1325         NA          0.0           NA           0           0         NA
# 1326         NA          0.0           NA           0           0         NA
# 1337         NA          0.0           NA           0           0         NA
# 1349         NA          0.0           NA           0           0         NA
# 1407         NA          0.0           NA           0           0         NA
# 1449         NA          0.0           NA           0           0         NA
# 1450         NA          0.0           NA           0           0         NA
# 1453         NA          0.0           NA           0           0         NA
#
#      GarageCond
# 39           NA
# 48           NA
# 78           NA
# 88           NA
# 89           NA
# 99           NA
# 108          NA
# 125          NA
# 127          NA
# 140          NA
# 148          NA
# 155          NA
# 163          NA
# 165          NA
# 198          NA
# 210          NA
# 241          NA
# 250          NA
# 287          NA
# 291          NA
# 307          NA
# 375          NA
# 386          NA
# 393          NA
# 431          NA
# 434          NA
# 441          NA
# 464          NA
# 495          NA
# 520          NA
# 528          NA
# 533          NA
# 535          NA
# 562          NA
# 582          NA
# 613          NA
# 614          NA
# 620          NA
# 635          NA
# 636          NA
# 638          NA
# 649          NA
# 705          NA
# 710          NA
# 738          NA
# 750          NA
# 784          NA
# 826          NA
# 843          NA
# 921          NA
# 942          NA
# 954          NA
# 960          NA
# 968          NA
# 970          NA
# 976          NA
# 1009         NA
# 1011         NA
# 1030         NA
# 1038         NA
# 1096         NA
# 1123         NA
# 1131         NA
# 1137         NA
# 1143         NA
# 1173         NA
# 1179         NA
# 1218         NA
# 1219         NA
# 1234         NA
# 1257         NA
# 1283         NA
# 1323         NA
# 1325         NA
# 1326         NA
# 1337         NA
# 1349         NA
# 1407         NA
# 1449         NA
# 1450         NA
# 1453         NA

# %%
df['GarageType'] = df['GarageType'].fillna('NA')
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(0)
df['GarageFinish'] = df['GarageFinish'].fillna('NA')
df['GarageQual'] = df['GarageQual'].fillna('NA')
df['GarageCond'] = df['GarageCond'].fillna('NA')

# %% [markdown]
# ****

# %%
df[df.PoolQC_missing == True]['PoolArea'].sum()
# Check if any areas without pool data recorded have a pool in the mix

# %%
df['PoolQC'] = df['PoolQC'].fillna('NA')

# %% [markdown]
# ***

# %%
df['Fence'] = df['Fence'].fillna('NA')

# %%
df['MiscFeature'] = df['MiscFeature'].fillna('NO_MISC_FEATURE_RECORDED')

# %% [markdown]
# ## 2. Create additional bespoke data features

# %%
# Created df['AlleyAccess_Flag'] above

# %% [markdown]
# ***

# %%
df['BsmtFinSF_Total'] = df['BsmtFinSF1']+df['BsmtFinSF2']

# %%
df['BsmtFinSF_Total'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ***

# %%
# Up to adding a typical_functionality flag.
